# %%
import os
import numpy as np
import torch
from torch.utils.data import TensorDataset, DataLoader, random_split, Subset
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.nn as nn
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold
import copy
import time
import logging
from typing import Any, Optional, List, Tuple, Dict
from torch.utils.data import TensorDataset, DataLoader, Subset, WeightedRandomSampler
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix

# %% [markdown]
# 定义准确率函数

# %%
def accuracy(outputs: torch.Tensor, labels: torch.Tensor) -> float:
    """
    计算准确率。

    参数:
    - outputs (torch.Tensor): 模型输出的 logits。
    - labels (torch.Tensor): 真实标签。

    返回:
    - float: 准确率。
    """
    _, preds = torch.max(outputs, 1)
    return (preds == labels).float().mean().item()

# %% [markdown]
# 集成模型（基于F1分数分配权重）

# %%
class EnsembleModel(nn.Module):
    """集成模型类，使用F1分数优化权重"""
    def __init__(self, base_models: List[nn.Module], ensemble_weights: Optional[List[float]] = None):
        super(EnsembleModel, self).__init__()
        self.base_models = nn.ModuleList(base_models)
        
        if ensemble_weights is None:
            # 如果没有提供权重，使用均等权重
            self.ensemble_weights = torch.ones(len(base_models)) / len(base_models)
        else:
            # 如果提供了权重（可能是F1分数），归一化处理
            weights = torch.tensor(ensemble_weights)
            self.ensemble_weights = weights / weights.sum()
        
        # 记录权重分配
        logging.info(f"集成模型权重: {self.ensemble_weights.tolist()}")
        
        self.register_buffer('weights', self.ensemble_weights)
    
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        predictions = []
        for model in self.base_models:
            with torch.no_grad():
                model.eval()
                pred = model(x)
                predictions.append(torch.softmax(pred, dim=1))
        
        stacked_preds = torch.stack(predictions, dim=0)
        weighted_preds = stacked_preds * self.weights.view(-1, 1, 1)
        return weighted_preds.sum(dim=0)

# %% [markdown]
# MLP模型框架

# %%
class MLPModel(nn.Module):
    def __init__(self, input_size: int, hidden_sizes: List[int], output_size: int, dropout_prob: float = 0.3):
        """
        初始化MLP模型。

        Args:
            input_size (int): 输入特征维度
            hidden_sizes (List[int]): 隐藏层维度列表，例如[512, 256]表示两个隐藏层
            output_size (int): 输出维度（类别数）
            dropout_prob (float): Dropout概率，默认0.3
        """
        super(MLPModel, self).__init__()
        
        # 存储所有层的列表
        self.hidden_layers = nn.ModuleList()
        
        # 第一个隐藏层
        self.hidden_layers.append(nn.Sequential(
            nn.Linear(input_size, hidden_sizes[0]),
            nn.BatchNorm1d(hidden_sizes[0]),
            nn.ReLU(),
            nn.Dropout(dropout_prob)
        ))
        
        # 中间隐藏层
        for i in range(1, len(hidden_sizes)):
            self.hidden_layers.append(nn.Sequential(
                nn.Linear(hidden_sizes[i-1], hidden_sizes[i]),
                nn.BatchNorm1d(hidden_sizes[i]),
                nn.ReLU(),
                nn.Dropout(dropout_prob)
            ))
        
        # 输出层
        self.output_layer = nn.Linear(hidden_sizes[-1], output_size)
    
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        """
        前向传播过程。

        Args:
            x (torch.Tensor): 输入张量，形状为 [batch_size, input_size]

        Returns:
            torch.Tensor: 输出张量，形状为 [batch_size, output_size]

        Raises:
            ValueError: 如果输入张量维度不是2维
        """
        # 检查输入维度
        if len(x.shape) != 2:
            raise ValueError(f"Expected input dimension of 2, got {len(x.shape)}")
        
        # 通过所有隐藏层
        for layer in self.hidden_layers:
            x = layer(x)
        
        # 通过输出层
        return self.output_layer(x)

# %% [markdown]
# 定义训练与评估循环函数

# %%
def train_eval_mlp(
    model: nn.Module,
    train_loader: DataLoader, 
    val_loader: DataLoader,
    loss_fn: nn.Module,
    optimizer: torch.optim.Optimizer,
    scheduler: lr_scheduler._LRScheduler,
    epochs: int,
    device: torch.device,
    log_epoch: Optional[List[str]] = None,
    max_grad_norm: Optional[float] = None
) -> Tuple[float, float, float, float, np.ndarray, np.ndarray, np.ndarray, np.ndarray, Dict]:
    """
    训练与评估MLP模型的主循环函数，支持类别平衡评估，使用F1分数选择最佳模型。
    增加了精确率、召回率、特异性和MCC评估指标。
    
    Args:
        model: 神经网络模型
        train_loader: 训练数据加载器
        val_loader: 验证数据加载器 
        loss_fn: 损失函数
        optimizer: 优化器
        scheduler: 学习率调度器
        epochs: 训练轮数
        device: 训练设备
        log_epoch: 可选的日志记录列表
        max_grad_norm: 可选的梯度裁剪阈值

    Returns:
        Tuple[float, float, float, float, np.ndarray, np.ndarray, np.ndarray, np.ndarray, Dict]:
            - train_loss: 最终训练损失
            - val_loss: 最终验证损失
            - train_acc: 最终训练准确率
            - val_acc: 最终验证准确率
            - train_probs: 训练集预测概率
            - train_labels: 训练集真实标签
            - val_probs: 验证集预测概率
            - val_labels: 验证集真实标签
            - model_state: 最佳模型状态字典
    """
    # 导入指标计算函数
    from sklearn.metrics import f1_score, precision_score, recall_score, matthews_corrcoef, confusion_matrix
    
    # 初始化记录器
    history = {
        'train_loss': [],
        'val_loss': [],
        'train_acc': [],
        'val_acc': [],
        'train_class_acc': [],     # 类别准确率记录
        'val_class_acc': [],       # 类别准确率记录
        'train_f1': [],            # F1分数记录
        'val_f1': [],              # F1分数记录
        'train_precision': [],     # 精确率记录
        'val_precision': [],       # 精确率记录
        'train_recall': [],        # 召回率记录
        'val_recall': [],          # 召回率记录
        'train_specificity': [],   # 特异性记录
        'val_specificity': [],     # 特异性记录
        'train_mcc': [],           # MCC记录
        'val_mcc': [],             # MCC记录
        'train_norm_mcc': [],      # 归一化MCC记录
        'val_norm_mcc': []         # 归一化MCC记录
    }
    
    best_model_state = None
    best_val_f1 = float('-inf')  # 使用F1分数选择最佳模型
    
    # 检查是否使用了带权重的损失函数
    has_weights = hasattr(loss_fn, 'weight') and loss_fn.weight is not None
    if has_weights:
        logging.info(f"使用带权重的损失函数，权重: {loss_fn.weight.cpu().numpy()}")
    
    for epoch in range(epochs):
        epoch_start_time = time.time()
        
        # ===== 训练阶段 =====
        model.train()
        train_loss = 0.0
        train_acc = 0.0
        epoch_train_probs = []
        epoch_train_labels = []
        epoch_train_preds = []  # 存储预测类别
        num_train_batches = 0
        
        for inputs, labels in train_loader:
            if inputs.size(0) <= 1:  # 跳过大小为1的批次
                continue
                
            inputs = inputs.to(device)
            labels = labels.to(device)
            
            # 前向传播
            outputs = model(inputs)
            if isinstance(outputs, tuple):
                outputs = outputs[0]
            
            # 计算损失和准确率
            loss = loss_fn(outputs, labels)
            batch_acc = accuracy(outputs, labels)
            
            # 反向传播和优化
            optimizer.zero_grad()
            loss.backward()
            
            # 梯度裁剪
            if max_grad_norm is not None:
                if isinstance(model, nn.DataParallel):
                    torch.nn.utils.clip_grad_norm_(
                        model.module.parameters(), 
                        max_grad_norm
                    )
                else:
                    torch.nn.utils.clip_grad_norm_(
                        model.parameters(), 
                        max_grad_norm
                    )
                
            optimizer.step()
            
            # 累积损失和准确率
            train_loss += loss.item()
            train_acc += batch_acc
            num_train_batches += 1
            
            # 保存预测概率、预测类别和标签
            probs = torch.softmax(outputs, dim=1)
            _, preds = torch.max(outputs, dim=1)
            epoch_train_probs.append(probs.detach().cpu().numpy())
            epoch_train_preds.append(preds.cpu().numpy())
            epoch_train_labels.append(labels.cpu().numpy())
        
        # 计算训练阶段平均指标
        avg_train_loss = train_loss / num_train_batches
        avg_train_acc = train_acc / num_train_batches
        
        # 计算每个类别的准确率和其他指标
        train_preds_all = np.concatenate(epoch_train_preds)
        train_labels_all = np.concatenate(epoch_train_labels)
        
        # F1分数
        train_f1 = f1_score(train_labels_all, train_preds_all, average='weighted')
        
        # 精确率
        train_precision = precision_score(train_labels_all, train_preds_all, average='weighted')
        
        # 召回率
        train_recall = recall_score(train_labels_all, train_preds_all, average='weighted')
        
        # 特异性 (Specificity) - 对于二分类问题
        train_cm = confusion_matrix(train_labels_all, train_preds_all)
        train_tn = train_cm[0, 0]
        train_fp = train_cm[0, 1]
        train_specificity = train_tn / (train_tn + train_fp) if (train_tn + train_fp) > 0 else 0
        
        # MCC (Matthews Correlation Coefficient)
        train_mcc = matthews_corrcoef(train_labels_all, train_preds_all)
        
        # 归一化MCC到[0,1]区间
        train_norm_mcc = (train_mcc + 1) / 2
        
        # 计算每个类别的准确率
        train_class_counts = np.bincount(train_labels_all, minlength=2)
        train_class_correct = np.bincount(
            train_labels_all[train_preds_all == train_labels_all], 
            minlength=2
        )
        train_class_acc = np.zeros(2)  # 初始化为零，避免除以零的问题
        for i in range(2):
            if train_class_counts[i] > 0:
                train_class_acc[i] = train_class_correct[i] / train_class_counts[i]
        
        # 记录训练指标
        history['train_loss'].append(avg_train_loss)
        history['train_acc'].append(avg_train_acc)
        history['train_class_acc'].append(train_class_acc.tolist())
        history['train_f1'].append(train_f1)
        history['train_precision'].append(train_precision)
        history['train_recall'].append(train_recall)
        history['train_specificity'].append(train_specificity)
        history['train_mcc'].append(train_mcc)
        history['train_norm_mcc'].append(train_norm_mcc)
        
        # ===== 验证阶段 =====
        model.eval()
        val_loss = 0.0
        val_acc = 0.0
        epoch_val_probs = []
        epoch_val_labels = []
        epoch_val_preds = []  # 存储预测类别
        num_val_batches = 0
        
        with torch.no_grad():
            for inputs, labels in val_loader:
                if inputs.size(0) <= 1:
                    continue
                    
                inputs = inputs.to(device)
                labels = labels.to(device)
                
                # 前向传播
                outputs = model(inputs)
                if isinstance(outputs, tuple):
                    outputs = outputs[0]
                
                # 计算损失和准确率
                loss = loss_fn(outputs, labels)
                batch_acc = accuracy(outputs, labels)
                
                val_loss += loss.item()
                val_acc += batch_acc
                num_val_batches += 1
                
                # 保存预测概率、预测类别和标签
                probs = torch.softmax(outputs, dim=1)
                _, preds = torch.max(outputs, dim=1)
                epoch_val_probs.append(probs.cpu().numpy())
                epoch_val_preds.append(preds.cpu().numpy())
                epoch_val_labels.append(labels.cpu().numpy())
        
        # 计算验证阶段平均指标
        avg_val_loss = val_loss / num_val_batches
        avg_val_acc = val_acc / num_val_batches
        
        # 计算每个类别的准确率和其他指标
        val_preds_all = np.concatenate(epoch_val_preds)
        val_labels_all = np.concatenate(epoch_val_labels)
        
        # F1分数
        val_f1 = f1_score(val_labels_all, val_preds_all, average='weighted')
        
        # 精确率
        val_precision = precision_score(val_labels_all, val_preds_all, average='weighted')
        
        # 召回率
        val_recall = recall_score(val_labels_all, val_preds_all, average='weighted')
        
        # 特异性 (Specificity) - 对于二分类问题
        val_cm = confusion_matrix(val_labels_all, val_preds_all)
        val_tn = val_cm[0, 0]
        val_fp = val_cm[0, 1]
        val_specificity = val_tn / (val_tn + val_fp) if (val_tn + val_fp) > 0 else 0
        
        # MCC (Matthews Correlation Coefficient)
        val_mcc = matthews_corrcoef(val_labels_all, val_preds_all)
        
        # 归一化MCC到[0,1]区间
        val_norm_mcc = (val_mcc + 1) / 2
        
        # 计算每个类别的准确率
        val_class_counts = np.bincount(val_labels_all, minlength=2)
        val_class_correct = np.bincount(
            val_labels_all[val_preds_all == val_labels_all], 
            minlength=2
        )
        val_class_acc = np.zeros(2)  # 初始化为零，避免除以零的问题
        for i in range(2):
            if val_class_counts[i] > 0:
                val_class_acc[i] = val_class_correct[i] / val_class_counts[i]
        
        # 记录验证指标
        history['val_loss'].append(avg_val_loss)
        history['val_acc'].append(avg_val_acc)
        history['val_class_acc'].append(val_class_acc.tolist())
        history['val_f1'].append(val_f1)
        history['val_precision'].append(val_precision)
        history['val_recall'].append(val_recall)
        history['val_specificity'].append(val_specificity)
        history['val_mcc'].append(val_mcc)
        history['val_norm_mcc'].append(val_norm_mcc)
        
        # 更新最佳模型状态，使用F1分数作为指标
        if val_f1 > best_val_f1:
            best_val_f1 = val_f1
            if isinstance(model, nn.DataParallel):
                best_model_state = copy.deepcopy(model.module.state_dict())
            else:
                best_model_state = copy.deepcopy(model.state_dict())
            logging.info(f"*** 新的最佳模型 (F1分数: {val_f1:.4f}) ***")
        
        # 更新学习率
        if isinstance(scheduler, lr_scheduler.ReduceLROnPlateau):
            scheduler.step(avg_val_loss)
        else:
            scheduler.step()
            
        # 获取当前学习率
        current_lr = optimizer.param_groups[0]['lr']
        
        # 记录训练日志，包含所有新增的评估指标
        epoch_log = (
            f'轮次 {epoch+1}/{epochs}, '
            f'训练损失: {avg_train_loss:.4f}, 训练准确率: {avg_train_acc:.4f}, '
            f'类别0/1: {train_class_acc[0]:.4f}/{train_class_acc[1]:.4f}, '
            f'训练F1: {train_f1:.4f}, 训练精确率: {train_precision:.4f}, '
            f'训练召回率: {train_recall:.4f}, 训练特异性: {train_specificity:.4f}, '
            f'训练MCC: {train_mcc:.4f}, 训练归一化MCC: {train_norm_mcc:.4f}, '
            f'验证损失: {avg_val_loss:.4f}, 验证准确率: {avg_val_acc:.4f}, '
            f'类别0/1: {val_class_acc[0]:.4f}/{val_class_acc[1]:.4f}, '
            f'验证F1: {val_f1:.4f}, 验证精确率: {val_precision:.4f}, '
            f'验证召回率: {val_recall:.4f}, 验证特异性: {val_specificity:.4f}, '
            f'验证MCC: {val_mcc:.4f}, 验证归一化MCC: {val_norm_mcc:.4f}, '
            f'学习率: {current_lr:.6f}'
        )
        logging.info(epoch_log)
        logging.info(f"本轮用时: {time.time() - epoch_start_time:.2f} 秒")
        logging.info("——————————————————————————————")
        
        if log_epoch is not None:
            log_epoch.append(epoch_log)
    
    # 加载最佳模型状态
    if best_model_state is not None:
        if isinstance(model, nn.DataParallel):
            model.module.load_state_dict(best_model_state)
        else:
            model.load_state_dict(best_model_state)
    
    # 整理最终结果
    final_train_probs = np.concatenate([p for p in epoch_train_probs], axis=0)
    final_train_labels = np.concatenate([l for l in epoch_train_labels], axis=0)
    final_val_probs = np.concatenate([p for p in epoch_val_probs], axis=0)
    final_val_labels = np.concatenate([l for l in epoch_val_labels], axis=0)
    
    # 计算最终的类别准确率和所有评估指标
    final_train_preds = np.argmax(final_train_probs, axis=1)
    final_val_preds = np.argmax(final_val_probs, axis=1)
    
    # F1分数
    final_train_f1 = f1_score(final_train_labels, final_train_preds, average='weighted')
    final_val_f1 = f1_score(final_val_labels, final_val_preds, average='weighted')
    
    # 精确率
    final_train_precision = precision_score(final_train_labels, final_train_preds, average='weighted')
    final_val_precision = precision_score(final_val_labels, final_val_preds, average='weighted')
    
    # 召回率
    final_train_recall = recall_score(final_train_labels, final_train_preds, average='weighted')
    final_val_recall = recall_score(final_val_labels, final_val_preds, average='weighted')
    
    # 特异性
    final_train_cm = confusion_matrix(final_train_labels, final_train_preds)
    final_train_tn = final_train_cm[0, 0]
    final_train_fp = final_train_cm[0, 1]
    final_train_specificity = final_train_tn / (final_train_tn + final_train_fp) if (final_train_tn + final_train_fp) > 0 else 0
    
    final_val_cm = confusion_matrix(final_val_labels, final_val_preds)
    final_val_tn = final_val_cm[0, 0]
    final_val_fp = final_val_cm[0, 1]
    final_val_specificity = final_val_tn / (final_val_tn + final_val_fp) if (final_val_tn + final_val_fp) > 0 else 0
    
    # MCC
    final_train_mcc = matthews_corrcoef(final_train_labels, final_train_preds)
    final_val_mcc = matthews_corrcoef(final_val_labels, final_val_preds)
    
    # 归一化MCC
    final_train_norm_mcc = (final_train_mcc + 1) / 2
    final_val_norm_mcc = (final_val_mcc + 1) / 2
    
    # 类别准确率
    train_class_acc = np.zeros(2)
    val_class_acc = np.zeros(2)
    
    for i in range(2):
        train_class_mask = (final_train_labels == i)
        val_class_mask = (final_val_labels == i)
        
        if np.sum(train_class_mask) > 0:
            train_class_acc[i] = np.mean(final_train_preds[train_class_mask] == final_train_labels[train_class_mask])
        
        if np.sum(val_class_mask) > 0:
            val_class_acc[i] = np.mean(final_val_preds[val_class_mask] == final_val_labels[val_class_mask])
    
    # 输出最终各项指标
    logging.info(f"最终训练类别准确率 - 类别0: {train_class_acc[0]:.4f}, 类别1: {train_class_acc[1]:.4f}")
    logging.info(f"最终验证类别准确率 - 类别0: {val_class_acc[0]:.4f}, 类别1: {val_class_acc[1]:.4f}")
    logging.info(f"最终F1分数 - 训练: {final_train_f1:.4f}, 验证: {final_val_f1:.4f}")
    logging.info(f"最终精确率 - 训练: {final_train_precision:.4f}, 验证: {final_val_precision:.4f}")
    logging.info(f"最终召回率 - 训练: {final_train_recall:.4f}, 验证: {final_val_recall:.4f}")
    logging.info(f"最终特异性 - 训练: {final_train_specificity:.4f}, 验证: {final_val_specificity:.4f}")
    logging.info(f"最终MCC - 训练: {final_train_mcc:.4f}, 验证: {final_val_mcc:.4f}")
    logging.info(f"最终归一化MCC - 训练: {final_train_norm_mcc:.4f}, 验证: {final_val_norm_mcc:.4f}")
    
    return (
        history['train_loss'][-1],    # 最终训练损失
        history['val_loss'][-1],      # 最终验证损失
        history['train_acc'][-1],     # 最终训练准确率
        history['val_acc'][-1],       # 最终验证准确率
        final_train_probs,           # 训练集预测概率
        final_train_labels,          # 训练集真实标签
        final_val_probs,             # 验证集预测概率
        final_val_labels,            # 验证集真实标签
        best_model_state             # 最佳模型状态
    )

# %% [markdown]
#  MLP 的 分层K折交叉验证与评估函数

# %%
def kfold_train_eval_mlp(
    model_class: Any,
    dataset: TensorDataset,
    loss_fn: nn.Module,
    optimizer_class: Any,
    optimizer_kwargs: dict,
    scheduler_class: Any,
    scheduler_kwargs: dict,
    epochs: int,
    device: torch.device,
    device_ids: Optional[List[int]],
    num_folds: int = 5,
    output_dir: str = r"C:\Users\USTC\Desktop\地磁论文（5级以上）\对比模型结果\MLP模型结果",
    model_name: str = "MLPModel",
    window_name: str = "7天",
    mapped_window_name: str = "window-7",
    max_grad_norm: Optional[float] = None,
    input_size: int = 1,
    output_size: int = 2,
    hidden_sizes: List[int] = [512, 256],  # 修改为与LSTM版本一致的默认值
    dropout_prob: float = 0.3,
    batch_size: int = 32
) -> Dict[str, List]:
    """
    使用分层K折交叉验证进行MLP模型的训练和评估，支持类别平衡评估，使用F1分数选择最佳模型。
    增加了精确率、召回率、特异性和MCC评估指标。
    
    Args:
        model_class: 模型类
        dataset: 数据集
        loss_fn: 损失函数
        optimizer_class: 优化器类
        optimizer_kwargs: 优化器参数
        scheduler_class: 学习率调度器类
        scheduler_kwargs: 学习率调度器参数
        epochs: 训练轮数
        device: 训练设备
        device_ids: GPU设备ID列表
        num_folds: 交叉验证折数
        output_dir: 模型保存目录
        model_name: 模型名称
        window_name: 时间窗口名称
        mapped_window_name: 映射后的窗口名称
        max_grad_norm: 梯度裁剪阈值
        input_size: 输入维度
        output_size: 输出维度
        hidden_sizes: MLP隐藏层大小列表，如 [512, 256]
        dropout_prob: Dropout概率
        batch_size: 批次大小
    
    Returns:
        Dict[str, List]: 包含训练结果的字典
    """
    from sklearn.model_selection import StratifiedKFold
    from sklearn.metrics import f1_score, precision_score, recall_score, matthews_corrcoef, confusion_matrix
    
    os.makedirs(output_dir, exist_ok=True)
    
    results_dict = {
        "train_losses": [],
        "val_losses": [],
        "train_accs": [],
        "val_accs": [],
        "train_f1s": [],           # F1分数记录
        "val_f1s": [],             # F1分数记录
        "train_precisions": [],    # 精确率记录
        "val_precisions": [],      # 精确率记录
        "train_recalls": [],       # 召回率记录
        "val_recalls": [],         # 召回率记录
        "train_specificities": [], # 特异性记录
        "val_specificities": [],   # 特异性记录
        "train_mccs": [],          # MCC记录
        "val_mccs": [],            # MCC记录
        "train_norm_mccs": [],     # 归一化MCC记录
        "val_norm_mccs": []         # 归一化MCC记录
    }
    
    # 添加fold_results到初始化字典中
    results_dict["fold_results"] = []
    
    total_start_time = time.time()
    
    # 获取数据集的标签，用于分层划分
    all_data = dataset.tensors[0].numpy()
    all_labels = dataset.tensors[1].numpy()
    
    # 创建分层K折交叉验证
    skf = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)
    
    num_gpus = len(device_ids) if device_ids else 1
    adjusted_batch_size = batch_size * num_gpus
    
    logging.info(f"使用设备数量: {num_gpus}")
    logging.info(f"批次大小: {batch_size} 调整后的批次大小: {adjusted_batch_size}")
    
    # 计算类别权重
    class_weights = calculate_class_weights(all_labels)
    logging.info(f"使用平方根缩放的类别权重: {class_weights}")
    
    # 创建加权损失函数
    weighted_loss_fn = nn.CrossEntropyLoss(weight=class_weights.to(device))
    logging.info(f"使用加权损失函数，权重: {class_weights.numpy()}")
    
    scheduler_kwargs['verbose'] = True
    
    # 使用分层K折训练
    for fold, (train_idx, val_idx) in enumerate(skf.split(all_data, all_labels), 1):
        fold_start_time = time.time()
        logging.info(f"开始训练第 {fold}/{num_folds} 折")
        
        # 准备数据加载器
        train_data = Subset(dataset, train_idx)
        val_data = Subset(dataset, val_idx)
        
        # 记录当前折叠的类别分布
        train_labels = dataset.tensors[1][train_idx].numpy()
        val_labels = dataset.tensors[1][val_idx].numpy()
        train_class_counts = np.bincount(train_labels)
        val_class_counts = np.bincount(val_labels)
        
        logging.info(f"训练集类别分布: 类别0: {train_class_counts[0]}, 类别1: {train_class_counts[1]}")
        logging.info(f"验证集类别分布: 类别0: {val_class_counts[0]}, 类别1: {val_class_counts[1]}")
        
        # 创建数据加载器
        train_loader = create_data_loaders_balanced(
            train_data, batch_size, num_gpus, is_train=True
        )
        
        val_loader = create_data_loaders(
            val_data, batch_size, num_gpus
        )
        
        # 初始化模型
        if model_class == MLPModel:
            assert hidden_sizes is not None, "MLPModel需要提供hidden_sizes参数"
            model = model_class(
                input_size=input_size,
                hidden_sizes=hidden_sizes,
                output_size=output_size,
                dropout_prob=dropout_prob
            ).to(device)
            
            if device_ids and len(device_ids) > 1:
                model = nn.DataParallel(model, device_ids=device_ids)
        else:
            # 处理其他可能的模型类型
            model = model_class(
                input_size=input_size,
                hidden_sizes=hidden_sizes,
                output_size=output_size,
                dropout_prob=dropout_prob
            ).to(device)
            
            if device_ids and len(device_ids) > 1:
                model = nn.DataParallel(model, device_ids=device_ids)
        
        optimizer = optimizer_class(model.parameters(), **optimizer_kwargs)
        scheduler = scheduler_class(optimizer, **scheduler_kwargs)
        
        epoch_logs = []
        try:
            # 训练单折模型，使用加权损失函数
            (train_loss, val_loss, 
             train_acc, val_acc,
             train_probs, train_labels,
             val_probs, val_labels,
             best_model_state) = train_eval_mlp(
                model=model,
                train_loader=train_loader,
                val_loader=val_loader,
                loss_fn=weighted_loss_fn,  # 使用加权损失函数
                optimizer=optimizer,
                scheduler=scheduler,
                epochs=epochs,
                device=device,
                log_epoch=epoch_logs,
                max_grad_norm=max_grad_norm,
            )
            
            # 保存模型和相关数据
            base_filename = os.path.join(output_dir, f"{model_name}_{window_name}_fold_{fold}")
            
            # 1. 保存模型权重
            model_path = f"{base_filename}.pth"
            torch.save(best_model_state, model_path)
            logging.info(f"已保存模型权重到: {model_path}")
            
            # 2. 保存训练日志
            log_path = f"{base_filename}_epoch_logs.txt"
            with open(log_path, 'w', encoding='utf-8') as f:
                f.write('\n'.join(epoch_logs))
            logging.info(f"已保存训练日志到: {log_path}")
            
            # 3. 保存训练集预测概率
            train_probs_path = f"{base_filename}_train_probs.npy"
            np.save(train_probs_path, train_probs)
            logging.info(f"已保存训练集预测概率到: {train_probs_path}")
            
            # 4. 保存训练集标签
            train_labels_path = f"{base_filename}_train_labels.npy"
            np.save(train_labels_path, train_labels)
            logging.info(f"已保存训练集标签到: {train_labels_path}")
            
            # 5. 保存测试集预测概率
            test_probs_path = f"{base_filename}_test_probs.npy"
            np.save(test_probs_path, val_probs)
            logging.info(f"已保存测试集预测概率到: {test_probs_path}")
            
            # 6. 保存测试集标签
            test_labels_path = f"{base_filename}_test_labels.npy"
            np.save(test_labels_path, val_labels)
            logging.info(f"已保存测试集标签到: {test_labels_path}")
            
            # 计算预测值
            train_preds = np.argmax(train_probs, axis=1)
            val_preds = np.argmax(val_probs, axis=1)
            
            # 计算各种评估指标
            # F1分数
            train_f1 = f1_score(train_labels, train_preds, average='weighted')
            val_f1 = f1_score(val_labels, val_preds, average='weighted')
            
            # 精确率 (Precision)
            train_precision = precision_score(train_labels, train_preds, average='weighted')
            val_precision = precision_score(val_labels, val_preds, average='weighted')
            
            # 召回率 (Recall)
            train_recall = recall_score(train_labels, train_preds, average='weighted')
            val_recall = recall_score(val_labels, val_preds, average='weighted')
            
            # 特异性 (Specificity) - 需要计算混淆矩阵
            train_cm = confusion_matrix(train_labels, train_preds)
            val_cm = confusion_matrix(val_labels, val_preds)
            
            # 对于二分类，特异性 = TN / (TN + FP)
            train_tn = train_cm[0, 0]
            train_fp = train_cm[0, 1]
            train_specificity = train_tn / (train_tn + train_fp) if (train_tn + train_fp) > 0 else 0
            
            val_tn = val_cm[0, 0]
            val_fp = val_cm[0, 1]
            val_specificity = val_tn / (val_tn + val_fp) if (val_tn + val_fp) > 0 else 0
            
            # MCC (Matthews Correlation Coefficient)
            train_mcc = matthews_corrcoef(train_labels, train_preds)
            val_mcc = matthews_corrcoef(val_labels, val_preds)
            
            # 归一化MCC到[0,1]区间
            train_norm_mcc = (train_mcc + 1) / 2
            val_norm_mcc = (val_mcc + 1) / 2
            
            # 计算每个类别的性能指标
            class_counts = np.bincount(val_labels.astype(int))
            class_correct = np.bincount(val_labels.astype(int) * (val_preds == val_labels), minlength=2)
            class_acc = class_correct / class_counts
            
            logging.info(f"类别准确率: 类别0: {class_acc[0]:.4f}, 类别1: {class_acc[1]:.4f}")
            logging.info(f"F1分数: 训练: {train_f1:.4f}, 验证: {val_f1:.4f}")
            logging.info(f"精确率: 训练: {train_precision:.4f}, 验证: {val_precision:.4f}")
            logging.info(f"召回率: 训练: {train_recall:.4f}, 验证: {val_recall:.4f}")
            logging.info(f"特异性: 训练: {train_specificity:.4f}, 验证: {val_specificity:.4f}")
            logging.info(f"MCC: 训练: {train_mcc:.4f}, 验证: {val_mcc:.4f}")
            logging.info(f"归一化MCC: 训练: {train_norm_mcc:.4f}, 验证: {val_norm_mcc:.4f}")
            
            # 收集每折的结果
            fold_result = {
                'fold': fold,
                'train_loss': train_loss,
                'val_loss': val_loss,
                'train_acc': train_acc,
                'val_acc': val_acc,
                'train_f1': train_f1,
                'val_f1': val_f1,
                'train_precision': train_precision,
                'val_precision': val_precision,
                'train_recall': train_recall,
                'val_recall': val_recall,
                'train_specificity': train_specificity,
                'val_specificity': val_specificity,
                'train_mcc': train_mcc,
                'val_mcc': val_mcc,
                'train_norm_mcc': train_norm_mcc,
                'val_norm_mcc': val_norm_mcc,
                'class_acc': class_acc.tolist(),  # 添加每个类别的准确率
                'model_path': model_path,
                'train_probs_path': train_probs_path,
                'train_labels_path': train_labels_path,
                'test_probs_path': test_probs_path,
                'test_labels_path': test_labels_path,
                'log_path': log_path,
                'time_taken': time.time() - fold_start_time
            }
            results_dict['fold_results'].append(fold_result)
            
            # 更新汇总指标
            results_dict['train_losses'].append(train_loss)
            results_dict['val_losses'].append(val_loss)
            results_dict['train_accs'].append(train_acc)
            results_dict['val_accs'].append(val_acc)
            results_dict['train_f1s'].append(train_f1)
            results_dict['val_f1s'].append(val_f1)
            results_dict['train_precisions'].append(train_precision)
            results_dict['val_precisions'].append(val_precision)
            results_dict['train_recalls'].append(train_recall)
            results_dict['val_recalls'].append(val_recall)
            results_dict['train_specificities'].append(train_specificity)
            results_dict['val_specificities'].append(val_specificity)
            results_dict['train_mccs'].append(train_mcc)
            results_dict['val_mccs'].append(val_mcc)
            results_dict['train_norm_mccs'].append(train_norm_mcc)
            results_dict['val_norm_mccs'].append(val_norm_mcc)
            
            logging.info(f"第 {fold} 折训练完成")
            
        except Exception as e:
            logging.error(f"训练第 {fold} 折时出错: {str(e)}")
            logging.error("详细错误信息:", exc_info=True)
            continue
        
        logging.info(f"第 {fold} 折训练结束")
    
    # 计算总训练时间
    total_duration = time.time() - total_start_time
    hours = int(total_duration // 3600)
    minutes = int((total_duration % 3600) // 60)
    seconds = int(total_duration % 60)
    
    # 计算统计结果
    train_acc_mean = np.mean(results_dict['train_accs'])
    train_acc_std = np.std(results_dict['train_accs'])
    val_acc_mean = np.mean(results_dict['val_accs'])
    val_acc_std = np.std(results_dict['val_accs'])
    
    train_f1_mean = np.mean(results_dict['train_f1s'])
    val_f1_mean = np.mean(results_dict['val_f1s'])
    
    train_precision_mean = np.mean(results_dict['train_precisions'])
    val_precision_mean = np.mean(results_dict['val_precisions'])
    
    train_recall_mean = np.mean(results_dict['train_recalls'])
    val_recall_mean = np.mean(results_dict['val_recalls'])
    
    train_specificity_mean = np.mean(results_dict['train_specificities'])
    val_specificity_mean = np.mean(results_dict['val_specificities'])
    
    train_mcc_mean = np.mean(results_dict['train_mccs'])
    val_mcc_mean = np.mean(results_dict['val_mccs'])
    
    train_norm_mcc_mean = np.mean(results_dict['train_norm_mccs'])
    val_norm_mcc_mean = np.mean(results_dict['val_norm_mccs'])
    
    # 计算每个类别的平均准确率
    class0_accs = [res['class_acc'][0] for res in results_dict['fold_results']]
    class1_accs = [res['class_acc'][1] for res in results_dict['fold_results']]
    class0_acc_mean = np.mean(class0_accs)
    class1_acc_mean = np.mean(class1_accs)
    
    # 保存训练配置和结果，包括类别平衡信息
    config = {
        'model_params': {
            'input_size': input_size,
            'hidden_sizes': hidden_sizes,
            'output_size': output_size,
            'dropout_prob': dropout_prob,
            'num_layers': len(hidden_sizes) if hidden_sizes else 0
        },
        'training_params': {
            'optimizer': optimizer_class.__name__,
            'optimizer_kwargs': optimizer_kwargs,
            'scheduler': scheduler_class.__name__,
            'scheduler_kwargs': scheduler_kwargs,
            'epochs': epochs,
            'batch_size': batch_size,
            'class_weights': class_weights.tolist(),  # 保存类别权重
            'balanced_sampling': True  # 标记使用了平衡采样
        },
        'results': {
            'train_acc_mean': float(train_acc_mean),
            'train_acc_std': float(train_acc_std),
            'val_acc_mean': float(val_acc_mean),
            'val_acc_std': float(val_acc_std),
            'train_f1_mean': float(train_f1_mean),
            'val_f1_mean': float(val_f1_mean),
            'train_precision_mean': float(train_precision_mean),
            'val_precision_mean': float(val_precision_mean),
            'train_recall_mean': float(train_recall_mean),
            'val_recall_mean': float(val_recall_mean),
            'train_specificity_mean': float(train_specificity_mean),
            'val_specificity_mean': float(val_specificity_mean),
            'train_mcc_mean': float(train_mcc_mean),
            'val_mcc_mean': float(val_mcc_mean),
            'train_norm_mcc_mean': float(train_norm_mcc_mean),
            'val_norm_mcc_mean': float(val_norm_mcc_mean),
            'class0_acc_mean': float(class0_acc_mean),
            'class1_acc_mean': float(class1_acc_mean),
            'training_time': {
                'hours': hours,
                'minutes': minutes,
                'seconds': seconds
            },
            'fold_results': results_dict['fold_results']
        }
    }
    
    config_path = os.path.join(output_dir, f"{model_name}_{window_name}_config.json")
    with open(config_path, 'w', encoding='utf-8') as f:
        json.dump(config, f, indent=4, ensure_ascii=False)
    
    # 记录训练总结
    logging.info("\n训练总结:")
    logging.info(f"- 总训练时间: {hours}小时 {minutes}分钟 {seconds}秒")
    logging.info(f"- 平均训练准确率: {train_acc_mean:.4f} ± {train_acc_std:.4f}")
    logging.info(f"- 平均验证准确率: {val_acc_mean:.4f} ± {val_acc_std:.4f}")
    logging.info(f"- 平均训练F1分数: {train_f1_mean:.4f}")
    logging.info(f"- 平均验证F1分数: {val_f1_mean:.4f}")
    logging.info(f"- 平均训练精确率: {train_precision_mean:.4f}")
    logging.info(f"- 平均验证精确率: {val_precision_mean:.4f}")
    logging.info(f"- 平均训练召回率: {train_recall_mean:.4f}")
    logging.info(f"- 平均验证召回率: {val_recall_mean:.4f}")
    logging.info(f"- 平均训练特异性: {train_specificity_mean:.4f}")
    logging.info(f"- 平均验证特异性: {val_specificity_mean:.4f}")
    logging.info(f"- 平均训练MCC: {train_mcc_mean:.4f}")
    logging.info(f"- 平均验证MCC: {val_mcc_mean:.4f}")
    logging.info(f"- 平均训练归一化MCC: {train_norm_mcc_mean:.4f}")
    logging.info(f"- 平均验证归一化MCC: {val_norm_mcc_mean:.4f}")
    logging.info(f"- 类别0平均准确率: {class0_acc_mean:.4f}")
    logging.info(f"- 类别1平均准确率: {class1_acc_mean:.4f}")
    logging.info(f"- 平均验证损失: {np.mean(results_dict['val_losses']):.4f} ± {np.std(results_dict['val_losses']):.4f}")
    
    return results_dict

# %%
import torch
print("CUDA 是否可用:", torch.cuda.is_available())
print("当前 PyTorch 版本:", torch.__version__)
print("CUDA 版本:", torch.version.cuda)
print("GPU 数量:", torch.cuda.device_count())

if torch.cuda.is_available():
    for i in range(torch.cuda.device_count()):
        print(f"GPU {i}: {torch.cuda.get_device_name(i)}")
# Out:
# CUDA 是否可用: True
# 当前 PyTorch 版本: 2.5.1+cu118
# CUDA 版本: 11.8
# GPU 数量: 2
# GPU 0: NVIDIA GeForce RTX 4090
# GPU 1: NVIDIA GeForce RTX 4090

# %% [markdown]
# 检查数据集的大小，以便更科学的数据平衡

# %%
import os
import numpy as np

base_path = r"C:\Users\USTC\Desktop\地磁论文（5级以上）"

# 检查各个时间窗口的数据分布
window_periods = ['7', '14', '30']

for period in window_periods:
    window_path = os.path.join(base_path, f"window-{period}")
    
    try:
        # 加载数据文件
        data_0_path = os.path.join(window_path, "data_0.npy")
        data_1_path = os.path.join(window_path, "data_1.npy")
        
        if os.path.exists(data_0_path) and os.path.exists(data_1_path):
            data_0 = np.load(data_0_path)
            data_1 = np.load(data_1_path)
            
            # 提取标签信息
            labels_0 = data_0[:, -1].astype(int)
            labels_1 = data_1[:, -1].astype(int)
            
            # 合并数据和标签
            all_data = np.concatenate([data_0, data_1], axis=0)
            all_labels = all_data[:, -1].astype(int)
            
            # 计算类别分布
            class_counts = np.bincount(all_labels)
            
            print(f"\n=== 时间窗口: {period}天 ===")
            print(f"数据形状 - data_0: {data_0.shape}, data_1: {data_1.shape}")
            print(f"总样本数: {len(all_labels)}")
            if len(class_counts) >= 2:
                print(f"类别0样本数: {class_counts[0]}")
                print(f"类别1样本数: {class_counts[1]}")
                print(f"类别比例(1:0): 1:{class_counts[0]/class_counts[1]:.2f}")
            else:
                print(f"警告: 只有一个类别 - {class_counts}")
                
            # 计算平衡建议
            if class_counts[0] > class_counts[1]:
                minority_class = 1
                minority_count = class_counts[1]
                majority_count = class_counts[0]
            else:
                minority_class = 0
                minority_count = class_counts[0]
                majority_count = class_counts[1]
                
            imbalance_ratio = majority_count / minority_count
            
            print(f"\n数据不平衡分析:")
            print(f"不平衡比例: {imbalance_ratio:.2f}:1")
            
            if imbalance_ratio < 1.5:
                print("评估: 数据集相对平衡，简单的类别权重调整应该足够")
                weight_suggestion = f"类别权重建议: [1.0, {imbalance_ratio:.2f}]" if minority_class == 1 else f"类别权重建议: [{imbalance_ratio:.2f}, 1.0]"
                print(weight_suggestion)
            elif imbalance_ratio < 10:
                print("评估: 中度不平衡，建议结合类别权重和采样技术")
                # 计算平方根缩放的权重
                sqrt_weights = np.sqrt(class_counts) / np.sum(np.sqrt(class_counts)) * len(class_counts)
                weights_str = "[{:.2f}, {:.2f}]".format(sqrt_weights[0], sqrt_weights[1])
                print(f"类别权重建议(平方根缩放): {weights_str}")
                print("采样策略: 使用WeightedRandomSampler进行训练")
            else:
                print("评估: 严重不平衡，建议使用组合策略")
                print("建议策略:")
                print("1. 使用有效样本数计算权重")
                print("2. 考虑使用Focal Loss代替CrossEntropyLoss")
                print("3. 结合过采样和欠采样技术")
                print("4. 使用数据增强生成少数类样本")
        else:
            print(f"错误: 无法找到窗口 {period} 的数据文件")
    except Exception as e:
        print(f"处理窗口 {period} 时出错: {str(e)}")
# Out:
# === 时间窗口: 7天 ===
# 数据形状 - data_0: (1661, 10081), data_1: (999, 10081)
# 总样本数: 2660
# 类别0样本数: 1661
# 类别1样本数: 999
# 类别比例(1:0): 1:1.66
#
# 数据不平衡分析:
# 不平衡比例: 1.66:1
# 评估: 中度不平衡，建议结合类别权重和采样技术
# 类别权重建议(平方根缩放): [1.13, 0.87]
# 采样策略: 使用WeightedRandomSampler进行训练
#
# === 时间窗口: 14天 ===
# 数据形状 - data_0: (1878, 20161), data_1: (826, 20161)
# 总样本数: 2704
# 类别0样本数: 1878
# 类别1样本数: 826
# 类别比例(1:0): 1:2.27
#
# 数据不平衡分析:
# 不平衡比例: 2.27:1
# 评估: 中度不平衡，建议结合类别权重和采样技术
# 类别权重建议(平方根缩放): [1.20, 0.80]
# 采样策略: 使用WeightedRandomSampler进行训练
#
# === 时间窗口: 30天 ===
# 数据形状 - data_0: (1421, 43201), data_1: (770, 43201)
# 总样本数: 2191
# 类别0样本数: 1421
# 类别1样本数: 770
# 类别比例(1:0): 1:1.85
#
# 数据不平衡分析:
# 不平衡比例: 1.85:1
# 评估: 中度不平衡，建议结合类别权重和采样技术
# 类别权重建议(平方根缩放): [1.15, 0.85]
# 采样策略: 使用WeightedRandomSampler进行训练

# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader, Subset
from torch.optim import lr_scheduler
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score
import logging
import time
import json
from typing import Dict, Any, Optional, List, Tuple
import copy

import warnings
warnings.filterwarnings("ignore", message="PyTorch is not compiled with NCCL support")

def setup_logging(log_file: str = 'training.log'):
    """设置日志配置"""
    logging.basicConfig(
        level=logging.INFO,
        format='%(asctime)s - %(levelname)s - %(message)s',
        datefmt='%Y-%m-%d %H:%M:%S'  # 移除了 ,%f，因为这不是标准的时间格式
    )
    # 如果需要添加文件处理器
    file_handler = logging.FileHandler(log_file, encoding='utf-8')
    file_handler.setFormatter(
        logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
    )
    logger = logging.getLogger(__name__)
    logger.addHandler(file_handler)
    return logger

def setup_device() -> Tuple[torch.device, Optional[List[int]]]:
    """配置训练设备，最大化利用所有可用NVIDIA GPU"""
    if torch.cuda.device_count() > 1:
        # 获取所有可用GPU
        device_count = torch.cuda.device_count()
        device_ids = list(range(device_count))
        device = torch.device(f'cuda:{device_ids[0]}')
        
        # 输出每个GPU的信息
        gpu_info = []
        for i in device_ids:
            gpu_name = torch.cuda.get_device_name(i)
            gpu_info.append(f"GPU {i}: {gpu_name}")
        
        logging.info(f"使用 {len(device_ids)} 个GPU设备: {device_ids}")
        logging.info("GPU详情: " + ", ".join(gpu_info))
        
        # 设置主设备，确保初始化顺序正确
        torch.cuda.set_device(device_ids[0])
        
        return device, device_ids
    elif torch.cuda.is_available():
        device = torch.device('cuda:0')
        gpu_name = torch.cuda.get_device_name(0)
        logging.info(f"使用单个GPU设备: {gpu_name}")
        return device, None
    else:
        device = torch.device('cpu')
        logging.info("使用CPU设备")
        return device, None

def calculate_class_weights(labels):
    """计算平方根缩放的类别权重"""
    class_counts = np.bincount(labels)
    logging.info(f"类别分布: 类别0: {class_counts[0]}, 类别1: {class_counts[1]}")
    
    # 使用平方根缩放计算权重
    weights_sqrt = np.sqrt(class_counts.sum() / class_counts / len(class_counts))
    return torch.FloatTensor(weights_sqrt)

def create_balanced_sampler(dataset):
    """创建平衡采样器"""
    # 提取数据集的标签
    if isinstance(dataset, TensorDataset):
        labels = dataset.tensors[1].numpy()
    elif isinstance(dataset, Subset):
        labels = dataset.dataset.tensors[1][dataset.indices].numpy()
    else:
        raise TypeError("不支持的数据集类型")
    
    # 计算类别权重（反比例，但不使用平方根缩放）
    class_counts = np.bincount(labels)
    logging.info(f"原始类别分布: {class_counts}")
    
    # 计算每个样本的权重
    class_weights = 1.0 / class_counts
    # 确保少数类有更高的采样概率
    sample_weights = class_weights[labels]
    
    # 创建采样器
    sampler = WeightedRandomSampler(
        weights=sample_weights,
        num_samples=len(sample_weights),
        replacement=True  # 允许重复采样
    )
    
    return sampler

def create_data_loaders_balanced(dataset, batch_size, num_gpus=1, is_train=True):
    """创建带有平衡采样的数据加载器"""
    effective_batch_size = batch_size * num_gpus if num_gpus > 1 else batch_size
    
    if is_train:
        # 训练集使用加权采样
        sampler = create_balanced_sampler(dataset)
        logging.info(f"批次大小: {batch_size} 调整后的批次大小: {effective_batch_size} (使用平衡采样)")
        return DataLoader(
            dataset,
            batch_size=effective_batch_size,
            sampler=sampler,  # 使用采样器替代shuffle
            num_workers=4 * num_gpus,
            pin_memory=True
        )
    else:
        # 验证集不需要平衡采样
        logging.info(f"批次大小: {batch_size} 调整后的批次大小: {effective_batch_size}")
        return DataLoader(
            dataset,
            batch_size=effective_batch_size,
            shuffle=False,
            num_workers=4 * num_gpus,
            pin_memory=True
        )

def create_data_loaders(dataset: TensorDataset, batch_size: int, num_gpus: int = 1) -> DataLoader:
    """创建数据加载器"""
    effective_batch_size = batch_size * num_gpus if num_gpus > 1 else batch_size
    logging.info(f"批次大小: {batch_size} 调整后的批次大小: {effective_batch_size}")
    
    return DataLoader(
        dataset,
        batch_size=effective_batch_size,
        shuffle=True,
        num_workers=4 * num_gpus,
        pin_memory=True
    )

def create_model(model_class, input_size, hidden_sizes, output_size, dropout_prob, device, device_ids=None):
    """创建模型"""
    model = model_class(
        input_size=input_size,
        hidden_sizes=hidden_sizes,
        output_size=output_size,
        dropout_prob=dropout_prob
    )
    
    if device_ids and len(device_ids) > 1:
        model = nn.DataParallel(model, device_ids=device_ids)
    
    return model.to(device)

def main_mlp(optimize: bool = False) -> None:
    """主函数"""
    setup_logging()
    device, device_ids = setup_device()
    base_path = r"C:\Users\USTC\Desktop\地磁论文（5级以上）"
    output_dir = os.path.join(base_path, '对比模型结果', 'MLP模型结果')
    os.makedirs(output_dir, exist_ok=True)

    logging.info(f"开始训练流程 - 使用设备: {device}")

    window_mapping = {
        "window-7": {"name": "7天", "features": 10080},
        "window-14": {"name": "14天", "features": 20160},
        "window-30": {"name": "30天", "features": 43200}
    }

    try:
        # 定义训练参数
        training_config = {
            'hidden_sizes': [512, 256],
            'dropout_prob': 0.3,
            'learning_rate': 0.001,
            'batch_size': 32,
            'weight_decay': 0.01,
            'max_grad_norm': 1.0
        }

        optimizer_kwargs = {
            'lr': training_config['learning_rate'],
            'weight_decay': training_config['weight_decay']
        }

        scheduler_kwargs = {
            'mode': 'min',
            'factor': 0.1,
            'patience': 10,
            'min_lr': 1e-6,
            'verbose': True
        }

        for window_period in ['7', '14', '30']:
            current_window_name = f"window-{window_period}"
            window_info = window_mapping[current_window_name]
            
            logging.info(f"\n=== 开始处理时间窗口: {window_info['name']} ===")

            try:
                # 加载数据
                data_dir = os.path.join(base_path, current_window_name)
                data_0 = np.load(os.path.join(data_dir, "data_0.npy"))
                data_1 = np.load(os.path.join(data_dir, "data_1.npy"))
                
                data = np.concatenate([data_0, data_1], axis=0)
                X = data[:, :-1]
                Y = data[:, -1].astype(int)
                
                X_tensor = torch.from_numpy(X).type(torch.float32)
                Y_tensor = torch.from_numpy(Y).type(torch.long)
                dataset = TensorDataset(X_tensor, Y_tensor)
                
                # 计算类别权重，用于损失函数
                class_weights = calculate_class_weights(Y)
                weighted_loss = nn.CrossEntropyLoss(weight=class_weights)
                logging.info(f"使用带权重的损失函数，权重: {class_weights.numpy()}")

                # 开始分层K折训练
                results = kfold_train_eval_mlp( 
                    model_class=MLPModel,
                    dataset=dataset,
                    loss_fn=weighted_loss,  # 使用带权重的损失函数
                    optimizer_class=optim.AdamW,
                    optimizer_kwargs=optimizer_kwargs,
                    scheduler_class=optim.lr_scheduler.ReduceLROnPlateau,
                    scheduler_kwargs=scheduler_kwargs,
                    epochs=1,
                    device=device,
                    device_ids=device_ids,
                    num_folds=5,
                    output_dir=output_dir,
                    model_name="MLPModel",
                    window_name=window_info['name'],
                    mapped_window_name=current_window_name,
                    input_size=window_info['features'],
                    output_size=2,
                    dropout_prob=training_config['dropout_prob'],
                    hidden_sizes=training_config['hidden_sizes'],
                    batch_size=training_config['batch_size']
                )
                
                # 执行基于F1分数的模型集成
                perform_model_ensemble(
                    window_info=window_info,
                    training_config=training_config,
                    output_dir=output_dir,
                    device=device,
                    device_ids=device_ids,
                    current_window_name=current_window_name
                )

            except Exception as e:
                logging.error(f"处理 {window_info['name']} 时出错: {str(e)}")
                continue

        logging.info("\n=== 所有处理完成！===")

    except Exception as e:
        logging.error(f"程序执行出错: {str(e)}")
        raise

def perform_model_ensemble(
    window_info: Dict,
    training_config: Dict,
    output_dir: str,
    device: torch.device,
    device_ids: Optional[List[int]],
    current_window_name: str,
    ensemble_method: str = 'f1'  # 可选值: 'f1', 'mcc', 'balanced'
) -> None:
    """
    执行模型集成过程，支持多种集成权重策略，提供完整的评估指标计算
    
    Args:
        window_info: 窗口信息
        training_config: 训练配置
        output_dir: 输出目录
        device: 计算设备
        device_ids: GPU设备ID列表
        current_window_name: 当前窗口名称
        ensemble_method: 集成方法 ('f1', 'mcc', 'balanced')
    """
    from sklearn.metrics import f1_score, precision_score, recall_score, matthews_corrcoef, confusion_matrix
    
    model_name = "MLPModel"
    window_name = window_info['name']
    logging.info(f"开始进行模型集成 - {model_name}_{window_name} (方法: {ensemble_method})")
    
    try:
        # 加载各个折叠的模型
        models = []
        model_metrics = {
            'f1_scores': [],            # F1分数
            'precisions': [],           # 精确率
            'recalls': [],              # 召回率
            'specificities': [],        # 特异性
            'mccs': [],                 # MCC
            'norm_mccs': [],            # 归一化MCC
            'accuracies': []            # 准确率
        }
        num_folds = 5
        
        for fold in range(1, num_folds + 1):
            # 创建基础模型
            model = MLPModel(
                input_size=window_info['features'],
                hidden_sizes=training_config['hidden_sizes'],
                output_size=2,
                dropout_prob=training_config['dropout_prob']
            ).to(device)
            
            if device_ids and len(device_ids) > 1:
                model = nn.DataParallel(model, device_ids=device_ids)
            
            # 加载模型权重
            model_path = os.path.join(output_dir, f"{model_name}_{window_name}_fold_{fold}.pth")
            if os.path.exists(model_path):
                state_dict = torch.load(model_path)
                if device_ids and len(device_ids) > 1:
                    if not list(state_dict.keys())[0].startswith('module.'):
                        state_dict = {'module.' + k: v for k, v in state_dict.items()}
                model.load_state_dict(state_dict)
                model.eval()
                models.append(model)
                
                # 加载验证数据
                test_probs_path = os.path.join(output_dir, f"{model_name}_{window_name}_fold_{fold}_test_probs.npy")
                test_labels_path = os.path.join(output_dir, f"{model_name}_{window_name}_fold_{fold}_test_labels.npy")
                
                if os.path.exists(test_probs_path) and os.path.exists(test_labels_path):
                    test_probs = np.load(test_probs_path)
                    test_labels = np.load(test_labels_path)
                    test_preds = np.argmax(test_probs, axis=1)
                    
                    # 计算所有评估指标
                    fold_f1 = f1_score(test_labels, test_preds, average='weighted')
                    fold_precision = precision_score(test_labels, test_preds, average='weighted')
                    fold_recall = recall_score(test_labels, test_preds, average='weighted')
                    
                    # 计算特异性 (针对二分类)
                    fold_cm = confusion_matrix(test_labels, test_preds)
                    tn, fp, fn, tp = fold_cm.ravel() if fold_cm.size == 4 else (fold_cm[0, 0], fold_cm[0, 1], fold_cm[1, 0], fold_cm[1, 1])
                    fold_specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
                    
                    # 计算MCC和归一化MCC
                    fold_mcc = matthews_corrcoef(test_labels, test_preds)
                    fold_norm_mcc = (fold_mcc + 1) / 2  # 归一化到[0,1]区间
                    
                    # 计算准确率
                    fold_accuracy = (tp + tn) / (tp + tn + fp + fn) if (tp + tn + fp + fn) > 0 else 0
                    
                    # 确保F1分数非零(用于权重计算)
                    fold_f1 = max(fold_f1, 0.01)
                    
                    # 存储所有指标
                    model_metrics['f1_scores'].append(fold_f1)
                    model_metrics['precisions'].append(fold_precision)
                    model_metrics['recalls'].append(fold_recall)
                    model_metrics['specificities'].append(fold_specificity)
                    model_metrics['mccs'].append(fold_mcc)
                    model_metrics['norm_mccs'].append(fold_norm_mcc)
                    model_metrics['accuracies'].append(fold_accuracy)
                    
                    # 输出详细的评估日志
                    logging.info(f"第 {fold} 折模型评估指标:")
                    logging.info(f"  F1分数: {fold_f1:.4f}")
                    logging.info(f"  精确率: {fold_precision:.4f}")
                    logging.info(f"  召回率: {fold_recall:.4f}")
                    logging.info(f"  特异性: {fold_specificity:.4f}")
                    logging.info(f"  MCC: {fold_mcc:.4f}")
                    logging.info(f"  归一化MCC: {fold_norm_mcc:.4f}")
                    logging.info(f"  准确率: {fold_accuracy:.4f}")
                    
                else:
                    # 如果找不到验证数据，从配置文件中尝试获取各项指标
                    config_path = os.path.join(output_dir, f"{model_name}_{window_name}_config.json")
                    if os.path.exists(config_path):
                        with open(config_path, 'r', encoding='utf-8') as f:
                            config = json.load(f)
                            fold_results = config['results']['fold_results']
                            fold_result = next((result for result in fold_results if result['fold'] == fold), None)
                            
                            if fold_result:
                                # 提取所有可用的指标
                                fold_f1 = fold_result.get('val_f1', 1.0)
                                model_metrics['f1_scores'].append(fold_f1)
                                
                                if 'val_precision' in fold_result:
                                    model_metrics['precisions'].append(fold_result['val_precision'])
                                else:
                                    model_metrics['precisions'].append(0.0)
                                    
                                if 'val_recall' in fold_result:
                                    model_metrics['recalls'].append(fold_result['val_recall'])
                                else:
                                    model_metrics['recalls'].append(0.0)
                                    
                                if 'val_specificity' in fold_result:
                                    model_metrics['specificities'].append(fold_result['val_specificity'])
                                else:
                                    model_metrics['specificities'].append(0.0)
                                    
                                if 'val_mcc' in fold_result:
                                    model_metrics['mccs'].append(fold_result['val_mcc'])
                                else:
                                    model_metrics['mccs'].append(0.0)
                                    
                                if 'val_norm_mcc' in fold_result:
                                    model_metrics['norm_mccs'].append(fold_result['val_norm_mcc'])
                                else:
                                    model_metrics['norm_mccs'].append(0.5)  # 0.5是归一化MCC的中间值
                                    
                                if 'val_acc' in fold_result:
                                    model_metrics['accuracies'].append(fold_result['val_acc'])
                                else:
                                    model_metrics['accuracies'].append(0.0)
                                
                                logging.info(f"第 {fold} 折模型F1分数(从配置获取): {fold_f1:.4f}")
                            else:
                                # 如果找不到特定折的结果，使用默认值
                                model_metrics['f1_scores'].append(1.0)
                                model_metrics['precisions'].append(0.0)
                                model_metrics['recalls'].append(0.0)
                                model_metrics['specificities'].append(0.0)
                                model_metrics['mccs'].append(0.0)
                                model_metrics['norm_mccs'].append(0.5)
                                model_metrics['accuracies'].append(0.0)
                                logging.warning(f"未找到第 {fold} 折的F1分数，使用默认值1.0")
                    else:
                        # 如果找不到配置文件，使用默认值
                        model_metrics['f1_scores'].append(1.0)
                        model_metrics['precisions'].append(0.0)
                        model_metrics['recalls'].append(0.0)
                        model_metrics['specificities'].append(0.0)
                        model_metrics['mccs'].append(0.0)
                        model_metrics['norm_mccs'].append(0.5)
                        model_metrics['accuracies'].append(0.0)
                        logging.warning(f"未找到第 {fold} 折的验证集结果，使用默认F1=1.0")
                
                logging.info(f"已加载第 {fold} 折模型")
            else:
                logging.warning(f"未找到第 {fold} 折模型权重文件: {model_path}")
        
        if models:
            # 根据指定的集成方法确定权重
            if ensemble_method == 'f1':
                weights = np.array(model_metrics['f1_scores'])
            elif ensemble_method == 'mcc':
                weights = np.array(model_metrics['norm_mccs'])
            elif ensemble_method == 'balanced':
                # 使用F1和归一化MCC的平均值
                weights = np.array(model_metrics['f1_scores']) * 0.5 + np.array(model_metrics['norm_mccs']) * 0.5
            else:
                # 默认使用F1
                weights = np.array(model_metrics['f1_scores'])
                
            # 归一化权重
            weights = weights / weights.sum() if weights.sum() > 0 else np.ones(len(weights)) / len(weights)
            logging.info(f"基于{ensemble_method}的模型权重: {weights}")
            
            # 创建集成模型
            ensemble_model = EnsembleModel(
                base_models=models,
                ensemble_weights=weights
            ).to(device)
            
            if device_ids and len(device_ids) > 1:
                ensemble_model = nn.DataParallel(ensemble_model, device_ids=device_ids)
            
            # 保存集成模型
            ensemble_path = os.path.join(output_dir, f"{model_name}_{window_name}.pth")
            torch.save(ensemble_model.state_dict(), ensemble_path)
            
            # 计算各项指标的平均值
            avg_metrics = {}
            for metric_name, values in model_metrics.items():
                if values:
                    avg_metrics[f'avg_{metric_name}'] = float(np.mean(values))
                    avg_metrics[f'std_{metric_name}'] = float(np.std(values))
            
            # 保存集成配置，包含所有评估指标
            ensemble_config = {
                'model_name': model_name,
                'window_name': window_name,
                'ensemble_weights': weights.tolist(),
                'ensemble_method': ensemble_method,
                'window_info': window_info,
                'training_config': training_config,
                'fold_metrics': {
                    'f1_scores': model_metrics['f1_scores'],
                    'precisions': model_metrics['precisions'],
                    'recalls': model_metrics['recalls'],
                    'specificities': model_metrics['specificities'],
                    'mccs': model_metrics['mccs'],
                    'norm_mccs': model_metrics['norm_mccs'],
                    'accuracies': model_metrics['accuracies']
                },
                'average_metrics': avg_metrics
            }
            
            config_path = os.path.join(output_dir, f"{model_name}_{window_name}_ensemble_config.json")
            with open(config_path, 'w', encoding='utf-8') as f:
                json.dump(ensemble_config, f, indent=4, ensure_ascii=False)
            
            # 输出集成模型的平均表现
            logging.info(f"{ensemble_method}加权集成模型已保存: {ensemble_path}")
            logging.info("集成模型平均评估指标:")
            for metric_name, value in avg_metrics.items():
                if metric_name.startswith('avg_'):
                    display_name = metric_name[4:].replace('_', ' ')
                    logging.info(f"  平均{display_name}: {value:.4f}")
            
            logging.info(f"集成配置已保存: {config_path}")
        else:
            logging.error("没有可用的模型进行集成")
            
    except Exception as e:
        logging.error(f"模型集成过程出错: {str(e)}")
        logging.error("详细错误信息:", exc_info=True)

def load_ensemble_model(model_path: str, config_path: str, device: torch.device, device_ids=None) -> EnsembleModel:
    """加载集成模型"""
    with open(config_path, 'r') as f:
        config = json.load(f)
    
    base_models = []
    for _ in range(5):
        model = create_model(
            model_class=MLPModel,
            input_size=config['window_info']['features'],
            hidden_sizes=config['training_config']['hidden_sizes'],
            output_size=2,
            dropout_prob=config['training_config']['dropout_prob'],
            device=device,
            device_ids=device_ids
        )
        base_models.append(model)
    
    ensemble_model = EnsembleModel(
        base_models=base_models,
        ensemble_weights=config['ensemble_weights']
    ).to(device)
    
    if device_ids and len(device_ids) > 1:
        ensemble_model = nn.DataParallel(ensemble_model, device_ids=device_ids)
    
    ensemble_model.load_state_dict(torch.load(model_path))
    return ensemble_model

if __name__ == "__main__":
    main_mlp()
# Out:
# 2025-03-11 16:50:12 - INFO - 使用 2 个GPU设备: [0, 1]
# 2025-03-11 16:50:12 - INFO - GPU详情: GPU 0: NVIDIA GeForce RTX 4090, GPU 1: NVIDIA GeForce RTX 4090
# 2025-03-11 16:50:12 - INFO - 开始训练流程 - 使用设备: cuda:0
# 2025-03-11 16:50:12 - INFO -
# === 开始处理时间窗口: 7天 ===
# 2025-03-11 16:50:12 - INFO - 类别分布: 类别0: 1661, 类别1: 999
# 2025-03-11 16:50:12 - INFO - 使用带权重的损失函数，权重: [0.89483094 1.1538333 ]
# 2025-03-11 16:50:12 - INFO - 使用设备数量: 2
# 2025-03-11 16:50:12 - INFO - 批次大小: 32 调整后的批次大小: 64
# 2025-03-11 16:50:12 - INFO - 类别分布: 类别0: 1661, 类别1: 999
# 2025-03-11 16:50:12 - INFO - 使用平方根缩放的类别权重: tensor([0.8948, 1.1538])
# 2025-03-11 16:50:12 - INFO - 使用加权损失函数，权重: [0.89483094 1.1538333 ]
# 2025-03-11 16:50:12 - INFO - 开始训练第 1/5 折
# 2025-03-11 16:50:12 - INFO - 训练集类别分布: 类别0: 1328, 类别1: 800
# 2025-03-11 16:50:12 - INFO - 验证集类别分布: 类别0: 333, 类别1: 199
# 2025-03-11 16:50:12 - INFO - 原始类别分布: [1328  800]
# 2025-03-11 16:50:12 - INFO - 批次大小: 32 调整后的批次大小: 64 (使用平衡采样)
# 2025-03-11 16:50:12 - INFO - 批次大小: 32 调整后的批次大小: 64
# c:\Users\USTC\anaconda3\envs\gpupytorch\lib\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# 2025-03-11 16:50:12 - INFO - 使用带权重的损失函数，权重: [0.89483094 1.1538333 ]
# 2025-03-11 16:50:19 - INFO - *** 新的最佳模型 (F1分数: 0.2141) ***
# 2025-03-11 16:50:19 - INFO - 轮次 1/100, 训练损失: 0.7012, 训练准确率: 0.5630, 类别0/1: 0.3779/0.7469, 训练F1: 0.5448, 训练精确率: 0.5725, 训练召回率: 0.5602, 训练特异性: 0.3779, 训练MCC: 0.1342, 训练归一化MCC: 0.5671, 验证损失: 0.8399, 验证准确率: 0.3778, 类别0/1: 0.0090/0.9899, 验证F1: 0.2141, 验证精确率: 0.5154, 验证召回率: 0.3759, 验证特异性: 0.0090, 验证MCC: -0.0052, 验证归一化MCC: 0.4974, 学习率: 0.001000
# 2025-03-11 16:50:19 - INFO - 本轮用时: 7.38 秒
# 2025-03-11 16:50:19 - INFO - ——————————————————————————————
# 2025-03-11 16:50:27 - INFO - 轮次 2/100, 训练损失: 0.6396, 训练准确率: 0.6025, 类别0/1: 0.4063/0.8203, 训练F1: 0.5870, 训练精确率: 0.6387, 训练召回率: 0.6034, 训练特异性: 0.4063, 训练MCC: 0.2473, 训练归一化MCC: 0.6237, 验证损失: 0.7258, 验证准确率: 0.3875, 类别0/1: 0.0060/0.9899, 验证F1: 0.2102, 验证精确率: 0.4525, 验证召回率: 0.3741, 验证特异性: 0.0060, 验证MCC: -0.0227, 验证归一化MCC: 0.4887, 学习率: 0.001000
# 2025-03-11 16:50:27 - INFO - 本轮用时: 7.42 秒
# 2025-03-11 16:50:27 - INFO - ——————————————————————————————
# 2025-03-11 16:50:35 - INFO - 轮次 3/100, 训练损失: 0.5740, 训练准确率: 0.6719, 类别0/1: 0.5595/0.7809, 训练F1: 0.6673, 训练精确率: 0.6788, 训练召回率: 0.6715, 训练特异性: 0.5595, 训练MCC: 0.3493, 训练归一化MCC: 0.6747, 验证损失: 0.9853, 验证准确率: 0.3740, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.001000
# 2025-03-11 16:50:35 - INFO - 本轮用时: 8.08 秒
# 2025-03-11 16:50:35 - INFO - ——————————————————————————————
# 2025-03-11 16:50:42 - INFO - 轮次 4/100, 训练损失: 0.5266, 训练准确率: 0.7109, 类别0/1: 0.5653/0.8517, 训练F1: 0.7051, 训练精确率: 0.7271, 训练召回率: 0.7115, 训练特异性: 0.5653, 训练MCC: 0.4364, 训练归一化MCC: 0.7182, 验证损失: 0.7861, 验证准确率: 0.3740, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.001000
# 2025-03-11 16:50:42 - INFO - 本轮用时: 7.75 秒
# 2025-03-11 16:50:42 - INFO - ——————————————————————————————
# 2025-03-11 16:50:50 - INFO - 轮次 5/100, 训练损失: 0.4925, 训练准确率: 0.7348, 类别0/1: 0.7006/0.7683, 训练F1: 0.7342, 训练精确率: 0.7355, 训练召回率: 0.7345, 训练特异性: 0.7006, 训练MCC: 0.4700, 训练归一化MCC: 0.7350, 验证损失: 0.8389, 验证准确率: 0.3740, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.001000
# 2025-03-11 16:50:50 - INFO - 本轮用时: 7.43 秒
# 2025-03-11 16:50:50 - INFO - ——————————————————————————————
# 2025-03-11 16:50:57 - INFO - 轮次 6/100, 训练损失: 0.4537, 训练准确率: 0.7528, 类别0/1: 0.6421/0.8711, 训练F1: 0.7525, 训练精确率: 0.7708, 训练召回率: 0.7556, 训练特异性: 0.6421, 训练MCC: 0.5267, 训练归一化MCC: 0.7633, 验证损失: 0.8057, 验证准确率: 0.3608, 类别0/1: 0.0060/0.9899, 验证F1: 0.2102, 验证精确率: 0.4525, 验证召回率: 0.3741, 验证特异性: 0.0060, 验证MCC: -0.0227, 验证归一化MCC: 0.4887, 学习率: 0.001000
# 2025-03-11 16:50:57 - INFO - 本轮用时: 7.19 秒
# 2025-03-11 16:50:57 - INFO - ——————————————————————————————
# 2025-03-11 16:51:05 - INFO - 轮次 7/100, 训练损失: 0.4446, 训练准确率: 0.7642, 类别0/1: 0.6931/0.8354, 训练F1: 0.7633, 训练精确率: 0.7697, 训练召回率: 0.7646, 训练特异性: 0.6931, 训练MCC: 0.5341, 训练归一化MCC: 0.7670, 验证损失: 0.8080, 验证准确率: 0.3760, 类别0/1: 0.0060/0.9899, 验证F1: 0.2102, 验证精确率: 0.4525, 验证召回率: 0.3741, 验证特异性: 0.0060, 验证MCC: -0.0227, 验证归一化MCC: 0.4887, 学习率: 0.001000
# 2025-03-11 16:51:05 - INFO - 本轮用时: 7.49 秒
# 2025-03-11 16:51:05 - INFO - ——————————————————————————————
# c:\Users\USTC\anaconda3\envs\gpupytorch\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2025-03-11 16:51:12 - INFO - 轮次 8/100, 训练损失: 0.4644, 训练准确率: 0.7348, 类别0/1: 0.6002/0.8701, 训练F1: 0.7309, 训练精确率: 0.7536, 训练召回率: 0.7359, 训练特异性: 0.6002, 训练MCC: 0.4888, 训练归一化MCC: 0.7444, 验证损失: 0.8490, 验证准确率: 0.3760, 类别0/1: 0.0000/1.0000, 验证F1: 0.2037, 验证精确率: 0.1399, 验证召回率: 0.3741, 验证特异性: 0.0000, 验证MCC: 0.0000, 验证归一化MCC: 0.5000, 学习率: 0.001000
# 2025-03-11 16:51:12 - INFO - 本轮用时: 7.59 秒
# 2025-03-11 16:51:12 - INFO - ——————————————————————————————
# 2025-03-11 16:51:20 - INFO - 轮次 9/100, 训练损失: 0.4677, 训练准确率: 0.7339, 类别0/1: 0.6215/0.8503, 训练F1: 0.7304, 训练精确率: 0.7490, 训练召回率: 0.7336, 训练特异性: 0.6215, 训练MCC: 0.4835, 训练归一化MCC: 0.7417, 验证损失: 0.7119, 验证准确率: 0.3684, 类别0/1: 0.0060/0.9899, 验证F1: 0.2102, 验证精确率: 0.4525, 验证召回率: 0.3741, 验证特异性: 0.0060, 验证MCC: -0.0227, 验证归一化MCC: 0.4887, 学习率: 0.001000
# 2025-03-11 16:51:20 - INFO - 本轮用时: 7.90 秒
# 2025-03-11 16:51:20 - INFO - ——————————————————————————————
# 2025-03-11 16:51:28 - INFO - 轮次 10/100, 训练损失: 0.4618, 训练准确率: 0.7385, 类别0/1: 0.6567/0.8324, 训练F1: 0.7420, 训练精确率: 0.7523, 训练召回率: 0.7439, 训练特异性: 0.6567, 训练MCC: 0.4965, 训练归一化MCC: 0.7482, 验证损失: 0.8965, 验证准确率: 0.3701, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.001000
# 2025-03-11 16:51:28 - INFO - 本轮用时: 7.86 秒
# 2025-03-11 16:51:28 - INFO - ——————————————————————————————
# 2025-03-11 16:51:36 - INFO - 轮次 11/100, 训练损失: 0.5209, 训练准确率: 0.6870, 类别0/1: 0.5834/0.7867, 训练F1: 0.6810, 训练精确率: 0.6931, 训练召回率: 0.6842, 训练特异性: 0.5834, 训练MCC: 0.3778, 训练归一化MCC: 0.6889, 验证损失: 0.8156, 验证准确率: 0.3799, 类别0/1: 0.0060/0.9899, 验证F1: 0.2102, 验证精确率: 0.4525, 验证召回率: 0.3741, 验证特异性: 0.0060, 验证MCC: -0.0227, 验证归一化MCC: 0.4887, 学习率: 0.001000
# 2025-03-11 16:51:36 - INFO - 本轮用时: 7.93 秒
# 2025-03-11 16:51:36 - INFO - ——————————————————————————————
# 2025-03-11 16:51:44 - INFO - 轮次 12/100, 训练损失: 0.3907, 训练准确率: 0.7909, 类别0/1: 0.7116/0.8642, 训练F1: 0.7864, 训练精确率: 0.7947, 训练召回率: 0.7876, 训练特异性: 0.7116, 训练MCC: 0.5824, 训练归一化MCC: 0.7912, 验证损失: 0.8285, 验证准确率: 0.3663, 类别0/1: 0.0090/0.9899, 验证F1: 0.2141, 验证精确率: 0.5154, 验证召回率: 0.3759, 验证特异性: 0.0090, 验证MCC: -0.0052, 验证归一化MCC: 0.4974, 学习率: 0.001000
# 2025-03-11 16:51:44 - INFO - 本轮用时: 7.82 秒
# 2025-03-11 16:51:44 - INFO - ——————————————————————————————
# 2025-03-11 16:51:51 - INFO - 轮次 13/100, 训练损失: 0.3554, 训练准确率: 0.8171, 类别0/1: 0.7488/0.8870, 训练F1: 0.8164, 训练精确率: 0.8240, 训练召回率: 0.8172, 训练特异性: 0.7488, 训练MCC: 0.6414, 训练归一化MCC: 0.8207, 验证损失: 1.5513, 验证准确率: 0.3799, 类别0/1: 0.0060/0.9899, 验证F1: 0.2102, 验证精确率: 0.4525, 验证召回率: 0.3741, 验证特异性: 0.0060, 验证MCC: -0.0227, 验证归一化MCC: 0.4887, 学习率: 0.001000
# 2025-03-11 16:51:51 - INFO - 本轮用时: 6.85 秒
# 2025-03-11 16:51:51 - INFO - ——————————————————————————————
# 2025-03-11 16:51:58 - INFO - 轮次 14/100, 训练损失: 0.4501, 训练准确率: 0.7482, 类别0/1: 0.6207/0.8749, 训练F1: 0.7427, 训练精确率: 0.7649, 训练召回率: 0.7467, 训练特异性: 0.6207, 训练MCC: 0.5118, 训练归一化MCC: 0.7559, 验证损失: 0.8988, 验证准确率: 0.3701, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.001000
# 2025-03-11 16:51:58 - INFO - 本轮用时: 6.98 秒
# 2025-03-11 16:51:58 - INFO - ——————————————————————————————
# c:\Users\USTC\anaconda3\envs\gpupytorch\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2025-03-11 16:52:04 - INFO - 轮次 15/100, 训练损失: 0.4106, 训练准确率: 0.7656, 类别0/1: 0.6689/0.8719, 训练F1: 0.7678, 训练精确率: 0.7820, 训练召回率: 0.7702, 训练特异性: 0.6689, 训练MCC: 0.5522, 训练归一化MCC: 0.7761, 验证损失: 0.9462, 验证准确率: 0.3799, 类别0/1: 0.0000/1.0000, 验证F1: 0.2037, 验证精确率: 0.1399, 验证召回率: 0.3741, 验证特异性: 0.0000, 验证MCC: 0.0000, 验证归一化MCC: 0.5000, 学习率: 0.001000
# 2025-03-11 16:52:04 - INFO - 本轮用时: 6.86 秒
# 2025-03-11 16:52:04 - INFO - ——————————————————————————————
# 2025-03-11 16:52:12 - INFO - 轮次 16/100, 训练损失: 0.4103, 训练准确率: 0.7661, 类别0/1: 0.6519/0.8852, 训练F1: 0.7635, 训练精确率: 0.7839, 训练召回率: 0.7664, 训练特异性: 0.6519, 训练MCC: 0.5509, 训练归一化MCC: 0.7755, 验证损失: 0.8888, 验证准确率: 0.3816, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.001000
# 2025-03-11 16:52:12 - INFO - 本轮用时: 7.28 秒
# 2025-03-11 16:52:12 - INFO - ——————————————————————————————
# c:\Users\USTC\anaconda3\envs\gpupytorch\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2025-03-11 16:52:19 - INFO - 轮次 17/100, 训练损失: 0.3846, 训练准确率: 0.7960, 类别0/1: 0.6763/0.9138, 训练F1: 0.7913, 训练精确率: 0.8126, 训练召回率: 0.7942, 训练特异性: 0.6763, 训练MCC: 0.6068, 训练归一化MCC: 0.8034, 验证损失: 1.0059, 验证准确率: 0.3722, 类别0/1: 0.0000/1.0000, 验证F1: 0.2037, 验证精确率: 0.1399, 验证召回率: 0.3741, 验证特异性: 0.0000, 验证MCC: 0.0000, 验证归一化MCC: 0.5000, 学习率: 0.001000
# 2025-03-11 16:52:19 - INFO - 本轮用时: 7.72 秒
# 2025-03-11 16:52:19 - INFO - ——————————————————————————————
# 2025-03-11 16:52:27 - INFO - 轮次 18/100, 训练损失: 0.3643, 训练准确率: 0.8111, 类别0/1: 0.7157/0.8978, 训练F1: 0.8091, 训练精确率: 0.8182, 训练召回率: 0.8111, 训练特异性: 0.7157, 训练MCC: 0.6269, 训练归一化MCC: 0.8135, 验证损失: 1.0318, 验证准确率: 0.3701, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.001000
# 2025-03-11 16:52:27 - INFO - 本轮用时: 7.87 秒
# 2025-03-11 16:52:27 - INFO - ——————————————————————————————
# 2025-03-11 16:52:35 - INFO - 轮次 19/100, 训练损失: 0.3827, 训练准确率: 0.7812, 类别0/1: 0.6395/0.9190, 训练F1: 0.7760, 训练精确率: 0.8031, 训练召回率: 0.7805, 训练特异性: 0.6395, 训练MCC: 0.5826, 训练归一化MCC: 0.7913, 验证损失: 1.0169, 验证准确率: 0.3663, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.001000
# 2025-03-11 16:52:35 - INFO - 本轮用时: 7.35 秒
# 2025-03-11 16:52:35 - INFO - ——————————————————————————————
# 2025-03-11 16:52:42 - INFO - 轮次 20/100, 训练损失: 0.3571, 训练准确率: 0.8084, 类别0/1: 0.7521/0.8639, 训练F1: 0.8064, 训练精确率: 0.8117, 训练召回率: 0.8069, 训练特异性: 0.7521, 训练MCC: 0.6189, 训练归一化MCC: 0.8094, 验证损失: 1.3606, 验证准确率: 0.3722, 类别0/1: 0.0060/0.9899, 验证F1: 0.2102, 验证精确率: 0.4525, 验证召回率: 0.3741, 验证特异性: 0.0060, 验证MCC: -0.0227, 验证归一化MCC: 0.4887, 学习率: 0.000100
# 2025-03-11 16:52:42 - INFO - 本轮用时: 7.35 秒
# 2025-03-11 16:52:42 - INFO - ——————————————————————————————
# 2025-03-11 16:52:52 - INFO - 轮次 21/100, 训练损失: 0.3762, 训练准确率: 0.7748, 类别0/1: 0.6538/0.8889, 训练F1: 0.7680, 训练精确率: 0.7872, 训练召回率: 0.7711, 训练特异性: 0.6538, 训练MCC: 0.5582, 训练归一化MCC: 0.7791, 验证损失: 1.0815, 验证准确率: 0.3663, 类别0/1: 0.0090/0.9899, 验证F1: 0.2141, 验证精确率: 0.5154, 验证召回率: 0.3759, 验证特异性: 0.0090, 验证MCC: -0.0052, 验证归一化MCC: 0.4974, 学习率: 0.000100
# 2025-03-11 16:52:52 - INFO - 本轮用时: 9.85 秒
# 2025-03-11 16:52:52 - INFO - ——————————————————————————————
# 2025-03-11 16:53:02 - INFO - 轮次 22/100, 训练损失: 0.3392, 训练准确率: 0.8006, 类别0/1: 0.6888/0.9100, 训练F1: 0.7952, 训练精确率: 0.8146, 训练召回率: 0.7975, 训练特异性: 0.6888, 训练MCC: 0.6125, 训练归一化MCC: 0.8063, 验证损失: 0.9994, 验证准确率: 0.3854, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000100
# 2025-03-11 16:53:02 - INFO - 本轮用时: 9.82 秒
# 2025-03-11 16:53:02 - INFO - ——————————————————————————————
# 2025-03-11 16:53:11 - INFO - 轮次 23/100, 训练损失: 0.3281, 训练准确率: 0.8111, 类别0/1: 0.7189/0.9070, 训练F1: 0.8096, 训练精确率: 0.8241, 训练召回率: 0.8111, 训练特异性: 0.7189, 训练MCC: 0.6357, 训练归一化MCC: 0.8178, 验证损失: 0.9274, 验证准确率: 0.3816, 类别0/1: 0.0090/0.9899, 验证F1: 0.2141, 验证精确率: 0.5154, 验证召回率: 0.3759, 验证特异性: 0.0090, 验证MCC: -0.0052, 验证归一化MCC: 0.4974, 学习率: 0.000100
# 2025-03-11 16:53:11 - INFO - 本轮用时: 9.13 秒
# 2025-03-11 16:53:11 - INFO - ——————————————————————————————
# 2025-03-11 16:53:19 - INFO - 轮次 24/100, 训练损失: 0.3040, 训练准确率: 0.8249, 类别0/1: 0.7323/0.9164, 训练F1: 0.8211, 训练精确率: 0.8353, 训练召回率: 0.8224, 训练特异性: 0.7323, 训练MCC: 0.6582, 训练归一化MCC: 0.8291, 验证损失: 0.9449, 验证准确率: 0.3663, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000100
# 2025-03-11 16:53:19 - INFO - 本轮用时: 7.98 秒
# 2025-03-11 16:53:19 - INFO - ——————————————————————————————
# 2025-03-11 16:53:26 - INFO - 轮次 25/100, 训练损失: 0.3518, 训练准确率: 0.7918, 类别0/1: 0.7013/0.8827, 训练F1: 0.7885, 训练精确率: 0.8017, 训练召回率: 0.7899, 训练特异性: 0.7013, 训练MCC: 0.5923, 训练归一化MCC: 0.7961, 验证损失: 0.8700, 验证准确率: 0.3625, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000100
# 2025-03-11 16:53:26 - INFO - 本轮用时: 7.01 秒
# 2025-03-11 16:53:26 - INFO - ——————————————————————————————
# 2025-03-11 16:53:32 - INFO - 轮次 26/100, 训练损失: 0.3353, 训练准确率: 0.8097, 类别0/1: 0.7208/0.8995, 训练F1: 0.8057, 训练精确率: 0.8199, 训练召回率: 0.8069, 训练特异性: 0.7208, 训练MCC: 0.6275, 训练归一化MCC: 0.8138, 验证损失: 0.8361, 验证准确率: 0.3778, 类别0/1: 0.0090/0.9899, 验证F1: 0.2141, 验证精确率: 0.5154, 验证召回率: 0.3759, 验证特异性: 0.0090, 验证MCC: -0.0052, 验证归一化MCC: 0.4974, 学习率: 0.000100
# 2025-03-11 16:53:32 - INFO - 本轮用时: 6.62 秒
# 2025-03-11 16:53:32 - INFO - ——————————————————————————————
# 2025-03-11 16:53:38 - INFO - 轮次 27/100, 训练损失: 0.3289, 训练准确率: 0.7960, 类别0/1: 0.6983/0.8872, 训练F1: 0.7909, 训练精确率: 0.8036, 训练召回率: 0.7928, 训练特异性: 0.6983, 训练MCC: 0.5963, 训练归一化MCC: 0.7981, 验证损失: 0.9544, 验证准确率: 0.3760, 类别0/1: 0.0060/0.9899, 验证F1: 0.2102, 验证精确率: 0.4525, 验证召回率: 0.3741, 验证特异性: 0.0060, 验证MCC: -0.0227, 验证归一化MCC: 0.4887, 学习率: 0.000100
# 2025-03-11 16:53:38 - INFO - 本轮用时: 5.45 秒
# 2025-03-11 16:53:38 - INFO - ——————————————————————————————
# 2025-03-11 16:53:43 - INFO - 轮次 28/100, 训练损失: 0.2935, 训练准确率: 0.8373, 类别0/1: 0.7530/0.9220, 训练F1: 0.8354, 训练精确率: 0.8471, 训练召回率: 0.8365, 训练特异性: 0.7530, 训练MCC: 0.6838, 训练归一化MCC: 0.8419, 验证损失: 0.9823, 验证准确率: 0.3740, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000100
# 2025-03-11 16:53:43 - INFO - 本轮用时: 5.59 秒
# 2025-03-11 16:53:43 - INFO - ——————————————————————————————
# 2025-03-11 16:53:49 - INFO - 轮次 29/100, 训练损失: 0.2341, 训练准确率: 0.8796, 类别0/1: 0.8234/0.9282, 训练F1: 0.8764, 训练精确率: 0.8804, 训练召回率: 0.8769, 训练特异性: 0.8234, 训练MCC: 0.7569, 训练归一化MCC: 0.8785, 验证损失: 1.1191, 验证准确率: 0.3816, 类别0/1: 0.0090/0.9899, 验证F1: 0.2141, 验证精确率: 0.5154, 验证召回率: 0.3759, 验证特异性: 0.0090, 验证MCC: -0.0052, 验证归一化MCC: 0.4974, 学习率: 0.000100
# 2025-03-11 16:53:49 - INFO - 本轮用时: 5.47 秒
# 2025-03-11 16:53:49 - INFO - ——————————————————————————————
# 2025-03-11 16:53:54 - INFO - 轮次 30/100, 训练损失: 0.2690, 训练准确率: 0.8516, 类别0/1: 0.7666/0.9350, 训练F1: 0.8474, 训练精确率: 0.8603, 训练召回率: 0.8482, 训练特异性: 0.7666, 训练MCC: 0.7090, 训练归一化MCC: 0.8545, 验证损失: 1.1818, 验证准确率: 0.3816, 类别0/1: 0.0090/0.9899, 验证F1: 0.2141, 验证精确率: 0.5154, 验证召回率: 0.3759, 验证特异性: 0.0090, 验证MCC: -0.0052, 验证归一化MCC: 0.4974, 学习率: 0.000100
# 2025-03-11 16:53:54 - INFO - 本轮用时: 5.49 秒
# 2025-03-11 16:53:54 - INFO - ——————————————————————————————
# 2025-03-11 16:54:00 - INFO - 轮次 31/100, 训练损失: 0.3137, 训练准确率: 0.8166, 类别0/1: 0.7348/0.9194, 训练F1: 0.8239, 训练精确率: 0.8382, 训练召回率: 0.8252, 训练特异性: 0.7348, 训练MCC: 0.6638, 训练归一化MCC: 0.8319, 验证损失: 0.8430, 验证准确率: 0.3816, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000010
# 2025-03-11 16:54:00 - INFO - 本轮用时: 5.41 秒
# 2025-03-11 16:54:00 - INFO - ——————————————————————————————
# 2025-03-11 16:54:05 - INFO - 轮次 32/100, 训练损失: 0.3487, 训练准确率: 0.7831, 类别0/1: 0.6757/0.8960, 训练F1: 0.7827, 训练精确率: 0.8004, 训练召回率: 0.7852, 训练特异性: 0.6757, 训练MCC: 0.5857, 训练归一化MCC: 0.7928, 验证损失: 0.8298, 验证准确率: 0.3854, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000010
# 2025-03-11 16:54:05 - INFO - 本轮用时: 5.46 秒
# 2025-03-11 16:54:05 - INFO - ——————————————————————————————
# 2025-03-11 16:54:12 - INFO - 轮次 33/100, 训练损失: 0.2454, 训练准确率: 0.8690, 类别0/1: 0.8098/0.9197, 训练F1: 0.8682, 训练精确率: 0.8710, 训练召回率: 0.8689, 训练特异性: 0.8098, 训练MCC: 0.7375, 训练归一化MCC: 0.8687, 验证损失: 1.0552, 验证准确率: 0.3816, 类别0/1: 0.0090/0.9899, 验证F1: 0.2141, 验证精确率: 0.5154, 验证召回率: 0.3759, 验证特异性: 0.0090, 验证MCC: -0.0052, 验证归一化MCC: 0.4974, 学习率: 0.000010
# 2025-03-11 16:54:12 - INFO - 本轮用时: 7.13 秒
# 2025-03-11 16:54:12 - INFO - ——————————————————————————————
# 2025-03-11 16:54:19 - INFO - 轮次 34/100, 训练损失: 0.2981, 训练准确率: 0.8231, 类别0/1: 0.7289/0.9262, 训练F1: 0.8209, 训练精确率: 0.8397, 训练召回率: 0.8219, 训练特异性: 0.7289, 训练MCC: 0.6625, 训练归一化MCC: 0.8313, 验证损失: 1.1060, 验证准确率: 0.3740, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000010
# 2025-03-11 16:54:19 - INFO - 本轮用时: 7.12 秒
# 2025-03-11 16:54:19 - INFO - ——————————————————————————————
# 2025-03-11 16:54:26 - INFO - 轮次 35/100, 训练损失: 0.2638, 训练准确率: 0.8539, 类别0/1: 0.7850/0.9352, 训练F1: 0.8583, 训练精确率: 0.8680, 训练召回率: 0.8590, 训练特异性: 0.7850, 训练MCC: 0.7273, 训练归一化MCC: 0.8636, 验证损失: 1.0758, 验证准确率: 0.3701, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000010
# 2025-03-11 16:54:26 - INFO - 本轮用时: 6.93 秒
# 2025-03-11 16:54:26 - INFO - ——————————————————————————————
# 2025-03-11 16:54:33 - INFO - 轮次 36/100, 训练损失: 0.3466, 训练准确率: 0.7877, 类别0/1: 0.6841/0.8970, 训练F1: 0.7876, 训练精确率: 0.8043, 训练召回率: 0.7899, 训练特异性: 0.6841, 训练MCC: 0.5943, 训练归一化MCC: 0.7971, 验证损失: 1.0748, 验证准确率: 0.3816, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000010
# 2025-03-11 16:54:33 - INFO - 本轮用时: 6.49 秒
# 2025-03-11 16:54:33 - INFO - ——————————————————————————————
# 2025-03-11 16:54:40 - INFO - 轮次 37/100, 训练损失: 0.2842, 训练准确率: 0.8355, 类别0/1: 0.7575/0.9139, 训练F1: 0.8350, 训练精确率: 0.8442, 训练召回率: 0.8360, 训练特异性: 0.7575, 训练MCC: 0.6800, 训练归一化MCC: 0.8400, 验证损失: 1.0229, 验证准确率: 0.3816, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000010
# 2025-03-11 16:54:40 - INFO - 本轮用时: 6.73 秒
# 2025-03-11 16:54:40 - INFO - ——————————————————————————————
# 2025-03-11 16:54:46 - INFO - 轮次 38/100, 训练损失: 0.2266, 训练准确率: 0.8722, 类别0/1: 0.8248/0.9182, 训练F1: 0.8731, 训练精确率: 0.8757, 训练召回率: 0.8736, 训练特异性: 0.8248, 训练MCC: 0.7483, 训练归一化MCC: 0.8741, 验证损失: 1.2121, 验证准确率: 0.3663, 类别0/1: 0.0090/0.9899, 验证F1: 0.2141, 验证精确率: 0.5154, 验证召回率: 0.3759, 验证特异性: 0.0090, 验证MCC: -0.0052, 验证归一化MCC: 0.4974, 学习率: 0.000010
# 2025-03-11 16:54:46 - INFO - 本轮用时: 6.42 秒
# 2025-03-11 16:54:46 - INFO - ——————————————————————————————
# 2025-03-11 16:54:53 - INFO - 轮次 39/100, 训练损失: 0.2892, 训练准确率: 0.8323, 类别0/1: 0.7490/0.9111, 训练F1: 0.8300, 训练精确率: 0.8393, 训练召回率: 0.8313, 训练特异性: 0.7490, 训练MCC: 0.6701, 训练归一化MCC: 0.8350, 验证损失: 0.8842, 验证准确率: 0.3778, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000010
# 2025-03-11 16:54:53 - INFO - 本轮用时: 6.82 秒
# 2025-03-11 16:54:53 - INFO - ——————————————————————————————
# 2025-03-11 16:54:59 - INFO - 轮次 40/100, 训练损失: 0.2996, 训练准确率: 0.8217, 类别0/1: 0.7310/0.9155, 训练F1: 0.8218, 训练精确率: 0.8346, 训练召回率: 0.8233, 训练特异性: 0.7310, 训练MCC: 0.6578, 训练归一化MCC: 0.8289, 验证损失: 1.0565, 验证准确率: 0.3816, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000010
# 2025-03-11 16:54:59 - INFO - 本轮用时: 6.26 秒
# 2025-03-11 16:54:59 - INFO - ——————————————————————————————
# 2025-03-11 16:55:06 - INFO - 轮次 41/100, 训练损失: 0.2848, 训练准确率: 0.8263, 类别0/1: 0.7303/0.9249, 训练F1: 0.8238, 训练精确率: 0.8399, 训练召回率: 0.8252, 训练特异性: 0.7303, 训练MCC: 0.6656, 训练归一化MCC: 0.8328, 验证损失: 1.0154, 验证准确率: 0.3854, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000010
# 2025-03-11 16:55:06 - INFO - 本轮用时: 6.54 秒
# 2025-03-11 16:55:06 - INFO - ——————————————————————————————
# 2025-03-11 16:55:12 - INFO - 轮次 42/100, 训练损失: 0.3247, 训练准确率: 0.8047, 类别0/1: 0.6901/0.9140, 训练F1: 0.7980, 训练精确率: 0.8177, 训练召回率: 0.8003, 训练特异性: 0.6901, 训练MCC: 0.6184, 训练归一化MCC: 0.8092, 验证损失: 0.8408, 验证准确率: 0.3701, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000001
# 2025-03-11 16:55:12 - INFO - 本轮用时: 6.56 秒
# 2025-03-11 16:55:12 - INFO - ——————————————————————————————
# 2025-03-11 16:55:19 - INFO - 轮次 43/100, 训练损失: 0.2606, 训练准确率: 0.8488, 类别0/1: 0.7757/0.9231, 训练F1: 0.8463, 训练精确率: 0.8564, 训练召回率: 0.8468, 训练特异性: 0.7757, 训练MCC: 0.7037, 训练归一化MCC: 0.8518, 验证损失: 1.0885, 验证准确率: 0.3701, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000001
# 2025-03-11 16:55:19 - INFO - 本轮用时: 6.37 秒
# 2025-03-11 16:55:19 - INFO - ——————————————————————————————
# 2025-03-11 16:55:25 - INFO - 轮次 44/100, 训练损失: 0.2697, 训练准确率: 0.8424, 类别0/1: 0.7624/0.9160, 训练F1: 0.8379, 训练精确率: 0.8473, 训练召回率: 0.8388, 训练特异性: 0.7624, 训练MCC: 0.6861, 训练归一化MCC: 0.8431, 验证损失: 0.9829, 验证准确率: 0.3816, 类别0/1: 0.0090/0.9899, 验证F1: 0.2141, 验证精确率: 0.5154, 验证召回率: 0.3759, 验证特异性: 0.0090, 验证MCC: -0.0052, 验证归一化MCC: 0.4974, 学习率: 0.000001
# 2025-03-11 16:55:25 - INFO - 本轮用时: 6.29 秒
# 2025-03-11 16:55:25 - INFO - ——————————————————————————————
# 2025-03-11 16:55:32 - INFO - 轮次 45/100, 训练损失: 0.3297, 训练准确率: 0.7941, 类别0/1: 0.6796/0.9184, 训练F1: 0.7939, 训练精确率: 0.8167, 训练召回率: 0.7965, 训练特异性: 0.6796, 训练MCC: 0.6138, 训练归一化MCC: 0.8069, 验证损失: 0.9499, 验证准确率: 0.3778, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000001
# 2025-03-11 16:55:32 - INFO - 本轮用时: 6.81 秒
# 2025-03-11 16:55:32 - INFO - ——————————————————————————————
# 2025-03-11 16:55:38 - INFO - 轮次 46/100, 训练损失: 0.2963, 训练准确率: 0.8125, 类别0/1: 0.7432/0.9039, 训练F1: 0.8201, 训练精确率: 0.8316, 训练召回率: 0.8210, 训练特异性: 0.7432, 训练MCC: 0.6532, 训练归一化MCC: 0.8266, 验证损失: 0.9389, 验证准确率: 0.3625, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000001
# 2025-03-11 16:55:38 - INFO - 本轮用时: 6.66 秒
# 2025-03-11 16:55:38 - INFO - ——————————————————————————————
# 2025-03-11 16:55:46 - INFO - 轮次 47/100, 训练损失: 0.3263, 训练准确率: 0.7950, 类别0/1: 0.6809/0.9093, 训练F1: 0.7907, 训练精确率: 0.8111, 训练召回率: 0.7932, 训练特异性: 0.6809, 训练MCC: 0.6047, 训练归一化MCC: 0.8024, 验证损失: 0.8374, 验证准确率: 0.3816, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000001
# 2025-03-11 16:55:46 - INFO - 本轮用时: 7.24 秒
# 2025-03-11 16:55:46 - INFO - ——————————————————————————————
# 2025-03-11 16:55:53 - INFO - 轮次 48/100, 训练损失: 0.3167, 训练准确率: 0.8019, 类别0/1: 0.6867/0.9120, 训练F1: 0.7951, 训练精确率: 0.8151, 训练召回率: 0.7975, 训练特异性: 0.6867, 训练MCC: 0.6130, 训练归一化MCC: 0.8065, 验证损失: 0.9438, 验证准确率: 0.3816, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000001
# 2025-03-11 16:55:53 - INFO - 本轮用时: 7.20 秒
# 2025-03-11 16:55:53 - INFO - ——————————————————————————————
# 2025-03-11 16:56:00 - INFO - 轮次 49/100, 训练损失: 0.2564, 训练准确率: 0.8502, 类别0/1: 0.7759/0.9259, 训练F1: 0.8477, 训练精确率: 0.8582, 训练召回率: 0.8482, 训练特异性: 0.7759, 训练MCC: 0.7069, 训练归一化MCC: 0.8534, 验证损失: 1.1291, 验证准确率: 0.3740, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000001
# 2025-03-11 16:56:00 - INFO - 本轮用时: 7.31 秒
# 2025-03-11 16:56:00 - INFO - ——————————————————————————————
# 2025-03-11 16:56:09 - INFO - 轮次 50/100, 训练损失: 0.3176, 训练准确率: 0.8056, 类别0/1: 0.6987/0.9071, 训练F1: 0.8017, 训练精确率: 0.8168, 训练召回率: 0.8040, 训练特异性: 0.6987, 训练MCC: 0.6202, 训练归一化MCC: 0.8101, 验证损失: 0.9171, 验证准确率: 0.3549, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000001
# 2025-03-11 16:56:09 - INFO - 本轮用时: 9.13 秒
# 2025-03-11 16:56:09 - INFO - ——————————————————————————————
# 2025-03-11 16:56:18 - INFO - 轮次 51/100, 训练损失: 0.2648, 训练准确率: 0.8552, 类别0/1: 0.7933/0.9061, 训练F1: 0.8513, 训练精确率: 0.8550, 训练召回率: 0.8520, 训练特异性: 0.7933, 训练MCC: 0.7059, 训练归一化MCC: 0.8529, 验证损失: 1.0706, 验证准确率: 0.3701, 类别0/1: 0.0090/0.9899, 验证F1: 0.2141, 验证精确率: 0.5154, 验证召回率: 0.3759, 验证特异性: 0.0090, 验证MCC: -0.0052, 验证归一化MCC: 0.4974, 学习率: 0.000001
# 2025-03-11 16:56:18 - INFO - 本轮用时: 8.88 秒
# 2025-03-11 16:56:18 - INFO - ——————————————————————————————
# 2025-03-11 16:56:27 - INFO - 轮次 52/100, 训练损失: 0.2456, 训练准确率: 0.8676, 类别0/1: 0.8107/0.9229, 训练F1: 0.8670, 训练精确率: 0.8717, 训练召回率: 0.8675, 训练特异性: 0.8107, 训练MCC: 0.7390, 训练归一化MCC: 0.8695, 验证损失: 1.0339, 验证准确率: 0.3778, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000001
# 2025-03-11 16:56:27 - INFO - 本轮用时: 8.48 秒
# 2025-03-11 16:56:27 - INFO - ——————————————————————————————
# 2025-03-11 16:56:37 - INFO - 轮次 53/100, 训练损失: 0.2273, 训练准确率: 0.8782, 类别0/1: 0.8175/0.9493, 训练F1: 0.8796, 训练精确率: 0.8887, 训练召回率: 0.8797, 训练特异性: 0.8175, 训练MCC: 0.7686, 训练归一化MCC: 0.8843, 验证损失: 1.0222, 验证准确率: 0.3740, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000001
# 2025-03-11 16:56:37 - INFO - 本轮用时: 10.15 秒
# 2025-03-11 16:56:37 - INFO - ——————————————————————————————
# 2025-03-11 16:56:46 - INFO - 轮次 54/100, 训练损失: 0.2677, 训练准确率: 0.8392, 类别0/1: 0.7445/0.9302, 训练F1: 0.8368, 训练精确率: 0.8497, 训练召回率: 0.8383, 训练特异性: 0.7445, 训练MCC: 0.6876, 训练归一化MCC: 0.8438, 验证损失: 1.3399, 验证准确率: 0.3701, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000001
# 2025-03-11 16:56:46 - INFO - 本轮用时: 9.70 秒
# 2025-03-11 16:56:46 - INFO - ——————————————————————————————
# 2025-03-11 16:56:56 - INFO - 轮次 55/100, 训练损失: 0.3103, 训练准确率: 0.8148, 类别0/1: 0.7076/0.9184, 训练F1: 0.8100, 训练精确率: 0.8274, 训练召回率: 0.8120, 训练特异性: 0.7076, 训练MCC: 0.6396, 训练归一化MCC: 0.8198, 验证损失: 1.1783, 验证准确率: 0.3740, 类别0/1: 0.0090/0.9899, 验证F1: 0.2141, 验证精确率: 0.5154, 验证召回率: 0.3759, 验证特异性: 0.0090, 验证MCC: -0.0052, 验证归一化MCC: 0.4974, 学习率: 0.000001
# 2025-03-11 16:56:56 - INFO - 本轮用时: 9.27 秒
# 2025-03-11 16:56:56 - INFO - ——————————————————————————————
# 2025-03-11 16:57:05 - INFO - 轮次 56/100, 训练损失: 0.2901, 训练准确率: 0.8327, 类别0/1: 0.7488/0.9196, 训练F1: 0.8333, 训练精确率: 0.8443, 训练召回率: 0.8346, 训练特异性: 0.7488, 训练MCC: 0.6787, 训练归一化MCC: 0.8394, 验证损失: 1.1472, 验证准确率: 0.3587, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000001
# 2025-03-11 16:57:05 - INFO - 本轮用时: 9.61 秒
# 2025-03-11 16:57:05 - INFO - ——————————————————————————————
# 2025-03-11 16:57:14 - INFO - 轮次 57/100, 训练损失: 0.3111, 训练准确率: 0.8130, 类别0/1: 0.7279/0.8938, 训练F1: 0.8089, 训练精确率: 0.8195, 训练召回率: 0.8102, 训练特异性: 0.7279, 训练MCC: 0.6299, 训练归一化MCC: 0.8149, 验证损失: 1.1639, 验证准确率: 0.3778, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000001
# 2025-03-11 16:57:14 - INFO - 本轮用时: 8.69 秒
# 2025-03-11 16:57:14 - INFO - ——————————————————————————————
# 2025-03-11 16:57:22 - INFO - 轮次 58/100, 训练损失: 0.3341, 训练准确率: 0.7863, 类别0/1: 0.6905/0.8894, 训练F1: 0.7866, 训练精确率: 0.8017, 训练召回率: 0.7885, 训练特异性: 0.6905, 训练MCC: 0.5907, 训练归一化MCC: 0.7953, 验证损失: 1.0303, 验证准确率: 0.3892, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000001
# 2025-03-11 16:57:22 - INFO - 本轮用时: 7.51 秒
# 2025-03-11 16:57:22 - INFO - ——————————————————————————————
# 2025-03-11 16:57:29 - INFO - 轮次 59/100, 训练损失: 0.2995, 训练准确率: 0.8180, 类别0/1: 0.7233/0.9245, 训练F1: 0.8195, 训练精确率: 0.8369, 训练召回率: 0.8210, 训练特异性: 0.7233, 训练MCC: 0.6585, 训练归一化MCC: 0.8293, 验证损失: 0.9909, 验证准确率: 0.3969, 类别0/1: 0.0090/0.9899, 验证F1: 0.2141, 验证精确率: 0.5154, 验证召回率: 0.3759, 验证特异性: 0.0090, 验证MCC: -0.0052, 验证归一化MCC: 0.4974, 学习率: 0.000001
# 2025-03-11 16:57:29 - INFO - 本轮用时: 7.39 秒
# 2025-03-11 16:57:29 - INFO - ——————————————————————————————
# 2025-03-11 16:57:36 - INFO - 轮次 60/100, 训练损失: 0.2368, 训练准确率: 0.8681, 类别0/1: 0.8007/0.9326, 训练F1: 0.8647, 训练精确率: 0.8726, 训练召回率: 0.8651, 训练特异性: 0.8007, 训练MCC: 0.7380, 训练归一化MCC: 0.8690, 验证损失: 1.0235, 验证准确率: 0.3625, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000001
# 2025-03-11 16:57:36 - INFO - 本轮用时: 6.98 秒
# 2025-03-11 16:57:36 - INFO - ——————————————————————————————
# 2025-03-11 16:57:43 - INFO - 轮次 61/100, 训练损失: 0.2932, 训练准确率: 0.8194, 类别0/1: 0.7197/0.9107, 训练F1: 0.8161, 训练精确率: 0.8278, 训练召回率: 0.8181, 训练特异性: 0.7197, 训练MCC: 0.6445, 训练归一化MCC: 0.8222, 验证损失: 0.8112, 验证准确率: 0.3816, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000001
# 2025-03-11 16:57:43 - INFO - 本轮用时: 7.48 秒
# 2025-03-11 16:57:43 - INFO - ——————————————————————————————
# 2025-03-11 16:57:51 - INFO - 轮次 62/100, 训练损失: 0.2841, 训练准确率: 0.8263, 类别0/1: 0.7305/0.9200, 训练F1: 0.8236, 训练精确率: 0.8374, 训练召回率: 0.8252, 训练特异性: 0.7305, 训练MCC: 0.6625, 训练归一化MCC: 0.8312, 验证损失: 0.8963, 验证准确率: 0.3816, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000001
# 2025-03-11 16:57:51 - INFO - 本轮用时: 7.14 秒
# 2025-03-11 16:57:51 - INFO - ——————————————————————————————
# 2025-03-11 16:57:58 - INFO - 轮次 63/100, 训练损失: 0.2988, 训练准确率: 0.8208, 类别0/1: 0.7193/0.9161, 训练F1: 0.8176, 训练精确率: 0.8309, 训练召回率: 0.8195, 训练特异性: 0.7193, 训练MCC: 0.6496, 训练归一化MCC: 0.8248, 验证损失: 0.8499, 验证准确率: 0.3722, 类别0/1: 0.0060/0.9899, 验证F1: 0.2102, 验证精确率: 0.4525, 验证召回率: 0.3741, 验证特异性: 0.0060, 验证MCC: -0.0227, 验证归一化MCC: 0.4887, 学习率: 0.000001
# 2025-03-11 16:57:58 - INFO - 本轮用时: 7.09 秒
# 2025-03-11 16:57:58 - INFO - ——————————————————————————————
# 2025-03-11 16:58:05 - INFO - 轮次 64/100, 训练损失: 0.2887, 训练准确率: 0.8341, 类别0/1: 0.7441/0.9146, 训练F1: 0.8316, 训练精确率: 0.8403, 训练召回率: 0.8332, 训练特异性: 0.7441, 训练MCC: 0.6716, 训练归一化MCC: 0.8358, 验证损失: 1.0961, 验证准确率: 0.3778, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000001
# 2025-03-11 16:58:05 - INFO - 本轮用时: 7.07 秒
# 2025-03-11 16:58:05 - INFO - ——————————————————————————————
# 2025-03-11 16:58:12 - INFO - 轮次 65/100, 训练损失: 0.3391, 训练准确率: 0.7748, 类别0/1: 0.6509/0.8972, 训练F1: 0.7693, 训练精确率: 0.7916, 训练召回率: 0.7726, 训练特异性: 0.6509, 训练MCC: 0.5645, 训练归一化MCC: 0.7823, 验证损失: 0.8139, 验证准确率: 0.3701, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000001
# 2025-03-11 16:58:12 - INFO - 本轮用时: 7.07 秒
# 2025-03-11 16:58:12 - INFO - ——————————————————————————————
# 2025-03-11 16:58:19 - INFO - 轮次 66/100, 训练损失: 0.3202, 训练准确率: 0.8088, 类别0/1: 0.7173/0.9029, 训练F1: 0.8098, 训练精确率: 0.8214, 训练召回率: 0.8116, 训练特异性: 0.7173, 训练MCC: 0.6323, 训练归一化MCC: 0.8161, 验证损失: 0.8523, 验证准确率: 0.3816, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000001
# 2025-03-11 16:58:19 - INFO - 本轮用时: 7.13 秒
# 2025-03-11 16:58:19 - INFO - ——————————————————————————————
# 2025-03-11 16:58:26 - INFO - 轮次 67/100, 训练损失: 0.3373, 训练准确率: 0.7973, 类别0/1: 0.6766/0.9098, 训练F1: 0.7925, 训练精确率: 0.8104, 训练召回率: 0.7956, 训练特异性: 0.6766, 训练MCC: 0.6047, 训练归一化MCC: 0.8023, 验证损失: 0.9307, 验证准确率: 0.3969, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000001
# 2025-03-11 16:58:26 - INFO - 本轮用时: 7.25 秒
# 2025-03-11 16:58:26 - INFO - ——————————————————————————————
# 2025-03-11 16:58:33 - INFO - 轮次 68/100, 训练损失: 0.2805, 训练准确率: 0.8359, 类别0/1: 0.7578/0.9119, 训练F1: 0.8340, 训练精确率: 0.8430, 训练召回率: 0.8351, 训练特异性: 0.7578, 训练MCC: 0.6780, 训练归一化MCC: 0.8390, 验证损失: 1.0708, 验证准确率: 0.3816, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000001
# 2025-03-11 16:58:33 - INFO - 本轮用时: 6.84 秒
# 2025-03-11 16:58:33 - INFO - ——————————————————————————————
# 2025-03-11 16:58:40 - INFO - 轮次 69/100, 训练损失: 0.2866, 训练准确率: 0.8336, 类别0/1: 0.7417/0.9237, 训练F1: 0.8301, 训练精确率: 0.8437, 训练召回率: 0.8313, 训练特异性: 0.7417, 训练MCC: 0.6753, 训练归一化MCC: 0.8377, 验证损失: 1.1636, 验证准确率: 0.3587, 类别0/1: 0.0090/0.9899, 验证F1: 0.2141, 验证精确率: 0.5154, 验证召回率: 0.3759, 验证特异性: 0.0090, 验证MCC: -0.0052, 验证归一化MCC: 0.4974, 学习率: 0.000001
# 2025-03-11 16:58:40 - INFO - 本轮用时: 6.74 秒
# 2025-03-11 16:58:40 - INFO - ——————————————————————————————
# 2025-03-11 16:58:46 - INFO - 轮次 70/100, 训练损失: 0.3166, 训练准确率: 0.8042, 类别0/1: 0.6948/0.9059, 训练F1: 0.7989, 训练精确率: 0.8145, 训练召回率: 0.8012, 训练特异性: 0.6948, 训练MCC: 0.6152, 训练归一化MCC: 0.8076, 验证损失: 0.9105, 验证准确率: 0.3701, 类别0/1: 0.0090/0.9899, 验证F1: 0.2141, 验证精确率: 0.5154, 验证召回率: 0.3759, 验证特异性: 0.0090, 验证MCC: -0.0052, 验证归一化MCC: 0.4974, 学习率: 0.000001
# 2025-03-11 16:58:46 - INFO - 本轮用时: 6.67 秒
# 2025-03-11 16:58:46 - INFO - ——————————————————————————————
# 2025-03-11 16:58:53 - INFO - 轮次 71/100, 训练损失: 0.2933, 训练准确率: 0.8199, 类别0/1: 0.7089/0.9168, 训练F1: 0.8134, 训练精确率: 0.8277, 训练召回率: 0.8158, 训练特异性: 0.7089, 训练MCC: 0.6420, 训练归一化MCC: 0.8210, 验证损失: 1.0433, 验证准确率: 0.3816, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000001
# 2025-03-11 16:58:53 - INFO - 本轮用时: 6.65 秒
# 2025-03-11 16:58:53 - INFO - ——————————————————————————————
# 2025-03-11 16:59:01 - INFO - 轮次 72/100, 训练损失: 0.2746, 训练准确率: 0.8442, 类别0/1: 0.7563/0.9255, 训练F1: 0.8396, 训练精确率: 0.8509, 训练召回率: 0.8407, 训练特异性: 0.7563, 训练MCC: 0.6916, 训练归一化MCC: 0.8458, 验证损失: 0.9973, 验证准确率: 0.3854, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000001
# 2025-03-11 16:59:01 - INFO - 本轮用时: 7.56 秒
# 2025-03-11 16:59:01 - INFO - ——————————————————————————————
# 2025-03-11 16:59:09 - INFO - 轮次 73/100, 训练损失: 0.2951, 训练准确率: 0.8295, 类别0/1: 0.7528/0.9204, 训练F1: 0.8357, 训练精确率: 0.8464, 训练召回率: 0.8369, 训练特异性: 0.7528, 训练MCC: 0.6832, 训练归一化MCC: 0.8416, 验证损失: 0.9629, 验证准确率: 0.3625, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000001
# 2025-03-11 16:59:09 - INFO - 本轮用时: 8.31 秒
# 2025-03-11 16:59:09 - INFO - ——————————————————————————————
# 2025-03-11 16:59:16 - INFO - 轮次 74/100, 训练损失: 0.3013, 训练准确率: 0.8171, 类别0/1: 0.7237/0.9209, 训练F1: 0.8173, 训练精确率: 0.8346, 训练召回率: 0.8186, 训练特异性: 0.7237, 训练MCC: 0.6540, 训练归一化MCC: 0.8270, 验证损失: 0.9175, 验证准确率: 0.3816, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000001
# 2025-03-11 16:59:16 - INFO - 本轮用时: 7.36 秒
# 2025-03-11 16:59:16 - INFO - ——————————————————————————————
# 2025-03-11 16:59:23 - INFO - 轮次 75/100, 训练损失: 0.3431, 训练准确率: 0.7941, 类别0/1: 0.6848/0.8955, 训练F1: 0.7910, 训练精确率: 0.8042, 训练召回率: 0.7937, 训练特异性: 0.6848, 训练MCC: 0.5960, 训练归一化MCC: 0.7980, 验证损失: 0.9926, 验证准确率: 0.3740, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000001
# 2025-03-11 16:59:23 - INFO - 本轮用时: 6.85 秒
# 2025-03-11 16:59:23 - INFO - ——————————————————————————————
# 2025-03-11 16:59:30 - INFO - 轮次 76/100, 训练损失: 0.2708, 训练准确率: 0.8511, 类别0/1: 0.7621/0.9276, 训练F1: 0.8477, 训练精确率: 0.8561, 训练召回率: 0.8492, 训练特异性: 0.7621, 训练MCC: 0.7032, 训练归一化MCC: 0.8516, 验证损失: 0.9295, 验证准确率: 0.3892, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000001
# 2025-03-11 16:59:30 - INFO - 本轮用时: 6.72 秒
# 2025-03-11 16:59:30 - INFO - ——————————————————————————————
# 2025-03-11 16:59:36 - INFO - 轮次 77/100, 训练损失: 0.2594, 训练准确率: 0.8585, 类别0/1: 0.8060/0.9149, 训练F1: 0.8630, 训练精确率: 0.8661, 训练召回率: 0.8637, 训练特异性: 0.8060, 训练MCC: 0.7281, 训练归一化MCC: 0.8640, 验证损失: 0.9707, 验证准确率: 0.3740, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000001
# 2025-03-11 16:59:36 - INFO - 本轮用时: 6.56 秒
# 2025-03-11 16:59:36 - INFO - ——————————————————————————————
# 2025-03-11 16:59:43 - INFO - 轮次 78/100, 训练损失: 0.2983, 训练准确率: 0.8199, 类别0/1: 0.7176/0.9327, 训练F1: 0.8223, 训练精确率: 0.8407, 训练召回率: 0.8242, 训练特异性: 0.7176, 训练MCC: 0.6651, 训练归一化MCC: 0.8325, 验证损失: 0.8347, 验证准确率: 0.3778, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000001
# 2025-03-11 16:59:43 - INFO - 本轮用时: 6.91 秒
# 2025-03-11 16:59:43 - INFO - ——————————————————————————————
# 2025-03-11 16:59:51 - INFO - 轮次 79/100, 训练损失: 0.3829, 训练准确率: 0.7583, 类别0/1: 0.6124/0.8910, 训练F1: 0.7490, 训练精确率: 0.7731, 训练召回率: 0.7542, 训练特异性: 0.6124, 训练MCC: 0.5256, 训练归一化MCC: 0.7628, 验证损失: 0.8748, 验证准确率: 0.3701, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000001
# 2025-03-11 16:59:51 - INFO - 本轮用时: 7.56 秒
# 2025-03-11 16:59:51 - INFO - ——————————————————————————————
# 2025-03-11 16:59:58 - INFO - 轮次 80/100, 训练损失: 0.3422, 训练准确率: 0.8061, 类别0/1: 0.6810/0.9132, 训练F1: 0.7985, 训练精确率: 0.8150, 训练召回率: 0.8017, 训练特异性: 0.6810, 训练MCC: 0.6142, 训练归一化MCC: 0.8071, 验证损失: 0.8218, 验证准确率: 0.3969, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000001
# 2025-03-11 16:59:58 - INFO - 本轮用时: 7.47 秒
# 2025-03-11 16:59:58 - INFO - ——————————————————————————————
# 2025-03-11 17:00:06 - INFO - 轮次 81/100, 训练损失: 0.3089, 训练准确率: 0.8171, 类别0/1: 0.7289/0.9102, 训练F1: 0.8160, 训练精确率: 0.8300, 训练召回率: 0.8172, 训练特异性: 0.7289, 训练MCC: 0.6478, 训练归一化MCC: 0.8239, 验证损失: 1.1443, 验证准确率: 0.3701, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000001
# 2025-03-11 17:00:06 - INFO - 本轮用时: 7.34 秒
# 2025-03-11 17:00:06 - INFO - ——————————————————————————————
# 2025-03-11 17:00:13 - INFO - 轮次 82/100, 训练损失: 0.3439, 训练准确率: 0.7881, 类别0/1: 0.6716/0.9025, 训练F1: 0.7834, 训练精确率: 0.8031, 训练召回率: 0.7862, 训练特异性: 0.6716, 训练MCC: 0.5894, 训练归一化MCC: 0.7947, 验证损失: 1.0194, 验证准确率: 0.3740, 类别0/1: 0.0090/0.9899, 验证F1: 0.2141, 验证精确率: 0.5154, 验证召回率: 0.3759, 验证特异性: 0.0090, 验证MCC: -0.0052, 验证归一化MCC: 0.4974, 学习率: 0.000001
# 2025-03-11 17:00:13 - INFO - 本轮用时: 7.15 秒
# 2025-03-11 17:00:13 - INFO - ——————————————————————————————
# 2025-03-11 17:00:20 - INFO - 轮次 83/100, 训练损失: 0.3213, 训练准确率: 0.8006, 类别0/1: 0.6952/0.9052, 训练F1: 0.7980, 训练精确率: 0.8140, 训练召回率: 0.8003, 训练特异性: 0.6952, 训练MCC: 0.6141, 训练归一化MCC: 0.8071, 验证损失: 0.9578, 验证准确率: 0.3816, 类别0/1: 0.0090/0.9899, 验证F1: 0.2141, 验证精确率: 0.5154, 验证召回率: 0.3759, 验证特异性: 0.0090, 验证MCC: -0.0052, 验证归一化MCC: 0.4974, 学习率: 0.000001
# 2025-03-11 17:00:20 - INFO - 本轮用时: 6.93 秒
# 2025-03-11 17:00:20 - INFO - ——————————————————————————————
# 2025-03-11 17:00:27 - INFO - 轮次 84/100, 训练损失: 0.2812, 训练准确率: 0.8346, 类别0/1: 0.7440/0.9171, 训练F1: 0.8308, 训练精确率: 0.8412, 训练召回率: 0.8322, 训练特异性: 0.7440, 训练MCC: 0.6727, 训练归一化MCC: 0.8363, 验证损失: 0.8799, 验证准确率: 0.3854, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000001
# 2025-03-11 17:00:27 - INFO - 本轮用时: 7.61 秒
# 2025-03-11 17:00:27 - INFO - ——————————————————————————————
# 2025-03-11 17:00:36 - INFO - 轮次 85/100, 训练损失: 0.2478, 训练准确率: 0.8658, 类别0/1: 0.7950/0.9269, 训练F1: 0.8620, 训练精确率: 0.8680, 训练召回率: 0.8628, 训练特异性: 0.7950, 训练MCC: 0.7301, 训练归一化MCC: 0.8650, 验证损失: 1.0627, 验证准确率: 0.3778, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000001
# 2025-03-11 17:00:36 - INFO - 本轮用时: 8.55 秒
# 2025-03-11 17:00:36 - INFO - ——————————————————————————————
# 2025-03-11 17:00:46 - INFO - 轮次 86/100, 训练损失: 0.2575, 训练准确率: 0.8585, 类别0/1: 0.7794/0.9275, 训练F1: 0.8543, 训练精确率: 0.8620, 训练召回率: 0.8553, 训练特异性: 0.7794, 训练MCC: 0.7166, 训练归一化MCC: 0.8583, 验证损失: 0.9426, 验证准确率: 0.3816, 类别0/1: 0.0090/0.9899, 验证F1: 0.2141, 验证精确率: 0.5154, 验证召回率: 0.3759, 验证特异性: 0.0090, 验证MCC: -0.0052, 验证归一化MCC: 0.4974, 学习率: 0.000001
# 2025-03-11 17:00:46 - INFO - 本轮用时: 9.51 秒
# 2025-03-11 17:00:46 - INFO - ——————————————————————————————
# 2025-03-11 17:00:55 - INFO - 轮次 87/100, 训练损失: 0.3151, 训练准确率: 0.8208, 类别0/1: 0.6989/0.9265, 训练F1: 0.8152, 训练精确率: 0.8311, 训练召回率: 0.8181, 训练特异性: 0.6989, 训练MCC: 0.6465, 训练归一化MCC: 0.8232, 验证损失: 0.8694, 验证准确率: 0.3663, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000001
# 2025-03-11 17:00:55 - INFO - 本轮用时: 9.62 秒
# 2025-03-11 17:00:55 - INFO - ——————————————————————————————
# 2025-03-11 17:01:05 - INFO - 轮次 88/100, 训练损失: 0.2893, 训练准确率: 0.8318, 类别0/1: 0.7454/0.9160, 训练F1: 0.8283, 训练精确率: 0.8403, 训练召回率: 0.8294, 训练特异性: 0.7454, 训练MCC: 0.6700, 训练归一化MCC: 0.8350, 验证损失: 0.9372, 验证准确率: 0.3663, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000001
# 2025-03-11 17:01:05 - INFO - 本轮用时: 9.62 秒
# 2025-03-11 17:01:05 - INFO - ——————————————————————————————
# 2025-03-11 17:01:14 - INFO - 轮次 89/100, 训练损失: 0.2624, 训练准确率: 0.8552, 类别0/1: 0.7869/0.9221, 训练F1: 0.8554, 训练精确率: 0.8617, 训练召回率: 0.8562, 训练特异性: 0.7869, 训练MCC: 0.7172, 训练归一化MCC: 0.8586, 验证损失: 0.9883, 验证准确率: 0.3701, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000001
# 2025-03-11 17:01:14 - INFO - 本轮用时: 9.52 秒
# 2025-03-11 17:01:14 - INFO - ——————————————————————————————
# 2025-03-11 17:01:24 - INFO - 轮次 90/100, 训练损失: 0.3020, 训练准确率: 0.8130, 类别0/1: 0.7029/0.9201, 训练F1: 0.8081, 训练精确率: 0.8266, 训练召回率: 0.8102, 训练特异性: 0.7029, 训练MCC: 0.6371, 训练归一化MCC: 0.8185, 验证损失: 1.2086, 验证准确率: 0.3816, 类别0/1: 0.0090/0.9899, 验证F1: 0.2141, 验证精确率: 0.5154, 验证召回率: 0.3759, 验证特异性: 0.0090, 验证MCC: -0.0052, 验证归一化MCC: 0.4974, 学习率: 0.000001
# 2025-03-11 17:01:24 - INFO - 本轮用时: 9.29 秒
# 2025-03-11 17:01:24 - INFO - ——————————————————————————————
# 2025-03-11 17:01:33 - INFO - 轮次 91/100, 训练损失: 0.2854, 训练准确率: 0.8277, 类别0/1: 0.7422/0.9175, 训练F1: 0.8269, 训练精确率: 0.8399, 训练召回率: 0.8280, 训练特异性: 0.7422, 训练MCC: 0.6683, 训练归一化MCC: 0.8341, 验证损失: 0.9593, 验证准确率: 0.3701, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000001
# 2025-03-11 17:01:33 - INFO - 本轮用时: 9.72 秒
# 2025-03-11 17:01:33 - INFO - ——————————————————————————————
# 2025-03-11 17:01:43 - INFO - 轮次 92/100, 训练损失: 0.2600, 训练准确率: 0.8516, 类别0/1: 0.7692/0.9372, 训练F1: 0.8490, 训练精确率: 0.8624, 训练召回率: 0.8496, 训练特异性: 0.7692, 训练MCC: 0.7126, 训练归一化MCC: 0.8563, 验证损失: 0.9801, 验证准确率: 0.3892, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000001
# 2025-03-11 17:01:43 - INFO - 本轮用时: 9.44 秒
# 2025-03-11 17:01:43 - INFO - ——————————————————————————————
# 2025-03-11 17:01:52 - INFO - 轮次 93/100, 训练损失: 0.2865, 训练准确率: 0.8300, 类别0/1: 0.7367/0.9200, 训练F1: 0.8249, 训练精确率: 0.8393, 训练召回率: 0.8261, 训练特异性: 0.7367, 训练MCC: 0.6659, 训练归一化MCC: 0.8330, 验证损失: 1.0157, 验证准确率: 0.3778, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000001
# 2025-03-11 17:01:52 - INFO - 本轮用时: 9.70 秒
# 2025-03-11 17:01:52 - INFO - ——————————————————————————————
# 2025-03-11 17:02:02 - INFO - 轮次 94/100, 训练损失: 0.2987, 训练准确率: 0.8143, 类别0/1: 0.7224/0.9055, 训练F1: 0.8128, 训练精确率: 0.8249, 训练召回率: 0.8144, 训练特异性: 0.7224, 训练MCC: 0.6391, 训练归一化MCC: 0.8195, 验证损失: 1.0183, 验证准确率: 0.3854, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000001
# 2025-03-11 17:02:02 - INFO - 本轮用时: 9.71 秒
# 2025-03-11 17:02:02 - INFO - ——————————————————————————————
# 2025-03-11 17:02:12 - INFO - 轮次 95/100, 训练损失: 0.3283, 训练准确率: 0.8033, 类别0/1: 0.7094/0.8961, 训练F1: 0.8013, 训练精确率: 0.8137, 训练召回率: 0.8031, 训练特异性: 0.7094, 训练MCC: 0.6166, 训练归一化MCC: 0.8083, 验证损失: 0.8884, 验证准确率: 0.3816, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000001
# 2025-03-11 17:02:12 - INFO - 本轮用时: 10.15 秒
# 2025-03-11 17:02:12 - INFO - ——————————————————————————————
# 2025-03-11 17:02:23 - INFO - 轮次 96/100, 训练损失: 0.2793, 训练准确率: 0.8341, 类别0/1: 0.7348/0.9241, 训练F1: 0.8313, 训练精确率: 0.8428, 训练召回率: 0.8332, 训练特异性: 0.7348, 训练MCC: 0.6742, 训练归一化MCC: 0.8371, 验证损失: 0.8964, 验证准确率: 0.3701, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000001
# 2025-03-11 17:02:23 - INFO - 本轮用时: 10.26 秒
# 2025-03-11 17:02:23 - INFO - ——————————————————————————————
# 2025-03-11 17:02:33 - INFO - 轮次 97/100, 训练损失: 0.3139, 训练准确率: 0.8185, 类别0/1: 0.7155/0.9083, 训练F1: 0.8124, 训练精确率: 0.8245, 训练召回率: 0.8144, 训练特异性: 0.7155, 训练MCC: 0.6377, 训练归一化MCC: 0.8189, 验证损失: 0.8546, 验证准确率: 0.3701, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000001
# 2025-03-11 17:02:33 - INFO - 本轮用时: 10.03 秒
# 2025-03-11 17:02:33 - INFO - ——————————————————————————————
# 2025-03-11 17:02:43 - INFO - 轮次 98/100, 训练损失: 0.3244, 训练准确率: 0.7955, 类别0/1: 0.6740/0.9122, 训练F1: 0.7919, 训练精确率: 0.8111, 训练召回率: 0.7951, 训练特异性: 0.6740, 训练MCC: 0.6050, 训练归一化MCC: 0.8025, 验证损失: 0.8257, 验证准确率: 0.3778, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000001
# 2025-03-11 17:02:43 - INFO - 本轮用时: 10.06 秒
# 2025-03-11 17:02:43 - INFO - ——————————————————————————————
# 2025-03-11 17:02:53 - INFO - 轮次 99/100, 训练损失: 0.2688, 训练准确率: 0.8405, 类别0/1: 0.7479/0.9293, 训练F1: 0.8370, 训练精确率: 0.8501, 训练召回率: 0.8383, 训练特异性: 0.7479, 训练MCC: 0.6884, 训练归一化MCC: 0.8442, 验证损失: 1.0025, 验证准确率: 0.3740, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000001
# 2025-03-11 17:02:53 - INFO - 本轮用时: 9.89 秒
# 2025-03-11 17:02:53 - INFO - ——————————————————————————————
# 2025-03-11 17:03:02 - INFO - 轮次 100/100, 训练损失: 0.2745, 训练准确率: 0.8309, 类别0/1: 0.7338/0.9257, 训练F1: 0.8270, 训练精确率: 0.8421, 训练召回率: 0.8285, 训练特异性: 0.7338, 训练MCC: 0.6708, 训练归一化MCC: 0.8354, 验证损失: 1.1499, 验证准确率: 0.3778, 类别0/1: 0.0030/1.0000, 验证F1: 0.2077, 验证精确率: 0.7661, 验证召回率: 0.3759, 验证特异性: 0.0030, 验证MCC: 0.0335, 验证归一化MCC: 0.5168, 学习率: 0.000001
# 2025-03-11 17:03:02 - INFO - 本轮用时: 9.47 秒
# 2025-03-11 17:03:02 - INFO - ——————————————————————————————
# 2025-03-11 17:03:02 - INFO - 最终训练类别准确率 - 类别0: 0.7338, 类别1: 0.9257
# 2025-03-11 17:03:02 - INFO - 最终验证类别准确率 - 类别0: 0.0030, 类别1: 1.0000
# 2025-03-11 17:03:02 - INFO - 最终F1分数 - 训练: 0.8270, 验证: 0.2077
# 2025-03-11 17:03:02 - INFO - 最终精确率 - 训练: 0.8421, 验证: 0.7661
# 2025-03-11 17:03:02 - INFO - 最终召回率 - 训练: 0.8285, 验证: 0.3759
# 2025-03-11 17:03:02 - INFO - 最终特异性 - 训练: 0.7338, 验证: 0.0030
# 2025-03-11 17:03:02 - INFO - 最终MCC - 训练: 0.6708, 验证: 0.0335
# 2025-03-11 17:03:02 - INFO - 最终归一化MCC - 训练: 0.8354, 验证: 0.5168
# 2025-03-11 17:03:02 - INFO - 已保存模型权重到: C:\Users\USTC\Desktop\地磁论文（5级以上）\对比模型结果\MLP模型结果\MLPModel_7天_fold_1.pth
# 2025-03-11 17:03:02 - INFO - 已保存训练日志到: C:\Users\USTC\Desktop\地磁论文（5级以上）\对比模型结果\MLP模型结果\MLPModel_7天_fold_1_epoch_logs.txt
# 2025-03-11 17:03:02 - INFO - 已保存训练集预测概率到: C:\Users\USTC\Desktop\地磁论文（5级以上）\对比模型结果\MLP模型结果\MLPModel_7天_fold_1_train_probs.npy
# 2025-03-11 17:03:02 - INFO - 已保存训练集标签到: C:\Users\USTC\Desktop\地磁论文（5级以上）\对比模型结果\MLP模型结果\MLPModel_7天_fold_1_train_labels.npy
# 2025-03-11 17:03:02 - INFO - 已保存测试集预测概率到: C:\Users\USTC\Desktop\地磁论文（5级以上）\对比模型结果\MLP模型结果\MLPModel_7天_fold_1_test_probs.npy
# 2025-03-11 17:03:02 - INFO - 已保存测试集标签到: C:\Users\USTC\Desktop\地磁论文（5级以上）\对比模型结果\MLP模型结果\MLPModel_7天_fold_1_test_labels.npy
# 2025-03-11 17:03:02 - INFO - 类别准确率: 类别0: 1.0000, 类别1: 1.0000
# 2025-03-11 17:03:02 - INFO - F1分数: 训练: 0.8270, 验证: 0.2077
# 2025-03-11 17:03:02 - INFO - 精确率: 训练: 0.8421, 验证: 0.7661
# 2025-03-11 17:03:02 - INFO - 召回率: 训练: 0.8285, 验证: 0.3759
# ...
# 2025-03-11 20:45:37 - INFO - 轮次 84/100, 训练损失: 0.0959, 训练准确率: 0.9520, 类别0/1: 0.9322/0.9714, 训练F1: 0.9510, 训练精确率: 0.9519, 训练召回率: 0.9509, 训练特异性: 0.9322, 训练MCC: 0.9027, 训练归一化MCC: 0.9514, 验证损失: 1.2180, 验证准确率: 0.6500, 类别0/1: 0.9965/0.0065, 验证F1: 0.5142, 验证精确率: 0.5967, 验证召回率: 0.6484, 验证特异性: 0.9965, 验证MCC: 0.0211, 验证归一化MCC: 0.5105, 学习率: 0.000001
# 2025-03-11 20:45:37 - INFO - 本轮用时: 10.17 秒
# 2025-03-11 20:45:37 - INFO - ——————————————————————————————
# 2025-03-11 20:45:47 - INFO - 轮次 85/100, 训练损失: 0.1331, 训练准确率: 0.9216, 类别0/1: 0.9034/0.9377, 训练F1: 0.9207, 训练精确率: 0.9211, 训练召回率: 0.9207, 训练特异性: 0.9034, 训练MCC: 0.8418, 训练归一化MCC: 0.9209, 验证损失: 1.1979, 验证准确率: 0.6484, 类别0/1: 0.9965/0.0065, 验证F1: 0.5142, 验证精确率: 0.5967, 验证召回率: 0.6484, 验证特异性: 0.9965, 验证MCC: 0.0211, 验证归一化MCC: 0.5105, 学习率: 0.000001
# 2025-03-11 20:45:47 - INFO - 本轮用时: 10.15 秒
# 2025-03-11 20:45:47 - INFO - ——————————————————————————————
# 2025-03-11 20:45:58 - INFO - 轮次 86/100, 训练损失: 0.1355, 训练准确率: 0.9271, 类别0/1: 0.9023/0.9507, 训练F1: 0.9264, 训练精确率: 0.9275, 训练召回率: 0.9264, 训练特异性: 0.9023, 训练MCC: 0.8539, 训练归一化MCC: 0.9269, 验证损失: 0.9951, 验证准确率: 0.6480, 类别0/1: 0.9965/0.0065, 验证F1: 0.5142, 验证精确率: 0.5967, 验证召回率: 0.6484, 验证特异性: 0.9965, 验证MCC: 0.0211, 验证归一化MCC: 0.5105, 学习率: 0.000001
# 2025-03-11 20:45:58 - INFO - 本轮用时: 10.15 秒
# 2025-03-11 20:45:58 - INFO - ——————————————————————————————
# 2025-03-11 20:46:08 - INFO - 轮次 87/100, 训练损失: 0.1214, 训练准确率: 0.9383, 类别0/1: 0.9142/0.9601, 训练F1: 0.9378, 训练精确率: 0.9385, 训练召回率: 0.9378, 训练特异性: 0.9142, 训练MCC: 0.8762, 训练归一化MCC: 0.9381, 验证损失: 0.9614, 验证准确率: 0.6521, 类别0/1: 0.9965/0.0065, 验证F1: 0.5142, 验证精确率: 0.5967, 验证召回率: 0.6484, 验证特异性: 0.9965, 验证MCC: 0.0211, 验证归一化MCC: 0.5105, 学习率: 0.000001
# 2025-03-11 20:46:08 - INFO - 本轮用时: 10.27 秒
# 2025-03-11 20:46:08 - INFO - ——————————————————————————————
# 2025-03-11 20:46:18 - INFO - 轮次 88/100, 训练损失: 0.1095, 训练准确率: 0.9450, 类别0/1: 0.9308/0.9587, 训练F1: 0.9447, 训练精确率: 0.9450, 训练召回率: 0.9447, 训练特异性: 0.9308, 训练MCC: 0.8897, 训练归一化MCC: 0.9449, 验证损失: 1.0920, 验证准确率: 0.6480, 类别0/1: 0.9965/0.0065, 验证F1: 0.5142, 验证精确率: 0.5967, 验证召回率: 0.6484, 验证特异性: 0.9965, 验证MCC: 0.0211, 验证归一化MCC: 0.5105, 学习率: 0.000001
# 2025-03-11 20:46:18 - INFO - 本轮用时: 10.09 秒
# 2025-03-11 20:46:18 - INFO - ——————————————————————————————
# 2025-03-11 20:46:28 - INFO - 轮次 89/100, 训练损失: 0.1163, 训练准确率: 0.9369, 类别0/1: 0.9240/0.9476, 训练F1: 0.9355, 训练精确率: 0.9359, 训练召回率: 0.9355, 训练特异性: 0.9240, 训练MCC: 0.8714, 训练归一化MCC: 0.9357, 验证损失: 0.8044, 验证准确率: 0.6484, 类别0/1: 0.9965/0.0065, 验证F1: 0.5142, 验证精确率: 0.5967, 验证召回率: 0.6484, 验证特异性: 0.9965, 验证MCC: 0.0211, 验证归一化MCC: 0.5105, 学习率: 0.000001
# 2025-03-11 20:46:28 - INFO - 本轮用时: 10.09 秒
# 2025-03-11 20:46:28 - INFO - ——————————————————————————————
# 2025-03-11 20:46:38 - INFO - 轮次 90/100, 训练损失: 0.1535, 训练准确率: 0.9071, 类别0/1: 0.8973/0.9266, 训练F1: 0.9121, 训练精确率: 0.9124, 训练召回率: 0.9122, 训练特异性: 0.8973, 训练MCC: 0.8245, 训练归一化MCC: 0.9123, 验证损失: 0.8081, 验证准确率: 0.6496, 类别0/1: 0.9965/0.0065, 验证F1: 0.5142, 验证精确率: 0.5967, 验证召回率: 0.6484, 验证特异性: 0.9965, 验证MCC: 0.0211, 验证归一化MCC: 0.5105, 学习率: 0.000001
# 2025-03-11 20:46:38 - INFO - 本轮用时: 9.92 秒
# 2025-03-11 20:46:38 - INFO - ——————————————————————————————
# 2025-03-11 20:46:48 - INFO - 轮次 91/100, 训练损失: 0.1148, 训练准确率: 0.9422, 类别0/1: 0.9255/0.9580, 训练F1: 0.9418, 训练精确率: 0.9423, 训练召回率: 0.9418, 训练特异性: 0.9255, 训练MCC: 0.8841, 训练归一化MCC: 0.9420, 验证损失: 0.9587, 验证准确率: 0.6492, 类别0/1: 0.9965/0.0065, 验证F1: 0.5142, 验证精确率: 0.5967, 验证召回率: 0.6484, 验证特异性: 0.9965, 验证MCC: 0.0211, 验证归一化MCC: 0.5105, 学习率: 0.000001
# 2025-03-11 20:46:48 - INFO - 本轮用时: 10.12 秒
# 2025-03-11 20:46:48 - INFO - ——————————————————————————————
# 2025-03-11 20:46:58 - INFO - 轮次 92/100, 训练损失: 0.1356, 训练准确率: 0.9230, 类别0/1: 0.9042/0.9396, 训练F1: 0.9213, 训练精确率: 0.9221, 训练召回率: 0.9213, 训练特异性: 0.9042, 训练MCC: 0.8433, 训练归一化MCC: 0.9216, 验证损失: 0.7726, 验证准确率: 0.6467, 类别0/1: 0.9965/0.0065, 验证F1: 0.5142, 验证精确率: 0.5967, 验证召回率: 0.6484, 验证特异性: 0.9965, 验证MCC: 0.0211, 验证归一化MCC: 0.5105, 学习率: 0.000001
# 2025-03-11 20:46:58 - INFO - 本轮用时: 10.04 秒
# 2025-03-11 20:46:58 - INFO - ——————————————————————————————
# 2025-03-11 20:47:08 - INFO - 轮次 93/100, 训练损失: 0.1596, 训练准确率: 0.9028, 类别0/1: 0.8870/0.9176, 训练F1: 0.9024, 训练精确率: 0.9028, 训练召回率: 0.9025, 训练特异性: 0.8870, 训练MCC: 0.8052, 训练归一化MCC: 0.9026, 验证损失: 0.9766, 验证准确率: 0.6513, 类别0/1: 0.9965/0.0065, 验证F1: 0.5142, 验证精确率: 0.5967, 验证召回率: 0.6484, 验证特异性: 0.9965, 验证MCC: 0.0211, 验证归一化MCC: 0.5105, 学习率: 0.000001
# 2025-03-11 20:47:08 - INFO - 本轮用时: 10.04 秒
# 2025-03-11 20:47:08 - INFO - ——————————————————————————————
# 2025-03-11 20:47:18 - INFO - 轮次 94/100, 训练损失: 0.1378, 训练准确率: 0.9237, 类别0/1: 0.9131/0.9366, 训练F1: 0.9247, 训练精确率: 0.9250, 训练召回率: 0.9247, 训练特异性: 0.9131, 训练MCC: 0.8497, 训练归一化MCC: 0.9248, 验证损失: 0.8097, 验证准确率: 0.6467, 类别0/1: 0.9965/0.0065, 验证F1: 0.5142, 验证精确率: 0.5967, 验证召回率: 0.6484, 验证特异性: 0.9965, 验证MCC: 0.0211, 验证归一化MCC: 0.5105, 学习率: 0.000001
# 2025-03-11 20:47:18 - INFO - 本轮用时: 10.04 秒
# 2025-03-11 20:47:18 - INFO - ——————————————————————————————
# 2025-03-11 20:47:28 - INFO - 轮次 95/100, 训练损失: 0.0986, 训练准确率: 0.9595, 类别0/1: 0.9463/0.9732, 训练F1: 0.9595, 训练精确率: 0.9599, 训练召回率: 0.9595, 训练特异性: 0.9463, 训练MCC: 0.9194, 训练归一化MCC: 0.9597, 验证损失: 1.0275, 验证准确率: 0.6492, 类别0/1: 0.9965/0.0065, 验证F1: 0.5142, 验证精确率: 0.5967, 验证召回率: 0.6484, 验证特异性: 0.9965, 验证MCC: 0.0211, 验证归一化MCC: 0.5105, 学习率: 0.000001
# 2025-03-11 20:47:28 - INFO - 本轮用时: 9.93 秒
# 2025-03-11 20:47:28 - INFO - ——————————————————————————————
# 2025-03-11 20:47:38 - INFO - 轮次 96/100, 训练损失: 0.0915, 训练准确率: 0.9539, 类别0/1: 0.9358/0.9736, 训练F1: 0.9538, 训练精确率: 0.9547, 训练召回率: 0.9538, 训练特异性: 0.9358, 训练MCC: 0.9084, 训练归一化MCC: 0.9542, 验证损失: 1.3035, 验证准确率: 0.6472, 类别0/1: 0.9965/0.0065, 验证F1: 0.5142, 验证精确率: 0.5967, 验证召回率: 0.6484, 验证特异性: 0.9965, 验证MCC: 0.0211, 验证归一化MCC: 0.5105, 学习率: 0.000001
# 2025-03-11 20:47:38 - INFO - 本轮用时: 10.06 秒
# 2025-03-11 20:47:38 - INFO - ——————————————————————————————
# 2025-03-11 20:47:48 - INFO - 轮次 97/100, 训练损失: 0.1544, 训练准确率: 0.9057, 类别0/1: 0.8754/0.9355, 训练F1: 0.9037, 训练精确率: 0.9061, 训练召回率: 0.9036, 训练特异性: 0.8754, 训练MCC: 0.8094, 训练归一化MCC: 0.9047, 验证损失: 0.9121, 验证准确率: 0.6476, 类别0/1: 0.9965/0.0065, 验证F1: 0.5142, 验证精确率: 0.5967, 验证召回率: 0.6484, 验证特异性: 0.9965, 验证MCC: 0.0211, 验证归一化MCC: 0.5105, 学习率: 0.000001
# 2025-03-11 20:47:48 - INFO - 本轮用时: 10.14 秒
# 2025-03-11 20:47:48 - INFO - ——————————————————————————————
# 2025-03-11 20:47:58 - INFO - 轮次 98/100, 训练损失: 0.1455, 训练准确率: 0.9160, 类别0/1: 0.9061/0.9360, 训练F1: 0.9212, 训练精确率: 0.9216, 训练召回率: 0.9213, 训练特异性: 0.9061, 训练MCC: 0.8428, 训练归一化MCC: 0.9214, 验证损失: 0.9260, 验证准确率: 0.6447, 类别0/1: 0.9965/0.0065, 验证F1: 0.5142, 验证精确率: 0.5967, 验证召回率: 0.6484, 验证特异性: 0.9965, 验证MCC: 0.0211, 验证归一化MCC: 0.5105, 学习率: 0.000001
# 2025-03-11 20:47:58 - INFO - 本轮用时: 10.18 秒
# 2025-03-11 20:47:58 - INFO - ——————————————————————————————
# 2025-03-11 20:48:08 - INFO - 轮次 99/100, 训练损失: 0.0723, 训练准确率: 0.9728, 类别0/1: 0.9656/0.9854, 训练F1: 0.9749, 训练精确率: 0.9752, 训练召回率: 0.9749, 训练特异性: 0.9656, 训练MCC: 0.9499, 训练归一化MCC: 0.9750, 验证损失: 1.2987, 验证准确率: 0.6484, 类别0/1: 0.9965/0.0065, 验证F1: 0.5142, 验证精确率: 0.5967, 验证召回率: 0.6484, 验证特异性: 0.9965, 验证MCC: 0.0211, 验证归一化MCC: 0.5105, 学习率: 0.000001
# 2025-03-11 20:48:08 - INFO - 本轮用时: 10.02 秒
# 2025-03-11 20:48:08 - INFO - ——————————————————————————————
# 2025-03-11 20:48:19 - INFO - 轮次 100/100, 训练损失: 0.1347, 训练准确率: 0.9297, 类别0/1: 0.8935/0.9632, 训练F1: 0.9281, 训练精确率: 0.9303, 训练召回率: 0.9281, 训练特异性: 0.8935, 训练MCC: 0.8585, 训练归一化MCC: 0.9292, 验证损失: 0.8628, 验证准确率: 0.6492, 类别0/1: 0.9965/0.0065, 验证F1: 0.5142, 验证精确率: 0.5967, 验证召回率: 0.6484, 验证特异性: 0.9965, 验证MCC: 0.0211, 验证归一化MCC: 0.5105, 学习率: 0.000001
# 2025-03-11 20:48:19 - INFO - 本轮用时: 10.04 秒
# 2025-03-11 20:48:19 - INFO - ——————————————————————————————
# 2025-03-11 20:48:19 - INFO - 最终训练类别准确率 - 类别0: 0.8935, 类别1: 0.9632
# 2025-03-11 20:48:19 - INFO - 最终验证类别准确率 - 类别0: 0.9965, 类别1: 0.0065
# 2025-03-11 20:48:19 - INFO - 最终F1分数 - 训练: 0.9281, 验证: 0.5142
# 2025-03-11 20:48:19 - INFO - 最终精确率 - 训练: 0.9303, 验证: 0.5967
# 2025-03-11 20:48:19 - INFO - 最终召回率 - 训练: 0.9281, 验证: 0.6484
# 2025-03-11 20:48:19 - INFO - 最终特异性 - 训练: 0.8935, 验证: 0.9965
# 2025-03-11 20:48:19 - INFO - 最终MCC - 训练: 0.8585, 验证: 0.0211
# 2025-03-11 20:48:19 - INFO - 最终归一化MCC - 训练: 0.9292, 验证: 0.5105
# 2025-03-11 20:48:19 - INFO - 已保存模型权重到: C:\Users\USTC\Desktop\地磁论文（5级以上）\对比模型结果\MLP模型结果\MLPModel_30天_fold_5.pth
# 2025-03-11 20:48:19 - INFO - 已保存训练日志到: C:\Users\USTC\Desktop\地磁论文（5级以上）\对比模型结果\MLP模型结果\MLPModel_30天_fold_5_epoch_logs.txt
# 2025-03-11 20:48:19 - INFO - 已保存训练集预测概率到: C:\Users\USTC\Desktop\地磁论文（5级以上）\对比模型结果\MLP模型结果\MLPModel_30天_fold_5_train_probs.npy
# 2025-03-11 20:48:19 - INFO - 已保存训练集标签到: C:\Users\USTC\Desktop\地磁论文（5级以上）\对比模型结果\MLP模型结果\MLPModel_30天_fold_5_train_labels.npy
# 2025-03-11 20:48:19 - INFO - 已保存测试集预测概率到: C:\Users\USTC\Desktop\地磁论文（5级以上）\对比模型结果\MLP模型结果\MLPModel_30天_fold_5_test_probs.npy
# 2025-03-11 20:48:19 - INFO - 已保存测试集标签到: C:\Users\USTC\Desktop\地磁论文（5级以上）\对比模型结果\MLP模型结果\MLPModel_30天_fold_5_test_labels.npy
# 2025-03-11 20:48:19 - INFO - 类别准确率: 类别0: 1.5387, 类别1: 0.0065
# 2025-03-11 20:48:19 - INFO - F1分数: 训练: 0.9281, 验证: 0.5142
# 2025-03-11 20:48:19 - INFO - 精确率: 训练: 0.9303, 验证: 0.5967
# 2025-03-11 20:48:19 - INFO - 召回率: 训练: 0.9281, 验证: 0.6484
# 2025-03-11 20:48:19 - INFO - 特异性: 训练: 0.8935, 验证: 0.9965
# 2025-03-11 20:48:19 - INFO - MCC: 训练: 0.8585, 验证: 0.0211
# 2025-03-11 20:48:19 - INFO - 归一化MCC: 训练: 0.9292, 验证: 0.5105
# 2025-03-11 20:48:19 - INFO - 第 5 折训练完成
# 2025-03-11 20:48:19 - INFO - 第 5 折训练结束
# 2025-03-11 20:48:19 - INFO -
# 训练总结:
# 2025-03-11 20:48:19 - INFO - - 总训练时间: 1小时 23分钟 15秒
# 2025-03-11 20:48:19 - INFO - - 平均训练准确率: 0.9238 ± 0.0142
# 2025-03-11 20:48:19 - INFO - - 平均验证准确率: 0.5909 ± 0.1203
# 2025-03-11 20:48:19 - INFO - - 平均训练F1分数: 0.9236
# 2025-03-11 20:48:19 - INFO - - 平均验证F1分数: 0.4488
# 2025-03-11 20:48:19 - INFO - - 平均训练精确率: 0.9266
# 2025-03-11 20:48:19 - INFO - - 平均验证精确率: 0.4673
# 2025-03-11 20:48:19 - INFO - - 平均训练召回率: 0.9238
# 2025-03-11 20:48:19 - INFO - - 平均验证召回率: 0.5906
# 2025-03-11 20:48:19 - INFO - - 平均训练特异性: 0.8826
# 2025-03-11 20:48:19 - INFO - - 平均验证特异性: 0.7993
# 2025-03-11 20:48:19 - INFO - - 平均训练MCC: 0.8503
# 2025-03-11 20:48:19 - INFO - - 平均验证MCC: 0.0268
# 2025-03-11 20:48:19 - INFO - - 平均训练归一化MCC: 0.9252
# 2025-03-11 20:48:19 - INFO - - 平均验证归一化MCC: 0.5134
# 2025-03-11 20:48:19 - INFO - - 类别0平均准确率: 1.4306
# 2025-03-11 20:48:19 - INFO - - 类别1平均准确率: 0.2052
# 2025-03-11 20:48:19 - INFO - - 平均验证损失: 0.7587 ± 0.0703
# 2025-03-11 20:48:19 - INFO - 开始进行模型集成 - MLPModel_30天 (方法: f1)
# C:\Users\USTC\AppData\Local\Temp\ipykernel_42704\680156831.py:314: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(model_path)
# 2025-03-11 20:48:19 - INFO - 第 1 折模型F1分数: 0.5266
# 2025-03-11 20:48:19 - INFO - 已加载第 1 折模型
# C:\Users\USTC\AppData\Local\Temp\ipykernel_42704\680156831.py:314: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(model_path)
# 2025-03-11 20:48:19 - INFO - 第 2 折模型F1分数: 0.5101
# 2025-03-11 20:48:19 - INFO - 已加载第 2 折模型
# C:\Users\USTC\AppData\Local\Temp\ipykernel_42704\680156831.py:314: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(model_path)
# 2025-03-11 20:48:20 - INFO - 第 3 折模型F1分数: 0.1829
# 2025-03-11 20:48:20 - INFO - 已加载第 3 折模型
# C:\Users\USTC\AppData\Local\Temp\ipykernel_42704\680156831.py:314: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(model_path)
# 2025-03-11 20:48:20 - INFO - 第 4 折模型F1分数: 0.5101
# 2025-03-11 20:48:20 - INFO - 已加载第 4 折模型
# C:\Users\USTC\AppData\Local\Temp\ipykernel_42704\680156831.py:314: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(model_path)
# 2025-03-11 20:48:20 - INFO - 第 5 折模型F1分数: 0.5142
# 2025-03-11 20:48:20 - INFO - 已加载第 5 折模型
# 2025-03-11 20:48:20 - INFO - 基于f1的模型权重: [0.23469104 0.22731779 0.08151803 0.22731779 0.22915536]
# 2025-03-11 20:48:20 - INFO - 集成模型权重: [0.2346910398683974, 0.22731778711994066, 0.08151802930498968, 0.22731778711994066, 0.22915535658673164]
# 2025-03-11 20:48:21 - INFO - f1加权集成模型已保存: C:\Users\USTC\Desktop\地磁论文（5级以上）\对比模型结果\MLP模型结果\MLPModel_30天.pth
# 2025-03-11 20:48:21 - INFO -
# === 所有处理完成！===
