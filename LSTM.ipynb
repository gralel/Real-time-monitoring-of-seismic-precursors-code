# %%
import os
import numpy as np
import torch
from torch.utils.data import TensorDataset, DataLoader, random_split, Subset
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.nn as nn
import optuna
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold
import copy
import time
import logging
from typing import Any, Optional, List, Tuple, Dict
from torch.utils.data import TensorDataset, DataLoader, Subset, WeightedRandomSampler
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix

# %% [markdown]
# 定义准确率函数

# %%
def accuracy(outputs: torch.Tensor, labels: torch.Tensor) -> float:
    """
    计算准确率。

    参数:
    - outputs (torch.Tensor): 模型输出的 logits。
    - labels (torch.Tensor): 真实标签。

    返回:
    - float: 准确率。
    """
    _, preds = torch.max(outputs, 1)
    return (preds == labels).float().mean().item()

# %% [markdown]
# 集成模型（基于F1分数分配权重）

# %%
class EnsembleModel(nn.Module):
    """集成模型类，使用F1分数优化权重"""
    def __init__(self, base_models: List[nn.Module], ensemble_weights: Optional[List[float]] = None):
        super(EnsembleModel, self).__init__()
        self.base_models = nn.ModuleList(base_models)
        
        if ensemble_weights is None:
            # 如果没有提供权重，使用均等权重
            self.ensemble_weights = torch.ones(len(base_models)) / len(base_models)
        else:
            # 如果提供了权重（可能是F1分数），归一化处理
            weights = torch.tensor(ensemble_weights)
            self.ensemble_weights = weights / weights.sum()
        
        # 记录权重分配
        logging.info(f"集成模型权重: {self.ensemble_weights.tolist()}")
        
        self.register_buffer('weights', self.ensemble_weights)
    
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        predictions = []
        for model in self.base_models:
            with torch.no_grad():
                model.eval()
                pred = model(x)
                predictions.append(torch.softmax(pred, dim=1))
        
        stacked_preds = torch.stack(predictions, dim=0)
        weighted_preds = stacked_preds * self.weights.view(-1, 1, 1)
        return weighted_preds.sum(dim=0)

# %% [markdown]
# LSTM模型框架+BN层

# %%
class LSTMModel(nn.Module):
    """
    支持不同大小隐藏层的LSTM模型实现
    
    Args:
        input_size (int): 输入特征维度
        hidden_sizes (list): 隐藏层大小列表，如 [512, 256]
        output_size (int): 输出维度
        dropout_prob (float): Dropout概率
    """
    def __init__(self, input_size, hidden_sizes, output_size, dropout_prob=0.3):
        super(LSTMModel, self).__init__()
        
        self.hidden_sizes = hidden_sizes
        self.num_layers = len(hidden_sizes)
        
        # 创建多层LSTM
        self.lstm_layers = nn.ModuleList()
        
        # 第一层LSTM
        self.lstm_layers.append(
            nn.LSTM(
                input_size=input_size,
                hidden_size=hidden_sizes[0],
                num_layers=1,
                batch_first=True
            )
        )
        
        # 创建后续层LSTM（如果有）
        for i in range(1, self.num_layers):
            self.lstm_layers.append(
                nn.LSTM(
                    input_size=hidden_sizes[i-1],
                    hidden_size=hidden_sizes[i],
                    num_layers=1,
                    batch_first=True
                )
            )
        
        # 批归一化层，使用最后一层的hidden_size
        self.bn = nn.BatchNorm1d(hidden_sizes[-1])
        
        # Dropout层
        self.dropout = nn.Dropout(dropout_prob)
        
        # 输出层，使用最后一层的hidden_size
        self.fc = nn.Linear(hidden_sizes[-1], output_size)
    
    def forward(self, x):
        """
        前向传播函数
        
        Args:
            x (torch.Tensor): 输入张量，形状为 (batch_size, seq_length, input_size)
            
        Returns:
            torch.Tensor: 输出张量，形状为 (batch_size, output_size)
        """
        # 通过每一层LSTM
        for i, lstm_layer in enumerate(self.lstm_layers):
            # 初始化当前层的隐藏状态和单元状态
            h0 = torch.zeros(1, x.size(0), self.hidden_sizes[i]).to(x.device)
            c0 = torch.zeros(1, x.size(0), self.hidden_sizes[i]).to(x.device)
            
            # LSTM前向传播
            x, (_, _) = lstm_layer(x, (h0, c0))
            
            # 如果不是最后一层，应用dropout
            if i < len(self.lstm_layers) - 1:
                x = self.dropout(x)
        
        # 只取最后一个时间步的输出
        out = x[:, -1, :]
        
        # 批归一化
        out = self.bn(out)
        
        # Dropout
        out = self.dropout(out)
        
        # 通过全连接层得到最终输出
        out = self.fc(out)
        
        return out

# %% [markdown]
# 定义训练与评估循环函数

# %%
def train_eval_lstm(
    model: nn.Module,
    train_loader: DataLoader, 
    val_loader: DataLoader,
    loss_fn: nn.Module,
    optimizer: torch.optim.Optimizer,
    scheduler: lr_scheduler._LRScheduler,
    epochs: int,
    device: torch.device,
    log_epoch: Optional[List[str]] = None,
    max_grad_norm: Optional[float] = None
) -> Tuple[float, float, float, float, np.ndarray, np.ndarray, np.ndarray, np.ndarray, Dict]:
    """
    训练与评估LSTM模型的主循环函数，支持类别平衡评估，使用F1分数选择最佳模型。
    增加了精确率、召回率、特异性和MCC评估指标。
    
    Args:
        model: 神经网络模型
        train_loader: 训练数据加载器
        val_loader: 验证数据加载器 
        loss_fn: 损失函数
        optimizer: 优化器
        scheduler: 学习率调度器
        epochs: 训练轮数
        device: 训练设备
        log_epoch: 可选的日志记录列表
        max_grad_norm: 可选的梯度裁剪阈值

    Returns:
        Tuple[float, float, float, float, np.ndarray, np.ndarray, np.ndarray, np.ndarray, Dict]:
            - train_loss: 最终训练损失
            - val_loss: 最终验证损失
            - train_acc: 最终训练准确率
            - val_acc: 最终验证准确率
            - train_probs: 训练集预测概率
            - train_labels: 训练集真实标签
            - val_probs: 验证集预测概率
            - val_labels: 验证集真实标签
            - model_state: 最佳模型状态字典
    """
    # 导入指标计算函数
    from sklearn.metrics import f1_score, precision_score, recall_score, matthews_corrcoef, confusion_matrix
    
    # 初始化记录器
    history = {
        'train_loss': [],
        'val_loss': [],
        'train_acc': [],
        'val_acc': [],
        'train_class_acc': [],     # 类别准确率记录
        'val_class_acc': [],       # 类别准确率记录
        'train_f1': [],            # F1分数记录
        'val_f1': [],              # F1分数记录
        'train_precision': [],     # 精确率记录
        'val_precision': [],       # 精确率记录
        'train_recall': [],        # 召回率记录
        'val_recall': [],          # 召回率记录
        'train_specificity': [],   # 特异性记录
        'val_specificity': [],     # 特异性记录
        'train_mcc': [],           # MCC记录
        'val_mcc': [],             # MCC记录
        'train_norm_mcc': [],      # 归一化MCC记录
        'val_norm_mcc': []         # 归一化MCC记录
    }
    
    best_model_state = None
    best_val_f1 = float('-inf')  # 使用F1分数选择最佳模型
    
    # 检查是否使用了带权重的损失函数
    has_weights = hasattr(loss_fn, 'weight') and loss_fn.weight is not None
    if has_weights:
        logging.info(f"使用带权重的损失函数，权重: {loss_fn.weight.cpu().numpy()}")
    
    for epoch in range(epochs):
        epoch_start_time = time.time()
        
        # ===== 训练阶段 =====
        model.train()
        train_loss = 0.0
        train_acc = 0.0
        epoch_train_probs = []
        epoch_train_labels = []
        epoch_train_preds = []  # 存储预测类别
        num_train_batches = 0
        
        for inputs, labels in train_loader:
            if inputs.size(0) <= 1:  # 跳过大小为1的批次
                continue
                
            inputs = inputs.to(device)
            labels = labels.to(device)
            
            # 前向传播
            outputs = model(inputs)
            if isinstance(outputs, tuple):
                outputs = outputs[0]
            
            # 计算损失和准确率
            loss = loss_fn(outputs, labels)
            batch_acc = accuracy(outputs, labels)
            
            # 反向传播和优化
            optimizer.zero_grad()
            loss.backward()
            
            # 梯度裁剪
            if max_grad_norm is not None:
                if isinstance(model, nn.DataParallel):
                    torch.nn.utils.clip_grad_norm_(
                        model.module.parameters(), 
                        max_grad_norm
                    )
                else:
                    torch.nn.utils.clip_grad_norm_(
                        model.parameters(), 
                        max_grad_norm
                    )
                
            optimizer.step()
            
            # 累积损失和准确率
            train_loss += loss.item()
            train_acc += batch_acc
            num_train_batches += 1
            
            # 保存预测概率、预测类别和标签
            probs = torch.softmax(outputs, dim=1)
            _, preds = torch.max(outputs, dim=1)
            epoch_train_probs.append(probs.detach().cpu().numpy())
            epoch_train_preds.append(preds.cpu().numpy())
            epoch_train_labels.append(labels.cpu().numpy())
        
        # 计算训练阶段平均指标
        avg_train_loss = train_loss / num_train_batches
        avg_train_acc = train_acc / num_train_batches
        
        # 计算每个类别的准确率和其他指标
        train_preds_all = np.concatenate(epoch_train_preds)
        train_labels_all = np.concatenate(epoch_train_labels)
        
        # F1分数
        train_f1 = f1_score(train_labels_all, train_preds_all, average='weighted')
        
        # 精确率
        train_precision = precision_score(train_labels_all, train_preds_all, average='weighted')
        
        # 召回率
        train_recall = recall_score(train_labels_all, train_preds_all, average='weighted')
        
        # 特异性 (Specificity) - 对于二分类问题
        train_cm = confusion_matrix(train_labels_all, train_preds_all)
        train_tn = train_cm[0, 0]
        train_fp = train_cm[0, 1]
        train_specificity = train_tn / (train_tn + train_fp) if (train_tn + train_fp) > 0 else 0
        
        # MCC (Matthews Correlation Coefficient)
        train_mcc = matthews_corrcoef(train_labels_all, train_preds_all)
        
        # 归一化MCC到[0,1]区间
        train_norm_mcc = (train_mcc + 1) / 2
        
        # 计算每个类别的准确率
        train_class_counts = np.bincount(train_labels_all, minlength=2)
        train_class_correct = np.bincount(
            train_labels_all[train_preds_all == train_labels_all], 
            minlength=2
        )
        train_class_acc = np.zeros(2)  # 初始化为零，避免除以零的问题
        for i in range(2):
            if train_class_counts[i] > 0:
                train_class_acc[i] = train_class_correct[i] / train_class_counts[i]
        
        # 记录训练指标
        history['train_loss'].append(avg_train_loss)
        history['train_acc'].append(avg_train_acc)
        history['train_class_acc'].append(train_class_acc.tolist())
        history['train_f1'].append(train_f1)
        history['train_precision'].append(train_precision)
        history['train_recall'].append(train_recall)
        history['train_specificity'].append(train_specificity)
        history['train_mcc'].append(train_mcc)
        history['train_norm_mcc'].append(train_norm_mcc)
        
        # ===== 验证阶段 =====
        model.eval()
        val_loss = 0.0
        val_acc = 0.0
        epoch_val_probs = []
        epoch_val_labels = []
        epoch_val_preds = []  # 存储预测类别
        num_val_batches = 0
        
        with torch.no_grad():
            for inputs, labels in val_loader:
                if inputs.size(0) <= 1:
                    continue
                    
                inputs = inputs.to(device)
                labels = labels.to(device)
                
                # 前向传播
                outputs = model(inputs)
                if isinstance(outputs, tuple):
                    outputs = outputs[0]
                
                # 计算损失和准确率
                loss = loss_fn(outputs, labels)
                batch_acc = accuracy(outputs, labels)
                
                val_loss += loss.item()
                val_acc += batch_acc
                num_val_batches += 1
                
                # 保存预测概率、预测类别和标签
                probs = torch.softmax(outputs, dim=1)
                _, preds = torch.max(outputs, dim=1)
                epoch_val_probs.append(probs.cpu().numpy())
                epoch_val_preds.append(preds.cpu().numpy())
                epoch_val_labels.append(labels.cpu().numpy())
        
        # 计算验证阶段平均指标
        avg_val_loss = val_loss / num_val_batches
        avg_val_acc = val_acc / num_val_batches
        
        # 计算每个类别的准确率和其他指标
        val_preds_all = np.concatenate(epoch_val_preds)
        val_labels_all = np.concatenate(epoch_val_labels)
        
        # F1分数
        val_f1 = f1_score(val_labels_all, val_preds_all, average='weighted')
        
        # 精确率
        val_precision = precision_score(val_labels_all, val_preds_all, average='weighted')
        
        # 召回率
        val_recall = recall_score(val_labels_all, val_preds_all, average='weighted')
        
        # 特异性 (Specificity) - 对于二分类问题
        val_cm = confusion_matrix(val_labels_all, val_preds_all)
        val_tn = val_cm[0, 0]
        val_fp = val_cm[0, 1]
        val_specificity = val_tn / (val_tn + val_fp) if (val_tn + val_fp) > 0 else 0
        
        # MCC (Matthews Correlation Coefficient)
        val_mcc = matthews_corrcoef(val_labels_all, val_preds_all)
        
        # 归一化MCC到[0,1]区间
        val_norm_mcc = (val_mcc + 1) / 2
        
        # 计算每个类别的准确率
        val_class_counts = np.bincount(val_labels_all, minlength=2)
        val_class_correct = np.bincount(
            val_labels_all[val_preds_all == val_labels_all], 
            minlength=2
        )
        val_class_acc = np.zeros(2)  # 初始化为零，避免除以零的问题
        for i in range(2):
            if val_class_counts[i] > 0:
                val_class_acc[i] = val_class_correct[i] / val_class_counts[i]
        
        # 记录验证指标
        history['val_loss'].append(avg_val_loss)
        history['val_acc'].append(avg_val_acc)
        history['val_class_acc'].append(val_class_acc.tolist())
        history['val_f1'].append(val_f1)
        history['val_precision'].append(val_precision)
        history['val_recall'].append(val_recall)
        history['val_specificity'].append(val_specificity)
        history['val_mcc'].append(val_mcc)
        history['val_norm_mcc'].append(val_norm_mcc)
        
        # 更新最佳模型状态，使用F1分数作为指标
        if val_f1 > best_val_f1:
            best_val_f1 = val_f1
            if isinstance(model, nn.DataParallel):
                best_model_state = copy.deepcopy(model.module.state_dict())
            else:
                best_model_state = copy.deepcopy(model.state_dict())
            logging.info(f"*** 新的最佳模型 (F1分数: {val_f1:.4f}) ***")
        
        # 更新学习率
        if isinstance(scheduler, lr_scheduler.ReduceLROnPlateau):
            scheduler.step(avg_val_loss)
        else:
            scheduler.step()
            
        # 获取当前学习率
        current_lr = optimizer.param_groups[0]['lr']
        
        # 记录训练日志，包含所有新增的评估指标
        epoch_log = (
            f'轮次 {epoch+1}/{epochs}, '
            f'训练损失: {avg_train_loss:.4f}, 训练准确率: {avg_train_acc:.4f}, '
            f'类别0/1: {train_class_acc[0]:.4f}/{train_class_acc[1]:.4f}, '
            f'训练F1: {train_f1:.4f}, 训练精确率: {train_precision:.4f}, '
            f'训练召回率: {train_recall:.4f}, 训练特异性: {train_specificity:.4f}, '
            f'训练MCC: {train_mcc:.4f}, 训练归一化MCC: {train_norm_mcc:.4f}, '
            f'验证损失: {avg_val_loss:.4f}, 验证准确率: {avg_val_acc:.4f}, '
            f'类别0/1: {val_class_acc[0]:.4f}/{val_class_acc[1]:.4f}, '
            f'验证F1: {val_f1:.4f}, 验证精确率: {val_precision:.4f}, '
            f'验证召回率: {val_recall:.4f}, 验证特异性: {val_specificity:.4f}, '
            f'验证MCC: {val_mcc:.4f}, 验证归一化MCC: {val_norm_mcc:.4f}, '
            f'学习率: {current_lr:.6f}'
        )
        logging.info(epoch_log)
        logging.info(f"本轮用时: {time.time() - epoch_start_time:.2f} 秒")
        logging.info("——————————————————————————————")
        
        if log_epoch is not None:
            log_epoch.append(epoch_log)
    
    # 加载最佳模型状态
    if best_model_state is not None:
        if isinstance(model, nn.DataParallel):
            model.module.load_state_dict(best_model_state)
        else:
            model.load_state_dict(best_model_state)
    
    # 整理最终结果
    final_train_probs = np.concatenate([p for p in epoch_train_probs], axis=0)
    final_train_labels = np.concatenate([l for l in epoch_train_labels], axis=0)
    final_val_probs = np.concatenate([p for p in epoch_val_probs], axis=0)
    final_val_labels = np.concatenate([l for l in epoch_val_labels], axis=0)
    
    # 计算最终的类别准确率和所有评估指标
    final_train_preds = np.argmax(final_train_probs, axis=1)
    final_val_preds = np.argmax(final_val_probs, axis=1)
    
    # F1分数
    final_train_f1 = f1_score(final_train_labels, final_train_preds, average='weighted')
    final_val_f1 = f1_score(final_val_labels, final_val_preds, average='weighted')
    
    # 精确率
    final_train_precision = precision_score(final_train_labels, final_train_preds, average='weighted')
    final_val_precision = precision_score(final_val_labels, final_val_preds, average='weighted')
    
    # 召回率
    final_train_recall = recall_score(final_train_labels, final_train_preds, average='weighted')
    final_val_recall = recall_score(final_val_labels, final_val_preds, average='weighted')
    
    # 特异性
    final_train_cm = confusion_matrix(final_train_labels, final_train_preds)
    final_train_tn = final_train_cm[0, 0]
    final_train_fp = final_train_cm[0, 1]
    final_train_specificity = final_train_tn / (final_train_tn + final_train_fp) if (final_train_tn + final_train_fp) > 0 else 0
    
    final_val_cm = confusion_matrix(final_val_labels, final_val_preds)
    final_val_tn = final_val_cm[0, 0]
    final_val_fp = final_val_cm[0, 1]
    final_val_specificity = final_val_tn / (final_val_tn + final_val_fp) if (final_val_tn + final_val_fp) > 0 else 0
    
    # MCC
    final_train_mcc = matthews_corrcoef(final_train_labels, final_train_preds)
    final_val_mcc = matthews_corrcoef(final_val_labels, final_val_preds)
    
    # 归一化MCC
    final_train_norm_mcc = (final_train_mcc + 1) / 2
    final_val_norm_mcc = (final_val_mcc + 1) / 2
    
    # 类别准确率
    train_class_acc = np.zeros(2)
    val_class_acc = np.zeros(2)
    
    for i in range(2):
        train_class_mask = (final_train_labels == i)
        val_class_mask = (final_val_labels == i)
        
        if np.sum(train_class_mask) > 0:
            train_class_acc[i] = np.mean(final_train_preds[train_class_mask] == final_train_labels[train_class_mask])
        
        if np.sum(val_class_mask) > 0:
            val_class_acc[i] = np.mean(final_val_preds[val_class_mask] == final_val_labels[val_class_mask])
    
    # 输出最终各项指标
    logging.info(f"最终训练类别准确率 - 类别0: {train_class_acc[0]:.4f}, 类别1: {train_class_acc[1]:.4f}")
    logging.info(f"最终验证类别准确率 - 类别0: {val_class_acc[0]:.4f}, 类别1: {val_class_acc[1]:.4f}")
    logging.info(f"最终F1分数 - 训练: {final_train_f1:.4f}, 验证: {final_val_f1:.4f}")
    logging.info(f"最终精确率 - 训练: {final_train_precision:.4f}, 验证: {final_val_precision:.4f}")
    logging.info(f"最终召回率 - 训练: {final_train_recall:.4f}, 验证: {final_val_recall:.4f}")
    logging.info(f"最终特异性 - 训练: {final_train_specificity:.4f}, 验证: {final_val_specificity:.4f}")
    logging.info(f"最终MCC - 训练: {final_train_mcc:.4f}, 验证: {final_val_mcc:.4f}")
    logging.info(f"最终归一化MCC - 训练: {final_train_norm_mcc:.4f}, 验证: {final_val_norm_mcc:.4f}")
    
    return (
        history['train_loss'][-1],    # 最终训练损失
        history['val_loss'][-1],      # 最终验证损失
        history['train_acc'][-1],     # 最终训练准确率
        history['val_acc'][-1],       # 最终验证准确率
        final_train_probs,           # 训练集预测概率
        final_train_labels,          # 训练集真实标签
        final_val_probs,             # 验证集预测概率
        final_val_labels,            # 验证集真实标签
        best_model_state             # 最佳模型状态
    )

# %% [markdown]
#  LSTM 的 K-Fold 训练与评估函数

# %%
def kfold_train_eval_lstm(
    model_class: Any,
    dataset: TensorDataset,
    loss_fn: nn.Module,
    optimizer_class: Any,
    optimizer_kwargs: dict,
    scheduler_class: Any,
    scheduler_kwargs: dict,
    epochs: int,
    device: torch.device,
    device_ids: Optional[List[int]],
    num_folds: int = 5,
    output_dir: str = r"C:\Users\USTC\Desktop\地磁论文（5级以上）\对比模型结果\LSTM模型结果",
    model_name: str = "LSTMModel",
    window_name: str = "7天",
    mapped_window_name: str = "window-7",
    max_grad_norm: Optional[float] = None,
    input_size: int = 1,
    output_size: int = 2,
    hidden_sizes: List[int] = [512, 256],  # 修改为多个隐藏层大小的列表
    dropout_prob: float = 0.3,
    batch_size: int = 32
) -> Dict[str, List]:
    """
    使用分层K折交叉验证进行LSTM模型的训练和评估，使用F1分数优化模型选择。
    
    Args:
        model_class: 模型类
        dataset: 数据集
        loss_fn: 损失函数
        optimizer_class: 优化器类
        optimizer_kwargs: 优化器参数
        scheduler_class: 学习率调度器类
        scheduler_kwargs: 学习率调度器参数
        epochs: 训练轮数
        device: 训练设备
        device_ids: GPU设备ID列表
        num_folds: 交叉验证折数
        output_dir: 模型保存目录
        model_name: 模型名称
        window_name: 时间窗口名称
        mapped_window_name: 映射后的窗口名称
        max_grad_norm: 梯度裁剪阈值
        input_size: 输入维度
        output_size: 输出维度
        hidden_sizes: LSTM隐藏层大小列表，如 [512, 256]
        dropout_prob: Dropout概率
        batch_size: 批次大小
    
    Returns:
        Dict[str, List]: 包含训练结果的字典
    """
    from sklearn.model_selection import StratifiedKFold
    from sklearn.metrics import f1_score, precision_score, recall_score, matthews_corrcoef, confusion_matrix
    
    os.makedirs(output_dir, exist_ok=True)
    
    results_dict = {
        "train_losses": [],
        "val_losses": [],
        "train_accs": [],
        "val_accs": [],
        "train_f1s": [],       # F1分数记录
        "val_f1s": [],         # F1分数记录
        "train_precisions": [], # 精确率记录
        "val_precisions": [],   # 精确率记录
        "train_recalls": [],    # 召回率记录
        "val_recalls": [],      # 召回率记录
        "train_specificities": [], # 特异性记录
        "val_specificities": [],   # 特异性记录
        "train_mccs": [],      # MCC记录
        "val_mccs": [],        # MCC记录
        "train_norm_mccs": [], # 归一化MCC记录
        "val_norm_mccs": [],   # 归一化MCC记录
        "fold_results": []     # 存储每个折叠的详细结果
    }
    
    total_start_time = time.time()
    
    # 获取数据集的标签，用于分层划分
    all_data = dataset.tensors[0].numpy()
    all_labels = dataset.tensors[1].numpy()
    
    # 创建分层K折交叉验证
    skf = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)
    
    num_gpus = len(device_ids) if device_ids else 1
    adjusted_batch_size = batch_size * num_gpus
    
    logging.info(f"使用设备数量: {num_gpus}")
    logging.info(f"批次大小: {batch_size} 调整后的批次大小: {adjusted_batch_size}")
    
    # 计算类别权重，用于损失函数
    class_weights = calculate_class_weights(all_labels)
    weighted_loss_fn = nn.CrossEntropyLoss(weight=class_weights.to(device))
    logging.info(f"使用带权重的损失函数，权重: {class_weights.numpy()}")
    
    scheduler_kwargs['verbose'] = True
    
    # 使用分层K折训练
    for fold, (train_idx, val_idx) in enumerate(skf.split(all_data, all_labels), 1):
        fold_start_time = time.time()
        logging.info(f"开始训练第 {fold}/{num_folds} 折")
        
        # 准备数据加载器
        train_data = Subset(dataset, train_idx)
        val_data = Subset(dataset, val_idx)
        
        # 记录当前折叠的类别分布
        train_labels = dataset.tensors[1][train_idx].numpy()
        val_labels = dataset.tensors[1][val_idx].numpy()
        train_class_counts = np.bincount(train_labels)
        val_class_counts = np.bincount(val_labels)
        
        logging.info(f"训练集类别分布: 类别0: {train_class_counts[0]}, 类别1: {train_class_counts[1]}")
        logging.info(f"验证集类别分布: 类别0: {val_class_counts[0]}, 类别1: {val_class_counts[1]}")
        
        # 创建数据加载器
        train_loader = create_data_loaders_balanced(
            train_data, batch_size, num_gpus, is_train=True
        )
        
        val_loader = create_data_loaders(
            val_data, batch_size, num_gpus
        )
        
        # 初始化模型
        model = model_class(
            input_size=input_size,
            hidden_sizes=hidden_sizes,  # 使用修改后的参数名
            output_size=output_size,
            dropout_prob=dropout_prob
        ).to(device)
        
        if device_ids and len(device_ids) > 1:
            model = nn.DataParallel(model, device_ids=device_ids)
        
        optimizer = optimizer_class(model.parameters(), **optimizer_kwargs)
        scheduler = scheduler_class(optimizer, **scheduler_kwargs)
        
        epoch_logs = []
        try:
            # 训练单折模型，使用带权重的损失函数
            (train_loss, val_loss, 
             train_acc, val_acc,
             train_probs, train_labels,
             val_probs, val_labels,
             best_model_state) = train_eval_lstm(
                model=model,
                train_loader=train_loader,
                val_loader=val_loader,
                loss_fn=weighted_loss_fn,  # 使用带权重的损失函数
                optimizer=optimizer,
                scheduler=scheduler,
                epochs=epochs,
                device=device,
                log_epoch=epoch_logs,
                max_grad_norm=max_grad_norm,
            )
            
            # 保存模型和相关数据
            base_filename = os.path.join(output_dir, f"{model_name}_{window_name}_fold_{fold}")
            
            # 1. 保存模型权重
            model_path = f"{base_filename}.pth"
            torch.save(best_model_state, model_path)
            logging.info(f"已保存模型权重到: {model_path}")
            
            # 2. 保存训练日志
            log_path = f"{base_filename}_epoch_logs.txt"
            with open(log_path, 'w', encoding='utf-8') as f:
                f.write('\n'.join(epoch_logs))
            logging.info(f"已保存训练日志到: {log_path}")
            
            # 3. 保存训练集预测概率
            train_probs_path = f"{base_filename}_train_probs.npy"
            np.save(train_probs_path, train_probs)
            logging.info(f"已保存训练集预测概率到: {train_probs_path}")
            
            # 4. 保存训练集标签
            train_labels_path = f"{base_filename}_train_labels.npy"
            np.save(train_labels_path, train_labels)
            logging.info(f"已保存训练集标签到: {train_labels_path}")
            
            # 5. 保存测试集预测概率
            test_probs_path = f"{base_filename}_test_probs.npy"
            np.save(test_probs_path, val_probs)
            logging.info(f"已保存测试集预测概率到: {test_probs_path}")
            
            # 6. 保存测试集标签
            test_labels_path = f"{base_filename}_test_labels.npy"
            np.save(test_labels_path, val_labels)
            logging.info(f"已保存测试集标签到: {test_labels_path}")
            
            # 计算预测值
            train_preds = np.argmax(train_probs, axis=1)
            val_preds = np.argmax(val_probs, axis=1)
            
            # 计算各种评估指标
            # F1分数
            train_f1 = f1_score(train_labels, train_preds, average='weighted')
            val_f1 = f1_score(val_labels, val_preds, average='weighted')
            
            # 精确率 (Precision)
            train_precision = precision_score(train_labels, train_preds, average='weighted')
            val_precision = precision_score(val_labels, val_preds, average='weighted')
            
            # 召回率 (Recall)
            train_recall = recall_score(train_labels, train_preds, average='weighted')
            val_recall = recall_score(val_labels, val_preds, average='weighted')
            
            # 特异性 (Specificity) - 需要计算混淆矩阵
            train_cm = confusion_matrix(train_labels, train_preds)
            val_cm = confusion_matrix(val_labels, val_preds)
            
            # 对于二分类，特异性 = TN / (TN + FP)
            train_tn = train_cm[0, 0]
            train_fp = train_cm[0, 1]
            train_specificity = train_tn / (train_tn + train_fp) if (train_tn + train_fp) > 0 else 0
            
            val_tn = val_cm[0, 0]
            val_fp = val_cm[0, 1]
            val_specificity = val_tn / (val_tn + val_fp) if (val_tn + val_fp) > 0 else 0
            
            # MCC (Matthews Correlation Coefficient)
            train_mcc = matthews_corrcoef(train_labels, train_preds)
            val_mcc = matthews_corrcoef(val_labels, val_preds)
            
            # 归一化MCC到[0,1]区间
            train_norm_mcc = (train_mcc + 1) / 2
            val_norm_mcc = (val_mcc + 1) / 2
            
            # 计算每个类别的性能指标
            class_counts = np.bincount(val_labels.astype(int))
            class_correct = np.bincount(val_labels.astype(int) * (val_preds == val_labels), minlength=2)
            class_acc = class_correct / class_counts
            
            logging.info(f"类别准确率: 类别0: {class_acc[0]:.4f}, 类别1: {class_acc[1]:.4f}")
            logging.info(f"F1分数: 训练: {train_f1:.4f}, 验证: {val_f1:.4f}")
            logging.info(f"精确率: 训练: {train_precision:.4f}, 验证: {val_precision:.4f}")
            logging.info(f"召回率: 训练: {train_recall:.4f}, 验证: {val_recall:.4f}")
            logging.info(f"特异性: 训练: {train_specificity:.4f}, 验证: {val_specificity:.4f}")
            logging.info(f"MCC: 训练: {train_mcc:.4f}, 验证: {val_mcc:.4f}")
            logging.info(f"归一化MCC: 训练: {train_norm_mcc:.4f}, 验证: {val_norm_mcc:.4f}")
            
            # 收集每折的结果
            fold_result = {
                'fold': fold,
                'train_loss': train_loss,
                'val_loss': val_loss,
                'train_acc': train_acc,
                'val_acc': val_acc,
                'train_f1': train_f1,
                'val_f1': val_f1,
                'train_precision': train_precision,
                'val_precision': val_precision,
                'train_recall': train_recall,
                'val_recall': val_recall,
                'train_specificity': train_specificity,
                'val_specificity': val_specificity,
                'train_mcc': train_mcc,
                'val_mcc': val_mcc,
                'train_norm_mcc': train_norm_mcc,
                'val_norm_mcc': val_norm_mcc,
                'class_acc': class_acc.tolist(),  # 添加每个类别的准确率
                'model_path': model_path,
                'train_probs_path': train_probs_path,
                'train_labels_path': train_labels_path,
                'test_probs_path': test_probs_path,
                'test_labels_path': test_labels_path,
                'log_path': log_path,
                'time_taken': time.time() - fold_start_time
            }
            results_dict['fold_results'].append(fold_result)
            
            # 更新汇总指标
            results_dict['train_losses'].append(train_loss)
            results_dict['val_losses'].append(val_loss)
            results_dict['train_accs'].append(train_acc)
            results_dict['val_accs'].append(val_acc)
            results_dict['train_f1s'].append(train_f1)
            results_dict['val_f1s'].append(val_f1)
            results_dict['train_precisions'].append(train_precision)
            results_dict['val_precisions'].append(val_precision)
            results_dict['train_recalls'].append(train_recall)
            results_dict['val_recalls'].append(val_recall)
            results_dict['train_specificities'].append(train_specificity)
            results_dict['val_specificities'].append(val_specificity)
            results_dict['train_mccs'].append(train_mcc)
            results_dict['val_mccs'].append(val_mcc)
            results_dict['train_norm_mccs'].append(train_norm_mcc)
            results_dict['val_norm_mccs'].append(val_norm_mcc)
            
            logging.info(f"第 {fold} 折训练完成")
            
        except Exception as e:
            logging.error(f"训练第 {fold} 折时出错: {str(e)}")
            logging.error("详细错误信息:", exc_info=True)
            continue
        
        logging.info(f"第 {fold} 折训练结束")
    
    # 计算总训练时间
    total_duration = time.time() - total_start_time
    hours = int(total_duration // 3600)
    minutes = int((total_duration % 3600) // 60)
    seconds = int(total_duration % 60)
    
    # 计算统计结果
    train_acc_mean = np.mean(results_dict['train_accs'])
    train_acc_std = np.std(results_dict['train_accs'])
    val_acc_mean = np.mean(results_dict['val_accs'])
    val_acc_std = np.std(results_dict['val_accs'])
    
    train_f1_mean = np.mean(results_dict['train_f1s'])
    val_f1_mean = np.mean(results_dict['val_f1s'])
    
    train_precision_mean = np.mean(results_dict['train_precisions'])
    val_precision_mean = np.mean(results_dict['val_precisions'])
    
    train_recall_mean = np.mean(results_dict['train_recalls'])
    val_recall_mean = np.mean(results_dict['val_recalls'])
    
    train_specificity_mean = np.mean(results_dict['train_specificities'])
    val_specificity_mean = np.mean(results_dict['val_specificities'])
    
    train_mcc_mean = np.mean(results_dict['train_mccs'])
    val_mcc_mean = np.mean(results_dict['val_mccs'])
    
    train_norm_mcc_mean = np.mean(results_dict['train_norm_mccs'])
    val_norm_mcc_mean = np.mean(results_dict['val_norm_mccs'])
    
    # 计算每个类别的平均准确率
    class0_accs = [res['class_acc'][0] for res in results_dict['fold_results']]
    class1_accs = [res['class_acc'][1] for res in results_dict['fold_results']]
    class0_acc_mean = np.mean(class0_accs)
    class1_acc_mean = np.mean(class1_accs)
    
    # 保存训练配置和结果，包括类别平衡信息
    config = {
        'model_params': {
            'input_size': input_size,
            'hidden_sizes': hidden_sizes,
            'output_size': output_size,
            'dropout_prob': dropout_prob,
            'num_layers': len(hidden_sizes)
        },
        'training_params': {
            'optimizer': optimizer_class.__name__,
            'optimizer_kwargs': optimizer_kwargs,
            'scheduler': scheduler_class.__name__,
            'scheduler_kwargs': scheduler_kwargs,
            'epochs': epochs,
            'batch_size': batch_size,
            'class_weights': class_weights.tolist(),  # 保存类别权重
            'balanced_sampling': True  # 标记使用了平衡采样
        },
        'results': {
            'train_acc_mean': float(train_acc_mean),
            'train_acc_std': float(train_acc_std),
            'val_acc_mean': float(val_acc_mean),
            'val_acc_std': float(val_acc_std),
            'train_f1_mean': float(train_f1_mean),
            'val_f1_mean': float(val_f1_mean),
            'train_precision_mean': float(train_precision_mean),
            'val_precision_mean': float(val_precision_mean),
            'train_recall_mean': float(train_recall_mean),
            'val_recall_mean': float(val_recall_mean),
            'train_specificity_mean': float(train_specificity_mean),
            'val_specificity_mean': float(val_specificity_mean),
            'train_mcc_mean': float(train_mcc_mean),
            'val_mcc_mean': float(val_mcc_mean),
            'train_norm_mcc_mean': float(train_norm_mcc_mean),
            'val_norm_mcc_mean': float(val_norm_mcc_mean),
            'class0_acc_mean': float(class0_acc_mean),
            'class1_acc_mean': float(class1_acc_mean),
            'training_time': {
                'hours': hours,
                'minutes': minutes,
                'seconds': seconds
            },
            'fold_results': results_dict['fold_results']
        }
    }
    
    config_path = os.path.join(output_dir, f"{model_name}_{window_name}_config.json")
    with open(config_path, 'w', encoding='utf-8') as f:
        json.dump(config, f, indent=4, ensure_ascii=False)
    
    # 记录训练总结
    logging.info("\n训练总结:")
    logging.info(f"- 总训练时间: {hours}小时 {minutes}分钟 {seconds}秒")
    logging.info(f"- 平均训练准确率: {train_acc_mean:.4f} ± {train_acc_std:.4f}")
    logging.info(f"- 平均验证准确率: {val_acc_mean:.4f} ± {val_acc_std:.4f}")
    logging.info(f"- 平均训练精确率: {train_precision_mean:.4f}")
    logging.info(f"- 平均验证精确率: {val_precision_mean:.4f}")
    logging.info(f"- 平均训练召回率: {train_recall_mean:.4f}")
    logging.info(f"- 平均验证召回率: {val_recall_mean:.4f}")
    logging.info(f"- 平均训练特异性: {train_specificity_mean:.4f}")
    logging.info(f"- 平均验证特异性: {val_specificity_mean:.4f}")
    logging.info(f"- 平均训练MCC: {train_mcc_mean:.4f}")
    logging.info(f"- 平均验证MCC: {val_mcc_mean:.4f}")
    logging.info(f"- 平均训练归一化MCC: {train_norm_mcc_mean:.4f}")
    logging.info(f"- 平均验证归一化MCC: {val_norm_mcc_mean:.4f}")
    logging.info(f"- 类别0平均准确率: {class0_acc_mean:.4f}")
    logging.info(f"- 类别1平均准确率: {class1_acc_mean:.4f}")
    logging.info(f"- 平均验证损失: {np.mean(results_dict['val_losses']):.4f} ± {np.std(results_dict['val_losses']):.4f}")
    
    return results_dict

# %%
import torch
print("CUDA 是否可用:", torch.cuda.is_available())
print("当前 PyTorch 版本:", torch.__version__)
print("CUDA 版本:", torch.version.cuda)
print("GPU 数量:", torch.cuda.device_count())

if torch.cuda.is_available():
    for i in range(torch.cuda.device_count()):
        print(f"GPU {i}: {torch.cuda.get_device_name(i)}")
# Out:
# CUDA 是否可用: True
# 当前 PyTorch 版本: 2.5.1+cu118
# CUDA 版本: 11.8
# GPU 数量: 2
# GPU 0: NVIDIA GeForce RTX 4090
# GPU 1: NVIDIA GeForce RTX 4090

# %% [markdown]
# 检查数据集的大小，以便更科学的数据平衡

# %%
import os
import numpy as np

base_path = r"C:\Users\USTC\Desktop\地磁论文（5级以上）"

# 检查各个时间窗口的数据分布
window_periods = ['7', '14', '30']

for period in window_periods:
    window_path = os.path.join(base_path, f"window-{period}")
    
    try:
        # 加载数据文件
        data_0_path = os.path.join(window_path, "data_0.npy")
        data_1_path = os.path.join(window_path, "data_1.npy")
        
        if os.path.exists(data_0_path) and os.path.exists(data_1_path):
            data_0 = np.load(data_0_path)
            data_1 = np.load(data_1_path)
            
            # 提取标签信息
            labels_0 = data_0[:, -1].astype(int)
            labels_1 = data_1[:, -1].astype(int)
            
            # 合并数据和标签
            all_data = np.concatenate([data_0, data_1], axis=0)
            all_labels = all_data[:, -1].astype(int)
            
            # 计算类别分布
            class_counts = np.bincount(all_labels)
            
            print(f"\n=== 时间窗口: {period}天 ===")
            print(f"数据形状 - data_0: {data_0.shape}, data_1: {data_1.shape}")
            print(f"总样本数: {len(all_labels)}")
            if len(class_counts) >= 2:
                print(f"类别0样本数: {class_counts[0]}")
                print(f"类别1样本数: {class_counts[1]}")
                print(f"类别比例(1:0): 1:{class_counts[0]/class_counts[1]:.2f}")
            else:
                print(f"警告: 只有一个类别 - {class_counts}")
                
            # 计算平衡建议
            if class_counts[0] > class_counts[1]:
                minority_class = 1
                minority_count = class_counts[1]
                majority_count = class_counts[0]
            else:
                minority_class = 0
                minority_count = class_counts[0]
                majority_count = class_counts[1]
                
            imbalance_ratio = majority_count / minority_count
            
            print(f"\n数据不平衡分析:")
            print(f"不平衡比例: {imbalance_ratio:.2f}:1")
            
            if imbalance_ratio < 1.5:
                print("评估: 数据集相对平衡，简单的类别权重调整应该足够")
                weight_suggestion = f"类别权重建议: [1.0, {imbalance_ratio:.2f}]" if minority_class == 1 else f"类别权重建议: [{imbalance_ratio:.2f}, 1.0]"
                print(weight_suggestion)
            elif imbalance_ratio < 10:
                print("评估: 中度不平衡，建议结合类别权重和采样技术")
                # 计算平方根缩放的权重
                sqrt_weights = np.sqrt(class_counts) / np.sum(np.sqrt(class_counts)) * len(class_counts)
                weights_str = "[{:.2f}, {:.2f}]".format(sqrt_weights[0], sqrt_weights[1])
                print(f"类别权重建议(平方根缩放): {weights_str}")
                print("采样策略: 使用WeightedRandomSampler进行训练")
            else:
                print("评估: 严重不平衡，建议使用组合策略")
                print("建议策略:")
                print("1. 使用有效样本数计算权重")
                print("2. 考虑使用Focal Loss代替CrossEntropyLoss")
                print("3. 结合过采样和欠采样技术")
                print("4. 使用数据增强生成少数类样本")
        else:
            print(f"错误: 无法找到窗口 {period} 的数据文件")
    except Exception as e:
        print(f"处理窗口 {period} 时出错: {str(e)}")
# Out:
# === 时间窗口: 7天 ===
# 数据形状 - data_0: (1661, 10081), data_1: (999, 10081)
# 总样本数: 2660
# 类别0样本数: 1661
# 类别1样本数: 999
# 类别比例(1:0): 1:1.66
#
# 数据不平衡分析:
# 不平衡比例: 1.66:1
# 评估: 中度不平衡，建议结合类别权重和采样技术
# 类别权重建议(平方根缩放): [1.13, 0.87]
# 采样策略: 使用WeightedRandomSampler进行训练
#
# === 时间窗口: 14天 ===
# 数据形状 - data_0: (1878, 20161), data_1: (826, 20161)
# 总样本数: 2704
# 类别0样本数: 1878
# 类别1样本数: 826
# 类别比例(1:0): 1:2.27
#
# 数据不平衡分析:
# 不平衡比例: 2.27:1
# 评估: 中度不平衡，建议结合类别权重和采样技术
# 类别权重建议(平方根缩放): [1.20, 0.80]
# 采样策略: 使用WeightedRandomSampler进行训练
#
# === 时间窗口: 30天 ===
# 数据形状 - data_0: (1421, 43201), data_1: (770, 43201)
# 总样本数: 2191
# 类别0样本数: 1421
# 类别1样本数: 770
# 类别比例(1:0): 1:1.85
#
# 数据不平衡分析:
# 不平衡比例: 1.85:1
# 评估: 中度不平衡，建议结合类别权重和采样技术
# 类别权重建议(平方根缩放): [1.15, 0.85]
# 采样策略: 使用WeightedRandomSampler进行训练

# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader, Subset
from torch.optim import lr_scheduler
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score
import logging
import time
import json
from typing import Dict, Any, Optional, List, Tuple
import copy

import warnings
warnings.filterwarnings("ignore", message="PyTorch is not compiled with NCCL support")

def setup_logging(log_file: str = 'training.log'):
    """设置日志配置"""
    logging.basicConfig(
        level=logging.INFO,
        format='%(asctime)s - %(levelname)s - %(message)s',
        datefmt='%Y-%m-%d %H:%M:%S'  # 移除了 ,%f，因为这不是标准的时间格式
    )
    # 如果需要添加文件处理器
    file_handler = logging.FileHandler(log_file, encoding='utf-8')
    file_handler.setFormatter(
        logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
    )
    logger = logging.getLogger(__name__)
    logger.addHandler(file_handler)
    return logger

def setup_device() -> Tuple[torch.device, Optional[List[int]]]:
    """配置训练设备，最大化利用所有可用NVIDIA GPU"""
    if torch.cuda.device_count() > 1:
        # 获取所有可用GPU
        device_count = torch.cuda.device_count()
        device_ids = list(range(device_count))
        device = torch.device(f'cuda:{device_ids[0]}')
        
        # 输出每个GPU的信息
        gpu_info = []
        for i in device_ids:
            gpu_name = torch.cuda.get_device_name(i)
            gpu_info.append(f"GPU {i}: {gpu_name}")
        
        logging.info(f"使用 {len(device_ids)} 个GPU设备: {device_ids}")
        logging.info("GPU详情: " + ", ".join(gpu_info))
        
        # 设置主设备，确保初始化顺序正确
        torch.cuda.set_device(device_ids[0])
        
        return device, device_ids
    elif torch.cuda.is_available():
        device = torch.device('cuda:0')
        gpu_name = torch.cuda.get_device_name(0)
        logging.info(f"使用单个GPU设备: {gpu_name}")
        return device, None
    else:
        device = torch.device('cpu')
        logging.info("使用CPU设备")
        return device, None

def calculate_class_weights(labels):
    """计算平方根缩放的类别权重"""
    class_counts = np.bincount(labels)
    logging.info(f"类别分布: 类别0: {class_counts[0]}, 类别1: {class_counts[1]}")
    
    # 使用平方根缩放计算权重
    weights_sqrt = np.sqrt(class_counts.sum() / class_counts / len(class_counts))
    return torch.FloatTensor(weights_sqrt)

def create_balanced_sampler(dataset):
    """创建平衡采样器"""
    # 提取数据集的标签
    if isinstance(dataset, TensorDataset):
        labels = dataset.tensors[1].numpy()
    elif isinstance(dataset, Subset):
        labels = dataset.dataset.tensors[1][dataset.indices].numpy()
    else:
        raise TypeError("不支持的数据集类型")
    
    # 计算类别权重（反比例，但不使用平方根缩放）
    class_counts = np.bincount(labels)
    logging.info(f"原始类别分布: {class_counts}")
    
    # 计算每个样本的权重
    class_weights = 1.0 / class_counts
    # 确保少数类有更高的采样概率
    sample_weights = class_weights[labels]
    
    # 创建采样器
    sampler = WeightedRandomSampler(
        weights=sample_weights,
        num_samples=len(sample_weights),
        replacement=True  # 允许重复采样
    )
    
    return sampler

def create_data_loaders_balanced(dataset, batch_size, num_gpus=1, is_train=True):
    """创建带有平衡采样的数据加载器"""
    effective_batch_size = batch_size * num_gpus if num_gpus > 1 else batch_size
    
    if is_train:
        # 训练集使用加权采样
        sampler = create_balanced_sampler(dataset)
        logging.info(f"批次大小: {batch_size} 调整后的批次大小: {effective_batch_size} (使用平衡采样)")
        return DataLoader(
            dataset,
            batch_size=effective_batch_size,
            sampler=sampler,  # 使用采样器替代shuffle
            num_workers=4 * num_gpus,
            pin_memory=True
        )
    else:
        # 验证集不需要平衡采样
        logging.info(f"批次大小: {batch_size} 调整后的批次大小: {effective_batch_size}")
        return DataLoader(
            dataset,
            batch_size=effective_batch_size,
            shuffle=False,
            num_workers=4 * num_gpus,
            pin_memory=True
        )

def create_data_loaders(dataset: TensorDataset, batch_size: int, num_gpus: int = 1) -> DataLoader:
    """创建数据加载器"""
    effective_batch_size = batch_size * num_gpus if num_gpus > 1 else batch_size
    logging.info(f"批次大小: {batch_size} 调整后的批次大小: {effective_batch_size}")
    
    return DataLoader(
        dataset,
        batch_size=effective_batch_size,
        shuffle=True,
        num_workers=4 * num_gpus,
        pin_memory=True
    )

def create_model(model_class, input_size, hidden_sizes, output_size, dropout_prob, device, device_ids=None):
    """创建模型"""
    model = model_class(
        input_size=input_size,
        hidden_sizes=hidden_sizes,
        output_size=output_size,
        dropout_prob=dropout_prob
    )
    
    if device_ids and len(device_ids) > 1:
        model = nn.DataParallel(model, device_ids=device_ids)
    
    return model.to(device)

def reshape_data_for_lstm(X: np.ndarray, seq_length: int) -> np.ndarray:
    """重塑数据为LSTM输入格式"""
    try:
        batch_size = X.shape[0]
        feature_per_timestamp = X.shape[1] // seq_length
        X_reshaped = X.reshape(batch_size, seq_length, feature_per_timestamp)
        logging.info(f"数据重塑成功: {X.shape} -> {X_reshaped.shape}")
        return X_reshaped
    except Exception as e:
        logging.error(f"数据重塑失败: {str(e)}")
        raise

def main_lstm(optimize: bool = False) -> None:
    """主训练函数 - 使用分层K折交叉验证和F1分数优化"""
    
    setup_logging()  # 设置日志
    device, device_ids = setup_device()
    base_path = r"C:\Users\USTC\Desktop\地磁论文（5级以上）"
    output_dir = os.path.join(base_path, '对比模型结果', 'LSTM模型结果')
    os.makedirs(output_dir, exist_ok=True)

    logging.info(f"开始训练流程 - 使用设备: {device}")

    window_mapping = {
        "window-7": {"name": "7天", "seq_length": 7},
        "window-14": {"name": "14天", "seq_length": 14},
        "window-30": {"name": "30天", "seq_length": 30}
    }

    try:
        # 训练参数设置
        training_config = {
            'hidden_sizes': [512, 256],    # 隐藏层大小，与MLP保持一致
            'num_layers': 2,               # 层数保持为2
            'dropout_prob': 0.3,           # dropout率
            'learning_rate': 0.001,        # 学习率
            'batch_size': 32,              # batch size
            'weight_decay': 0.01,          # L2正则化参数
            'max_grad_norm': 1.0           # 梯度裁剪阈值
        }
        
        optimizer_kwargs = {
            'lr': training_config['learning_rate'],
            'weight_decay': training_config['weight_decay']
        }
        
        scheduler_kwargs = {
            'mode': 'min',
            'factor': 0.1,
            'patience': 10,
            'min_lr': 1e-6,
            'verbose': True
        }
        
        num_gpus = len(device_ids) if device_ids else 1
        
        for window_period in ['7', '14', '30']:
            current_window_name = f"window-{window_period}"
            window_info = window_mapping[current_window_name]
            
            logging.info(f"\n=== 开始处理时间窗口: {window_info['name']} ===")

            try:
                # 加载数据
                data_dir = os.path.join(base_path, current_window_name)
                data_0 = np.load(os.path.join(data_dir, "data_0.npy"))
                data_1 = np.load(os.path.join(data_dir, "data_1.npy"))
                
                data = np.concatenate([data_0, data_1], axis=0)
                X = data[:, :-1]
                Y = data[:, -1].astype(int)
                
                # 记录类别分布
                class_counts = np.bincount(Y)
                logging.info(f"类别分布: 类别0: {class_counts[0]}, 类别1: {class_counts[1]}")
                
                # 计算类别权重，用于损失函数
                class_weights = calculate_class_weights(Y)
                logging.info(f"使用平方根缩放的类别权重: {class_weights}")
                weighted_loss = nn.CrossEntropyLoss(weight=class_weights)
                
                # 重塑数据为LSTM格式
                X = reshape_data_for_lstm(X, window_info['seq_length'])
                
                # 转换为张量
                X_tensor = torch.from_numpy(X).type(torch.float32)
                Y_tensor = torch.from_numpy(Y).type(torch.long)
                dataset = TensorDataset(X_tensor, Y_tensor)

                # 使用分层K折交叉验证训练
                results = kfold_train_eval_lstm(
                    model_class=LSTMModel,
                    dataset=dataset,
                    loss_fn=weighted_loss,  # 使用带权重的损失函数
                    optimizer_class=optim.AdamW,
                    optimizer_kwargs=optimizer_kwargs,
                    scheduler_class=optim.lr_scheduler.ReduceLROnPlateau,
                    scheduler_kwargs=scheduler_kwargs,
                    epochs=100,
                    device=device,
                    device_ids=device_ids,
                    num_folds=5,
                    output_dir=output_dir,
                    model_name="LSTMModel",
                    window_name=window_info['name'],
                    mapped_window_name=current_window_name,
                    input_size=X.shape[2],
                    output_size=2,
                    hidden_sizes=training_config['hidden_sizes'],
                    dropout_prob=training_config['dropout_prob'],
                    batch_size=training_config['batch_size'],
                    max_grad_norm=training_config['max_grad_norm']
                )

                # 执行基于F1分数的模型集成
                perform_model_ensemble(
                    model_name="LSTMModel",
                    window_name=window_info['name'],
                    output_dir=output_dir,
                    device=device,
                    device_ids=device_ids,
                    model_class=LSTMModel,
                    input_size=X.shape[2],
                    hidden_sizes=training_config['hidden_sizes'],
                    output_size=2,
                    dropout_prob=training_config['dropout_prob'],
                    num_folds=5
                )

            except Exception as e:
                logging.error(f"处理 {window_info['name']} 时出错: {str(e)}")
                logging.error("详细错误信息:", exc_info=True)
                continue

        logging.info("\n=== 所有处理完成！===")

    except Exception as e:
        logging.error(f"程序执行出错: {str(e)}")
        raise

def perform_model_ensemble(
    model_name: str,
    window_name: str,
    output_dir: str,
    device: torch.device,
    device_ids: Optional[List[int]],
    model_class: Any,
    input_size: int,
    hidden_sizes: List[int],
    output_size: int,
    dropout_prob: float,
    num_folds: int
) -> None:
    """
    执行模型集成过程，使用F1分数优化权重分配，同时保存全面的评估指标
    
    Args:
        model_name: 模型名称
        window_name: 时间窗口名称
        output_dir: 输出目录
        device: 设备
        device_ids: GPU设备ID列表
        model_class: 模型类
        input_size: 输入维度
        hidden_sizes: LSTM隐藏层大小列表
        output_size: 输出维度
        dropout_prob: Dropout概率
        num_folds: 折叠数量
    """
    from sklearn.metrics import f1_score, precision_score, recall_score, matthews_corrcoef, confusion_matrix
    
    logging.info(f"开始进行模型集成 - {model_name}_{window_name}")
    
    try:
        # 加载各个折叠的模型
        models = []
        model_metrics = {
            'f1_scores': [],            # F1分数
            'precisions': [],           # 精确率
            'recalls': [],              # 召回率
            'specificities': [],        # 特异性
            'mccs': [],                 # MCC
            'norm_mccs': []             # 归一化MCC
        }
        
        for fold in range(1, num_folds + 1):
            # 创建基础模型
            model = model_class(
                input_size=input_size,
                hidden_sizes=hidden_sizes,
                output_size=output_size,
                dropout_prob=dropout_prob
            ).to(device)
            
            if device_ids and len(device_ids) > 1:
                model = nn.DataParallel(model, device_ids=device_ids)
            
            # 加载模型权重
            model_path = os.path.join(output_dir, f"{model_name}_{window_name}_fold_{fold}.pth")
            if os.path.exists(model_path):
                state_dict = torch.load(model_path)
                if device_ids and len(device_ids) > 1:
                    if not list(state_dict.keys())[0].startswith('module.'):
                        state_dict = {'module.' + k: v for k, v in state_dict.items()}
                model.load_state_dict(state_dict)
                model.eval()
                models.append(model)
                
                # 加载验证数据，计算各项指标
                test_probs_path = os.path.join(output_dir, f"{model_name}_{window_name}_fold_{fold}_test_probs.npy")
                test_labels_path = os.path.join(output_dir, f"{model_name}_{window_name}_fold_{fold}_test_labels.npy")
                
                if os.path.exists(test_probs_path) and os.path.exists(test_labels_path):
                    test_probs = np.load(test_probs_path)
                    test_labels = np.load(test_labels_path)
                    
                    test_preds = np.argmax(test_probs, axis=1)
                    
                    # 计算所有评估指标
                    fold_f1 = f1_score(test_labels, test_preds, average='weighted')
                    fold_precision = precision_score(test_labels, test_preds, average='weighted')
                    fold_recall = recall_score(test_labels, test_preds, average='weighted')
                    
                    # 计算特异性 (针对二分类)
                    fold_cm = confusion_matrix(test_labels, test_preds)
                    fold_tn = fold_cm[0, 0]
                    fold_fp = fold_cm[0, 1]
                    fold_specificity = fold_tn / (fold_tn + fold_fp) if (fold_tn + fold_fp) > 0 else 0
                    
                    # 计算MCC和归一化MCC
                    fold_mcc = matthews_corrcoef(test_labels, test_preds)
                    fold_norm_mcc = (fold_mcc + 1) / 2  # 归一化到[0,1]区间
                    
                    # 确保F1分数非零(用于权重计算)
                    fold_f1 = max(fold_f1, 0.01)
                    
                    # 存储所有指标
                    model_metrics['f1_scores'].append(fold_f1)
                    model_metrics['precisions'].append(fold_precision)
                    model_metrics['recalls'].append(fold_recall)
                    model_metrics['specificities'].append(fold_specificity)
                    model_metrics['mccs'].append(fold_mcc)
                    model_metrics['norm_mccs'].append(fold_norm_mcc)
                    
                    logging.info(f"第 {fold} 折模型评估指标:")
                    logging.info(f"  F1分数: {fold_f1:.4f}")
                    logging.info(f"  精确率: {fold_precision:.4f}")
                    logging.info(f"  召回率: {fold_recall:.4f}")
                    logging.info(f"  特异性: {fold_specificity:.4f}")
                    logging.info(f"  MCC: {fold_mcc:.4f}")
                    logging.info(f"  归一化MCC: {fold_norm_mcc:.4f}")
                else:
                    # 如果找不到验证数据，从配置文件中尝试获取各项指标
                    config_path = os.path.join(output_dir, f"{model_name}_{window_name}_config.json")
                    if os.path.exists(config_path):
                        with open(config_path, 'r', encoding='utf-8') as f:
                            config = json.load(f)
                            fold_results = config['results']['fold_results']
                            fold_result = next((result for result in fold_results if result['fold'] == fold), None)
                            
                            if fold_result:
                                # 提取所有可用的指标
                                fold_f1 = fold_result.get('val_f1', 1.0)
                                model_metrics['f1_scores'].append(fold_f1)
                                
                                if 'val_precision' in fold_result:
                                    model_metrics['precisions'].append(fold_result['val_precision'])
                                else:
                                    model_metrics['precisions'].append(0.0)
                                    
                                if 'val_recall' in fold_result:
                                    model_metrics['recalls'].append(fold_result['val_recall'])
                                else:
                                    model_metrics['recalls'].append(0.0)
                                    
                                if 'val_specificity' in fold_result:
                                    model_metrics['specificities'].append(fold_result['val_specificity'])
                                else:
                                    model_metrics['specificities'].append(0.0)
                                    
                                if 'val_mcc' in fold_result:
                                    model_metrics['mccs'].append(fold_result['val_mcc'])
                                else:
                                    model_metrics['mccs'].append(0.0)
                                    
                                if 'val_norm_mcc' in fold_result:
                                    model_metrics['norm_mccs'].append(fold_result['val_norm_mcc'])
                                else:
                                    model_metrics['norm_mccs'].append(0.5)  # 0.5是归一化MCC的中间值
                                
                                logging.info(f"第 {fold} 折模型F1分数(从配置获取): {fold_f1:.4f}")
                            else:
                                # 如果找不到特定折的结果，使用默认值
                                model_metrics['f1_scores'].append(1.0)
                                model_metrics['precisions'].append(0.0)
                                model_metrics['recalls'].append(0.0)
                                model_metrics['specificities'].append(0.0)
                                model_metrics['mccs'].append(0.0)
                                model_metrics['norm_mccs'].append(0.5)
                                logging.warning(f"未找到第 {fold} 折的F1分数，使用默认值1.0")
                    else:
                        # 如果找不到配置文件，使用默认值
                        model_metrics['f1_scores'].append(1.0)
                        model_metrics['precisions'].append(0.0)
                        model_metrics['recalls'].append(0.0)
                        model_metrics['specificities'].append(0.0)
                        model_metrics['mccs'].append(0.0)
                        model_metrics['norm_mccs'].append(0.5)
                        logging.warning(f"未找到第 {fold} 折的验证集结果，使用默认F1=1.0")
                
                logging.info(f"已加载第 {fold} 折模型")
            else:
                logging.warning(f"未找到第 {fold} 折模型权重文件: {model_path}")
        
        if models:
            # 使用基于F1分数的集成权重
            weights = np.array(model_metrics['f1_scores'])
            weights = weights / weights.sum()
            logging.info(f"基于F1分数的模型权重: {weights}")
            
            # 创建集成模型
            ensemble_model = EnsembleModel(
                base_models=models,
                ensemble_weights=weights
            ).to(device)
            
            if device_ids and len(device_ids) > 1:
                ensemble_model = nn.DataParallel(ensemble_model, device_ids=device_ids)
            
            # 保存集成模型
            ensemble_path = os.path.join(output_dir, f"{model_name}_{window_name}.pth")
            torch.save(ensemble_model.state_dict(), ensemble_path)
            
            # 计算各项指标的平均值
            avg_metrics = {}
            for metric_name, values in model_metrics.items():
                if values:
                    avg_metrics[f'avg_{metric_name}'] = float(np.mean(values))
                    avg_metrics[f'std_{metric_name}'] = float(np.std(values))
            
            # 保存集成配置，包含所有评估指标
            ensemble_config = {
                'model_name': model_name,
                'window_name': window_name,
                'ensemble_weights': weights.tolist(),
                'ensemble_method': 'f1_weighted',  # 标记使用F1加权
                'model_params': {
                    'input_size': input_size,
                    'hidden_sizes': hidden_sizes,
                    'output_size': output_size,
                    'dropout_prob': dropout_prob
                },
                'fold_metrics': {
                    'f1_scores': model_metrics['f1_scores'],
                    'precisions': model_metrics['precisions'],
                    'recalls': model_metrics['recalls'],
                    'specificities': model_metrics['specificities'],
                    'mccs': model_metrics['mccs'],
                    'norm_mccs': model_metrics['norm_mccs']
                },
                'average_metrics': avg_metrics
            }
            
            config_path = os.path.join(output_dir, f"{model_name}_{window_name}_ensemble_config.json")
            with open(config_path, 'w', encoding='utf-8') as f:
                json.dump(ensemble_config, f, indent=4, ensure_ascii=False)
            
            # 输出集成模型的平均表现
            logging.info(f"F1加权集成模型已保存: {ensemble_path}")
            logging.info("集成模型平均评估指标:")
            for metric_name, value in avg_metrics.items():
                if metric_name.startswith('avg_'):
                    display_name = metric_name[4:].replace('_', ' ')
                    logging.info(f"  平均{display_name}: {value:.4f}")
            
            logging.info(f"集成配置已保存: {config_path}")
        else:
            logging.error("没有可用的模型进行集成")
            
    except Exception as e:
        logging.error(f"模型集成过程出错: {str(e)}")
        logging.error("详细错误信息:", exc_info=True)

def load_ensemble_model(
    model_path: str,
    config_path: str,
    device: torch.device,
    model_class: Any,
    device_ids: Optional[List[int]] = None
) -> EnsembleModel:
    """
    加载集成模型
    
    Args:
        model_path: 模型路径
        config_path: 配置文件路径
        device: 设备
        model_class: 模型类
        device_ids: GPU设备ID列表
    
    Returns:
        EnsembleModel: 加载的集成模型
    """
    with open(config_path, 'r') as f:
        config = json.load(f)
    
    base_models = []
    num_folds = len(config['ensemble_weights'])
    
    for _ in range(num_folds):
        model = model_class(
            input_size=config['model_params']['input_size'],
            hidden_sizes=config['model_params']['hidden_sizes'],
            output_size=config['model_params']['output_size'],
            dropout_prob=config['model_params']['dropout_prob']
        ).to(device)
        base_models.append(model)

    ensemble_model = EnsembleModel(
        base_models=base_models,
        ensemble_weights=config['ensemble_weights']
    ).to(device)
    
    if device_ids and len(device_ids) > 1:
        ensemble_model = nn.DataParallel(ensemble_model, device_ids=device_ids)
    
    ensemble_model.load_state_dict(torch.load(model_path))
    return ensemble_model

if __name__ == "__main__":
    main_lstm()
# Out:
# 2025-03-11 16:56:03 - INFO - 使用 2 个GPU设备: [0, 1]
# 2025-03-11 16:56:03 - INFO - GPU详情: GPU 0: NVIDIA GeForce RTX 4090, GPU 1: NVIDIA GeForce RTX 4090
# 2025-03-11 16:56:03 - INFO - 开始训练流程 - 使用设备: cuda:0
# 2025-03-11 16:56:03 - INFO -
# === 开始处理时间窗口: 7天 ===
# 2025-03-11 16:56:04 - INFO - 类别分布: 类别0: 1661, 类别1: 999
# 2025-03-11 16:56:04 - INFO - 类别分布: 类别0: 1661, 类别1: 999
# 2025-03-11 16:56:04 - INFO - 使用平方根缩放的类别权重: tensor([0.8948, 1.1538])
# 2025-03-11 16:56:04 - INFO - 数据重塑成功: (2660, 10080) -> (2660, 7, 1440)
# 2025-03-11 16:56:04 - INFO - 使用设备数量: 2
# 2025-03-11 16:56:04 - INFO - 批次大小: 32 调整后的批次大小: 64
# 2025-03-11 16:56:04 - INFO - 类别分布: 类别0: 1661, 类别1: 999
# 2025-03-11 16:56:04 - INFO - 使用带权重的损失函数，权重: [0.89483094 1.1538333 ]
# 2025-03-11 16:56:04 - INFO - 开始训练第 1/5 折
# 2025-03-11 16:56:04 - INFO - 训练集类别分布: 类别0: 1328, 类别1: 800
# 2025-03-11 16:56:04 - INFO - 验证集类别分布: 类别0: 333, 类别1: 199
# 2025-03-11 16:56:04 - INFO - 原始类别分布: [1328  800]
# 2025-03-11 16:56:04 - INFO - 批次大小: 32 调整后的批次大小: 64 (使用平衡采样)
# 2025-03-11 16:56:04 - INFO - 批次大小: 32 调整后的批次大小: 64
# c:\Users\USTC\anaconda3\envs\gpupytorch\lib\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# 2025-03-11 16:56:04 - INFO - 使用带权重的损失函数，权重: [0.89483094 1.1538333 ]
# 2025-03-11 16:56:14 - INFO - *** 新的最佳模型 (F1分数: 0.2707) ***
# 2025-03-11 16:56:14 - INFO - 轮次 1/100, 训练损失: 0.8007, 训练准确率: 0.4991, 类别0/1: 0.4108/0.5857, 训练F1: 0.4952, 训练精确率: 0.4982, 训练召回率: 0.4991, 训练特异性: 0.4108, 训练MCC: -0.0036, 训练归一化MCC: 0.4982, 验证损失: 0.8059, 验证准确率: 0.3896, 类别0/1: 0.0601/0.9497, 验证F1: 0.2707, 验证精确率: 0.5581, 验证召回率: 0.3929, 验证特异性: 0.0601, 验证MCC: 0.0206, 验证归一化MCC: 0.5103, 学习率: 0.001000
# 2025-03-11 16:56:14 - INFO - 本轮用时: 10.22 秒
# 2025-03-11 16:56:14 - INFO - ——————————————————————————————
# 2025-03-11 16:56:22 - INFO - *** 新的最佳模型 (F1分数: 0.5818) ***
# 2025-03-11 16:56:22 - INFO - 轮次 2/100, 训练损失: 0.7149, 训练准确率: 0.5542, 类别0/1: 0.4280/0.6758, 训练F1: 0.5443, 训练精确率: 0.5554, 训练召回率: 0.5512, 训练特异性: 0.4280, 训练MCC: 0.1072, 训练归一化MCC: 0.5536, 验证损失: 0.6712, 验证准确率: 0.5747, 类别0/1: 0.6577/0.4523, 验证F1: 0.5818, 验证精确率: 0.5830, 验证召回率: 0.5808, 验证特异性: 0.6577, 验证MCC: 0.1094, 验证归一化MCC: 0.5547, 学习率: 0.001000
# 2025-03-11 16:56:22 - INFO - 本轮用时: 8.21 秒
# 2025-03-11 16:56:22 - INFO - ——————————————————————————————
# 2025-03-11 16:56:32 - INFO - 轮次 3/100, 训练损失: 0.6821, 训练准确率: 0.5625, 类别0/1: 0.4023/0.7085, 训练F1: 0.5475, 训练精确率: 0.5610, 训练召回率: 0.5583, 训练特异性: 0.4023, 训练MCC: 0.1164, 训练归一化MCC: 0.5582, 验证损失: 0.6972, 验证准确率: 0.6132, 类别0/1: 0.9459/0.0704, 验证F1: 0.5187, 验证精确率: 0.5580, 验证召回率: 0.6184, 验证特异性: 0.9459, 验证MCC: 0.0332, 验证归一化MCC: 0.5166, 学习率: 0.001000
# 2025-03-11 16:56:32 - INFO - 本轮用时: 9.86 秒
# 2025-03-11 16:56:32 - INFO - ——————————————————————————————
# 2025-03-11 16:56:42 - INFO - 轮次 4/100, 训练损失: 0.6689, 训练准确率: 0.5731, 类别0/1: 0.4017/0.7386, 训练F1: 0.5593, 训练精确率: 0.5790, 训练召回率: 0.5719, 训练特异性: 0.4017, 训练MCC: 0.1491, 训练归一化MCC: 0.5746, 验证损失: 0.8477, 验证准确率: 0.4434, 类别0/1: 0.1171/0.9548, 验证F1: 0.3363, 验证精确率: 0.6554, 验证召回率: 0.4305, 验证特异性: 0.1171, 验证MCC: 0.1214, 验证归一化MCC: 0.5607, 学习率: 0.001000
# 2025-03-11 16:56:42 - INFO - 本轮用时: 9.88 秒
# 2025-03-11 16:56:42 - INFO - ——————————————————————————————
# 2025-03-11 16:56:51 - INFO - *** 新的最佳模型 (F1分数: 0.6304) ***
# 2025-03-11 16:56:51 - INFO - 轮次 5/100, 训练损失: 0.6501, 训练准确率: 0.5938, 类别0/1: 0.4040/0.7881, 训练F1: 0.5739, 训练精确率: 0.6141, 训练召回率: 0.5888, 训练特异性: 0.4040, 训练MCC: 0.2072, 训练归一化MCC: 0.6036, 验证损失: 0.6410, 验证准确率: 0.6361, 类别0/1: 0.7658/0.4271, 验证F1: 0.6304, 验证精确率: 0.6276, 验证召回率: 0.6391, 验证特异性: 0.7658, 验证MCC: 0.2025, 验证归一化MCC: 0.6012, 学习率: 0.001000
# 2025-03-11 16:56:51 - INFO - 本轮用时: 9.48 秒
# 2025-03-11 16:56:51 - INFO - ——————————————————————————————
# 2025-03-11 16:57:01 - INFO - 轮次 6/100, 训练损失: 0.6429, 训练准确率: 0.6158, 类别0/1: 0.4375/0.8019, 训练F1: 0.6029, 训练精确率: 0.6387, 训练召回率: 0.6156, 训练特异性: 0.4375, 训练MCC: 0.2565, 训练归一化MCC: 0.6282, 验证损失: 0.6699, 验证准确率: 0.6191, 类别0/1: 0.7898/0.3266, 验证F1: 0.5966, 验证精确率: 0.5948, 验证召回率: 0.6165, 验证特异性: 0.7898, 验证MCC: 0.1295, 验证归一化MCC: 0.5647, 学习率: 0.001000
# 2025-03-11 16:57:01 - INFO - 本轮用时: 9.45 秒
# 2025-03-11 16:57:01 - INFO - ——————————————————————————————
# 2025-03-11 16:57:11 - INFO - *** 新的最佳模型 (F1分数: 0.6626) ***
# 2025-03-11 16:57:11 - INFO - 轮次 7/100, 训练损失: 0.6368, 训练准确率: 0.6172, 类别0/1: 0.4817/0.7531, 训练F1: 0.6099, 训练精确率: 0.6268, 训练召回率: 0.6170, 训练特异性: 0.4817, 训练MCC: 0.2439, 训练归一化MCC: 0.6219, 验证损失: 0.6283, 验证准确率: 0.6625, 类别0/1: 0.7387/0.5377, 验证F1: 0.6626, 验证精确率: 0.6619, 验证召回率: 0.6635, 验证特异性: 0.7387, 验证MCC: 0.2779, 验证归一化MCC: 0.6389, 学习率: 0.001000
# 2025-03-11 16:57:11 - INFO - 本轮用时: 9.70 秒
# 2025-03-11 16:57:11 - INFO - ——————————————————————————————
# 2025-03-11 16:57:18 - INFO - 轮次 8/100, 训练损失: 0.6163, 训练准确率: 0.6402, 类别0/1: 0.4767/0.8004, 训练F1: 0.6306, 训练精确率: 0.6546, 训练召回率: 0.6405, 训练特异性: 0.4767, 训练MCC: 0.2932, 训练归一化MCC: 0.6466, 验证损失: 0.7223, 验证准确率: 0.5677, 类别0/1: 0.3634/0.9246, 验证F1: 0.5543, 验证精确率: 0.7307, 验证召回率: 0.5733, 验证特异性: 0.3634, 验证MCC: 0.3195, 验证归一化MCC: 0.6597, 学习率: 0.001000
# 2025-03-11 16:57:18 - INFO - 本轮用时: 7.48 秒
# 2025-03-11 16:57:18 - INFO - ——————————————————————————————
# 2025-03-11 16:57:26 - INFO - *** 新的最佳模型 (F1分数: 0.6672) ***
# 2025-03-11 16:57:26 - INFO - 轮次 9/100, 训练损失: 0.6130, 训练准确率: 0.6374, 类别0/1: 0.4730/0.7946, 训练F1: 0.6251, 训练精确率: 0.6491, 训练召回率: 0.6349, 训练特异性: 0.4730, 训练MCC: 0.2828, 训练归一化MCC: 0.6414, 验证损失: 0.6707, 验证准确率: 0.6642, 类别0/1: 0.7147/0.5829, 验证F1: 0.6672, 验证精确率: 0.6697, 验证召回率: 0.6654, 验证特异性: 0.7147, 验证MCC: 0.2944, 验证归一化MCC: 0.6472, 学习率: 0.001000
# 2025-03-11 16:57:26 - INFO - 本轮用时: 7.69 秒
# 2025-03-11 16:57:26 - INFO - ——————————————————————————————
# 2025-03-11 16:57:33 - INFO - 轮次 10/100, 训练损失: 0.6054, 训练准确率: 0.6369, 类别0/1: 0.5230/0.7640, 训练F1: 0.6340, 训练精确率: 0.6534, 训练召回率: 0.6386, 训练特异性: 0.5230, 训练MCC: 0.2946, 训练归一化MCC: 0.6473, 验证损失: 0.6375, 验证准确率: 0.6340, 类别0/1: 0.5736/0.7538, 验证F1: 0.6458, 验证精确率: 0.6903, 验证召回率: 0.6410, 验证特异性: 0.5736, 验证MCC: 0.3183, 验证归一化MCC: 0.6592, 学习率: 0.001000
# 2025-03-11 16:57:33 - INFO - 本轮用时: 7.00 秒
# 2025-03-11 16:57:33 - INFO - ——————————————————————————————
# 2025-03-11 16:57:40 - INFO - *** 新的最佳模型 (F1分数: 0.6917) ***
# 2025-03-11 16:57:40 - INFO - 轮次 11/100, 训练损失: 0.5702, 训练准确率: 0.6733, 类别0/1: 0.5438/0.7904, 训练F1: 0.6634, 训练精确率: 0.6778, 训练召回率: 0.6687, 训练特异性: 0.5438, 训练MCC: 0.3452, 训练归一化MCC: 0.6726, 验证损失: 0.5805, 验证准确率: 0.7038, 类别0/1: 0.7538/0.5879, 验证F1: 0.6917, 验证精确率: 0.6917, 验证召回率: 0.6917, 验证特异性: 0.7538, 验证MCC: 0.3417, 验证归一化MCC: 0.6708, 学习率: 0.001000
# 2025-03-11 16:57:40 - INFO - 本轮用时: 7.23 秒
# 2025-03-11 16:57:40 - INFO - ——————————————————————————————
# 2025-03-11 16:57:47 - INFO - 轮次 12/100, 训练损失: 0.5730, 训练准确率: 0.6824, 类别0/1: 0.5930/0.7756, 训练F1: 0.6824, 训练精确率: 0.6906, 训练召回率: 0.6852, 训练特异性: 0.5930, 训练MCC: 0.3751, 训练归一化MCC: 0.6876, 验证损失: 0.6896, 验证准确率: 0.5559, 类别0/1: 0.3363/0.9246, 验证F1: 0.5327, 验证精确率: 0.7220, 验证召回率: 0.5564, 验证特异性: 0.3363, 验证MCC: 0.2962, 验证归一化MCC: 0.6481, 学习率: 0.001000
# 2025-03-11 16:57:47 - INFO - 本轮用时: 7.01 秒
# 2025-03-11 16:57:47 - INFO - ——————————————————————————————
# 2025-03-11 16:57:54 - INFO - 轮次 13/100, 训练损失: 0.5343, 训练准确率: 0.7142, 类别0/1: 0.6386/0.7989, 训练F1: 0.7159, 训练精确率: 0.7246, 训练召回率: 0.7176, 训练特异性: 0.6386, 训练MCC: 0.4427, 训练归一化MCC: 0.7213, 验证损失: 0.9130, 验证准确率: 0.5003, 类别0/1: 0.2252/0.9497, 验证F1: 0.4435, 验证精确率: 0.7105, 验证召回率: 0.4962, 验证特异性: 0.2252, 验证MCC: 0.2311, 验证归一化MCC: 0.6155, 学习率: 0.001000
# 2025-03-11 16:57:54 - INFO - 本轮用时: 7.08 秒
# 2025-03-11 16:57:54 - INFO - ——————————————————————————————
# 2025-03-11 16:58:01 - INFO - *** 新的最佳模型 (F1分数: 0.6966) ***
# 2025-03-11 16:58:01 - INFO - 轮次 14/100, 训练损失: 0.5540, 训练准确率: 0.6958, 类别0/1: 0.6056/0.7864, 训练F1: 0.6910, 训练精确率: 0.7031, 训练召回率: 0.6931, 训练特异性: 0.6056, 训练MCC: 0.3975, 训练归一化MCC: 0.6988, 验证损失: 0.6237, 验证准确率: 0.6809, 类别0/1: 0.6396/0.7789, 验证F1: 0.6966, 验证精确率: 0.7296, 验证召回率: 0.6917, 验证特异性: 0.6396, 验证MCC: 0.4053, 验证归一化MCC: 0.7026, 学习率: 0.001000
# 2025-03-11 16:58:01 - INFO - 本轮用时: 7.25 秒
# 2025-03-11 16:58:01 - INFO - ——————————————————————————————
# 2025-03-11 16:58:09 - INFO - 轮次 15/100, 训练损失: 0.5338, 训练准确率: 0.7275, 类别0/1: 0.6756/0.7769, 训练F1: 0.7250, 训练精确率: 0.7287, 训练召回率: 0.7256, 训练特异性: 0.6756, 训练MCC: 0.4546, 训练归一化MCC: 0.7273, 验证损失: 0.6461, 验证准确率: 0.6462, 类别0/1: 0.4535/0.9347, 验证F1: 0.6258, 验证精确率: 0.7654, 验证召回率: 0.6335, 验证特异性: 0.4535, 验证MCC: 0.4067, 验证归一化MCC: 0.7034, 学习率: 0.001000
# 2025-03-11 16:58:09 - INFO - 本轮用时: 7.35 秒
# 2025-03-11 16:58:09 - INFO - ——————————————————————————————
# 2025-03-11 16:58:16 - INFO - *** 新的最佳模型 (F1分数: 0.7344) ***
# 2025-03-11 16:58:16 - INFO - 轮次 16/100, 训练损失: 0.4928, 训练准确率: 0.7459, 类别0/1: 0.6940/0.8024, 训练F1: 0.7454, 训练精确率: 0.7515, 训练召回率: 0.7458, 训练特异性: 0.6940, 训练MCC: 0.4977, 训练归一化MCC: 0.7489, 验证损失: 0.5862, 验证准确率: 0.7375, 类别0/1: 0.8468/0.5628, 验证F1: 0.7344, 验证精确率: 0.7354, 验证召回率: 0.7406, 验证特异性: 0.8468, 验证MCC: 0.4300, 验证归一化MCC: 0.7150, 学习率: 0.001000
# 2025-03-11 16:58:16 - INFO - 本轮用时: 6.94 秒
# 2025-03-11 16:58:16 - INFO - ——————————————————————————————
# 2025-03-11 16:58:23 - INFO - 轮次 17/100, 训练损失: 0.4767, 训练准确率: 0.7551, 类别0/1: 0.6984/0.8127, 训练F1: 0.7544, 训练精确率: 0.7589, 训练召回率: 0.7552, 训练特异性: 0.6984, 训练MCC: 0.5143, 训练归一化MCC: 0.7571, 验证损失: 0.6035, 验证准确率: 0.7417, 类别0/1: 0.9550/0.3719, 验证F1: 0.7052, 验证精确率: 0.7603, 验证召回率: 0.7368, 验证特异性: 0.9550, 验证MCC: 0.4237, 验证归一化MCC: 0.7118, 学习率: 0.001000
# 2025-03-11 16:58:23 - INFO - 本轮用时: 7.46 秒
# 2025-03-11 16:58:23 - INFO - ——————————————————————————————
# 2025-03-11 16:58:30 - INFO - 轮次 18/100, 训练损失: 0.4748, 训练准确率: 0.7610, 类别0/1: 0.7022/0.8151, 训练F1: 0.7577, 训练精确率: 0.7620, 训练召回率: 0.7585, 训练特异性: 0.7022, 训练MCC: 0.5205, 训练归一化MCC: 0.7603, 验证损失: 0.7770, 验证准确率: 0.6736, 类别0/1: 0.9610/0.1759, 验证F1: 0.5963, 验证精确率: 0.6866, 验证召回率: 0.6673, 验证特异性: 0.9610, 验证MCC: 0.2311, 验证归一化MCC: 0.6156, 学习率: 0.001000
# 2025-03-11 16:58:30 - INFO - 本轮用时: 6.81 秒
# 2025-03-11 16:58:30 - INFO - ——————————————————————————————
# 2025-03-11 16:58:37 - INFO - *** 新的最佳模型 (F1分数: 0.7860) ***
# 2025-03-11 16:58:37 - INFO - 轮次 19/100, 训练损失: 0.4418, 训练准确率: 0.7918, 类别0/1: 0.7510/0.8253, 训练F1: 0.7882, 训练精确率: 0.7898, 训练召回率: 0.7885, 训练特异性: 0.7510, 训练MCC: 0.5781, 训练归一化MCC: 0.7890, 验证损失: 0.4720, 验证准确率: 0.8003, 类别0/1: 0.7898/0.7739, 验证F1: 0.7860, 验证精确率: 0.7917, 验证召回率: 0.7838, 验证特异性: 0.7898, 验证MCC: 0.5524, 验证归一化MCC: 0.7762, 学习率: 0.001000
# 2025-03-11 16:58:37 - INFO - 本轮用时: 6.73 秒
# 2025-03-11 16:58:37 - INFO - ——————————————————————————————
# 2025-03-11 16:58:43 - INFO - 轮次 20/100, 训练损失: 0.4270, 训练准确率: 0.8006, 类别0/1: 0.7478/0.8445, 训练F1: 0.7969, 训练精确率: 0.7992, 训练召回率: 0.7975, 训练特异性: 0.7478, 训练MCC: 0.5959, 训练归一化MCC: 0.7979, 验证损失: 0.6489, 验证准确率: 0.6736, 类别0/1: 0.5616/0.8995, 验证F1: 0.6891, 验证精确率: 0.7715, 验证召回率: 0.6880, 验证特异性: 0.5616, 验证MCC: 0.4576, 验证归一化MCC: 0.7288, 学习率: 0.001000
# 2025-03-11 16:58:43 - INFO - 本轮用时: 6.69 秒
# 2025-03-11 16:58:43 - INFO - ——————————————————————————————
# 2025-03-11 16:58:50 - INFO - *** 新的最佳模型 (F1分数: 0.8201) ***
# 2025-03-11 16:58:50 - INFO - 轮次 21/100, 训练损失: 0.4091, 训练准确率: 0.8139, 类别0/1: 0.7730/0.8484, 训练F1: 0.8108, 训练精确率: 0.8125, 训练召回率: 0.8111, 训练特异性: 0.7730, 训练MCC: 0.6235, 训练归一化MCC: 0.8117, 验证损失: 0.4957, 验证准确率: 0.8163, 类别0/1: 0.7988/0.8492, 验证F1: 0.8201, 验证精确率: 0.8304, 验证召回率: 0.8177, 验证特异性: 0.7988, 验证MCC: 0.6312, 验证归一化MCC: 0.8156, 学习率: 0.001000
# 2025-03-11 16:58:50 - INFO - 本轮用时: 6.85 秒
# 2025-03-11 16:58:50 - INFO - ——————————————————————————————
# 2025-03-11 16:58:57 - INFO - 轮次 22/100, 训练损失: 0.4129, 训练准确率: 0.8056, 类别0/1: 0.7443/0.8661, 训练F1: 0.8047, 训练精确率: 0.8099, 训练召回率: 0.8055, 训练特异性: 0.7443, 训练MCC: 0.6152, 训练归一化MCC: 0.8076, 验证损失: 0.4762, 验证准确率: 0.8028, 类别0/1: 0.7778/0.8342, 验证F1: 0.8017, 验证精确率: 0.8139, 验证召回率: 0.7989, 验证特异性: 0.7778, 验证MCC: 0.5951, 验证归一化MCC: 0.7975, 学习率: 0.001000
# 2025-03-11 16:58:57 - INFO - 本轮用时: 7.10 秒
# 2025-03-11 16:58:57 - INFO - ——————————————————————————————
# 2025-03-11 16:59:05 - INFO - 轮次 23/100, 训练损失: 0.3999, 训练准确率: 0.8194, 类别0/1: 0.7795/0.8589, 训练F1: 0.8180, 训练精确率: 0.8211, 训练召回率: 0.8181, 训练特异性: 0.7795, 训练MCC: 0.6394, 训练归一化MCC: 0.8197, 验证损失: 0.4884, 验证准确率: 0.8024, 类别0/1: 0.8108/0.7889, 验证F1: 0.8044, 验证精确率: 0.8086, 验证召回率: 0.8026, 验证特异性: 0.8108, 验证MCC: 0.5893, 验证归一化MCC: 0.7946, 学习率: 0.001000
# 2025-03-11 16:59:05 - INFO - 本轮用时: 7.94 秒
# 2025-03-11 16:59:05 - INFO - ——————————————————————————————
# 2025-03-11 16:59:13 - INFO - 轮次 24/100, 训练损失: 0.3965, 训练准确率: 0.8281, 类别0/1: 0.7865/0.8679, 训练F1: 0.8268, 训练精确率: 0.8294, 训练召回率: 0.8271, 训练特异性: 0.7865, 训练MCC: 0.6565, 训练归一化MCC: 0.8282, 验证损失: 0.4587, 验证准确率: 0.8188, 类别0/1: 0.7868/0.8543, 验证F1: 0.8147, 验证精确率: 0.8274, 验证召回率: 0.8120, 验证特异性: 0.7868, 验证MCC: 0.6231, 验证归一化MCC: 0.8116, 学习率: 0.001000
# 2025-03-11 16:59:13 - INFO - 本轮用时: 7.57 秒
# 2025-03-11 16:59:13 - INFO - ——————————————————————————————
# 2025-03-11 16:59:20 - INFO - 轮次 25/100, 训练损失: 0.3609, 训练准确率: 0.8332, 类别0/1: 0.8013/0.8646, 训练F1: 0.8322, 训练精确率: 0.8341, 训练召回率: 0.8322, 训练特异性: 0.8013, 训练MCC: 0.6665, 训练归一化MCC: 0.8332, 验证损失: 0.6500, 验证准确率: 0.7115, 类别0/1: 0.5946/0.9095, 验证F1: 0.7144, 验证精确率: 0.7880, 验证召回率: 0.7124, 验证特异性: 0.5946, 验证MCC: 0.4967, 验证归一化MCC: 0.7484, 学习率: 0.001000
# 2025-03-11 16:59:20 - INFO - 本轮用时: 6.79 秒
# 2025-03-11 16:59:20 - INFO - ——————————————————————————————
# 2025-03-11 16:59:26 - INFO - *** 新的最佳模型 (F1分数: 0.8316) ***
# 2025-03-11 16:59:26 - INFO - 轮次 26/100, 训练损失: 0.3859, 训练准确率: 0.8244, 类别0/1: 0.7905/0.8626, 训练F1: 0.8272, 训练精确率: 0.8286, 训练召回率: 0.8275, 训练特异性: 0.7905, 训练MCC: 0.6556, 训练归一化MCC: 0.8278, 验证损失: 0.4048, 验证准确率: 0.8323, 类别0/1: 0.8498/0.7990, 验证F1: 0.8316, 验证精确率: 0.8330, 验证召回率: 0.8308, 验证特异性: 0.8498, 验证MCC: 0.6429, 验证归一化MCC: 0.8214, 学习率: 0.001000
# 2025-03-11 16:59:26 - INFO - 本轮用时: 6.81 秒
# 2025-03-11 16:59:26 - INFO - ——————————————————————————————
# 2025-03-11 16:59:33 - INFO - *** 新的最佳模型 (F1分数: 0.8332) ***
# 2025-03-11 16:59:33 - INFO - 轮次 27/100, 训练损失: 0.3322, 训练准确率: 0.8511, 类别0/1: 0.8220/0.8825, 训练F1: 0.8519, 训练精确率: 0.8535, 训练召回率: 0.8520, 训练特异性: 0.8220, 训练MCC: 0.7055, 训练归一化MCC: 0.8527, 验证损失: 0.4999, 验证准确率: 0.8208, 类别0/1: 0.8018/0.8794, 验证F1: 0.8332, 验证精确率: 0.8459, 验证召回率: 0.8308, 验证特异性: 0.8018, 验证MCC: 0.6622, 验证归一化MCC: 0.8311, 学习率: 0.001000
# 2025-03-11 16:59:33 - INFO - 本轮用时: 6.71 秒
# 2025-03-11 16:59:33 - INFO - ——————————————————————————————
# 2025-03-11 16:59:40 - INFO - *** 新的最佳模型 (F1分数: 0.8398) ***
# 2025-03-11 16:59:40 - INFO - 轮次 28/100, 训练损失: 0.3317, 训练准确率: 0.8552, 类别0/1: 0.8200/0.8887, 训练F1: 0.8546, 训练精确率: 0.8562, 训练召回率: 0.8548, 训练特异性: 0.8200, 训练MCC: 0.7108, 训练归一化MCC: 0.8554, 验证损失: 0.3793, 验证准确率: 0.8392, 类别0/1: 0.8378/0.8392, 验证F1: 0.8398, 验证精确率: 0.8442, 验证召回率: 0.8383, 验证特异性: 0.8378, 验证MCC: 0.6648, 验证归一化MCC: 0.8324, 学习率: 0.001000
# 2025-03-11 16:59:40 - INFO - 本轮用时: 6.70 秒
# 2025-03-11 16:59:40 - INFO - ——————————————————————————————
# 2025-03-11 16:59:47 - INFO - 轮次 29/100, 训练损失: 0.3126, 训练准确率: 0.8663, 类别0/1: 0.8381/0.8924, 训练F1: 0.8646, 训练精确率: 0.8662, 训练召回率: 0.8647, 训练特异性: 0.8381, 训练MCC: 0.7309, 训练归一化MCC: 0.8654, 验证损失: 0.4596, 验证准确率: 0.8247, 类别0/1: 0.9339/0.6583, 验证F1: 0.8252, 验证精确率: 0.8339, 验证召回率: 0.8308, 验证特异性: 0.9339, 验证MCC: 0.6331, 验证归一化MCC: 0.8165, 学习率: 0.001000
# 2025-03-11 16:59:47 - INFO - 本轮用时: 7.28 秒
# 2025-03-11 16:59:47 - INFO - ——————————————————————————————
# 2025-03-11 16:59:55 - INFO - *** 新的最佳模型 (F1分数: 0.8499) ***
# 2025-03-11 16:59:55 - INFO - 轮次 30/100, 训练损失: 0.3090, 训练准确率: 0.8681, 类别0/1: 0.8436/0.8969, 训练F1: 0.8706, 训练精确率: 0.8715, 训练召回率: 0.8708, 训练特异性: 0.8436, 训练MCC: 0.7420, 训练归一化MCC: 0.8710, 验证损失: 0.4165, 验证准确率: 0.8608, 类别0/1: 0.9369/0.7136, 验证F1: 0.8499, 验证精确率: 0.8551, 验证召回率: 0.8534, 验证特异性: 0.9369, 验证MCC: 0.6828, 验证归一化MCC: 0.8414, 学习率: 0.001000
# 2025-03-11 16:59:55 - INFO - 本轮用时: 7.75 秒
# 2025-03-11 16:59:55 - INFO - ——————————————————————————————
# 2025-03-11 17:00:02 - INFO - 轮次 31/100, 训练损失: 0.2983, 训练准确率: 0.8764, 类别0/1: 0.8505/0.9035, 训练F1: 0.8777, 训练精确率: 0.8784, 训练召回率: 0.8778, 训练特异性: 0.8505, 训练MCC: 0.7558, 训练归一化MCC: 0.8779, 验证损失: 0.4456, 验证准确率: 0.8108, 类别0/1: 0.7958/0.8492, 验证F1: 0.8182, 验证精确率: 0.8290, 验证召回率: 0.8158, 验证特异性: 0.7958, 验证MCC: 0.6280, 验证归一化MCC: 0.8140, 学习率: 0.001000
# 2025-03-11 17:00:02 - INFO - 本轮用时: 7.55 秒
# 2025-03-11 17:00:02 - INFO - ——————————————————————————————
# 2025-03-11 17:00:10 - INFO - *** 新的最佳模型 (F1分数: 0.8656) ***
# 2025-03-11 17:00:10 - INFO - 轮次 32/100, 训练损失: 0.3023, 训练准确率: 0.8722, 类别0/1: 0.8405/0.9052, 训练F1: 0.8734, 训练精确率: 0.8747, 训练召回率: 0.8736, 训练特异性: 0.8405, 训练MCC: 0.7481, 训练归一化MCC: 0.8740, 验证损失: 0.3573, 验证准确率: 0.8674, 类别0/1: 0.8679/0.8593, 验证F1: 0.8656, 验证精确率: 0.8682, 验证召回率: 0.8647, 验证特异性: 0.8679, 验证MCC: 0.7170, 验证归一化MCC: 0.8585, 学习率: 0.001000
# 2025-03-11 17:00:10 - INFO - 本轮用时: 7.23 秒
# 2025-03-11 17:00:10 - INFO - ——————————————————————————————
# 2025-03-11 17:00:17 - INFO - 轮次 33/100, 训练损失: 0.2871, 训练准确率: 0.8833, 类别0/1: 0.8586/0.9178, 训练F1: 0.8876, 训练精确率: 0.8893, 训练召回率: 0.8877, 训练特异性: 0.8586, 训练MCC: 0.7771, 训练归一化MCC: 0.8885, 验证损失: 0.4731, 验证准确率: 0.8059, 类别0/1: 0.7267/0.9397, 验证F1: 0.8094, 验证精确率: 0.8480, 验证召回率: 0.8064, 验证特异性: 0.7267, 验证MCC: 0.6456, 验证归一化MCC: 0.8228, 学习率: 0.001000
# 2025-03-11 17:00:17 - INFO - 本轮用时: 7.18 秒
# 2025-03-11 17:00:17 - INFO - ——————————————————————————————
# 2025-03-11 17:00:24 - INFO - 轮次 34/100, 训练损失: 0.2682, 训练准确率: 0.8814, 类别0/1: 0.8563/0.9080, 训练F1: 0.8828, 训练精确率: 0.8836, 训练召回率: 0.8830, 训练特异性: 0.8563, 训练MCC: 0.7662, 训练归一化MCC: 0.8831, 验证损失: 0.3993, 验证准确率: 0.8514, 类别0/1: 0.8048/0.9296, 验证F1: 0.8538, 验证精确率: 0.8717, 验证召回率: 0.8515, 验证特异性: 0.8048, 验证MCC: 0.7121, 验证归一化MCC: 0.8560, 学习率: 0.001000
# 2025-03-11 17:00:24 - INFO - 本轮用时: 7.24 秒
# 2025-03-11 17:00:24 - INFO - ——————————————————————————————
# 2025-03-11 17:00:32 - INFO - 轮次 35/100, 训练损失: 0.2513, 训练准确率: 0.8934, 类别0/1: 0.8703/0.9254, 训练F1: 0.8979, 训练精确率: 0.8991, 训练召回率: 0.8980, 训练特异性: 0.8703, 训练MCC: 0.7971, 训练归一化MCC: 0.8986, 验证损失: 0.3966, 验证准确率: 0.8601, 类别0/1: 0.9309/0.7437, 验证F1: 0.8584, 验证精确率: 0.8613, 验证召回率: 0.8609, 验证特异性: 0.9309, 验证MCC: 0.6990, 验证归一化MCC: 0.8495, 学习率: 0.001000
# 2025-03-11 17:00:32 - INFO - 本轮用时: 7.63 秒
# 2025-03-11 17:00:32 - INFO - ——————————————————————————————
# 2025-03-11 17:00:40 - INFO - 轮次 36/100, 训练损失: 0.2671, 训练准确率: 0.8842, 类别0/1: 0.8651/0.9088, 训练F1: 0.8871, 训练精确率: 0.8878, 训练召回率: 0.8872, 训练特异性: 0.8651, 训练MCC: 0.7750, 训练归一化MCC: 0.8875, 验证损失: 0.3912, 验证准确率: 0.8556, 类别0/1: 0.8859/0.7839, 验证F1: 0.8473, 验证精确率: 0.8471, 验证召回率: 0.8477, 验证特异性: 0.8859, 验证MCC: 0.6733, 验证归一化MCC: 0.8367, 学习率: 0.001000
# 2025-03-11 17:00:40 - INFO - 本轮用时: 8.86 秒
# 2025-03-11 17:00:40 - INFO - ——————————————————————————————
# 2025-03-11 17:00:50 - INFO - 轮次 37/100, 训练损失: 0.2866, 训练准确率: 0.8833, 类别0/1: 0.8563/0.9124, 训练F1: 0.8847, 训练精确率: 0.8858, 训练召回率: 0.8849, 训练特异性: 0.8563, 训练MCC: 0.7705, 训练归一化MCC: 0.8852, 验证损失: 0.3673, 验证准确率: 0.8635, 类别0/1: 0.8679/0.8593, 验证F1: 0.8656, 验证精确率: 0.8682, 验证召回率: 0.8647, 验证特异性: 0.8679, 验证MCC: 0.7170, 验证归一化MCC: 0.8585, 学习率: 0.001000
# 2025-03-11 17:00:50 - INFO - 本轮用时: 9.69 秒
# 2025-03-11 17:00:50 - INFO - ——————————————————————————————
# 2025-03-11 17:01:00 - INFO - 轮次 38/100, 训练损失: 0.2511, 训练准确率: 0.8957, 类别0/1: 0.8844/0.9077, 训练F1: 0.8961, 训练精确率: 0.8963, 训练召回率: 0.8961, 训练特异性: 0.8844, 训练MCC: 0.7924, 训练归一化MCC: 0.8962, 验证损失: 0.4120, 验证准确率: 0.8385, 类别0/1: 0.7928/0.9347, 验证F1: 0.8483, 验证精确率: 0.8694, 验证召回率: 0.8459, 验证特异性: 0.7928, 验证MCC: 0.7046, 验证归一化MCC: 0.8523, 学习率: 0.001000
# 2025-03-11 17:01:00 - INFO - 本轮用时: 9.66 秒
# 2025-03-11 17:01:00 - INFO - ——————————————————————————————
# 2025-03-11 17:01:09 - INFO - *** 新的最佳模型 (F1分数: 0.8792) ***
# 2025-03-11 17:01:09 - INFO - 轮次 39/100, 训练损失: 0.2166, 训练准确率: 0.9049, 类别0/1: 0.8908/0.9197, 训练F1: 0.9055, 训练精确率: 0.9058, 训练召回率: 0.9055, 训练特异性: 0.8908, 训练MCC: 0.8112, 训练归一化MCC: 0.9056, 验证损失: 0.3470, 验证准确率: 0.8872, 类别0/1: 0.8589/0.9095, 验证F1: 0.8792, 验证精确率: 0.8858, 验证召回率: 0.8778, 验证特异性: 0.8589, 验证MCC: 0.7513, 验证归一化MCC: 0.8757, 学习率: 0.001000
# 2025-03-11 17:01:09 - INFO - 本轮用时: 9.54 秒
# 2025-03-11 17:01:09 - INFO - ——————————————————————————————
# 2025-03-11 17:01:19 - INFO - 轮次 40/100, 训练损失: 0.2083, 训练准确率: 0.9177, 类别0/1: 0.9034/0.9315, 训练F1: 0.9173, 训练精确率: 0.9177, 训练召回率: 0.9173, 训练特异性: 0.9034, 训练MCC: 0.8350, 训练归一化MCC: 0.9175, 验证损失: 0.4087, 验证准确率: 0.8417, 类别0/1: 0.8168/0.9146, 验证F1: 0.8555, 验证精确率: 0.8693, 验证召回率: 0.8534, 验证特异性: 0.8168, 验证MCC: 0.7105, 验证归一化MCC: 0.8552, 学习率: 0.001000
# 2025-03-11 17:01:19 - INFO - 本轮用时: 9.38 秒
# 2025-03-11 17:01:19 - INFO - ——————————————————————————————
# 2025-03-11 17:01:28 - INFO - 轮次 41/100, 训练损失: 0.1976, 训练准确率: 0.9145, 类别0/1: 0.8997/0.9340, 训练F1: 0.9168, 训练精确率: 0.9173, 训练召回率: 0.9168, 训练特异性: 0.8997, 训练MCC: 0.8342, 训练归一化MCC: 0.9171, 验证损失: 0.4651, 验证准确率: 0.8347, 类别0/1: 0.7598/0.9347, 验证F1: 0.8280, 验证精确率: 0.8569, 验证召回率: 0.8252, 验证特异性: 0.7598, 验证MCC: 0.6720, 验证归一化MCC: 0.8360, 学习率: 0.001000
# 2025-03-11 17:01:28 - INFO - 本轮用时: 9.60 秒
# 2025-03-11 17:01:28 - INFO - ——————————————————————————————
# 2025-03-11 17:01:38 - INFO - *** 新的最佳模型 (F1分数: 0.8852) ***
# 2025-03-11 17:01:38 - INFO - 轮次 42/100, 训练损失: 0.1862, 训练准确率: 0.9182, 类别0/1: 0.8972/0.9378, 训练F1: 0.9177, 训练精确率: 0.9183, 训练召回率: 0.9178, 训练特异性: 0.8972, 训练MCC: 0.8360, 训练归一化MCC: 0.9180, 验证损失: 0.4121, 验证准确率: 0.8865, 类别0/1: 0.9129/0.8392, 验证F1: 0.8852, 验证精确率: 0.8850, 验证召回率: 0.8853, 验证特异性: 0.9129, 验证MCC: 0.7545, 验证归一化MCC: 0.8772, 学习率: 0.001000
# 2025-03-11 17:01:38 - INFO - 本轮用时: 9.44 秒
# 2025-03-11 17:01:38 - INFO - ——————————————————————————————
# 2025-03-11 17:01:48 - INFO - 轮次 43/100, 训练损失: 0.2066, 训练准确率: 0.9141, 类别0/1: 0.9029/0.9300, 训练F1: 0.9163, 训练精确率: 0.9167, 训练召回率: 0.9164, 训练特异性: 0.9029, 训练MCC: 0.8331, 训练归一化MCC: 0.9165, 验证损失: 0.4346, 验证准确率: 0.8267, 类别0/1: 0.7688/0.9296, 验证F1: 0.8317, 验证精确率: 0.8576, 验证召回率: 0.8289, 验证特异性: 0.7688, 验证MCC: 0.6760, 验证归一化MCC: 0.8380, 学习率: 0.001000
# 2025-03-11 17:01:48 - INFO - 本轮用时: 9.76 秒
# 2025-03-11 17:01:48 - INFO - ——————————————————————————————
# 2025-03-11 17:01:57 - INFO - 轮次 44/100, 训练损失: 0.2066, 训练准确率: 0.9269, 类别0/1: 0.9156/0.9350, 训练F1: 0.9253, 训练精确率: 0.9255, 训练召回率: 0.9253, 训练特异性: 0.9156, 训练MCC: 0.8507, 训练归一化MCC: 0.9254, 验证损失: 0.4473, 验证准确率: 0.8399, 类别0/1: 0.7748/0.9246, 验证F1: 0.8335, 验证精确率: 0.8573, 验证召回率: 0.8308, 验证特异性: 0.7748, 验证MCC: 0.6771, 验证归一化MCC: 0.8385, 学习率: 0.001000
# 2025-03-11 17:01:57 - INFO - 本轮用时: 9.78 秒
# 2025-03-11 17:01:57 - INFO - ——————————————————————————————
# 2025-03-11 17:02:07 - INFO - *** 新的最佳模型 (F1分数: 0.8998) ***
# 2025-03-11 17:02:07 - INFO - 轮次 45/100, 训练损失: 0.2019, 训练准确率: 0.9145, 类别0/1: 0.8965/0.9315, 训练F1: 0.9140, 训练精确率: 0.9145, 训练召回率: 0.9140, 训练特异性: 0.8965, 训练MCC: 0.8285, 训练归一化MCC: 0.9143, 验证损失: 0.3235, 验证准确率: 0.9042, 类别0/1: 0.9369/0.8392, 验证F1: 0.8998, 验证精确率: 0.9000, 验证召回率: 0.9004, 验证特异性: 0.9369, 验证MCC: 0.7856, 验证归一化MCC: 0.8928, 学习率: 0.001000
# 2025-03-11 17:02:07 - INFO - 本轮用时: 9.62 秒
# 2025-03-11 17:02:07 - INFO - ——————————————————————————————
# 2025-03-11 17:02:17 - INFO - *** 新的最佳模型 (F1分数: 0.9038) ***
# 2025-03-11 17:02:17 - INFO - 轮次 46/100, 训练损失: 0.1886, 训练准确率: 0.9334, 类别0/1: 0.9216/0.9477, 训练F1: 0.9347, 训练精确率: 0.9350, 训练召回率: 0.9347, 训练特异性: 0.9216, 训练MCC: 0.8696, 训练归一化MCC: 0.9348, 验证损失: 0.3341, 验证准确率: 0.8962, 类别0/1: 0.9339/0.8543, 验证F1: 0.9038, 验证精确率: 0.9037, 验证召回率: 0.9041, 验证特异性: 0.9339, 验证MCC: 0.7941, 验证归一化MCC: 0.8971, 学习率: 0.001000
# 2025-03-11 17:02:17 - INFO - 本轮用时: 10.21 秒
# 2025-03-11 17:02:17 - INFO - ——————————————————————————————
# 2025-03-11 17:02:27 - INFO - 轮次 47/100, 训练损失: 0.1897, 训练准确率: 0.9228, 类别0/1: 0.8963/0.9544, 训练F1: 0.9239, 训练精确率: 0.9260, 训练召回率: 0.9239, 训练特异性: 0.8963, 训练MCC: 0.8497, 训练归一化MCC: 0.9248, 验证损失: 0.4010, 验证准确率: 0.8764, 类别0/1: 0.9730/0.6985, 验证F1: 0.8654, 验证精确率: 0.8794, 验证召回率: 0.8703, 验证特异性: 0.9730, 验证MCC: 0.7251, 验证归一化MCC: 0.8625, 学习率: 0.001000
# 2025-03-11 17:02:27 - INFO - 本轮用时: 10.19 秒
# 2025-03-11 17:02:27 - INFO - ——————————————————————————————
# 2025-03-11 17:02:38 - INFO - 轮次 48/100, 训练损失: 0.1765, 训练准确率: 0.9256, 类别0/1: 0.9195/0.9309, 训练F1: 0.9253, 训练精确率: 0.9253, 训练召回率: 0.9253, 训练特异性: 0.9195, 训练MCC: 0.8505, 训练归一化MCC: 0.9253, 验证损失: 0.3735, 验证准确率: 0.8660, 类别0/1: 0.8168/0.9296, 验证F1: 0.8611, 验证精确率: 0.8766, 验证召回率: 0.8590, 验证特异性: 0.8168, 验证MCC: 0.7244, 验证归一化MCC: 0.8622, 学习率: 0.001000
# 2025-03-11 17:02:38 - INFO - 本轮用时: 10.18 秒
# 2025-03-11 17:02:38 - INFO - ——————————————————————————————
# 2025-03-11 17:02:48 - INFO - 轮次 49/100, 训练损失: 0.1439, 训练准确率: 0.9389, 类别0/1: 0.9280/0.9522, 训练F1: 0.9403, 训练精确率: 0.9405, 训练召回率: 0.9403, 训练特异性: 0.9280, 训练MCC: 0.8807, 训练归一化MCC: 0.9404, 验证损失: 0.3820, 验证准确率: 0.8813, 类别0/1: 0.8949/0.9095, 验证F1: 0.9011, 验证精确率: 0.9037, 验证召回率: 0.9004, 验证特异性: 0.8949, 验证MCC: 0.7926, 验证归一化MCC: 0.8963, 学习率: 0.001000
# 2025-03-11 17:02:48 - INFO - 本轮用时: 10.50 秒
# 2025-03-11 17:02:48 - INFO - ——————————————————————————————
# 2025-03-11 17:02:58 - INFO - 轮次 50/100, 训练损失: 0.1369, 训练准确率: 0.9481, 类别0/1: 0.9403/0.9538, 训练F1: 0.9469, 训练精确率: 0.9470, 训练召回率: 0.9469, 训练特异性: 0.9403, 训练MCC: 0.8939, 训练归一化MCC: 0.9469, 验证损失: 0.3628, 验证准确率: 0.8764, 类别0/1: 0.8348/0.9296, 验证F1: 0.8721, 验证精确率: 0.8843, 验证召回率: 0.8703, 验证特异性: 0.8348, 验证MCC: 0.7434, 验证归一化MCC: 0.8717, 学习率: 0.001000
# 2025-03-11 17:02:58 - INFO - 本轮用时: 9.73 秒
# 2025-03-11 17:02:58 - INFO - ——————————————————————————————
# 2025-03-11 17:03:07 - INFO - *** 新的最佳模型 (F1分数: 0.9095) ***
# 2025-03-11 17:03:07 - INFO - 轮次 51/100, 训练损失: 0.1810, 训练准确率: 0.9251, 类别0/1: 0.9167/0.9389, 训练F1: 0.9276, 训练精确率: 0.9279, 训练召回率: 0.9276, 训练特异性: 0.9167, 训练MCC: 0.8555, 训练归一化MCC: 0.9278, 验证损失: 0.3036, 验证准确率: 0.9167, 类别0/1: 0.9369/0.8643, 验证F1: 0.9095, 验证精确率: 0.9094, 验证召回率: 0.9098, 验证特异性: 0.9369, 验证MCC: 0.8064, 验证归一化MCC: 0.9032, 学习率: 0.001000
# 2025-03-11 17:03:07 - INFO - 本轮用时: 8.90 秒
# 2025-03-11 17:03:07 - INFO - ——————————————————————————————
# 2025-03-11 17:03:16 - INFO - *** 新的最佳模型 (F1分数: 0.9169) ***
# 2025-03-11 17:03:16 - INFO - 轮次 52/100, 训练损失: 0.1620, 训练准确率: 0.9297, 类别0/1: 0.9241/0.9320, 训练F1: 0.9281, 训练精确率: 0.9281, 训练召回率: 0.9281, 训练特异性: 0.9241, 训练MCC: 0.8562, 训练归一化MCC: 0.9281, 验证损失: 0.2813, 验证准确率: 0.9198, 类别0/1: 0.9459/0.8693, 验证F1: 0.9169, 验证精确率: 0.9170, 验证召回率: 0.9173, 验证特异性: 0.9459, 验证MCC: 0.8224, 验证归一化MCC: 0.9112, 学习率: 0.001000
# 2025-03-11 17:03:16 - INFO - 本轮用时: 9.43 秒
# 2025-03-11 17:03:16 - INFO - ——————————————————————————————
# 2025-03-11 17:03:26 - INFO - *** 新的最佳模型 (F1分数: 0.9299) ***
# 2025-03-11 17:03:26 - INFO - 轮次 53/100, 训练损失: 0.1647, 训练准确率: 0.9361, 类别0/1: 0.9241/0.9545, 训练F1: 0.9389, 训练精确率: 0.9395, 训练召回率: 0.9389, 训练特异性: 0.9241, 训练MCC: 0.8783, 训练归一化MCC: 0.9392, 验证损失: 0.3264, 验证准确率: 0.9243, 类别0/1: 0.9640/0.8744, 验证F1: 0.9299, 验证精确率: 0.9306, 验证召回率: 0.9305, 验证特异性: 0.9640, 验证MCC: 0.8507, 验证归一化MCC: 0.9253, 学习率: 0.001000
# 2025-03-11 17:03:26 - INFO - 本轮用时: 9.69 秒
# 2025-03-11 17:03:26 - INFO - ——————————————————————————————
# 2025-03-11 17:03:35 - INFO - 轮次 54/100, 训练损失: 0.1407, 训练准确率: 0.9517, 类别0/1: 0.9499/0.9514, 训练F1: 0.9507, 训练精确率: 0.9507, 训练召回率: 0.9507, 训练特异性: 0.9499, 训练MCC: 0.9013, 训练归一化MCC: 0.9507, 验证损失: 0.3459, 验证准确率: 0.9003, 类别0/1: 0.9550/0.8090, 验证F1: 0.8990, 验证精确率: 0.9013, 验证召回率: 0.9004, 验证特异性: 0.9550, 验证MCC: 0.7857, 验证归一化MCC: 0.8929, 学习率: 0.001000
# 2025-03-11 17:03:35 - INFO - 本轮用时: 8.90 秒
# 2025-03-11 17:03:35 - INFO - ——————————————————————————————
# 2025-03-11 17:03:44 - INFO - 轮次 55/100, 训练损失: 0.1205, 训练准确率: 0.9522, 类别0/1: 0.9471/0.9579, 训练F1: 0.9525, 训练精确率: 0.9526, 训练召回率: 0.9525, 训练特异性: 0.9471, 训练MCC: 0.9051, 训练归一化MCC: 0.9526, 验证损失: 0.3524, 验证准确率: 0.8990, 类别0/1: 0.8739/0.9296, 验证F1: 0.8959, 验证精确率: 0.9021, 验证召回率: 0.8947, 验证特异性: 0.8739, 验证MCC: 0.7861, 验证归一化MCC: 0.8931, 学习率: 0.001000
# 2025-03-11 17:03:44 - INFO - 本轮用时: 8.96 秒
# 2025-03-11 17:03:44 - INFO - ——————————————————————————————
# 2025-03-11 17:03:52 - INFO - 轮次 56/100, 训练损失: 0.1354, 训练准确率: 0.9517, 类别0/1: 0.9447/0.9595, 训练F1: 0.9521, 训练精确率: 0.9522, 训练召回率: 0.9521, 训练特异性: 0.9447, 训练MCC: 0.9042, 训练归一化MCC: 0.9521, 验证损失: 0.5339, 验证准确率: 0.8274, 类别0/1: 0.7508/0.9397, 验证F1: 0.8243, 验证精确率: 0.8563, 验证召回率: 0.8214, 验证特异性: 0.7508, 验证MCC: 0.6683, 验证归一化MCC: 0.8341, 学习率: 0.001000
# 2025-03-11 17:03:52 - INFO - 本轮用时: 8.60 秒
# 2025-03-11 17:03:52 - INFO - ——————————————————————————————
# 2025-03-11 17:04:01 - INFO - 轮次 57/100, 训练损失: 0.1254, 训练准确率: 0.9513, 类别0/1: 0.9471/0.9534, 训练F1: 0.9502, 训练精确率: 0.9502, 训练召回率: 0.9502, 训练特异性: 0.9471, 训练MCC: 0.9003, 训练归一化MCC: 0.9502, 验证损失: 0.3398, 验证准确率: 0.9038, 类别0/1: 0.9009/0.9095, 验证F1: 0.9048, 验证精确率: 0.9069, 验证召回率: 0.9041, 验证特异性: 0.9009, 验证MCC: 0.7997, 验证归一化MCC: 0.8999, 学习率: 0.001000
# 2025-03-11 17:04:01 - INFO - 本轮用时: 8.62 秒
# 2025-03-11 17:04:01 - INFO - ——————————————————————————————
# 2025-03-11 17:04:09 - INFO - 轮次 58/100, 训练损失: 0.1642, 训练准确率: 0.9301, 类别0/1: 0.9127/0.9505, 训练F1: 0.9314, 训练精确率: 0.9321, 训练召回率: 0.9314, 训练特异性: 0.9127, 训练MCC: 0.8635, 训练归一化MCC: 0.9318, 验证损失: 0.3275, 验证准确率: 0.9003, 类别0/1: 0.8799/0.9347, 验证F1: 0.9014, 验证精确率: 0.9072, 验证召回率: 0.9004, 验证特异性: 0.8799, 验证MCC: 0.7974, 验证归一化MCC: 0.8987, 学习率: 0.001000
# 2025-03-11 17:04:09 - INFO - 本轮用时: 8.58 秒
# 2025-03-11 17:04:09 - INFO - ——————————————————————————————
# 2025-03-11 17:04:19 - INFO - 轮次 59/100, 训练损失: 0.1389, 训练准确率: 0.9416, 类别0/1: 0.9419/0.9472, 训练F1: 0.9445, 训练精确率: 0.9446, 训练召回率: 0.9445, 训练特异性: 0.9419, 训练MCC: 0.8891, 训练归一化MCC: 0.9446, 验证损失: 0.2891, 验证准确率: 0.9087, 类别0/1: 0.9069/0.9246, 验证F1: 0.9141, 验证精确率: 0.9164, 验证召回率: 0.9135, 验证特异性: 0.9069, 验证MCC: 0.8199, 验证归一化MCC: 0.9100, 学习率: 0.001000
# 2025-03-11 17:04:19 - INFO - 本轮用时: 9.32 秒
# 2025-03-11 17:04:19 - INFO - ——————————————————————————————
# 2025-03-11 17:04:28 - INFO - 轮次 60/100, 训练损失: 0.1237, 训练准确率: 0.9531, 类别0/1: 0.9460/0.9585, 训练F1: 0.9521, 训练精确率: 0.9522, 训练召回率: 0.9521, 训练特异性: 0.9460, 训练MCC: 0.9042, 训练归一化MCC: 0.9521, 验证损失: 0.4037, 验证准确率: 0.8920, 类别0/1: 0.8559/0.9397, 验证F1: 0.8887, 验证精确率: 0.8983, 验证召回率: 0.8872, 验证特异性: 0.8559, 验证MCC: 0.7752, 验证归一化MCC: 0.8876, 学习率: 0.001000
# 2025-03-11 17:04:28 - INFO - 本轮用时: 8.77 秒
# 2025-03-11 17:04:28 - INFO - ——————————————————————————————
# 2025-03-11 17:04:36 - INFO - 轮次 61/100, 训练损失: 0.1511, 训练准确率: 0.9398, 类别0/1: 0.9296/0.9530, 训练F1: 0.9413, 训练精确率: 0.9415, 训练召回率: 0.9413, 训练特异性: 0.9296, 训练MCC: 0.8828, 训练归一化MCC: 0.9414, 验证损失: 0.3160, 验证准确率: 0.9125, 类别0/1: 0.9640/0.8291, 验证F1: 0.9124, 验证精确率: 0.9147, 验证召回率: 0.9135, 验证特异性: 0.9640, 验证MCC: 0.8145, 验证归一化MCC: 0.9072, 学习率: 0.001000
# 2025-03-11 17:04:36 - INFO - 本轮用时: 8.37 秒
# 2025-03-11 17:04:36 - INFO - ——————————————————————————————
# 2025-03-11 17:04:44 - INFO - 轮次 62/100, 训练损失: 0.1048, 训练准确率: 0.9655, 类别0/1: 0.9571/0.9722, 训练F1: 0.9648, 训练精确率: 0.9648, 训练召回率: 0.9648, 训练特异性: 0.9571, 训练MCC: 0.9296, 训练归一化MCC: 0.9648, 验证损失: 0.3355, 验证准确率: 0.8972, 类别0/1: 0.8799/0.9146, 验证F1: 0.8939, 验证精确率: 0.8983, 验证召回率: 0.8929, 验证特异性: 0.8799, 验证MCC: 0.7796, 验证归一化MCC: 0.8898, 学习率: 0.001000
# 2025-03-11 17:04:44 - INFO - 本轮用时: 8.09 秒
# 2025-03-11 17:04:44 - INFO - ——————————————————————————————
# 2025-03-11 17:04:52 - INFO - 轮次 63/100, 训练损失: 0.1186, 训练准确率: 0.9522, 类别0/1: 0.9466/0.9557, 训练F1: 0.9511, 训练精确率: 0.9512, 训练召回率: 0.9511, 训练特异性: 0.9466, 训练MCC: 0.9023, 训练归一化MCC: 0.9511, 验证损失: 0.2962, 验证准确率: 0.9146, 类别0/1: 0.9249/0.8894, 验证F1: 0.9118, 验证精确率: 0.9120, 验证召回率: 0.9117, 验证特异性: 0.9249, 验证MCC: 0.8120, 验证归一化MCC: 0.9060, 学习率: 0.000100
# 2025-03-11 17:04:52 - INFO - 本轮用时: 8.16 秒
# 2025-03-11 17:04:52 - INFO - ——————————————————————————————
# 2025-03-11 17:05:00 - INFO - 轮次 64/100, 训练损失: 0.0930, 训练准确率: 0.9573, 类别0/1: 0.9561/0.9620, 训练F1: 0.9591, 训练精确率: 0.9591, 训练召回率: 0.9591, 训练特异性: 0.9561, 训练MCC: 0.9182, 训练归一化MCC: 0.9591, 验证损失: 0.3103, 验证准确率: 0.9104, 类别0/1: 0.9129/0.9196, 验证F1: 0.9159, 验证精确率: 0.9175, 验证召回率: 0.9154, 验证特异性: 0.9129, 验证MCC: 0.8228, 验证归一化MCC: 0.9114, 学习率: 0.000100
# 2025-03-11 17:05:00 - INFO - 本轮用时: 8.06 秒
# 2025-03-11 17:05:00 - INFO - ——————————————————————————————
# 2025-03-11 17:05:08 - INFO - 轮次 65/100, 训练损失: 0.0760, 训练准确率: 0.9701, 类别0/1: 0.9658/0.9728, 训练F1: 0.9695, 训练精确率: 0.9695, 训练召回率: 0.9695, 训练特异性: 0.9658, 训练MCC: 0.9388, 训练归一化MCC: 0.9694, 验证损失: 0.3083, 验证准确率: 0.9156, 类别0/1: 0.9279/0.9095, 验证F1: 0.9213, 验证精确率: 0.9218, 验证召回率: 0.9211, 验证特异性: 0.9279, 验证MCC: 0.8327, 验证归一化MCC: 0.9163, 学习率: 0.000100
# 2025-03-11 17:05:08 - INFO - 本轮用时: 7.78 秒
# 2025-03-11 17:05:08 - INFO - ——————————————————————————————
# 2025-03-11 17:05:16 - INFO - 轮次 66/100, 训练损失: 0.0779, 训练准确率: 0.9743, 类别0/1: 0.9667/0.9866, 训练F1: 0.9765, 训练精确率: 0.9767, 训练召回率: 0.9765, 训练特异性: 0.9667, 训练MCC: 0.9532, 训练归一化MCC: 0.9766, 验证损失: 0.3182, 验证准确率: 0.9250, 类别0/1: 0.9429/0.8894, 验证F1: 0.9228, 验证精确率: 0.9228, 验证召回率: 0.9229, 验证特异性: 0.9429, 验证MCC: 0.8350, 验证归一化MCC: 0.9175, 学习率: 0.000100
# 2025-03-11 17:05:16 - INFO - 本轮用时: 7.57 秒
# 2025-03-11 17:05:16 - INFO - ——————————————————————————————
# 2025-03-11 17:05:24 - INFO - 轮次 67/100, 训练损失: 0.0669, 训练准确率: 0.9770, 类别0/1: 0.9721/0.9810, 训练F1: 0.9765, 训练精确率: 0.9765, 训练召回率: 0.9765, 训练特异性: 0.9721, 训练MCC: 0.9530, 训练归一化MCC: 0.9765, 验证损失: 0.2846, 验证准确率: 0.9250, 类别0/1: 0.9309/0.9095, 验证F1: 0.9231, 验证精确率: 0.9235, 验证召回率: 0.9229, 验证特异性: 0.9309, 验证MCC: 0.8364, 验证归一化MCC: 0.9182, 学习率: 0.000100
# 2025-03-11 17:05:24 - INFO - 本轮用时: 7.96 秒
# 2025-03-11 17:05:24 - INFO - ——————————————————————————————
# 2025-03-11 17:05:32 - INFO - 轮次 68/100, 训练损失: 0.0544, 训练准确率: 0.9770, 类别0/1: 0.9782/0.9748, 训练F1: 0.9765, 训练精确率: 0.9765, 训练召回率: 0.9765, 训练特异性: 0.9782, 训练MCC: 0.9530, 训练归一化MCC: 0.9765, 验证损失: 0.2758, 验证准确率: 0.9288, 类别0/1: 0.9309/0.9095, 验证F1: 0.9231, 验证精确率: 0.9235, 验证召回率: 0.9229, 验证特异性: 0.9309, 验证MCC: 0.8364, 验证归一化MCC: 0.9182, 学习率: 0.000100
# 2025-03-11 17:05:32 - INFO - 本轮用时: 8.13 秒
# 2025-03-11 17:05:32 - INFO - ——————————————————————————————
# 2025-03-11 17:05:40 - INFO - 轮次 69/100, 训练损失: 0.0781, 训练准确率: 0.9729, 类别0/1: 0.9672/0.9870, 训练F1: 0.9765, 训练精确率: 0.9768, 训练召回率: 0.9765, 训练特异性: 0.9672, 训练MCC: 0.9531, 训练归一化MCC: 0.9766, 验证损失: 0.3030, 验证准确率: 0.9170, 类别0/1: 0.9339/0.9146, 验证F1: 0.9269, 验证精确率: 0.9272, 验证召回率: 0.9267, 验证特异性: 0.9339, 验证MCC: 0.8444, 验证归一化MCC: 0.9222, 学习率: 0.000100
# 2025-03-11 17:05:40 - INFO - 本轮用时: 7.83 秒
# 2025-03-11 17:05:40 - INFO - ——————————————————————————————
# 2025-03-11 17:05:48 - INFO - 轮次 70/100, 训练损失: 0.0614, 训练准确率: 0.9738, 类别0/1: 0.9666/0.9800, 训练F1: 0.9732, 训练精确率: 0.9733, 训练召回率: 0.9732, 训练特异性: 0.9666, 训练MCC: 0.9465, 训练归一化MCC: 0.9733, 验证损失: 0.2626, 验证准确率: 0.9323, 类别0/1: 0.9369/0.9095, 验证F1: 0.9268, 验证精确率: 0.9270, 验证召回率: 0.9267, 验证特异性: 0.9369, 验证MCC: 0.8440, 验证归一化MCC: 0.9220, 学习率: 0.000100
# 2025-03-11 17:05:48 - INFO - 本轮用时: 8.52 秒
# 2025-03-11 17:05:48 - INFO - ——————————————————————————————
# 2025-03-11 17:05:56 - INFO - 轮次 71/100, 训练损失: 0.0635, 训练准确率: 0.9715, 类别0/1: 0.9688/0.9731, 训练F1: 0.9709, 训练精确率: 0.9709, 训练召回率: 0.9709, 训练特异性: 0.9688, 训练MCC: 0.9417, 训练归一化MCC: 0.9709, 验证损失: 0.2824, 验证准确率: 0.9302, 类别0/1: 0.9369/0.9146, 验证F1: 0.9287, 验证精确率: 0.9290, 验证召回率: 0.9286, 验证特异性: 0.9369, 验证MCC: 0.8482, 验证归一化MCC: 0.9241, 学习率: 0.000100
# 2025-03-11 17:05:56 - INFO - 本轮用时: 8.09 秒
# 2025-03-11 17:05:56 - INFO - ——————————————————————————————
# 2025-03-11 17:06:03 - INFO - 轮次 72/100, 训练损失: 0.0435, 训练准确率: 0.9830, 类别0/1: 0.9759/0.9895, 训练F1: 0.9826, 训练精确率: 0.9827, 训练召回率: 0.9826, 训练特异性: 0.9759, 训练MCC: 0.9653, 训练归一化MCC: 0.9827, 验证损失: 0.2823, 验证准确率: 0.9285, 类别0/1: 0.9339/0.9146, 验证F1: 0.9269, 验证精确率: 0.9272, 验证召回率: 0.9267, 验证特异性: 0.9339, 验证MCC: 0.8444, 验证归一化MCC: 0.9222, 学习率: 0.000100
# 2025-03-11 17:06:03 - INFO - 本轮用时: 6.89 秒
# 2025-03-11 17:06:03 - INFO - ——————————————————————————————
# 2025-03-11 17:06:10 - INFO - *** 新的最佳模型 (F1分数: 0.9324) ***
# 2025-03-11 17:06:10 - INFO - 轮次 73/100, 训练损失: 0.0525, 训练准确率: 0.9775, 类别0/1: 0.9718/0.9825, 训练F1: 0.9770, 训练精确率: 0.9771, 训练召回率: 0.9770, 训练特异性: 0.9718, 训练MCC: 0.9540, 训练归一化MCC: 0.9770, 验证损失: 0.2673, 验证准确率: 0.9299, 类别0/1: 0.9429/0.9146, 验证F1: 0.9324, 验证精确率: 0.9325, 验证召回率: 0.9323, 验证特异性: 0.9429, 验证MCC: 0.8558, 验证归一化MCC: 0.9279, 学习率: 0.000100
# 2025-03-11 17:06:10 - INFO - 本轮用时: 6.64 秒
# 2025-03-11 17:06:10 - INFO - ——————————————————————————————
# 2025-03-11 17:06:16 - INFO - 轮次 74/100, 训练损失: 0.0489, 训练准确率: 0.9812, 类别0/1: 0.9789/0.9825, 训练F1: 0.9807, 训练精确率: 0.9807, 训练召回率: 0.9807, 训练特异性: 0.9789, 训练MCC: 0.9614, 训练归一化MCC: 0.9807, 验证损失: 0.2645, 验证准确率: 0.9264, 类别0/1: 0.9399/0.9095, 验证F1: 0.9286, 验证精确率: 0.9287, 验证召回率: 0.9286, 验证特异性: 0.9399, 验证MCC: 0.8478, 验证归一化MCC: 0.9239, 学习率: 0.000100
# 2025-03-11 17:06:16 - INFO - 本轮用时: 6.51 秒
# 2025-03-11 17:06:16 - INFO - ——————————————————————————————
# 2025-03-11 17:06:23 - INFO - *** 新的最佳模型 (F1分数: 0.9343) ***
# 2025-03-11 17:06:23 - INFO - 轮次 75/100, 训练损失: 0.0564, 训练准确率: 0.9784, 类别0/1: 0.9798/0.9816, 训练F1: 0.9807, 训练精确率: 0.9807, 训练召回率: 0.9807, 训练特异性: 0.9798, 训练MCC: 0.9614, 训练归一化MCC: 0.9807, 验证损失: 0.2625, 验证准确率: 0.9392, 类别0/1: 0.9429/0.9196, 验证F1: 0.9343, 验证精确率: 0.9345, 验证召回率: 0.9342, 验证特异性: 0.9429, 验证MCC: 0.8600, 验证归一化MCC: 0.9300, 学习率: 0.000100
# 2025-03-11 17:06:23 - INFO - 本轮用时: 6.56 秒
# 2025-03-11 17:06:23 - INFO - ——————————————————————————————
# 2025-03-11 17:06:29 - INFO - 轮次 76/100, 训练损失: 0.0465, 训练准确率: 0.9807, 类别0/1: 0.9718/0.9887, 训练F1: 0.9803, 训练精确率: 0.9804, 训练召回率: 0.9803, 训练特异性: 0.9718, 训练MCC: 0.9607, 训练归一化MCC: 0.9803, 验证损失: 0.2812, 验证准确率: 0.9299, 类别0/1: 0.9429/0.9146, 验证F1: 0.9324, 验证精确率: 0.9325, 验证召回率: 0.9323, 验证特异性: 0.9429, 验证MCC: 0.8558, 验证归一化MCC: 0.9279, 学习率: 0.000100
# 2025-03-11 17:06:29 - INFO - 本轮用时: 6.54 秒
# 2025-03-11 17:06:29 - INFO - ——————————————————————————————
# 2025-03-11 17:06:36 - INFO - 轮次 77/100, 训练损失: 0.0415, 训练准确率: 0.9862, 类别0/1: 0.9861/0.9857, 训练F1: 0.9859, 训练精确率: 0.9859, 训练召回率: 0.9859, 训练特异性: 0.9861, 训练MCC: 0.9718, 训练归一化MCC: 0.9859, 验证损失: 0.2856, 验证准确率: 0.9281, 类别0/1: 0.9399/0.9146, 验证F1: 0.9306, 验证精确率: 0.9307, 验证召回率: 0.9305, 验证特异性: 0.9399, 验证MCC: 0.8520, 验证归一化MCC: 0.9260, 学习率: 0.000100
# 2025-03-11 17:06:36 - INFO - 本轮用时: 6.59 秒
# 2025-03-11 17:06:36 - INFO - ——————————————————————————————
# 2025-03-11 17:06:42 - INFO - 轮次 78/100, 训练损失: 0.0506, 训练准确率: 0.9812, 类别0/1: 0.9754/0.9864, 训练F1: 0.9807, 训练精确率: 0.9808, 训练召回率: 0.9807, 训练特异性: 0.9754, 训练MCC: 0.9615, 训练归一化MCC: 0.9808, 验证损失: 0.2701, 验证准确率: 0.9319, 类别0/1: 0.9369/0.9196, 验证F1: 0.9306, 验证精确率: 0.9310, 验证召回率: 0.9305, 验证特异性: 0.9369, 验证MCC: 0.8524, 验证归一化MCC: 0.9262, 学习率: 0.000100
# 2025-03-11 17:06:42 - INFO - 本轮用时: 6.55 秒
# 2025-03-11 17:06:42 - INFO - ——————————————————————————————
# 2025-03-11 17:06:49 - INFO - *** 新的最佳模型 (F1分数: 0.9345) ***
# 2025-03-11 17:06:49 - INFO - 轮次 79/100, 训练损失: 0.0560, 训练准确率: 0.9789, 类别0/1: 0.9792/0.9804, 训练F1: 0.9798, 训练精确率: 0.9798, 训练召回率: 0.9798, 训练特异性: 0.9792, 训练MCC: 0.9596, 训练归一化MCC: 0.9798, 验证损失: 0.3065, 验证准确率: 0.9278, 类别0/1: 0.9339/0.9347, 验证F1: 0.9345, 验证精确率: 0.9353, 验证召回率: 0.9342, 验证特异性: 0.9339, 验证MCC: 0.8613, 验证归一化MCC: 0.9307, 学习率: 0.000100
# 2025-03-11 17:06:49 - INFO - 本轮用时: 6.52 秒
# 2025-03-11 17:06:49 - INFO - ——————————————————————————————
# 2025-03-11 17:06:56 - INFO - 轮次 80/100, 训练损失: 0.0549, 训练准确率: 0.9798, 类别0/1: 0.9777/0.9836, 训练F1: 0.9807, 训练精确率: 0.9807, 训练召回率: 0.9807, 训练特异性: 0.9777, 训练MCC: 0.9614, 训练归一化MCC: 0.9807, 验证损失: 0.3071, 验证准确率: 0.9337, 类别0/1: 0.9279/0.9397, 验证F1: 0.9327, 验证精确率: 0.9341, 验证召回率: 0.9323, 验证特异性: 0.9279, 验证MCC: 0.8582, 验证归一化MCC: 0.9291, 学习率: 0.000100
# 2025-03-11 17:06:56 - INFO - 本轮用时: 6.69 秒
# 2025-03-11 17:06:56 - INFO - ——————————————————————————————
# 2025-03-11 17:07:03 - INFO - *** 新的最佳模型 (F1分数: 0.9380) ***
# 2025-03-11 17:07:03 - INFO - 轮次 81/100, 训练损失: 0.0485, 训练准确率: 0.9807, 类别0/1: 0.9709/0.9896, 训练F1: 0.9803, 训练精确率: 0.9804, 训练召回率: 0.9803, 训练特异性: 0.9709, 训练MCC: 0.9607, 训练归一化MCC: 0.9803, 验证损失: 0.2747, 验证准确率: 0.9389, 类别0/1: 0.9489/0.9196, 验证F1: 0.9380, 验证精确率: 0.9380, 验证召回率: 0.9380, 验证特异性: 0.9489, 验证MCC: 0.8677, 验证归一化MCC: 0.9338, 学习率: 0.000100
# 2025-03-11 17:07:03 - INFO - 本轮用时: 7.32 秒
# 2025-03-11 17:07:03 - INFO - ——————————————————————————————
# 2025-03-11 17:07:10 - INFO - *** 新的最佳模型 (F1分数: 0.9382) ***
# 2025-03-11 17:07:10 - INFO - 轮次 82/100, 训练损失: 0.0365, 训练准确率: 0.9867, 类别0/1: 0.9841/0.9915, 训练F1: 0.9878, 训练精确率: 0.9878, 训练召回率: 0.9878, 训练特异性: 0.9841, 训练MCC: 0.9756, 训练归一化MCC: 0.9878, 验证损失: 0.3022, 验证准确率: 0.9389, 类别0/1: 0.9369/0.9397, 验证F1: 0.9382, 验证精确率: 0.9391, 验证召回率: 0.9380, 验证特异性: 0.9369, 验证MCC: 0.8693, 验证归一化MCC: 0.9346, 学习率: 0.000100
# 2025-03-11 17:07:10 - INFO - 本轮用时: 7.28 秒
# 2025-03-11 17:07:10 - INFO - ——————————————————————————————
# 2025-03-11 17:07:17 - INFO - 轮次 83/100, 训练损失: 0.0388, 训练准确率: 0.9844, 类别0/1: 0.9814/0.9867, 训练F1: 0.9840, 训练精确率: 0.9840, 训练召回率: 0.9840, 训练特异性: 0.9814, 训练MCC: 0.9681, 训练归一化MCC: 0.9840, 验证损失: 0.2837, 验证准确率: 0.9337, 类别0/1: 0.9429/0.9146, 验证F1: 0.9324, 验证精确率: 0.9325, 验证召回率: 0.9323, 验证特异性: 0.9429, 验证MCC: 0.8558, 验证归一化MCC: 0.9279, 学习率: 0.000100
# 2025-03-11 17:07:17 - INFO - 本轮用时: 6.90 秒
# 2025-03-11 17:07:17 - INFO - ——————————————————————————————
# 2025-03-11 17:07:26 - INFO - 轮次 84/100, 训练损失: 0.0498, 训练准确率: 0.9793, 类别0/1: 0.9719/0.9859, 训练F1: 0.9789, 训练精确率: 0.9789, 训练召回率: 0.9789, 训练特异性: 0.9719, 训练MCC: 0.9578, 训练归一化MCC: 0.9789, 验证损失: 0.2985, 验证准确率: 0.9226, 类别0/1: 0.9279/0.9296, 验证F1: 0.9289, 验证精确率: 0.9299, 验证召回率: 0.9286, 验证特异性: 0.9279, 验证MCC: 0.8497, 验证归一化MCC: 0.9248, 学习率: 0.000100
# 2025-03-11 17:07:26 - INFO - 本轮用时: 8.38 秒
# 2025-03-11 17:07:26 - INFO - ——————————————————————————————
# 2025-03-11 17:07:36 - INFO - 轮次 85/100, 训练损失: 0.0426, 训练准确率: 0.9862, 类别0/1: 0.9877/0.9869, 训练F1: 0.9873, 训练精确率: 0.9873, 训练召回率: 0.9873, 训练特异性: 0.9877, 训练MCC: 0.9746, 训练归一化MCC: 0.9873, 验证损失: 0.3318, 验证准确率: 0.9351, 类别0/1: 0.9399/0.9347, 验证F1: 0.9382, 验证精确率: 0.9387, 验证召回率: 0.9380, 验证特异性: 0.9399, 验证MCC: 0.8688, 验证归一化MCC: 0.9344, 学习率: 0.000100
# 2025-03-11 17:07:36 - INFO - 本轮用时: 10.29 秒
# 2025-03-11 17:07:36 - INFO - ——————————————————————————————
# 2025-03-11 17:07:45 - INFO - 轮次 86/100, 训练损失: 0.0378, 训练准确率: 0.9876, 类别0/1: 0.9797/0.9952, 训练F1: 0.9873, 训练精确率: 0.9874, 训练召回率: 0.9873, 训练特异性: 0.9797, 训练MCC: 0.9747, 训练归一化MCC: 0.9874, 验证损失: 0.2826, 验证准确率: 0.9354, 类别0/1: 0.9429/0.9196, 验证F1: 0.9343, 验证精确率: 0.9345, 验证召回率: 0.9342, 验证特异性: 0.9429, 验证MCC: 0.8600, 验证归一化MCC: 0.9300, 学习率: 0.000010
# 2025-03-11 17:07:45 - INFO - 本轮用时: 9.21 秒
# 2025-03-11 17:07:45 - INFO - ——————————————————————————————
# 2025-03-11 17:07:54 - INFO - 轮次 87/100, 训练损失: 0.0378, 训练准确率: 0.9853, 类别0/1: 0.9880/0.9847, 训练F1: 0.9864, 训练精确率: 0.9864, 训练召回率: 0.9864, 训练特异性: 0.9880, 训练MCC: 0.9727, 训练归一化MCC: 0.9864, 验证损失: 0.3130, 验证准确率: 0.9372, 类别0/1: 0.9369/0.9347, 验证F1: 0.9363, 验证精确率: 0.9370, 验证召回率: 0.9361, 验证特异性: 0.9369, 验证MCC: 0.8651, 验证归一化MCC: 0.9325, 学习率: 0.000010
# 2025-03-11 17:07:54 - INFO - 本轮用时: 9.30 秒
# 2025-03-11 17:07:54 - INFO - ——————————————————————————————
# 2025-03-11 17:08:03 - INFO - 轮次 88/100, 训练损失: 0.0349, 训练准确率: 0.9867, 类别0/1: 0.9868/0.9860, 训练F1: 0.9864, 训练精确率: 0.9864, 训练召回率: 0.9864, 训练特异性: 0.9868, 训练MCC: 0.9727, 训练归一化MCC: 0.9864, 验证损失: 0.2811, 验证准确率: 0.9372, 类别0/1: 0.9369/0.9347, 验证F1: 0.9363, 验证精确率: 0.9370, 验证召回率: 0.9361, 验证特异性: 0.9369, 验证MCC: 0.8651, 验证归一化MCC: 0.9325, 学习率: 0.000010
# 2025-03-11 17:08:03 - INFO - 本轮用时: 9.14 秒
# 2025-03-11 17:08:03 - INFO - ——————————————————————————————
# 2025-03-11 17:08:13 - INFO - 轮次 89/100, 训练损失: 0.0457, 训练准确率: 0.9793, 类别0/1: 0.9739/0.9867, 训练F1: 0.9803, 训练精确率: 0.9803, 训练召回率: 0.9803, 训练特异性: 0.9739, 训练MCC: 0.9606, 训练归一化MCC: 0.9803, 验证损失: 0.3340, 验证准确率: 0.9257, 类别0/1: 0.9369/0.9347, 验证F1: 0.9363, 验证精确率: 0.9370, 验证召回率: 0.9361, 验证特异性: 0.9369, 验证MCC: 0.8651, 验证归一化MCC: 0.9325, 学习率: 0.000010
# 2025-03-11 17:08:13 - INFO - 本轮用时: 9.21 秒
# 2025-03-11 17:08:13 - INFO - ——————————————————————————————
# 2025-03-11 17:08:22 - INFO - 轮次 90/100, 训练损失: 0.0232, 训练准确率: 0.9917, 类别0/1: 0.9902/0.9927, 训练F1: 0.9915, 训练精确率: 0.9915, 训练召回率: 0.9915, 训练特异性: 0.9902, 训练MCC: 0.9831, 训练归一化MCC: 0.9915, 验证损失: 0.2901, 验证准确率: 0.9372, 类别0/1: 0.9369/0.9347, 验证F1: 0.9363, 验证精确率: 0.9370, 验证召回率: 0.9361, 验证特异性: 0.9369, 验证MCC: 0.8651, 验证归一化MCC: 0.9325, 学习率: 0.000010
# 2025-03-11 17:08:22 - INFO - 本轮用时: 9.30 秒
# 2025-03-11 17:08:22 - INFO - ——————————————————————————————
# 2025-03-11 17:08:31 - INFO - 轮次 91/100, 训练损失: 0.0378, 训练准确率: 0.9858, 类别0/1: 0.9801/0.9912, 训练F1: 0.9854, 训练精确率: 0.9855, 训练召回率: 0.9854, 训练特异性: 0.9801, 训练MCC: 0.9709, 训练归一化MCC: 0.9855, 验证损失: 0.2814, 验证准确率: 0.9410, 类别0/1: 0.9369/0.9347, 验证F1: 0.9363, 验证精确率: 0.9370, 验证召回率: 0.9361, 验证特异性: 0.9369, 验证MCC: 0.8651, 验证归一化MCC: 0.9325, 学习率: 0.000010
# 2025-03-11 17:08:31 - INFO - 本轮用时: 9.34 秒
# 2025-03-11 17:08:31 - INFO - ——————————————————————————————
# 2025-03-11 17:08:40 - INFO - 轮次 92/100, 训练损失: 0.0481, 训练准确率: 0.9789, 类别0/1: 0.9747/0.9849, 训练F1: 0.9798, 训练精确率: 0.9798, 训练召回率: 0.9798, 训练特异性: 0.9747, 训练MCC: 0.9596, 训练归一化MCC: 0.9798, 验证损失: 0.2853, 验证准确率: 0.9392, 类别0/1: 0.9369/0.9296, 验证F1: 0.9344, 验证精确率: 0.9350, 验证召回率: 0.9342, 验证特异性: 0.9369, 验证MCC: 0.8608, 验证归一化MCC: 0.9304, 学习率: 0.000010
# 2025-03-11 17:08:40 - INFO - 本轮用时: 8.76 秒
# 2025-03-11 17:08:40 - INFO - ——————————————————————————————
# 2025-03-11 17:08:49 - INFO - 轮次 93/100, 训练损失: 0.0391, 训练准确率: 0.9853, 类别0/1: 0.9824/0.9905, 训练F1: 0.9864, 训练精确率: 0.9864, 训练召回率: 0.9864, 训练特异性: 0.9824, 训练MCC: 0.9728, 训练归一化MCC: 0.9864, 验证损失: 0.3018, 验证准确率: 0.9316, 类别0/1: 0.9369/0.9296, 验证F1: 0.9344, 验证精确率: 0.9350, 验证召回率: 0.9342, 验证特异性: 0.9369, 验证MCC: 0.8608, 验证归一化MCC: 0.9304, 学习率: 0.000010
# 2025-03-11 17:08:49 - INFO - 本轮用时: 9.12 秒
# 2025-03-11 17:08:49 - INFO - ——————————————————————————————
# 2025-03-11 17:08:58 - INFO - 轮次 94/100, 训练损失: 0.0376, 训练准确率: 0.9825, 类别0/1: 0.9788/0.9881, 训练F1: 0.9836, 训练精确率: 0.9836, 训练召回率: 0.9836, 训练特异性: 0.9788, 训练MCC: 0.9671, 训练归一化MCC: 0.9836, 验证损失: 0.2914, 验证准确率: 0.9354, 类别0/1: 0.9399/0.9246, 验证F1: 0.9344, 验证精确率: 0.9347, 验证召回率: 0.9342, 验证特异性: 0.9399, 验证MCC: 0.8604, 验证归一化MCC: 0.9302, 学习率: 0.000010
# 2025-03-11 17:08:58 - INFO - 本轮用时: 9.13 秒
# 2025-03-11 17:08:58 - INFO - ——————————————————————————————
# 2025-03-11 17:09:07 - INFO - 轮次 95/100, 训练损失: 0.0353, 训练准确率: 0.9876, 类别0/1: 0.9873/0.9874, 训练F1: 0.9873, 训练精确率: 0.9873, 训练召回率: 0.9873, 训练特异性: 0.9873, 训练MCC: 0.9746, 训练归一化MCC: 0.9873, 验证损失: 0.3393, 验证准确率: 0.9333, 类别0/1: 0.9369/0.9347, 验证F1: 0.9363, 验证精确率: 0.9370, 验证召回率: 0.9361, 验证特异性: 0.9369, 验证MCC: 0.8651, 验证归一化MCC: 0.9325, 学习率: 0.000010
# 2025-03-11 17:09:07 - INFO - 本轮用时: 8.90 秒
# 2025-03-11 17:09:07 - INFO - ——————————————————————————————
# 2025-03-11 17:09:17 - INFO - 轮次 96/100, 训练损失: 0.0400, 训练准确率: 0.9816, 类别0/1: 0.9860/0.9820, 训练F1: 0.9840, 训练精确率: 0.9840, 训练召回率: 0.9840, 训练特异性: 0.9860, 训练MCC: 0.9680, 训练归一化MCC: 0.9840, 验证损失: 0.2811, 验证准确率: 0.9410, 类别0/1: 0.9399/0.9296, 验证F1: 0.9363, 验证精确率: 0.9367, 验证召回率: 0.9361, 验证特异性: 0.9399, 验证MCC: 0.8646, 验证归一化MCC: 0.9323, 学习率: 0.000010
# 2025-03-11 17:09:17 - INFO - 本轮用时: 9.33 秒
# 2025-03-11 17:09:17 - INFO - ——————————————————————————————
# 2025-03-11 17:09:26 - INFO - 轮次 97/100, 训练损失: 0.0416, 训练准确率: 0.9839, 类别0/1: 0.9855/0.9872, 训练F1: 0.9864, 训练精确率: 0.9864, 训练召回率: 0.9864, 训练特异性: 0.9855, 训练MCC: 0.9727, 训练归一化MCC: 0.9864, 验证损失: 0.3250, 验证准确率: 0.9372, 类别0/1: 0.9399/0.9296, 验证F1: 0.9363, 验证精确率: 0.9367, 验证召回率: 0.9361, 验证特异性: 0.9399, 验证MCC: 0.8646, 验证归一化MCC: 0.9323, 学习率: 0.000001
# 2025-03-11 17:09:26 - INFO - 本轮用时: 9.30 秒
# 2025-03-11 17:09:26 - INFO - ——————————————————————————————
# 2025-03-11 17:09:35 - INFO - 轮次 98/100, 训练损失: 0.0495, 训练准确率: 0.9825, 类别0/1: 0.9814/0.9886, 训练F1: 0.9850, 训练精确率: 0.9850, 训练召回率: 0.9850, 训练特异性: 0.9814, 训练MCC: 0.9700, 训练归一化MCC: 0.9850, 验证损失: 0.2928, 验证准确率: 0.9299, 类别0/1: 0.9339/0.9296, 验证F1: 0.9326, 验证精确率: 0.9333, 验证召回率: 0.9323, 验证特异性: 0.9339, 验证MCC: 0.8571, 验证归一化MCC: 0.9285, 学习率: 0.000001
# 2025-03-11 17:09:35 - INFO - 本轮用时: 9.58 秒
# 2025-03-11 17:09:35 - INFO - ——————————————————————————————
# 2025-03-11 17:09:45 - INFO - 轮次 99/100, 训练损失: 0.0433, 训练准确率: 0.9835, 类别0/1: 0.9812/0.9878, 训练F1: 0.9845, 训练精确率: 0.9845, 训练召回率: 0.9845, 训练特异性: 0.9812, 训练MCC: 0.9690, 训练归一化MCC: 0.9845, 验证损失: 0.3457, 验证准确率: 0.9278, 类别0/1: 0.9369/0.9296, 验证F1: 0.9344, 验证精确率: 0.9350, 验证召回率: 0.9342, 验证特异性: 0.9369, 验证MCC: 0.8608, 验证归一化MCC: 0.9304, 学习率: 0.000001
# 2025-03-11 17:09:45 - INFO - 本轮用时: 9.52 秒
# 2025-03-11 17:09:45 - INFO - ——————————————————————————————
# 2025-03-11 17:09:55 - INFO - 轮次 100/100, 训练损失: 0.0354, 训练准确率: 0.9858, 类别0/1: 0.9813/0.9896, 训练F1: 0.9854, 训练精确率: 0.9855, 训练召回率: 0.9854, 训练特异性: 0.9813, 训练MCC: 0.9709, 训练归一化MCC: 0.9854, 验证损失: 0.2829, 验证准确率: 0.9410, 类别0/1: 0.9399/0.9296, 验证F1: 0.9363, 验证精确率: 0.9367, 验证召回率: 0.9361, 验证特异性: 0.9399, 验证MCC: 0.8646, 验证归一化MCC: 0.9323, 学习率: 0.000001
# 2025-03-11 17:09:55 - INFO - 本轮用时: 9.60 秒
# 2025-03-11 17:09:55 - INFO - ——————————————————————————————
# 2025-03-11 17:09:55 - INFO - 最终训练类别准确率 - 类别0: 0.9813, 类别1: 0.9896
# 2025-03-11 17:09:55 - INFO - 最终验证类别准确率 - 类别0: 0.9399, 类别1: 0.9296
# 2025-03-11 17:09:55 - INFO - 最终F1分数 - 训练: 0.9854, 验证: 0.9363
# 2025-03-11 17:09:55 - INFO - 最终精确率 - 训练: 0.9855, 验证: 0.9367
# 2025-03-11 17:09:55 - INFO - 最终召回率 - 训练: 0.9854, 验证: 0.9361
# 2025-03-11 17:09:55 - INFO - 最终特异性 - 训练: 0.9813, 验证: 0.9399
# 2025-03-11 17:09:55 - INFO - 最终MCC - 训练: 0.9709, 验证: 0.8646
# 2025-03-11 17:09:55 - INFO - 最终归一化MCC - 训练: 0.9854, 验证: 0.9323
# 2025-03-11 17:09:55 - INFO - 已保存模型权重到: C:\Users\USTC\Desktop\地磁论文（5级以上）\对比模型结果\LSTM模型结果\LSTMModel_7天_fold_1.pth
# 2025-03-11 17:09:55 - INFO - 已保存训练日志到: C:\Users\USTC\Desktop\地磁论文（5级以上）\对比模型结果\LSTM模型结果\LSTMModel_7天_fold_1_epoch_logs.txt
# 2025-03-11 17:09:55 - INFO - 已保存训练集预测概率到: C:\Users\USTC\Desktop\地磁论文（5级以上）\对比模型结果\LSTM模型结果\LSTMModel_7天_fold_1_train_probs.npy
# ...
# 2025-03-11 20:52:54 - INFO - 本轮用时: 6.83 秒
# 2025-03-11 20:52:54 - INFO - ——————————————————————————————
# 2025-03-11 20:53:01 - INFO - 轮次 88/100, 训练损失: 0.0371, 训练准确率: 0.9866, 类别0/1: 0.9803/0.9921, 训练F1: 0.9863, 训练精确率: 0.9864, 训练召回率: 0.9863, 训练特异性: 0.9803, 训练MCC: 0.9727, 训练归一化MCC: 0.9863, 验证损失: 0.4461, 验证准确率: 0.9149, 类别0/1: 0.9472/0.8571, 验证F1: 0.9151, 验证精确率: 0.9151, 验证召回率: 0.9155, 验证特异性: 0.9472, 验证MCC: 0.8133, 验证归一化MCC: 0.9066, 学习率: 0.000001
# 2025-03-11 20:53:01 - INFO - 本轮用时: 6.95 秒
# 2025-03-11 20:53:01 - INFO - ——————————————————————————————
# 2025-03-11 20:53:08 - INFO - 轮次 89/100, 训练损失: 0.0463, 训练准确率: 0.9837, 类别0/1: 0.9816/0.9887, 训练F1: 0.9852, 训练精确率: 0.9852, 训练召回率: 0.9852, 训练特异性: 0.9816, 训练MCC: 0.9704, 训练归一化MCC: 0.9852, 验证损失: 0.4487, 验证准确率: 0.9109, 类别0/1: 0.9401/0.8571, 验证F1: 0.9106, 验证精确率: 0.9105, 验证召回率: 0.9110, 验证特异性: 0.9401, 验证MCC: 0.8035, 验证归一化MCC: 0.9018, 学习率: 0.000001
# 2025-03-11 20:53:08 - INFO - 本轮用时: 7.22 秒
# 2025-03-11 20:53:08 - INFO - ——————————————————————————————
# 2025-03-11 20:53:16 - INFO - 轮次 90/100, 训练损失: 0.0311, 训练准确率: 0.9911, 类别0/1: 0.9863/0.9954, 训练F1: 0.9909, 训练精确率: 0.9909, 训练召回率: 0.9909, 训练特异性: 0.9863, 训练MCC: 0.9818, 训练归一化MCC: 0.9909, 验证损失: 0.4396, 验证准确率: 0.9109, 类别0/1: 0.9401/0.8571, 验证F1: 0.9106, 验证精确率: 0.9105, 验证召回率: 0.9110, 验证特异性: 0.9401, 验证MCC: 0.8035, 验证归一化MCC: 0.9018, 学习率: 0.000001
# 2025-03-11 20:53:16 - INFO - 本轮用时: 7.24 秒
# 2025-03-11 20:53:16 - INFO - ——————————————————————————————
# 2025-03-11 20:53:23 - INFO - 轮次 91/100, 训练损失: 0.0427, 训练准确率: 0.9877, 类别0/1: 0.9799/0.9953, 训练F1: 0.9875, 训练精确率: 0.9876, 训练召回率: 0.9875, 训练特异性: 0.9799, 训练MCC: 0.9750, 训练归一化MCC: 0.9875, 验证损失: 0.4571, 验证准确率: 0.9056, 类别0/1: 0.9331/0.8571, 验证F1: 0.9062, 验证精确率: 0.9061, 验证召回率: 0.9064, 验证特异性: 0.9331, 验证MCC: 0.7939, 验证归一化MCC: 0.8969, 学习率: 0.000001
# 2025-03-11 20:53:23 - INFO - 本轮用时: 7.07 秒
# 2025-03-11 20:53:23 - INFO - ——————————————————————————————
# 2025-03-11 20:53:31 - INFO - 轮次 92/100, 训练损失: 0.0361, 训练准确率: 0.9866, 类别0/1: 0.9831/0.9896, 训练F1: 0.9863, 训练精确率: 0.9863, 训练召回率: 0.9863, 训练特异性: 0.9831, 训练MCC: 0.9726, 训练归一化MCC: 0.9863, 验证损失: 0.4402, 验证准确率: 0.9121, 类别0/1: 0.9401/0.8571, 验证F1: 0.9106, 验证精确率: 0.9105, 验证召回率: 0.9110, 验证特异性: 0.9401, 验证MCC: 0.8035, 验证归一化MCC: 0.9018, 学习率: 0.000001
# 2025-03-11 20:53:31 - INFO - 本轮用时: 8.44 秒
# 2025-03-11 20:53:31 - INFO - ——————————————————————————————
# 2025-03-11 20:53:39 - INFO - 轮次 93/100, 训练损失: 0.0333, 训练准确率: 0.9883, 类别0/1: 0.9837/0.9922, 训练F1: 0.9880, 训练精确率: 0.9880, 训练召回率: 0.9880, 训练特异性: 0.9837, 训练MCC: 0.9761, 训练归一化MCC: 0.9880, 验证损失: 0.4433, 验证准确率: 0.9113, 类别0/1: 0.9401/0.8571, 验证F1: 0.9106, 验证精确率: 0.9105, 验证召回率: 0.9110, 验证特异性: 0.9401, 验证MCC: 0.8035, 验证归一化MCC: 0.9018, 学习率: 0.000001
# 2025-03-11 20:53:39 - INFO - 本轮用时: 8.12 秒
# 2025-03-11 20:53:39 - INFO - ——————————————————————————————
# 2025-03-11 20:53:47 - INFO - 轮次 94/100, 训练损失: 0.0351, 训练准确率: 0.9880, 类别0/1: 0.9871/0.9900, 训练F1: 0.9886, 训练精确率: 0.9886, 训练召回率: 0.9886, 训练特异性: 0.9871, 训练MCC: 0.9772, 训练归一化MCC: 0.9886, 验证损失: 0.4450, 验证准确率: 0.9113, 类别0/1: 0.9401/0.8571, 验证F1: 0.9106, 验证精确率: 0.9105, 验证召回率: 0.9110, 验证特异性: 0.9401, 验证MCC: 0.8035, 验证归一化MCC: 0.9018, 学习率: 0.000001
# 2025-03-11 20:53:47 - INFO - 本轮用时: 7.80 秒
# 2025-03-11 20:53:47 - INFO - ——————————————————————————————
# 2025-03-11 20:53:55 - INFO - 轮次 95/100, 训练损失: 0.0388, 训练准确率: 0.9882, 类别0/1: 0.9872/0.9922, 训练F1: 0.9897, 训练精确率: 0.9897, 训练召回率: 0.9897, 训练特异性: 0.9872, 训练MCC: 0.9795, 训练归一化MCC: 0.9897, 验证损失: 0.4517, 验证准确率: 0.9170, 类别0/1: 0.9472/0.8571, 验证F1: 0.9151, 验证精确率: 0.9151, 验证召回率: 0.9155, 验证特异性: 0.9472, 验证MCC: 0.8133, 验证归一化MCC: 0.9066, 学习率: 0.000001
# 2025-03-11 20:53:55 - INFO - 本轮用时: 8.00 秒
# 2025-03-11 20:53:55 - INFO - ——————————————————————————————
# 2025-03-11 20:54:02 - INFO - 轮次 96/100, 训练损失: 0.0439, 训练准确率: 0.9849, 类别0/1: 0.9805/0.9887, 训练F1: 0.9846, 训练精确率: 0.9846, 训练召回率: 0.9846, 训练特异性: 0.9805, 训练MCC: 0.9692, 训练归一化MCC: 0.9846, 验证损失: 0.4351, 验证准确率: 0.9020, 类别0/1: 0.9190/0.8701, 验证F1: 0.9020, 验证精确率: 0.9023, 验证召回率: 0.9018, 验证特异性: 0.9190, 验证MCC: 0.7857, 验证归一化MCC: 0.8929, 学习率: 0.000001
# 2025-03-11 20:54:02 - INFO - 本轮用时: 7.44 秒
# 2025-03-11 20:54:02 - INFO - ——————————————————————————————
# 2025-03-11 20:54:10 - INFO - 轮次 97/100, 训练损失: 0.0370, 训练准确率: 0.9880, 类别0/1: 0.9819/0.9954, 训练F1: 0.9886, 训练精确率: 0.9887, 训练召回率: 0.9886, 训练特异性: 0.9819, 训练MCC: 0.9773, 训练归一化MCC: 0.9886, 验证损失: 0.4390, 验证准确率: 0.8997, 类别0/1: 0.9225/0.8571, 验证F1: 0.8995, 验证精确率: 0.8995, 验证召回率: 0.8995, 验证特异性: 0.9225, 验证MCC: 0.7797, 验证归一化MCC: 0.8898, 学习率: 0.000001
# 2025-03-11 20:54:10 - INFO - 本轮用时: 7.64 秒
# 2025-03-11 20:54:10 - INFO - ——————————————————————————————
# 2025-03-11 20:54:18 - INFO - 轮次 98/100, 训练损失: 0.0415, 训练准确率: 0.9841, 类别0/1: 0.9810/0.9883, 训练F1: 0.9846, 训练精确率: 0.9846, 训练召回率: 0.9846, 训练特异性: 0.9810, 训练MCC: 0.9692, 训练归一化MCC: 0.9846, 验证损失: 0.4554, 验证准确率: 0.9109, 类别0/1: 0.9401/0.8571, 验证F1: 0.9106, 验证精确率: 0.9105, 验证召回率: 0.9110, 验证特异性: 0.9401, 验证MCC: 0.8035, 验证归一化MCC: 0.9018, 学习率: 0.000001
# 2025-03-11 20:54:18 - INFO - 本轮用时: 7.70 秒
# 2025-03-11 20:54:18 - INFO - ——————————————————————————————
# 2025-03-11 20:54:26 - INFO - 轮次 99/100, 训练损失: 0.0329, 训练准确率: 0.9900, 类别0/1: 0.9916/0.9881, 训练F1: 0.9897, 训练精确率: 0.9897, 训练召回率: 0.9897, 训练特异性: 0.9916, 训练MCC: 0.9794, 训练归一化MCC: 0.9897, 验证损失: 0.4346, 验证准确率: 0.9064, 类别0/1: 0.9331/0.8571, 验证F1: 0.9062, 验证精确率: 0.9061, 验证召回率: 0.9064, 验证特异性: 0.9331, 验证MCC: 0.7939, 验证归一化MCC: 0.8969, 学习率: 0.000001
# 2025-03-11 20:54:26 - INFO - 本轮用时: 7.81 秒
# 2025-03-11 20:54:26 - INFO - ——————————————————————————————
# 2025-03-11 20:54:33 - INFO - 轮次 100/100, 训练损失: 0.0333, 训练准确率: 0.9855, 类别0/1: 0.9827/0.9876, 训练F1: 0.9852, 训练精确率: 0.9852, 训练召回率: 0.9852, 训练特异性: 0.9827, 训练MCC: 0.9703, 训练归一化MCC: 0.9852, 验证损失: 0.4493, 验证准确率: 0.9117, 类别0/1: 0.9401/0.8571, 验证F1: 0.9106, 验证精确率: 0.9105, 验证召回率: 0.9110, 验证特异性: 0.9401, 验证MCC: 0.8035, 验证归一化MCC: 0.9018, 学习率: 0.000001
# 2025-03-11 20:54:33 - INFO - 本轮用时: 7.81 秒
# 2025-03-11 20:54:33 - INFO - ——————————————————————————————
# 2025-03-11 20:54:33 - INFO - 最终训练类别准确率 - 类别0: 0.9827, 类别1: 0.9876
# 2025-03-11 20:54:33 - INFO - 最终验证类别准确率 - 类别0: 0.9401, 类别1: 0.8571
# 2025-03-11 20:54:33 - INFO - 最终F1分数 - 训练: 0.9852, 验证: 0.9106
# 2025-03-11 20:54:33 - INFO - 最终精确率 - 训练: 0.9852, 验证: 0.9105
# 2025-03-11 20:54:33 - INFO - 最终召回率 - 训练: 0.9852, 验证: 0.9110
# 2025-03-11 20:54:33 - INFO - 最终特异性 - 训练: 0.9827, 验证: 0.9401
# 2025-03-11 20:54:33 - INFO - 最终MCC - 训练: 0.9703, 验证: 0.8035
# 2025-03-11 20:54:33 - INFO - 最终归一化MCC - 训练: 0.9852, 验证: 0.9018
# 2025-03-11 20:54:33 - INFO - 已保存模型权重到: C:\Users\USTC\Desktop\地磁论文（5级以上）\对比模型结果\LSTM模型结果\LSTMModel_30天_fold_5.pth
# 2025-03-11 20:54:33 - INFO - 已保存训练日志到: C:\Users\USTC\Desktop\地磁论文（5级以上）\对比模型结果\LSTM模型结果\LSTMModel_30天_fold_5_epoch_logs.txt
# 2025-03-11 20:54:33 - INFO - 已保存训练集预测概率到: C:\Users\USTC\Desktop\地磁论文（5级以上）\对比模型结果\LSTM模型结果\LSTMModel_30天_fold_5_train_probs.npy
# 2025-03-11 20:54:33 - INFO - 已保存训练集标签到: C:\Users\USTC\Desktop\地磁论文（5级以上）\对比模型结果\LSTM模型结果\LSTMModel_30天_fold_5_train_labels.npy
# 2025-03-11 20:54:33 - INFO - 已保存测试集预测概率到: C:\Users\USTC\Desktop\地磁论文（5级以上）\对比模型结果\LSTM模型结果\LSTMModel_30天_fold_5_test_probs.npy
# 2025-03-11 20:54:33 - INFO - 已保存测试集标签到: C:\Users\USTC\Desktop\地磁论文（5级以上）\对比模型结果\LSTM模型结果\LSTMModel_30天_fold_5_test_labels.npy
# 2025-03-11 20:54:33 - INFO - 类别准确率: 类别0: 1.0775, 类别1: 0.8571
# 2025-03-11 20:54:33 - INFO - F1分数: 训练: 0.9852, 验证: 0.9106
# 2025-03-11 20:54:33 - INFO - 精确率: 训练: 0.9852, 验证: 0.9105
# 2025-03-11 20:54:33 - INFO - 召回率: 训练: 0.9852, 验证: 0.9110
# 2025-03-11 20:54:33 - INFO - 特异性: 训练: 0.9827, 验证: 0.9401
# 2025-03-11 20:54:33 - INFO - MCC: 训练: 0.9703, 验证: 0.8035
# 2025-03-11 20:54:33 - INFO - 归一化MCC: 训练: 0.9852, 验证: 0.9018
# 2025-03-11 20:54:33 - INFO - 第 5 折训练完成
# 2025-03-11 20:54:33 - INFO - 第 5 折训练结束
# 2025-03-11 20:54:33 - INFO -
# 训练总结:
# 2025-03-11 20:54:33 - INFO - - 总训练时间: 1小时 21分钟 8秒
# 2025-03-11 20:54:33 - INFO - - 平均训练准确率: 0.9779 ± 0.0135
# 2025-03-11 20:54:33 - INFO - - 平均验证准确率: 0.8981 ± 0.0179
# 2025-03-11 20:54:33 - INFO - - 平均训练精确率: 0.9782
# 2025-03-11 20:54:33 - INFO - - 平均验证精确率: 0.8985
# 2025-03-11 20:54:33 - INFO - - 平均训练召回率: 0.9781
# 2025-03-11 20:54:33 - INFO - - 平均验证召回率: 0.8978
# 2025-03-11 20:54:33 - INFO - - 平均训练特异性: 0.9728
# 2025-03-11 20:54:33 - INFO - - 平均验证特异性: 0.9198
# 2025-03-11 20:54:33 - INFO - - 平均训练MCC: 0.9562
# 2025-03-11 20:54:33 - INFO - - 平均验证MCC: 0.7768
# 2025-03-11 20:54:33 - INFO - - 平均训练归一化MCC: 0.9781
# 2025-03-11 20:54:33 - INFO - - 平均验证归一化MCC: 0.8884
# 2025-03-11 20:54:33 - INFO - - 类别0平均准确率: 1.0774
# 2025-03-11 20:54:33 - INFO - - 类别1平均准确率: 0.8571
# 2025-03-11 20:54:33 - INFO - - 平均验证损失: 0.4386 ± 0.0349
# 2025-03-11 20:54:33 - INFO - 开始进行模型集成 - LSTMModel_30天
# C:\Users\USTC\AppData\Local\Temp\ipykernel_46716\2347536899.py:356: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(model_path)
# 2025-03-11 20:54:34 - INFO - 第 1 折模型评估指标:
# 2025-03-11 20:54:34 - INFO -   F1分数: 0.8876
# 2025-03-11 20:54:34 - INFO -   精确率: 0.8876
# 2025-03-11 20:54:34 - INFO -   召回率: 0.8884
# 2025-03-11 20:54:34 - INFO -   特异性: 0.9298
# 2025-03-11 20:54:34 - INFO -   MCC: 0.7524
# 2025-03-11 20:54:34 - INFO -   归一化MCC: 0.8762
# 2025-03-11 20:54:34 - INFO - 已加载第 1 折模型
# C:\Users\USTC\AppData\Local\Temp\ipykernel_46716\2347536899.py:356: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(model_path)
# 2025-03-11 20:54:34 - INFO - 第 2 折模型评估指标:
# 2025-03-11 20:54:34 - INFO -   F1分数: 0.9158
# 2025-03-11 20:54:34 - INFO -   精确率: 0.9164
# 2025-03-11 20:54:34 - INFO -   召回率: 0.9155
# 2025-03-11 20:54:34 - INFO -   特异性: 0.9261
# 2025-03-11 20:54:34 - INFO -   MCC: 0.8163
# 2025-03-11 20:54:34 - INFO -   归一化MCC: 0.9082
# 2025-03-11 20:54:34 - INFO - 已加载第 2 折模型
# C:\Users\USTC\AppData\Local\Temp\ipykernel_46716\2347536899.py:356: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(model_path)
# 2025-03-11 20:54:34 - INFO - 第 3 折模型评估指标:
# 2025-03-11 20:54:34 - INFO -   F1分数: 0.9063
# 2025-03-11 20:54:34 - INFO -   精确率: 0.9063
# 2025-03-11 20:54:34 - INFO -   召回率: 0.9064
# 2025-03-11 20:54:34 - INFO -   特异性: 0.9296
# 2025-03-11 20:54:34 - INFO -   MCC: 0.7944
# 2025-03-11 20:54:34 - INFO -   归一化MCC: 0.8972
# 2025-03-11 20:54:34 - INFO - 已加载第 3 折模型
# C:\Users\USTC\AppData\Local\Temp\ipykernel_46716\2347536899.py:356: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(model_path)
# 2025-03-11 20:54:34 - INFO - 第 4 折模型评估指标:
# 2025-03-11 20:54:34 - INFO -   F1分数: 0.8688
# 2025-03-11 20:54:34 - INFO -   精确率: 0.8718
# 2025-03-11 20:54:34 - INFO -   召回率: 0.8676
# 2025-03-11 20:54:34 - INFO -   特异性: 0.8732
# 2025-03-11 20:54:34 - INFO -   MCC: 0.7172
# 2025-03-11 20:54:34 - INFO -   归一化MCC: 0.8586
# 2025-03-11 20:54:34 - INFO - 已加载第 4 折模型
# C:\Users\USTC\AppData\Local\Temp\ipykernel_46716\2347536899.py:356: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(model_path)
# 2025-03-11 20:54:34 - INFO - 第 5 折模型评估指标:
# 2025-03-11 20:54:34 - INFO -   F1分数: 0.9106
# 2025-03-11 20:54:34 - INFO -   精确率: 0.9105
# 2025-03-11 20:54:34 - INFO -   召回率: 0.9110
# 2025-03-11 20:54:34 - INFO -   特异性: 0.9401
# 2025-03-11 20:54:34 - INFO -   MCC: 0.8035
# 2025-03-11 20:54:34 - INFO -   归一化MCC: 0.9018
# 2025-03-11 20:54:34 - INFO - 已加载第 5 折模型
# 2025-03-11 20:54:34 - INFO - 基于F1分数的模型权重: [0.19771607 0.20401005 0.20189333 0.19353153 0.20284902]
# 2025-03-11 20:54:34 - INFO - 集成模型权重: [0.19771607171554545, 0.20401005127056232, 0.20189332524231357, 0.19353152986176947, 0.2028490219098092]
# 2025-03-11 20:54:34 - INFO - F1加权集成模型已保存: C:\Users\USTC\Desktop\地磁论文（5级以上）\对比模型结果\LSTM模型结果\LSTMModel_30天.pth
# 2025-03-11 20:54:34 - INFO - 集成模型平均评估指标:
# 2025-03-11 20:54:34 - INFO -   平均f1 scores: 0.8978
# 2025-03-11 20:54:34 - INFO -   平均precisions: 0.8985
# 2025-03-11 20:54:34 - INFO -   平均recalls: 0.8978
# 2025-03-11 20:54:34 - INFO -   平均specificities: 0.9198
# 2025-03-11 20:54:34 - INFO -   平均mccs: 0.7768
# 2025-03-11 20:54:34 - INFO -   平均norm mccs: 0.8884
# 2025-03-11 20:54:34 - INFO - 集成配置已保存: C:\Users\USTC\Desktop\地磁论文（5级以上）\对比模型结果\LSTM模型结果\LSTMModel_30天_ensemble_config.json
# 2025-03-11 20:54:34 - INFO -
# === 所有处理完成！===
