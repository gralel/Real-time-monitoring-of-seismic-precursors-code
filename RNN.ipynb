# %%
import os
import numpy as np
import torch
from torch.utils.data import TensorDataset, DataLoader, random_split, Subset
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.nn as nn
import optuna
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold
import copy
import time
import logging
from typing import Any, Optional, List, Tuple, Dict
from torch.utils.data import TensorDataset, DataLoader, Subset, WeightedRandomSampler
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix

# %% [markdown]
# 定义准确率函数

# %%
def accuracy(outputs: torch.Tensor, labels: torch.Tensor) -> float:
    """
    计算准确率。

    参数:
    - outputs (torch.Tensor): 模型输出的 logits。
    - labels (torch.Tensor): 真实标签。

    返回:
    - float: 准确率。
    """
    _, preds = torch.max(outputs, 1)
    return (preds == labels).float().mean().item()

# %% [markdown]
# 集成模型（基于F1分数分配权重）

# %%
class EnsembleModel(nn.Module):
    """集成模型类，使用F1分数优化权重"""
    def __init__(self, base_models: List[nn.Module], ensemble_weights: Optional[List[float]] = None):
        super(EnsembleModel, self).__init__()
        self.base_models = nn.ModuleList(base_models)
        
        if ensemble_weights is None:
            # 如果没有提供权重，使用均等权重
            self.ensemble_weights = torch.ones(len(base_models)) / len(base_models)
        else:
            # 如果提供了权重（可能是F1分数），归一化处理
            weights = torch.tensor(ensemble_weights)
            self.ensemble_weights = weights / weights.sum()
        
        # 记录权重分配
        logging.info(f"集成模型权重: {self.ensemble_weights.tolist()}")
        
        self.register_buffer('weights', self.ensemble_weights)
    
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        predictions = []
        for model in self.base_models:
            with torch.no_grad():
                model.eval()
                pred = model(x)
                predictions.append(torch.softmax(pred, dim=1))
        
        stacked_preds = torch.stack(predictions, dim=0)
        weighted_preds = stacked_preds * self.weights.view(-1, 1, 1)
        return weighted_preds.sum(dim=0)

# %% [markdown]
# RNN模型框架+BN层

# %%
class RNNModel(nn.Module):
    """
    支持不同大小隐藏层的RNN模型实现
    
    Args:
        input_size (int): 输入特征维度
        hidden_sizes (list): 隐藏层大小列表，如 [512, 256]
        output_size (int): 输出维度
        dropout_prob (float): Dropout概率
    """
    def __init__(self, input_size, hidden_sizes, output_size, dropout_prob=0.3):
        super(RNNModel, self).__init__()
        
        self.hidden_sizes = hidden_sizes
        self.num_layers = len(hidden_sizes)
        
        # 创建多层RNN
        self.rnn_layers = nn.ModuleList()
        
        # 第一层RNN
        self.rnn_layers.append(
            nn.RNN(
                input_size=input_size,
                hidden_size=hidden_sizes[0],
                num_layers=1,
                batch_first=True
            )
        )
        
        # 创建后续层RNN（如果有）
        for i in range(1, self.num_layers):
            self.rnn_layers.append(
                nn.RNN(
                    input_size=hidden_sizes[i-1],
                    hidden_size=hidden_sizes[i],
                    num_layers=1,
                    batch_first=True
                )
            )
        
        # 批归一化层，使用最后一层的hidden_size
        self.bn = nn.BatchNorm1d(hidden_sizes[-1])
        
        # Dropout层
        self.dropout = nn.Dropout(dropout_prob)
        
        # 输出层，使用最后一层的hidden_size
        self.fc = nn.Linear(hidden_sizes[-1], output_size)
    
    def forward(self, x):
        """
        前向传播函数
        
        Args:
            x (torch.Tensor): 输入张量，形状为 (batch_size, seq_length, input_size)
            
        Returns:
            torch.Tensor: 输出张量，形状为 (batch_size, output_size)
        """
        # 通过每一层RNN
        for i, rnn_layer in enumerate(self.rnn_layers):
            # 初始化当前层的隐藏状态
            h0 = torch.zeros(1, x.size(0), self.hidden_sizes[i]).to(x.device)
            
            # RNN前向传播
            x, _ = rnn_layer(x, h0)
            
            # 如果不是最后一层，应用dropout
            if i < len(self.rnn_layers) - 1:
                x = self.dropout(x)
        
        # 只取最后一个时间步的输出
        out = x[:, -1, :]
        
        # 批归一化
        out = self.bn(out)
        
        # Dropout
        out = self.dropout(out)
        
        # 通过全连接层得到最终输出
        out = self.fc(out)
        
        return out

# %% [markdown]
# 定义训练与评估循环函数

# %%
def train_eval_rnn(
    model: nn.Module,
    train_loader: DataLoader, 
    val_loader: DataLoader,
    loss_fn: nn.Module,
    optimizer: torch.optim.Optimizer,
    scheduler: lr_scheduler._LRScheduler,
    epochs: int,
    device: torch.device,
    log_epoch: Optional[List[str]] = None,
    max_grad_norm: Optional[float] = None
) -> Tuple[float, float, float, float, np.ndarray, np.ndarray, np.ndarray, np.ndarray, Dict]:
    """
    训练与评估RNN模型的主循环函数，支持类别平衡评估，使用F1分数选择最佳模型。
    增加了精确率、召回率、特异性和MCC评估指标。
    
    Args:
        model: 神经网络模型
        train_loader: 训练数据加载器
        val_loader: 验证数据加载器 
        loss_fn: 损失函数
        optimizer: 优化器
        scheduler: 学习率调度器
        epochs: 训练轮数
        device: 训练设备
        log_epoch: 可选的日志记录列表
        max_grad_norm: 可选的梯度裁剪阈值

    Returns:
        Tuple[float, float, float, float, np.ndarray, np.ndarray, np.ndarray, np.ndarray, Dict]:
            - train_loss: 最终训练损失
            - val_loss: 最终验证损失
            - train_acc: 最终训练准确率
            - val_acc: 最终验证准确率
            - train_probs: 训练集预测概率
            - train_labels: 训练集真实标签
            - val_probs: 验证集预测概率
            - val_labels: 验证集真实标签
            - model_state: 最佳模型状态字典
    """
    # 导入指标计算函数
    from sklearn.metrics import f1_score, precision_score, recall_score, matthews_corrcoef, confusion_matrix
    
    # 初始化记录器
    history = {
        'train_loss': [],
        'val_loss': [],
        'train_acc': [],
        'val_acc': [],
        'train_class_acc': [],     # 类别准确率记录
        'val_class_acc': [],       # 类别准确率记录
        'train_f1': [],            # F1分数记录
        'val_f1': [],              # F1分数记录
        'train_precision': [],     # 精确率记录
        'val_precision': [],       # 精确率记录
        'train_recall': [],        # 召回率记录
        'val_recall': [],          # 召回率记录
        'train_specificity': [],   # 特异性记录
        'val_specificity': [],     # 特异性记录
        'train_mcc': [],           # MCC记录
        'val_mcc': [],             # MCC记录
        'train_norm_mcc': [],      # 归一化MCC记录
        'val_norm_mcc': []         # 归一化MCC记录
    }
    
    best_model_state = None
    best_val_f1 = float('-inf')  # 使用F1分数选择最佳模型
    
    # 检查是否使用了带权重的损失函数
    has_weights = hasattr(loss_fn, 'weight') and loss_fn.weight is not None
    if has_weights:
        logging.info(f"使用带权重的损失函数，权重: {loss_fn.weight.cpu().numpy()}")
    
    for epoch in range(epochs):
        epoch_start_time = time.time()
        
        # ===== 训练阶段 =====
        model.train()
        train_loss = 0.0
        train_acc = 0.0
        epoch_train_probs = []
        epoch_train_labels = []
        epoch_train_preds = []  # 存储预测类别
        num_train_batches = 0
        
        for inputs, labels in train_loader:
            if inputs.size(0) <= 1:  # 跳过大小为1的批次
                continue
                
            inputs = inputs.to(device)
            labels = labels.to(device)
            
            # 前向传播
            outputs = model(inputs)
            if isinstance(outputs, tuple):
                outputs = outputs[0]
            
            # 计算损失和准确率
            loss = loss_fn(outputs, labels)
            batch_acc = accuracy(outputs, labels)
            
            # 反向传播和优化
            optimizer.zero_grad()
            loss.backward()
            
            # 梯度裁剪
            if max_grad_norm is not None:
                if isinstance(model, nn.DataParallel):
                    torch.nn.utils.clip_grad_norm_(
                        model.module.parameters(), 
                        max_grad_norm
                    )
                else:
                    torch.nn.utils.clip_grad_norm_(
                        model.parameters(), 
                        max_grad_norm
                    )
                
            optimizer.step()
            
            # 累积损失和准确率
            train_loss += loss.item()
            train_acc += batch_acc
            num_train_batches += 1
            
            # 保存预测概率、预测类别和标签
            probs = torch.softmax(outputs, dim=1)
            _, preds = torch.max(outputs, dim=1)
            epoch_train_probs.append(probs.detach().cpu().numpy())
            epoch_train_preds.append(preds.cpu().numpy())
            epoch_train_labels.append(labels.cpu().numpy())
        
        # 计算训练阶段平均指标
        avg_train_loss = train_loss / num_train_batches
        avg_train_acc = train_acc / num_train_batches
        
        # 计算每个类别的准确率和其他指标
        train_preds_all = np.concatenate(epoch_train_preds)
        train_labels_all = np.concatenate(epoch_train_labels)
        
        # F1分数
        train_f1 = f1_score(train_labels_all, train_preds_all, average='weighted')
        
        # 精确率
        train_precision = precision_score(train_labels_all, train_preds_all, average='weighted')
        
        # 召回率
        train_recall = recall_score(train_labels_all, train_preds_all, average='weighted')
        
        # 特异性 (Specificity) - 对于二分类问题
        train_cm = confusion_matrix(train_labels_all, train_preds_all)
        train_tn = train_cm[0, 0]
        train_fp = train_cm[0, 1]
        train_specificity = train_tn / (train_tn + train_fp) if (train_tn + train_fp) > 0 else 0
        
        # MCC (Matthews Correlation Coefficient)
        train_mcc = matthews_corrcoef(train_labels_all, train_preds_all)
        
        # 归一化MCC到[0,1]区间
        train_norm_mcc = (train_mcc + 1) / 2
        
        # 计算每个类别的准确率
        train_class_counts = np.bincount(train_labels_all, minlength=2)
        train_class_correct = np.bincount(
            train_labels_all[train_preds_all == train_labels_all], 
            minlength=2
        )
        train_class_acc = np.zeros(2)  # 初始化为零，避免除以零的问题
        for i in range(2):
            if train_class_counts[i] > 0:
                train_class_acc[i] = train_class_correct[i] / train_class_counts[i]
        
        # 记录训练指标
        history['train_loss'].append(avg_train_loss)
        history['train_acc'].append(avg_train_acc)
        history['train_class_acc'].append(train_class_acc.tolist())
        history['train_f1'].append(train_f1)
        history['train_precision'].append(train_precision)
        history['train_recall'].append(train_recall)
        history['train_specificity'].append(train_specificity)
        history['train_mcc'].append(train_mcc)
        history['train_norm_mcc'].append(train_norm_mcc)
        
        # ===== 验证阶段 =====
        model.eval()
        val_loss = 0.0
        val_acc = 0.0
        epoch_val_probs = []
        epoch_val_labels = []
        epoch_val_preds = []  # 存储预测类别
        num_val_batches = 0
        
        with torch.no_grad():
            for inputs, labels in val_loader:
                if inputs.size(0) <= 1:
                    continue
                    
                inputs = inputs.to(device)
                labels = labels.to(device)
                
                # 前向传播
                outputs = model(inputs)
                if isinstance(outputs, tuple):
                    outputs = outputs[0]
                
                # 计算损失和准确率
                loss = loss_fn(outputs, labels)
                batch_acc = accuracy(outputs, labels)
                
                val_loss += loss.item()
                val_acc += batch_acc
                num_val_batches += 1
                
                # 保存预测概率、预测类别和标签
                probs = torch.softmax(outputs, dim=1)
                _, preds = torch.max(outputs, dim=1)
                epoch_val_probs.append(probs.cpu().numpy())
                epoch_val_preds.append(preds.cpu().numpy())
                epoch_val_labels.append(labels.cpu().numpy())
        
        # 计算验证阶段平均指标
        avg_val_loss = val_loss / num_val_batches
        avg_val_acc = val_acc / num_val_batches
        
        # 计算每个类别的准确率和其他指标
        val_preds_all = np.concatenate(epoch_val_preds)
        val_labels_all = np.concatenate(epoch_val_labels)
        
        # F1分数
        val_f1 = f1_score(val_labels_all, val_preds_all, average='weighted')
        
        # 精确率
        val_precision = precision_score(val_labels_all, val_preds_all, average='weighted')
        
        # 召回率
        val_recall = recall_score(val_labels_all, val_preds_all, average='weighted')
        
        # 特异性 (Specificity) - 对于二分类问题
        val_cm = confusion_matrix(val_labels_all, val_preds_all)
        val_tn = val_cm[0, 0]
        val_fp = val_cm[0, 1]
        val_specificity = val_tn / (val_tn + val_fp) if (val_tn + val_fp) > 0 else 0
        
        # MCC (Matthews Correlation Coefficient)
        val_mcc = matthews_corrcoef(val_labels_all, val_preds_all)
        
        # 归一化MCC到[0,1]区间
        val_norm_mcc = (val_mcc + 1) / 2
        
        # 计算每个类别的准确率
        val_class_counts = np.bincount(val_labels_all, minlength=2)
        val_class_correct = np.bincount(
            val_labels_all[val_preds_all == val_labels_all], 
            minlength=2
        )
        val_class_acc = np.zeros(2)  # 初始化为零，避免除以零的问题
        for i in range(2):
            if val_class_counts[i] > 0:
                val_class_acc[i] = val_class_correct[i] / val_class_counts[i]
        
        # 记录验证指标
        history['val_loss'].append(avg_val_loss)
        history['val_acc'].append(avg_val_acc)
        history['val_class_acc'].append(val_class_acc.tolist())
        history['val_f1'].append(val_f1)
        history['val_precision'].append(val_precision)
        history['val_recall'].append(val_recall)
        history['val_specificity'].append(val_specificity)
        history['val_mcc'].append(val_mcc)
        history['val_norm_mcc'].append(val_norm_mcc)
        
        # 更新最佳模型状态，使用F1分数作为指标
        if val_f1 > best_val_f1:
            best_val_f1 = val_f1
            if isinstance(model, nn.DataParallel):
                best_model_state = copy.deepcopy(model.module.state_dict())
            else:
                best_model_state = copy.deepcopy(model.state_dict())
            logging.info(f"*** 新的最佳模型 (F1分数: {val_f1:.4f}) ***")
        
        # 更新学习率
        if isinstance(scheduler, lr_scheduler.ReduceLROnPlateau):
            scheduler.step(avg_val_loss)
        else:
            scheduler.step()
            
        # 获取当前学习率
        current_lr = optimizer.param_groups[0]['lr']
        
        # 记录训练日志，包含所有新增的评估指标
        epoch_log = (
            f'轮次 {epoch+1}/{epochs}, '
            f'训练损失: {avg_train_loss:.4f}, 训练准确率: {avg_train_acc:.4f}, '
            f'类别0/1: {train_class_acc[0]:.4f}/{train_class_acc[1]:.4f}, '
            f'训练F1: {train_f1:.4f}, 训练精确率: {train_precision:.4f}, '
            f'训练召回率: {train_recall:.4f}, 训练特异性: {train_specificity:.4f}, '
            f'训练MCC: {train_mcc:.4f}, 训练归一化MCC: {train_norm_mcc:.4f}, '
            f'验证损失: {avg_val_loss:.4f}, 验证准确率: {avg_val_acc:.4f}, '
            f'类别0/1: {val_class_acc[0]:.4f}/{val_class_acc[1]:.4f}, '
            f'验证F1: {val_f1:.4f}, 验证精确率: {val_precision:.4f}, '
            f'验证召回率: {val_recall:.4f}, 验证特异性: {val_specificity:.4f}, '
            f'验证MCC: {val_mcc:.4f}, 验证归一化MCC: {val_norm_mcc:.4f}, '
            f'学习率: {current_lr:.6f}'
        )
        logging.info(epoch_log)
        logging.info(f"本轮用时: {time.time() - epoch_start_time:.2f} 秒")
        logging.info("——————————————————————————————")
        
        if log_epoch is not None:
            log_epoch.append(epoch_log)
    
    # 加载最佳模型状态
    if best_model_state is not None:
        if isinstance(model, nn.DataParallel):
            model.module.load_state_dict(best_model_state)
        else:
            model.load_state_dict(best_model_state)
    
    # 整理最终结果
    final_train_probs = np.concatenate([p for p in epoch_train_probs], axis=0)
    final_train_labels = np.concatenate([l for l in epoch_train_labels], axis=0)
    final_val_probs = np.concatenate([p for p in epoch_val_probs], axis=0)
    final_val_labels = np.concatenate([l for l in epoch_val_labels], axis=0)
    
    # 计算最终的类别准确率和所有评估指标
    final_train_preds = np.argmax(final_train_probs, axis=1)
    final_val_preds = np.argmax(final_val_probs, axis=1)
    
    # F1分数
    final_train_f1 = f1_score(final_train_labels, final_train_preds, average='weighted')
    final_val_f1 = f1_score(final_val_labels, final_val_preds, average='weighted')
    
    # 精确率
    final_train_precision = precision_score(final_train_labels, final_train_preds, average='weighted')
    final_val_precision = precision_score(final_val_labels, final_val_preds, average='weighted')
    
    # 召回率
    final_train_recall = recall_score(final_train_labels, final_train_preds, average='weighted')
    final_val_recall = recall_score(final_val_labels, final_val_preds, average='weighted')
    
    # 特异性
    final_train_cm = confusion_matrix(final_train_labels, final_train_preds)
    final_train_tn = final_train_cm[0, 0]
    final_train_fp = final_train_cm[0, 1]
    final_train_specificity = final_train_tn / (final_train_tn + final_train_fp) if (final_train_tn + final_train_fp) > 0 else 0
    
    final_val_cm = confusion_matrix(final_val_labels, final_val_preds)
    final_val_tn = final_val_cm[0, 0]
    final_val_fp = final_val_cm[0, 1]
    final_val_specificity = final_val_tn / (final_val_tn + final_val_fp) if (final_val_tn + final_val_fp) > 0 else 0
    
    # MCC
    final_train_mcc = matthews_corrcoef(final_train_labels, final_train_preds)
    final_val_mcc = matthews_corrcoef(final_val_labels, final_val_preds)
    
    # 归一化MCC
    final_train_norm_mcc = (final_train_mcc + 1) / 2
    final_val_norm_mcc = (final_val_mcc + 1) / 2
    
    # 类别准确率
    train_class_acc = np.zeros(2)
    val_class_acc = np.zeros(2)
    
    for i in range(2):
        train_class_mask = (final_train_labels == i)
        val_class_mask = (final_val_labels == i)
        
        if np.sum(train_class_mask) > 0:
            train_class_acc[i] = np.mean(final_train_preds[train_class_mask] == final_train_labels[train_class_mask])
        
        if np.sum(val_class_mask) > 0:
            val_class_acc[i] = np.mean(final_val_preds[val_class_mask] == final_val_labels[val_class_mask])
    
    # 输出最终各项指标
    logging.info(f"最终训练类别准确率 - 类别0: {train_class_acc[0]:.4f}, 类别1: {train_class_acc[1]:.4f}")
    logging.info(f"最终验证类别准确率 - 类别0: {val_class_acc[0]:.4f}, 类别1: {val_class_acc[1]:.4f}")
    logging.info(f"最终F1分数 - 训练: {final_train_f1:.4f}, 验证: {final_val_f1:.4f}")
    logging.info(f"最终精确率 - 训练: {final_train_precision:.4f}, 验证: {final_val_precision:.4f}")
    logging.info(f"最终召回率 - 训练: {final_train_recall:.4f}, 验证: {final_val_recall:.4f}")
    logging.info(f"最终特异性 - 训练: {final_train_specificity:.4f}, 验证: {final_val_specificity:.4f}")
    logging.info(f"最终MCC - 训练: {final_train_mcc:.4f}, 验证: {final_val_mcc:.4f}")
    logging.info(f"最终归一化MCC - 训练: {final_train_norm_mcc:.4f}, 验证: {final_val_norm_mcc:.4f}")
    
    return (
        history['train_loss'][-1],    # 最终训练损失
        history['val_loss'][-1],      # 最终验证损失
        history['train_acc'][-1],     # 最终训练准确率
        history['val_acc'][-1],       # 最终验证准确率
        final_train_probs,           # 训练集预测概率
        final_train_labels,          # 训练集真实标签
        final_val_probs,             # 验证集预测概率
        final_val_labels,            # 验证集真实标签
        best_model_state             # 最佳模型状态
    )

# %% [markdown]
#  RNN 的 K-Fold 训练与评估函数

# %%
def kfold_train_eval_rnn(
    model_class: Any,
    dataset: TensorDataset,
    loss_fn: nn.Module,
    optimizer_class: Any,
    optimizer_kwargs: dict,
    scheduler_class: Any,
    scheduler_kwargs: dict,
    epochs: int,
    device: torch.device,
    device_ids: Optional[List[int]],
    num_folds: int = 5,
    output_dir: str = r"C:\Users\USTC\Desktop\地磁论文（5级以上）\对比模型结果\RNN模型结果",
    model_name: str = "RNNModel",
    window_name: str = "7天",
    mapped_window_name: str = "window-7",
    max_grad_norm: Optional[float] = None,
    input_size: int = 1,
    output_size: int = 2,
    hidden_sizes: List[int] = [512, 256],  # 修改为多个隐藏层大小的列表
    dropout_prob: float = 0.3,
    batch_size: int = 32
) -> Dict[str, List]:
    """
    使用分层K折交叉验证进行RNN模型的训练和评估，使用F1分数优化模型选择。
    
    Args:
        model_class: 模型类
        dataset: 数据集
        loss_fn: 损失函数
        optimizer_class: 优化器类
        optimizer_kwargs: 优化器参数
        scheduler_class: 学习率调度器类
        scheduler_kwargs: 学习率调度器参数
        epochs: 训练轮数
        device: 训练设备
        device_ids: GPU设备ID列表
        num_folds: 交叉验证折数
        output_dir: 模型保存目录
        model_name: 模型名称
        window_name: 时间窗口名称
        mapped_window_name: 映射后的窗口名称
        max_grad_norm: 梯度裁剪阈值
        input_size: 输入维度
        output_size: 输出维度
        hidden_sizes: RNN隐藏层大小列表，如 [512, 256]
        dropout_prob: Dropout概率
        batch_size: 批次大小
    
    Returns:
        Dict[str, List]: 包含训练结果的字典
    """
    from sklearn.model_selection import StratifiedKFold
    from sklearn.metrics import f1_score, precision_score, recall_score, matthews_corrcoef, confusion_matrix
    
    os.makedirs(output_dir, exist_ok=True)
    
    results_dict = {
        "train_losses": [],
        "val_losses": [],
        "train_accs": [],
        "val_accs": [],
        "train_f1s": [],       # F1分数记录
        "val_f1s": [],         # F1分数记录
        "train_precisions": [], # 精确率记录
        "val_precisions": [],   # 精确率记录
        "train_recalls": [],    # 召回率记录
        "val_recalls": [],      # 召回率记录
        "train_specificities": [], # 特异性记录
        "val_specificities": [],   # 特异性记录
        "train_mccs": [],      # MCC记录
        "val_mccs": [],        # MCC记录
        "train_norm_mccs": [], # 归一化MCC记录
        "val_norm_mccs": [],   # 归一化MCC记录
        "fold_results": []     # 存储每个折叠的详细结果
    }
    
    total_start_time = time.time()
    
    # 获取数据集的标签，用于分层划分
    all_data = dataset.tensors[0].numpy()
    all_labels = dataset.tensors[1].numpy()
    
    # 创建分层K折交叉验证
    skf = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)
    
    num_gpus = len(device_ids) if device_ids else 1
    adjusted_batch_size = batch_size * num_gpus
    
    logging.info(f"使用设备数量: {num_gpus}")
    logging.info(f"批次大小: {batch_size} 调整后的批次大小: {adjusted_batch_size}")
    
    # 计算类别权重，用于损失函数
    class_weights = calculate_class_weights(all_labels)
    weighted_loss_fn = nn.CrossEntropyLoss(weight=class_weights.to(device))
    logging.info(f"使用带权重的损失函数，权重: {class_weights.numpy()}")
    
    scheduler_kwargs['verbose'] = True
    
    # 使用分层K折训练
    for fold, (train_idx, val_idx) in enumerate(skf.split(all_data, all_labels), 1):
        fold_start_time = time.time()
        logging.info(f"开始训练第 {fold}/{num_folds} 折")
        
        # 准备数据加载器
        train_data = Subset(dataset, train_idx)
        val_data = Subset(dataset, val_idx)
        
        # 记录当前折叠的类别分布
        train_labels = dataset.tensors[1][train_idx].numpy()
        val_labels = dataset.tensors[1][val_idx].numpy()
        train_class_counts = np.bincount(train_labels)
        val_class_counts = np.bincount(val_labels)
        
        logging.info(f"训练集类别分布: 类别0: {train_class_counts[0]}, 类别1: {train_class_counts[1]}")
        logging.info(f"验证集类别分布: 类别0: {val_class_counts[0]}, 类别1: {val_class_counts[1]}")
        
        # 创建数据加载器
        train_loader = create_data_loaders_balanced(
            train_data, batch_size, num_gpus, is_train=True
        )
        
        val_loader = create_data_loaders(
            val_data, batch_size, num_gpus
        )
        
        # 初始化模型
        model = model_class(
            input_size=input_size,
            hidden_sizes=hidden_sizes,  # 使用修改后的参数名
            output_size=output_size,
            dropout_prob=dropout_prob
        ).to(device)
        
        if device_ids and len(device_ids) > 1:
            model = nn.DataParallel(model, device_ids=device_ids)
        
        optimizer = optimizer_class(model.parameters(), **optimizer_kwargs)
        scheduler = scheduler_class(optimizer, **scheduler_kwargs)
        
        epoch_logs = []
        try:
            # 训练单折模型，使用带权重的损失函数
            (train_loss, val_loss, 
             train_acc, val_acc,
             train_probs, train_labels,
             val_probs, val_labels,
             best_model_state) = train_eval_rnn(
                model=model,
                train_loader=train_loader,
                val_loader=val_loader,
                loss_fn=weighted_loss_fn,  # 使用带权重的损失函数
                optimizer=optimizer,
                scheduler=scheduler,
                epochs=epochs,
                device=device,
                log_epoch=epoch_logs,
                max_grad_norm=max_grad_norm,
            )
            
            # 保存模型和相关数据
            base_filename = os.path.join(output_dir, f"{model_name}_{window_name}_fold_{fold}")
            
            # 1. 保存模型权重
            model_path = f"{base_filename}.pth"
            torch.save(best_model_state, model_path)
            logging.info(f"已保存模型权重到: {model_path}")
            
            # 2. 保存训练日志
            log_path = f"{base_filename}_epoch_logs.txt"
            with open(log_path, 'w', encoding='utf-8') as f:
                f.write('\n'.join(epoch_logs))
            logging.info(f"已保存训练日志到: {log_path}")
            
            # 3. 保存训练集预测概率
            train_probs_path = f"{base_filename}_train_probs.npy"
            np.save(train_probs_path, train_probs)
            logging.info(f"已保存训练集预测概率到: {train_probs_path}")
            
            # 4. 保存训练集标签
            train_labels_path = f"{base_filename}_train_labels.npy"
            np.save(train_labels_path, train_labels)
            logging.info(f"已保存训练集标签到: {train_labels_path}")
            
            # 5. 保存测试集预测概率
            test_probs_path = f"{base_filename}_test_probs.npy"
            np.save(test_probs_path, val_probs)
            logging.info(f"已保存测试集预测概率到: {test_probs_path}")
            
            # 6. 保存测试集标签
            test_labels_path = f"{base_filename}_test_labels.npy"
            np.save(test_labels_path, val_labels)
            logging.info(f"已保存测试集标签到: {test_labels_path}")
            
            # 计算预测值
            train_preds = np.argmax(train_probs, axis=1)
            val_preds = np.argmax(val_probs, axis=1)
            
            # 计算各种评估指标
            # F1分数
            train_f1 = f1_score(train_labels, train_preds, average='weighted')
            val_f1 = f1_score(val_labels, val_preds, average='weighted')
            
            # 精确率 (Precision)
            train_precision = precision_score(train_labels, train_preds, average='weighted')
            val_precision = precision_score(val_labels, val_preds, average='weighted')
            
            # 召回率 (Recall)
            train_recall = recall_score(train_labels, train_preds, average='weighted')
            val_recall = recall_score(val_labels, val_preds, average='weighted')
            
            # 特异性 (Specificity) - 需要计算混淆矩阵
            train_cm = confusion_matrix(train_labels, train_preds)
            val_cm = confusion_matrix(val_labels, val_preds)
            
            # 对于二分类，特异性 = TN / (TN + FP)
            train_tn = train_cm[0, 0]
            train_fp = train_cm[0, 1]
            train_specificity = train_tn / (train_tn + train_fp) if (train_tn + train_fp) > 0 else 0
            
            val_tn = val_cm[0, 0]
            val_fp = val_cm[0, 1]
            val_specificity = val_tn / (val_tn + val_fp) if (val_tn + val_fp) > 0 else 0
            
            # MCC (Matthews Correlation Coefficient)
            train_mcc = matthews_corrcoef(train_labels, train_preds)
            val_mcc = matthews_corrcoef(val_labels, val_preds)
            
            # 归一化MCC到[0,1]区间
            train_norm_mcc = (train_mcc + 1) / 2
            val_norm_mcc = (val_mcc + 1) / 2
            
            # 计算每个类别的性能指标
            class_counts = np.bincount(val_labels.astype(int))
            class_correct = np.bincount(val_labels.astype(int) * (val_preds == val_labels), minlength=2)
            class_acc = class_correct / class_counts
            
            logging.info(f"类别准确率: 类别0: {class_acc[0]:.4f}, 类别1: {class_acc[1]:.4f}")
            logging.info(f"F1分数: 训练: {train_f1:.4f}, 验证: {val_f1:.4f}")
            logging.info(f"精确率: 训练: {train_precision:.4f}, 验证: {val_precision:.4f}")
            logging.info(f"召回率: 训练: {train_recall:.4f}, 验证: {val_recall:.4f}")
            logging.info(f"特异性: 训练: {train_specificity:.4f}, 验证: {val_specificity:.4f}")
            logging.info(f"MCC: 训练: {train_mcc:.4f}, 验证: {val_mcc:.4f}")
            logging.info(f"归一化MCC: 训练: {train_norm_mcc:.4f}, 验证: {val_norm_mcc:.4f}")
            
            # 收集每折的结果
            fold_result = {
                'fold': fold,
                'train_loss': train_loss,
                'val_loss': val_loss,
                'train_acc': train_acc,
                'val_acc': val_acc,
                'train_f1': train_f1,
                'val_f1': val_f1,
                'train_precision': train_precision,
                'val_precision': val_precision,
                'train_recall': train_recall,
                'val_recall': val_recall,
                'train_specificity': train_specificity,
                'val_specificity': val_specificity,
                'train_mcc': train_mcc,
                'val_mcc': val_mcc,
                'train_norm_mcc': train_norm_mcc,
                'val_norm_mcc': val_norm_mcc,
                'class_acc': class_acc.tolist(),  # 添加每个类别的准确率
                'model_path': model_path,
                'train_probs_path': train_probs_path,
                'train_labels_path': train_labels_path,
                'test_probs_path': test_probs_path,
                'test_labels_path': test_labels_path,
                'log_path': log_path,
                'time_taken': time.time() - fold_start_time
            }
            results_dict['fold_results'].append(fold_result)
            
            # 更新汇总指标
            results_dict['train_losses'].append(train_loss)
            results_dict['val_losses'].append(val_loss)
            results_dict['train_accs'].append(train_acc)
            results_dict['val_accs'].append(val_acc)
            results_dict['train_f1s'].append(train_f1)
            results_dict['val_f1s'].append(val_f1)
            results_dict['train_precisions'].append(train_precision)
            results_dict['val_precisions'].append(val_precision)
            results_dict['train_recalls'].append(train_recall)
            results_dict['val_recalls'].append(val_recall)
            results_dict['train_specificities'].append(train_specificity)
            results_dict['val_specificities'].append(val_specificity)
            results_dict['train_mccs'].append(train_mcc)
            results_dict['val_mccs'].append(val_mcc)
            results_dict['train_norm_mccs'].append(train_norm_mcc)
            results_dict['val_norm_mccs'].append(val_norm_mcc)
            
            logging.info(f"第 {fold} 折训练完成")
            
        except Exception as e:
            logging.error(f"训练第 {fold} 折时出错: {str(e)}")
            logging.error("详细错误信息:", exc_info=True)
            continue
        
        logging.info(f"第 {fold} 折训练结束")
    
    # 计算总训练时间
    total_duration = time.time() - total_start_time
    hours = int(total_duration // 3600)
    minutes = int((total_duration % 3600) // 60)
    seconds = int(total_duration % 60)
    
    # 计算统计结果
    train_acc_mean = np.mean(results_dict['train_accs'])
    train_acc_std = np.std(results_dict['train_accs'])
    val_acc_mean = np.mean(results_dict['val_accs'])
    val_acc_std = np.std(results_dict['val_accs'])
    
    train_f1_mean = np.mean(results_dict['train_f1s'])
    val_f1_mean = np.mean(results_dict['val_f1s'])
    
    train_precision_mean = np.mean(results_dict['train_precisions'])
    val_precision_mean = np.mean(results_dict['val_precisions'])
    
    train_recall_mean = np.mean(results_dict['train_recalls'])
    val_recall_mean = np.mean(results_dict['val_recalls'])
    
    train_specificity_mean = np.mean(results_dict['train_specificities'])
    val_specificity_mean = np.mean(results_dict['val_specificities'])
    
    train_mcc_mean = np.mean(results_dict['train_mccs'])
    val_mcc_mean = np.mean(results_dict['val_mccs'])
    
    train_norm_mcc_mean = np.mean(results_dict['train_norm_mccs'])
    val_norm_mcc_mean = np.mean(results_dict['val_norm_mccs'])
    
    # 计算每个类别的平均准确率
    class0_accs = [res['class_acc'][0] for res in results_dict['fold_results']]
    class1_accs = [res['class_acc'][1] for res in results_dict['fold_results']]
    class0_acc_mean = np.mean(class0_accs)
    class1_acc_mean = np.mean(class1_accs)
    
    # 保存训练配置和结果，包括类别平衡信息
    config = {
        'model_params': {
            'input_size': input_size,
            'hidden_sizes': hidden_sizes,
            'output_size': output_size,
            'dropout_prob': dropout_prob,
            'num_layers': len(hidden_sizes)
        },
        'training_params': {
            'optimizer': optimizer_class.__name__,
            'optimizer_kwargs': optimizer_kwargs,
            'scheduler': scheduler_class.__name__,
            'scheduler_kwargs': scheduler_kwargs,
            'epochs': epochs,
            'batch_size': batch_size,
            'class_weights': class_weights.tolist(),  # 保存类别权重
            'balanced_sampling': True  # 标记使用了平衡采样
        },
        'results': {
            'train_acc_mean': float(train_acc_mean),
            'train_acc_std': float(train_acc_std),
            'val_acc_mean': float(val_acc_mean),
            'val_acc_std': float(val_acc_std),
            'train_f1_mean': float(train_f1_mean),
            'val_f1_mean': float(val_f1_mean),
            'train_precision_mean': float(train_precision_mean),
            'val_precision_mean': float(val_precision_mean),
            'train_recall_mean': float(train_recall_mean),
            'val_recall_mean': float(val_recall_mean),
            'train_specificity_mean': float(train_specificity_mean),
            'val_specificity_mean': float(val_specificity_mean),
            'train_mcc_mean': float(train_mcc_mean),
            'val_mcc_mean': float(val_mcc_mean),
            'train_norm_mcc_mean': float(train_norm_mcc_mean),
            'val_norm_mcc_mean': float(val_norm_mcc_mean),
            'class0_acc_mean': float(class0_acc_mean),
            'class1_acc_mean': float(class1_acc_mean),
            'training_time': {
                'hours': hours,
                'minutes': minutes,
                'seconds': seconds
            },
            'fold_results': results_dict['fold_results']
        }
    }
    
    config_path = os.path.join(output_dir, f"{model_name}_{window_name}_config.json")
    with open(config_path, 'w', encoding='utf-8') as f:
        json.dump(config, f, indent=4, ensure_ascii=False)
    
    # 记录训练总结
    logging.info("\n训练总结:")
    logging.info(f"- 总训练时间: {hours}小时 {minutes}分钟 {seconds}秒")
    logging.info(f"- 平均训练准确率: {train_acc_mean:.4f} ± {train_acc_std:.4f}")
    logging.info(f"- 平均验证准确率: {val_acc_mean:.4f} ± {val_acc_std:.4f}")
    logging.info(f"- 平均训练精确率: {train_precision_mean:.4f}")
    logging.info(f"- 平均验证精确率: {val_precision_mean:.4f}")
    logging.info(f"- 平均训练召回率: {train_recall_mean:.4f}")
    logging.info(f"- 平均验证召回率: {val_recall_mean:.4f}")
    logging.info(f"- 平均训练特异性: {train_specificity_mean:.4f}")
    logging.info(f"- 平均验证特异性: {val_specificity_mean:.4f}")
    logging.info(f"- 平均训练MCC: {train_mcc_mean:.4f}")
    logging.info(f"- 平均验证MCC: {val_mcc_mean:.4f}")
    logging.info(f"- 平均训练归一化MCC: {train_norm_mcc_mean:.4f}")
    logging.info(f"- 平均验证归一化MCC: {val_norm_mcc_mean:.4f}")
    logging.info(f"- 类别0平均准确率: {class0_acc_mean:.4f}")
    logging.info(f"- 类别1平均准确率: {class1_acc_mean:.4f}")
    logging.info(f"- 平均验证损失: {np.mean(results_dict['val_losses']):.4f} ± {np.std(results_dict['val_losses']):.4f}")
    
    return results_dict

# %%
import torch
print("CUDA 是否可用:", torch.cuda.is_available())
print("当前 PyTorch 版本:", torch.__version__)
print("CUDA 版本:", torch.version.cuda)
print("GPU 数量:", torch.cuda.device_count())

if torch.cuda.is_available():
    for i in range(torch.cuda.device_count()):
        print(f"GPU {i}: {torch.cuda.get_device_name(i)}")
# Out:
# CUDA 是否可用: True
# 当前 PyTorch 版本: 2.5.1+cu118
# CUDA 版本: 11.8
# GPU 数量: 2
# GPU 0: NVIDIA GeForce RTX 4090
# GPU 1: NVIDIA GeForce RTX 4090

# %% [markdown]
# 检查数据集的大小，以便更科学的数据平衡

# %%
import os
import numpy as np

base_path = r"C:\Users\USTC\Desktop\地磁论文（5级以上）"

# 检查各个时间窗口的数据分布
window_periods = ['7', '14', '30']

for period in window_periods:
    window_path = os.path.join(base_path, f"window-{period}")
    
    try:
        # 加载数据文件
        data_0_path = os.path.join(window_path, "data_0.npy")
        data_1_path = os.path.join(window_path, "data_1.npy")
        
        if os.path.exists(data_0_path) and os.path.exists(data_1_path):
            data_0 = np.load(data_0_path)
            data_1 = np.load(data_1_path)
            
            # 提取标签信息
            labels_0 = data_0[:, -1].astype(int)
            labels_1 = data_1[:, -1].astype(int)
            
            # 合并数据和标签
            all_data = np.concatenate([data_0, data_1], axis=0)
            all_labels = all_data[:, -1].astype(int)
            
            # 计算类别分布
            class_counts = np.bincount(all_labels)
            
            print(f"\n=== 时间窗口: {period}天 ===")
            print(f"数据形状 - data_0: {data_0.shape}, data_1: {data_1.shape}")
            print(f"总样本数: {len(all_labels)}")
            if len(class_counts) >= 2:
                print(f"类别0样本数: {class_counts[0]}")
                print(f"类别1样本数: {class_counts[1]}")
                print(f"类别比例(1:0): 1:{class_counts[0]/class_counts[1]:.2f}")
            else:
                print(f"警告: 只有一个类别 - {class_counts}")
                
            # 计算平衡建议
            if class_counts[0] > class_counts[1]:
                minority_class = 1
                minority_count = class_counts[1]
                majority_count = class_counts[0]
            else:
                minority_class = 0
                minority_count = class_counts[0]
                majority_count = class_counts[1]
                
            imbalance_ratio = majority_count / minority_count
            
            print(f"\n数据不平衡分析:")
            print(f"不平衡比例: {imbalance_ratio:.2f}:1")
            
            if imbalance_ratio < 1.5:
                print("评估: 数据集相对平衡，简单的类别权重调整应该足够")
                weight_suggestion = f"类别权重建议: [1.0, {imbalance_ratio:.2f}]" if minority_class == 1 else f"类别权重建议: [{imbalance_ratio:.2f}, 1.0]"
                print(weight_suggestion)
            elif imbalance_ratio < 10:
                print("评估: 中度不平衡，建议结合类别权重和采样技术")
                # 计算平方根缩放的权重
                sqrt_weights = np.sqrt(class_counts) / np.sum(np.sqrt(class_counts)) * len(class_counts)
                weights_str = "[{:.2f}, {:.2f}]".format(sqrt_weights[0], sqrt_weights[1])
                print(f"类别权重建议(平方根缩放): {weights_str}")
                print("采样策略: 使用WeightedRandomSampler进行训练")
            else:
                print("评估: 严重不平衡，建议使用组合策略")
                print("建议策略:")
                print("1. 使用有效样本数计算权重")
                print("2. 考虑使用Focal Loss代替CrossEntropyLoss")
                print("3. 结合过采样和欠采样技术")
                print("4. 使用数据增强生成少数类样本")
        else:
            print(f"错误: 无法找到窗口 {period} 的数据文件")
    except Exception as e:
        print(f"处理窗口 {period} 时出错: {str(e)}")
# Out:
# === 时间窗口: 7天 ===
# 数据形状 - data_0: (1661, 10081), data_1: (999, 10081)
# 总样本数: 2660
# 类别0样本数: 1661
# 类别1样本数: 999
# 类别比例(1:0): 1:1.66
#
# 数据不平衡分析:
# 不平衡比例: 1.66:1
# 评估: 中度不平衡，建议结合类别权重和采样技术
# 类别权重建议(平方根缩放): [1.13, 0.87]
# 采样策略: 使用WeightedRandomSampler进行训练
#
# === 时间窗口: 14天 ===
# 数据形状 - data_0: (1878, 20161), data_1: (826, 20161)
# 总样本数: 2704
# 类别0样本数: 1878
# 类别1样本数: 826
# 类别比例(1:0): 1:2.27
#
# 数据不平衡分析:
# 不平衡比例: 2.27:1
# 评估: 中度不平衡，建议结合类别权重和采样技术
# 类别权重建议(平方根缩放): [1.20, 0.80]
# 采样策略: 使用WeightedRandomSampler进行训练
#
# === 时间窗口: 30天 ===
# 数据形状 - data_0: (1421, 43201), data_1: (770, 43201)
# 总样本数: 2191
# 类别0样本数: 1421
# 类别1样本数: 770
# 类别比例(1:0): 1:1.85
#
# 数据不平衡分析:
# 不平衡比例: 1.85:1
# 评估: 中度不平衡，建议结合类别权重和采样技术
# 类别权重建议(平方根缩放): [1.15, 0.85]
# 采样策略: 使用WeightedRandomSampler进行训练

# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader, Subset
from torch.optim import lr_scheduler
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score
import logging
import time
import json
from typing import Dict, Any, Optional, List, Tuple
import copy

import warnings
warnings.filterwarnings("ignore", message="PyTorch is not compiled with NCCL support")

def setup_logging(log_file: str = 'training.log'):
    """设置日志配置"""
    logging.basicConfig(
        level=logging.INFO,
        format='%(asctime)s - %(levelname)s - %(message)s',
        datefmt='%Y-%m-%d %H:%M:%S'  # 移除了 ,%f，因为这不是标准的时间格式
    )
    # 如果需要添加文件处理器
    file_handler = logging.FileHandler(log_file, encoding='utf-8')
    file_handler.setFormatter(
        logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
    )
    logger = logging.getLogger(__name__)
    logger.addHandler(file_handler)
    return logger

def setup_device() -> Tuple[torch.device, Optional[List[int]]]:
    """配置训练设备，最大化利用所有可用NVIDIA GPU"""
    if torch.cuda.device_count() > 1:
        # 获取所有可用GPU
        device_count = torch.cuda.device_count()
        device_ids = list(range(device_count))
        device = torch.device(f'cuda:{device_ids[0]}')
        
        # 输出每个GPU的信息
        gpu_info = []
        for i in device_ids:
            gpu_name = torch.cuda.get_device_name(i)
            gpu_info.append(f"GPU {i}: {gpu_name}")
        
        logging.info(f"使用 {len(device_ids)} 个GPU设备: {device_ids}")
        logging.info("GPU详情: " + ", ".join(gpu_info))
        
        # 设置主设备，确保初始化顺序正确
        torch.cuda.set_device(device_ids[0])
        
        return device, device_ids
    elif torch.cuda.is_available():
        device = torch.device('cuda:0')
        gpu_name = torch.cuda.get_device_name(0)
        logging.info(f"使用单个GPU设备: {gpu_name}")
        return device, None
    else:
        device = torch.device('cpu')
        logging.info("使用CPU设备")
        return device, None

def calculate_class_weights(labels):
    """计算平方根缩放的类别权重"""
    class_counts = np.bincount(labels)
    logging.info(f"类别分布: 类别0: {class_counts[0]}, 类别1: {class_counts[1]}")
    
    # 使用平方根缩放计算权重
    weights_sqrt = np.sqrt(class_counts.sum() / class_counts / len(class_counts))
    return torch.FloatTensor(weights_sqrt)

def create_balanced_sampler(dataset):
    """创建平衡采样器"""
    # 提取数据集的标签
    if isinstance(dataset, TensorDataset):
        labels = dataset.tensors[1].numpy()
    elif isinstance(dataset, Subset):
        labels = dataset.dataset.tensors[1][dataset.indices].numpy()
    else:
        raise TypeError("不支持的数据集类型")
    
    # 计算类别权重（反比例，但不使用平方根缩放）
    class_counts = np.bincount(labels)
    logging.info(f"原始类别分布: {class_counts}")
    
    # 计算每个样本的权重
    class_weights = 1.0 / class_counts
    # 确保少数类有更高的采样概率
    sample_weights = class_weights[labels]
    
    # 创建采样器
    sampler = WeightedRandomSampler(
        weights=sample_weights,
        num_samples=len(sample_weights),
        replacement=True  # 允许重复采样
    )
    
    return sampler

def create_data_loaders_balanced(dataset, batch_size, num_gpus=1, is_train=True):
    """创建带有平衡采样的数据加载器"""
    effective_batch_size = batch_size * num_gpus if num_gpus > 1 else batch_size
    
    if is_train:
        # 训练集使用加权采样
        sampler = create_balanced_sampler(dataset)
        logging.info(f"批次大小: {batch_size} 调整后的批次大小: {effective_batch_size} (使用平衡采样)")
        return DataLoader(
            dataset,
            batch_size=effective_batch_size,
            sampler=sampler,  # 使用采样器替代shuffle
            num_workers=4 * num_gpus,
            pin_memory=True
        )
    else:
        # 验证集不需要平衡采样
        logging.info(f"批次大小: {batch_size} 调整后的批次大小: {effective_batch_size}")
        return DataLoader(
            dataset,
            batch_size=effective_batch_size,
            shuffle=False,
            num_workers=4 * num_gpus,
            pin_memory=True
        )

def create_data_loaders(dataset: TensorDataset, batch_size: int, num_gpus: int = 1) -> DataLoader:
    """创建数据加载器"""
    effective_batch_size = batch_size * num_gpus if num_gpus > 1 else batch_size
    logging.info(f"批次大小: {batch_size} 调整后的批次大小: {effective_batch_size}")
    
    return DataLoader(
        dataset,
        batch_size=effective_batch_size,
        shuffle=True,
        num_workers=4 * num_gpus,
        pin_memory=True
    )

def create_model(model_class, input_size, hidden_sizes, output_size, dropout_prob, device, device_ids=None):
    """创建模型"""
    model = model_class(
        input_size=input_size,
        hidden_sizes=hidden_sizes,
        output_size=output_size,
        dropout_prob=dropout_prob
    )
    
    if device_ids and len(device_ids) > 1:
        model = nn.DataParallel(model, device_ids=device_ids)
    
    return model.to(device)

def reshape_data_for_rnn(X: np.ndarray, seq_length: int) -> np.ndarray:
    """重塑数据为RNN输入格式"""
    try:
        batch_size = X.shape[0]
        feature_per_timestamp = X.shape[1] // seq_length
        X_reshaped = X.reshape(batch_size, seq_length, feature_per_timestamp)
        logging.info(f"数据重塑成功: {X.shape} -> {X_reshaped.shape}")
        return X_reshaped
    except Exception as e:
        logging.error(f"数据重塑失败: {str(e)}")
        raise

def main_rnn(optimize: bool = False) -> None:
    """主训练函数 - 使用分层K折交叉验证和F1分数优化"""
    
    setup_logging()  # 设置日志
    device, device_ids = setup_device()
    base_path = r"C:\Users\USTC\Desktop\地磁论文（5级以上）"
    output_dir = os.path.join(base_path, '对比模型结果', 'RNN模型结果')
    os.makedirs(output_dir, exist_ok=True)

    logging.info(f"开始训练流程 - 使用设备: {device}")

    window_mapping = {
        "window-7": {"name": "7天", "seq_length": 7},
        "window-14": {"name": "14天", "seq_length": 14},
        "window-30": {"name": "30天", "seq_length": 30}
    }

    try:
        # 训练参数设置
        training_config = {
            'hidden_sizes': [512, 256],    # 隐藏层大小，与RNN保持一致
            'num_layers': 2,               # 层数保持为2
            'dropout_prob': 0.3,           # dropout率
            'learning_rate': 0.001,        # 学习率
            'batch_size': 32,              # batch size
            'weight_decay': 0.01,          # L2正则化参数
            'max_grad_norm': 1.0           # 梯度裁剪阈值
        }
        
        optimizer_kwargs = {
            'lr': training_config['learning_rate'],
            'weight_decay': training_config['weight_decay']
        }
        
        scheduler_kwargs = {
            'mode': 'min',
            'factor': 0.1,
            'patience': 10,
            'min_lr': 1e-6,
            'verbose': True
        }
        
        num_gpus = len(device_ids) if device_ids else 1
        
        for window_period in ['7', '14', '30']:
            current_window_name = f"window-{window_period}"
            window_info = window_mapping[current_window_name]
            
            logging.info(f"\n=== 开始处理时间窗口: {window_info['name']} ===")

            try:
                # 加载数据
                data_dir = os.path.join(base_path, current_window_name)
                data_0 = np.load(os.path.join(data_dir, "data_0.npy"))
                data_1 = np.load(os.path.join(data_dir, "data_1.npy"))
                
                data = np.concatenate([data_0, data_1], axis=0)
                X = data[:, :-1]
                Y = data[:, -1].astype(int)
                
                # 记录类别分布
                class_counts = np.bincount(Y)
                logging.info(f"类别分布: 类别0: {class_counts[0]}, 类别1: {class_counts[1]}")
                
                # 计算类别权重，用于损失函数
                class_weights = calculate_class_weights(Y)
                logging.info(f"使用平方根缩放的类别权重: {class_weights}")
                weighted_loss = nn.CrossEntropyLoss(weight=class_weights)
                
                # 重塑数据为RNN格式
                X = reshape_data_for_rnn(X, window_info['seq_length'])
                
                # 转换为张量
                X_tensor = torch.from_numpy(X).type(torch.float32)
                Y_tensor = torch.from_numpy(Y).type(torch.long)
                dataset = TensorDataset(X_tensor, Y_tensor)

                # 使用分层K折交叉验证训练
                results = kfold_train_eval_rnn(
                    model_class=RNNModel,
                    dataset=dataset,
                    loss_fn=weighted_loss,  # 使用带权重的损失函数
                    optimizer_class=optim.AdamW,
                    optimizer_kwargs=optimizer_kwargs,
                    scheduler_class=optim.lr_scheduler.ReduceLROnPlateau,
                    scheduler_kwargs=scheduler_kwargs,
                    epochs=100,
                    device=device,
                    device_ids=device_ids,
                    num_folds=5,
                    output_dir=output_dir,
                    model_name="RNNModel",
                    window_name=window_info['name'],
                    mapped_window_name=current_window_name,
                    input_size=X.shape[2],
                    output_size=2,
                    hidden_sizes=training_config['hidden_sizes'],
                    dropout_prob=training_config['dropout_prob'],
                    batch_size=training_config['batch_size'],
                    max_grad_norm=training_config['max_grad_norm']
                )

                # 执行基于F1分数的模型集成
                perform_model_ensemble(
                    model_name="RNNModel",
                    window_name=window_info['name'],
                    output_dir=output_dir,
                    device=device,
                    device_ids=device_ids,
                    model_class=RNNModel,
                    input_size=X.shape[2],
                    hidden_sizes=training_config['hidden_sizes'],
                    output_size=2,
                    dropout_prob=training_config['dropout_prob'],
                    num_folds=5
                )

            except Exception as e:
                logging.error(f"处理 {window_info['name']} 时出错: {str(e)}")
                logging.error("详细错误信息:", exc_info=True)
                continue

        logging.info("\n=== 所有处理完成！===")

    except Exception as e:
        logging.error(f"程序执行出错: {str(e)}")
        raise

def perform_model_ensemble(
    model_name: str,
    window_name: str,
    output_dir: str,
    device: torch.device,
    device_ids: Optional[List[int]],
    model_class: Any,
    input_size: int,
    hidden_sizes: List[int],
    output_size: int,
    dropout_prob: float,
    num_folds: int
) -> None:
    """
    执行模型集成过程，使用F1分数优化权重分配，同时保存全面的评估指标
    
    Args:
        model_name: 模型名称
        window_name: 时间窗口名称
        output_dir: 输出目录
        device: 设备
        device_ids: GPU设备ID列表
        model_class: 模型类
        input_size: 输入维度
        hidden_sizes: RNN隐藏层大小列表
        output_size: 输出维度
        dropout_prob: Dropout概率
        num_folds: 折叠数量
    """
    from sklearn.metrics import f1_score, precision_score, recall_score, matthews_corrcoef, confusion_matrix
    
    logging.info(f"开始进行模型集成 - {model_name}_{window_name}")
    
    try:
        # 加载各个折叠的模型
        models = []
        model_metrics = {
            'f1_scores': [],            # F1分数
            'precisions': [],           # 精确率
            'recalls': [],              # 召回率
            'specificities': [],        # 特异性
            'mccs': [],                 # MCC
            'norm_mccs': []             # 归一化MCC
        }
        
        for fold in range(1, num_folds + 1):
            # 创建基础模型
            model = model_class(
                input_size=input_size,
                hidden_sizes=hidden_sizes,
                output_size=output_size,
                dropout_prob=dropout_prob
            ).to(device)
            
            if device_ids and len(device_ids) > 1:
                model = nn.DataParallel(model, device_ids=device_ids)
            
            # 加载模型权重
            model_path = os.path.join(output_dir, f"{model_name}_{window_name}_fold_{fold}.pth")
            if os.path.exists(model_path):
                state_dict = torch.load(model_path)
                if device_ids and len(device_ids) > 1:
                    if not list(state_dict.keys())[0].startswith('module.'):
                        state_dict = {'module.' + k: v for k, v in state_dict.items()}
                model.load_state_dict(state_dict)
                model.eval()
                models.append(model)
                
                # 加载验证数据，计算各项指标
                test_probs_path = os.path.join(output_dir, f"{model_name}_{window_name}_fold_{fold}_test_probs.npy")
                test_labels_path = os.path.join(output_dir, f"{model_name}_{window_name}_fold_{fold}_test_labels.npy")
                
                if os.path.exists(test_probs_path) and os.path.exists(test_labels_path):
                    test_probs = np.load(test_probs_path)
                    test_labels = np.load(test_labels_path)
                    
                    test_preds = np.argmax(test_probs, axis=1)
                    
                    # 计算所有评估指标
                    fold_f1 = f1_score(test_labels, test_preds, average='weighted')
                    fold_precision = precision_score(test_labels, test_preds, average='weighted')
                    fold_recall = recall_score(test_labels, test_preds, average='weighted')
                    
                    # 计算特异性 (针对二分类)
                    fold_cm = confusion_matrix(test_labels, test_preds)
                    fold_tn = fold_cm[0, 0]
                    fold_fp = fold_cm[0, 1]
                    fold_specificity = fold_tn / (fold_tn + fold_fp) if (fold_tn + fold_fp) > 0 else 0
                    
                    # 计算MCC和归一化MCC
                    fold_mcc = matthews_corrcoef(test_labels, test_preds)
                    fold_norm_mcc = (fold_mcc + 1) / 2  # 归一化到[0,1]区间
                    
                    # 确保F1分数非零(用于权重计算)
                    fold_f1 = max(fold_f1, 0.01)
                    
                    # 存储所有指标
                    model_metrics['f1_scores'].append(fold_f1)
                    model_metrics['precisions'].append(fold_precision)
                    model_metrics['recalls'].append(fold_recall)
                    model_metrics['specificities'].append(fold_specificity)
                    model_metrics['mccs'].append(fold_mcc)
                    model_metrics['norm_mccs'].append(fold_norm_mcc)
                    
                    logging.info(f"第 {fold} 折模型评估指标:")
                    logging.info(f"  F1分数: {fold_f1:.4f}")
                    logging.info(f"  精确率: {fold_precision:.4f}")
                    logging.info(f"  召回率: {fold_recall:.4f}")
                    logging.info(f"  特异性: {fold_specificity:.4f}")
                    logging.info(f"  MCC: {fold_mcc:.4f}")
                    logging.info(f"  归一化MCC: {fold_norm_mcc:.4f}")
                else:
                    # 如果找不到验证数据，从配置文件中尝试获取各项指标
                    config_path = os.path.join(output_dir, f"{model_name}_{window_name}_config.json")
                    if os.path.exists(config_path):
                        with open(config_path, 'r', encoding='utf-8') as f:
                            config = json.load(f)
                            fold_results = config['results']['fold_results']
                            fold_result = next((result for result in fold_results if result['fold'] == fold), None)
                            
                            if fold_result:
                                # 提取所有可用的指标
                                fold_f1 = fold_result.get('val_f1', 1.0)
                                model_metrics['f1_scores'].append(fold_f1)
                                
                                if 'val_precision' in fold_result:
                                    model_metrics['precisions'].append(fold_result['val_precision'])
                                else:
                                    model_metrics['precisions'].append(0.0)
                                    
                                if 'val_recall' in fold_result:
                                    model_metrics['recalls'].append(fold_result['val_recall'])
                                else:
                                    model_metrics['recalls'].append(0.0)
                                    
                                if 'val_specificity' in fold_result:
                                    model_metrics['specificities'].append(fold_result['val_specificity'])
                                else:
                                    model_metrics['specificities'].append(0.0)
                                    
                                if 'val_mcc' in fold_result:
                                    model_metrics['mccs'].append(fold_result['val_mcc'])
                                else:
                                    model_metrics['mccs'].append(0.0)
                                    
                                if 'val_norm_mcc' in fold_result:
                                    model_metrics['norm_mccs'].append(fold_result['val_norm_mcc'])
                                else:
                                    model_metrics['norm_mccs'].append(0.5)  # 0.5是归一化MCC的中间值
                                
                                logging.info(f"第 {fold} 折模型F1分数(从配置获取): {fold_f1:.4f}")
                            else:
                                # 如果找不到特定折的结果，使用默认值
                                model_metrics['f1_scores'].append(1.0)
                                model_metrics['precisions'].append(0.0)
                                model_metrics['recalls'].append(0.0)
                                model_metrics['specificities'].append(0.0)
                                model_metrics['mccs'].append(0.0)
                                model_metrics['norm_mccs'].append(0.5)
                                logging.warning(f"未找到第 {fold} 折的F1分数，使用默认值1.0")
                    else:
                        # 如果找不到配置文件，使用默认值
                        model_metrics['f1_scores'].append(1.0)
                        model_metrics['precisions'].append(0.0)
                        model_metrics['recalls'].append(0.0)
                        model_metrics['specificities'].append(0.0)
                        model_metrics['mccs'].append(0.0)
                        model_metrics['norm_mccs'].append(0.5)
                        logging.warning(f"未找到第 {fold} 折的验证集结果，使用默认F1=1.0")
                
                logging.info(f"已加载第 {fold} 折模型")
            else:
                logging.warning(f"未找到第 {fold} 折模型权重文件: {model_path}")
        
        if models:
            # 使用基于F1分数的集成权重
            weights = np.array(model_metrics['f1_scores'])
            weights = weights / weights.sum()
            logging.info(f"基于F1分数的模型权重: {weights}")
            
            # 创建集成模型
            ensemble_model = EnsembleModel(
                base_models=models,
                ensemble_weights=weights
            ).to(device)
            
            if device_ids and len(device_ids) > 1:
                ensemble_model = nn.DataParallel(ensemble_model, device_ids=device_ids)
            
            # 保存集成模型
            ensemble_path = os.path.join(output_dir, f"{model_name}_{window_name}.pth")
            torch.save(ensemble_model.state_dict(), ensemble_path)
            
            # 计算各项指标的平均值
            avg_metrics = {}
            for metric_name, values in model_metrics.items():
                if values:
                    avg_metrics[f'avg_{metric_name}'] = float(np.mean(values))
                    avg_metrics[f'std_{metric_name}'] = float(np.std(values))
            
            # 保存集成配置，包含所有评估指标
            ensemble_config = {
                'model_name': model_name,
                'window_name': window_name,
                'ensemble_weights': weights.tolist(),
                'ensemble_method': 'f1_weighted',  # 标记使用F1加权
                'model_params': {
                    'input_size': input_size,
                    'hidden_sizes': hidden_sizes,
                    'output_size': output_size,
                    'dropout_prob': dropout_prob
                },
                'fold_metrics': {
                    'f1_scores': model_metrics['f1_scores'],
                    'precisions': model_metrics['precisions'],
                    'recalls': model_metrics['recalls'],
                    'specificities': model_metrics['specificities'],
                    'mccs': model_metrics['mccs'],
                    'norm_mccs': model_metrics['norm_mccs']
                },
                'average_metrics': avg_metrics
            }
            
            config_path = os.path.join(output_dir, f"{model_name}_{window_name}_ensemble_config.json")
            with open(config_path, 'w', encoding='utf-8') as f:
                json.dump(ensemble_config, f, indent=4, ensure_ascii=False)
            
            # 输出集成模型的平均表现
            logging.info(f"F1加权集成模型已保存: {ensemble_path}")
            logging.info("集成模型平均评估指标:")
            for metric_name, value in avg_metrics.items():
                if metric_name.startswith('avg_'):
                    display_name = metric_name[4:].replace('_', ' ')
                    logging.info(f"  平均{display_name}: {value:.4f}")
            
            logging.info(f"集成配置已保存: {config_path}")
        else:
            logging.error("没有可用的模型进行集成")
            
    except Exception as e:
        logging.error(f"模型集成过程出错: {str(e)}")
        logging.error("详细错误信息:", exc_info=True)

def load_ensemble_model(
    model_path: str,
    config_path: str,
    device: torch.device,
    model_class: Any,
    device_ids: Optional[List[int]] = None
) -> EnsembleModel:
    """
    加载集成模型
    
    Args:
        model_path: 模型路径
        config_path: 配置文件路径
        device: 设备
        model_class: 模型类
        device_ids: GPU设备ID列表
    
    Returns:
        EnsembleModel: 加载的集成模型
    """
    with open(config_path, 'r') as f:
        config = json.load(f)
    
    base_models = []
    num_folds = len(config['ensemble_weights'])
    
    for _ in range(num_folds):
        model = model_class(
            input_size=config['model_params']['input_size'],
            hidden_sizes=config['model_params']['hidden_sizes'],
            output_size=config['model_params']['output_size'],
            dropout_prob=config['model_params']['dropout_prob']
        ).to(device)
        base_models.append(model)

    ensemble_model = EnsembleModel(
        base_models=base_models,
        ensemble_weights=config['ensemble_weights']
    ).to(device)
    
    if device_ids and len(device_ids) > 1:
        ensemble_model = nn.DataParallel(ensemble_model, device_ids=device_ids)
    
    ensemble_model.load_state_dict(torch.load(model_path))
    return ensemble_model

if __name__ == "__main__":
    main_rnn()
# Out:
# 2025-03-10 02:17:17 - INFO - 使用 2 个GPU设备: [0, 1]
# 2025-03-10 02:17:17 - INFO - GPU详情: GPU 0: NVIDIA GeForce RTX 4090, GPU 1: NVIDIA GeForce RTX 4090
# 2025-03-10 02:17:17 - INFO - 开始训练流程 - 使用设备: cuda:0
# 2025-03-10 02:17:17 - INFO -
# === 开始处理时间窗口: 7天 ===
# 2025-03-10 02:17:17 - INFO - 类别分布: 类别0: 1661, 类别1: 999
# 2025-03-10 02:17:17 - INFO - 类别分布: 类别0: 1661, 类别1: 999
# 2025-03-10 02:17:17 - INFO - 使用平方根缩放的类别权重: tensor([0.8948, 1.1538])
# 2025-03-10 02:17:17 - INFO - 数据重塑成功: (2660, 10080) -> (2660, 7, 1440)
# 2025-03-10 02:17:17 - INFO - 使用设备数量: 2
# 2025-03-10 02:17:17 - INFO - 批次大小: 32 调整后的批次大小: 64
# 2025-03-10 02:17:17 - INFO - 类别分布: 类别0: 1661, 类别1: 999
# 2025-03-10 02:17:17 - INFO - 使用带权重的损失函数，权重: [0.89483094 1.1538333 ]
# 2025-03-10 02:17:17 - INFO - 开始训练第 1/5 折
# 2025-03-10 02:17:17 - INFO - 训练集类别分布: 类别0: 1328, 类别1: 800
# 2025-03-10 02:17:17 - INFO - 验证集类别分布: 类别0: 333, 类别1: 199
# 2025-03-10 02:17:17 - INFO - 原始类别分布: [1328  800]
# 2025-03-10 02:17:17 - INFO - 批次大小: 32 调整后的批次大小: 64 (使用平衡采样)
# 2025-03-10 02:17:17 - INFO - 批次大小: 32 调整后的批次大小: 64
# c:\Users\USTC\anaconda3\envs\gpupytorch\lib\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# 2025-03-10 02:17:17 - INFO - 使用带权重的损失函数，权重: [0.89483094 1.1538333 ]
# 2025-03-10 02:17:24 - INFO - *** 新的最佳模型 (F1分数: 0.4798) ***
# 2025-03-10 02:17:24 - INFO - 轮次 1/100, 训练损失: 0.7573, 训练准确率: 0.5317, 类别0/1: 0.4658/0.6107, 训练F1: 0.5356, 训练精确率: 0.5391, 训练召回率: 0.5381, 训练特异性: 0.4658, 训练MCC: 0.0774, 训练归一化MCC: 0.5387, 验证损失: 0.8302, 验证准确率: 0.5944, 类别0/1: 0.9790/0.0050, 验证F1: 0.4798, 验证精确率: 0.4362, 验证召回率: 0.6147, 验证特异性: 0.9790, 验证MCC: -0.0636, 验证归一化MCC: 0.4682, 学习率: 0.001000
# 2025-03-10 02:17:24 - INFO - 本轮用时: 7.00 秒
# 2025-03-10 02:17:24 - INFO - ——————————————————————————————
# 2025-03-10 02:17:31 - INFO - 轮次 2/100, 训练损失: 0.7179, 训练准确率: 0.5317, 类别0/1: 0.4117/0.6430, 训练F1: 0.5247, 训练精确率: 0.5292, 训练召回率: 0.5310, 训练特异性: 0.4117, 训练MCC: 0.0562, 训练归一化MCC: 0.5281, 验证损失: 0.7228, 验证准确率: 0.4080, 类别0/1: 0.1712/0.8392, 验证F1: 0.3637, 验证精确率: 0.5419, 验证召回率: 0.4211, 验证特异性: 0.1712, 验证MCC: 0.0134, 验证归一化MCC: 0.5067, 学习率: 0.001000
# 2025-03-10 02:17:31 - INFO - 本轮用时: 7.01 秒
# 2025-03-10 02:17:31 - INFO - ——————————————————————————————
# 2025-03-10 02:17:38 - INFO - *** 新的最佳模型 (F1分数: 0.5196) ***
# 2025-03-10 02:17:38 - INFO - 轮次 3/100, 训练损失: 0.6957, 训练准确率: 0.5308, 类别0/1: 0.3237/0.7305, 训练F1: 0.5111, 训练精确率: 0.5324, 训练召回率: 0.5315, 训练特异性: 0.3237, 训练MCC: 0.0593, 训练归一化MCC: 0.5297, 验证损失: 0.7064, 验证准确率: 0.5337, 类别0/1: 0.3754/0.7839, 验证F1: 0.5196, 验证精确率: 0.6260, 验证召回率: 0.5282, 验证特异性: 0.3754, 验证MCC: 0.1658, 验证归一化MCC: 0.5829, 学习率: 0.001000
# 2025-03-10 02:17:38 - INFO - 本轮用时: 6.76 秒
# 2025-03-10 02:17:38 - INFO - ——————————————————————————————
# 2025-03-10 02:17:45 - INFO - 轮次 4/100, 训练损失: 0.7017, 训练准确率: 0.5133, 类别0/1: 0.2396/0.8015, 训练F1: 0.4739, 训练精确率: 0.5306, 训练召回率: 0.5150, 训练特异性: 0.2396, 训练MCC: 0.0497, 训练归一化MCC: 0.5249, 验证损失: 0.7108, 验证准确率: 0.4010, 类别0/1: 0.0360/0.9899, 验证F1: 0.2488, 验证精确率: 0.6788, 验证召回率: 0.3929, 验证特异性: 0.0360, 验证MCC: 0.0786, 验证归一化MCC: 0.5393, 学习率: 0.001000
# 2025-03-10 02:17:45 - INFO - 本轮用时: 6.86 秒
# 2025-03-10 02:17:45 - INFO - ——————————————————————————————
# 2025-03-10 02:17:52 - INFO - 轮次 5/100, 训练损失: 0.6898, 训练准确率: 0.5335, 类别0/1: 0.2794/0.7802, 训练F1: 0.5029, 训练精确率: 0.5397, 训练召回率: 0.5343, 训练特异性: 0.2794, 训练MCC: 0.0690, 训练归一化MCC: 0.5345, 验证损失: 0.7299, 验证准确率: 0.3844, 类别0/1: 0.0390/0.9698, 验证F1: 0.2490, 验证精确率: 0.5690, 验证召回率: 0.3872, 验证特异性: 0.0390, 验证MCC: 0.0232, 验证归一化MCC: 0.5116, 学习率: 0.001000
# 2025-03-10 02:17:52 - INFO - 本轮用时: 7.16 秒
# 2025-03-10 02:17:52 - INFO - ——————————————————————————————
# 2025-03-10 02:17:59 - INFO - 轮次 6/100, 训练损失: 0.6832, 训练准确率: 0.5368, 类别0/1: 0.2749/0.8047, 训练F1: 0.5029, 训练精确率: 0.5556, 训练召回率: 0.5376, 训练特异性: 0.2749, 训练MCC: 0.0939, 训练归一化MCC: 0.5469, 验证损失: 0.7704, 验证准确率: 0.4785, 类别0/1: 0.2282/0.9146, 验证F1: 0.4368, 验证精确率: 0.6666, 验证召回率: 0.4850, 验证特异性: 0.2282, 验证MCC: 0.1819, 验证归一化MCC: 0.5910, 学习率: 0.001000
# 2025-03-10 02:17:59 - INFO - 本轮用时: 6.86 秒
# 2025-03-10 02:17:59 - INFO - ——————————————————————————————
# 2025-03-10 02:18:06 - INFO - *** 新的最佳模型 (F1分数: 0.5524) ***
# 2025-03-10 02:18:06 - INFO - 轮次 7/100, 训练损失: 0.6919, 训练准确率: 0.5400, 类别0/1: 0.2902/0.7916, 训练F1: 0.5115, 训练精确率: 0.5545, 训练召回率: 0.5423, 训练特异性: 0.2902, 训练MCC: 0.0945, 训练归一化MCC: 0.5473, 验证损失: 0.7429, 验证准确率: 0.6000, 类别0/1: 0.8318/0.2010, 验证F1: 0.5524, 验证精确率: 0.5535, 验证召回率: 0.5959, 验证特异性: 0.8318, 验证MCC: 0.0413, 验证归一化MCC: 0.5207, 学习率: 0.001000
# 2025-03-10 02:18:06 - INFO - 本轮用时: 7.08 秒
# 2025-03-10 02:18:06 - INFO - ——————————————————————————————
# 2025-03-10 02:18:16 - INFO - *** 新的最佳模型 (F1分数: 0.5897) ***
# 2025-03-10 02:18:16 - INFO - 轮次 8/100, 训练损失: 0.6803, 训练准确率: 0.5377, 类别0/1: 0.2890/0.7942, 训练F1: 0.5115, 训练精确率: 0.5557, 训练召回率: 0.5428, 训练特异性: 0.2890, 训练MCC: 0.0964, 训练归一化MCC: 0.5482, 验证损失: 0.7333, 验证准确率: 0.5781, 类别0/1: 0.5195/0.6935, 验证F1: 0.5897, 验证精确率: 0.6360, 验证召回率: 0.5846, 验证特异性: 0.5195, 验证MCC: 0.2076, 验证归一化MCC: 0.6038, 学习率: 0.001000
# 2025-03-10 02:18:16 - INFO - 本轮用时: 10.03 秒
# 2025-03-10 02:18:16 - INFO - ——————————————————————————————
# 2025-03-10 02:18:27 - INFO - *** 新的最佳模型 (F1分数: 0.6051) ***
# 2025-03-10 02:18:27 - INFO - 轮次 9/100, 训练损失: 0.6833, 训练准确率: 0.5446, 类别0/1: 0.2792/0.8162, 训练F1: 0.5091, 训练精确率: 0.5675, 训练召回率: 0.5442, 训练特异性: 0.2792, 训练MCC: 0.1130, 训练归一化MCC: 0.5565, 验证损失: 0.7129, 验证准确率: 0.6052, 类别0/1: 0.6486/0.5226, 验证F1: 0.6051, 验证精确率: 0.6108, 验证召回率: 0.6015, 验证特异性: 0.6486, 验证MCC: 0.1682, 验证归一化MCC: 0.5841, 学习率: 0.001000
# 2025-03-10 02:18:27 - INFO - 本轮用时: 10.52 秒
# 2025-03-10 02:18:27 - INFO - ——————————————————————————————
# 2025-03-10 02:18:36 - INFO - 轮次 10/100, 训练损失: 0.6776, 训练准确率: 0.5455, 类别0/1: 0.2848/0.8077, 训练F1: 0.5146, 训练精确率: 0.5635, 训练召回率: 0.5479, 训练特异性: 0.2848, 训练MCC: 0.1085, 训练归一化MCC: 0.5542, 验证损失: 0.7285, 验证准确率: 0.4469, 类别0/1: 0.1622/0.9447, 验证F1: 0.3810, 验证精确率: 0.6706, 验证召回率: 0.4549, 验证特异性: 0.1622, 验证MCC: 0.1579, 验证归一化MCC: 0.5790, 学习率: 0.001000
# 2025-03-10 02:18:36 - INFO - 本轮用时: 9.36 秒
# 2025-03-10 02:18:36 - INFO - ——————————————————————————————
# 2025-03-10 02:18:45 - INFO - 轮次 11/100, 训练损失: 0.6787, 训练准确率: 0.5533, 类别0/1: 0.2734/0.8408, 训练F1: 0.5144, 训练精确率: 0.5847, 训练召回率: 0.5531, 训练特异性: 0.2734, 训练MCC: 0.1385, 训练归一化MCC: 0.5692, 验证损失: 0.7713, 验证准确率: 0.5542, 类别0/1: 0.4174/0.7839, 验证F1: 0.5505, 验证精确率: 0.6448, 验证召回率: 0.5545, 验证特异性: 0.4174, 验证MCC: 0.2054, 验证归一化MCC: 0.6027, 学习率: 0.001000
# 2025-03-10 02:18:45 - INFO - 本轮用时: 9.18 秒
# 2025-03-10 02:18:45 - INFO - ——————————————————————————————
# 2025-03-10 02:18:55 - INFO - 轮次 12/100, 训练损失: 0.6806, 训练准确率: 0.5455, 类别0/1: 0.3416/0.7572, 训练F1: 0.5249, 训练精确率: 0.5603, 训练召回率: 0.5451, 训练特异性: 0.3416, 训练MCC: 0.1085, 训练归一化MCC: 0.5543, 验证损失: 0.7132, 验证准确率: 0.5316, 类别0/1: 0.3934/0.7588, 验证F1: 0.5250, 验证精确率: 0.6181, 验证召回率: 0.5301, 验证特异性: 0.3934, 验证MCC: 0.1559, 验证归一化MCC: 0.5779, 学习率: 0.001000
# 2025-03-10 02:18:55 - INFO - 本轮用时: 9.48 秒
# 2025-03-10 02:18:55 - INFO - ——————————————————————————————
# 2025-03-10 02:19:04 - INFO - 轮次 13/100, 训练损失: 0.6717, 训练准确率: 0.5699, 类别0/1: 0.3218/0.8220, 训练F1: 0.5415, 训练精确率: 0.5961, 训练召回率: 0.5700, 训练特异性: 0.3218, 训练MCC: 0.1659, 训练归一化MCC: 0.5830, 验证损失: 0.6805, 验证准确率: 0.6024, 类别0/1: 0.7598/0.3618, 验证F1: 0.5977, 验证精确率: 0.5939, 验证召回率: 0.6109, 验证特异性: 0.7598, 验证MCC: 0.1302, 验证归一化MCC: 0.5651, 学习率: 0.001000
# 2025-03-10 02:19:04 - INFO - 本轮用时: 9.29 秒
# 2025-03-10 02:19:04 - INFO - ——————————————————————————————
# 2025-03-10 02:19:13 - INFO - 轮次 14/100, 训练损失: 0.6642, 训练准确率: 0.5717, 类别0/1: 0.3285/0.7984, 训练F1: 0.5449, 训练精确率: 0.5810, 训练召回率: 0.5705, 训练特异性: 0.3285, 训练MCC: 0.1440, 训练归一化MCC: 0.5720, 验证损失: 0.7015, 验证准确率: 0.5420, 类别0/1: 0.3273/0.8995, 验证F1: 0.5178, 验证精确率: 0.6950, 验证召回率: 0.5414, 验证特异性: 0.3273, 验证MCC: 0.2561, 验证归一化MCC: 0.6280, 学习率: 0.001000
# 2025-03-10 02:19:13 - INFO - 本轮用时: 9.21 秒
# 2025-03-10 02:19:13 - INFO - ——————————————————————————————
# 2025-03-10 02:19:22 - INFO - 轮次 15/100, 训练损失: 0.6696, 训练准确率: 0.5708, 类别0/1: 0.3250/0.8215, 训练F1: 0.5403, 训练精确率: 0.5980, 训练召回率: 0.5681, 训练特异性: 0.3250, 训练MCC: 0.1684, 训练归一化MCC: 0.5842, 验证损失: 0.7140, 验证准确率: 0.4233, 类别0/1: 0.1081/0.9447, 验证F1: 0.3242, 验证精确率: 0.6244, 验证召回率: 0.4211, 验证特异性: 0.1081, 验证MCC: 0.0901, 验证归一化MCC: 0.5450, 学习率: 0.001000
# 2025-03-10 02:19:22 - INFO - 本轮用时: 9.09 秒
# 2025-03-10 02:19:22 - INFO - ——————————————————————————————
# 2025-03-10 02:19:31 - INFO - *** 新的最佳模型 (F1分数: 0.6145) ***
# 2025-03-10 02:19:31 - INFO - 轮次 16/100, 训练损失: 0.6642, 训练准确率: 0.5639, 类别0/1: 0.3251/0.7844, 训练F1: 0.5405, 训练精确率: 0.5692, 训练召回率: 0.5653, 训练特异性: 0.3251, 训练MCC: 0.1235, 训练归一化MCC: 0.5617, 验证损失: 0.6761, 验证准确率: 0.6045, 类别0/1: 0.6246/0.5829, 验证F1: 0.6145, 验证精确率: 0.6275, 验证召回率: 0.6090, 验证特异性: 0.6246, 验证MCC: 0.2017, 验证归一化MCC: 0.6009, 学习率: 0.001000
# 2025-03-10 02:19:31 - INFO - 本轮用时: 9.13 秒
# 2025-03-10 02:19:31 - INFO - ——————————————————————————————
# 2025-03-10 02:19:40 - INFO - 轮次 17/100, 训练损失: 0.6761, 训练准确率: 0.5565, 类别0/1: 0.3129/0.8106, 训练F1: 0.5263, 训练精确率: 0.5832, 训练召回率: 0.5550, 训练特异性: 0.3129, 训练MCC: 0.1421, 训练归一化MCC: 0.5710, 验证损失: 0.8253, 验证准确率: 0.3941, 类别0/1: 0.0270/0.9849, 验证F1: 0.2366, 验证精确率: 0.6104, 验证召回率: 0.3853, 验证特异性: 0.0270, 验证MCC: 0.0389, 验证归一化MCC: 0.5195, 学习率: 0.001000
# 2025-03-10 02:19:40 - INFO - 本轮用时: 9.10 秒
# 2025-03-10 02:19:40 - INFO - ——————————————————————————————
# 2025-03-10 02:19:50 - INFO - 轮次 18/100, 训练损失: 0.6711, 训练准确率: 0.5602, 类别0/1: 0.2912/0.8370, 训练F1: 0.5238, 训练精确率: 0.5921, 训练召回率: 0.5587, 训练特异性: 0.2912, 训练MCC: 0.1527, 训练归一化MCC: 0.5764, 验证损失: 0.6745, 验证准确率: 0.6444, 类别0/1: 0.9339/0.1256, 验证F1: 0.5520, 验证精确率: 0.6003, 验证召回率: 0.6316, 验证特异性: 0.9339, 验证MCC: 0.1016, 验证归一化MCC: 0.5508, 学习率: 0.001000
# 2025-03-10 02:19:50 - INFO - 本轮用时: 9.70 秒
# 2025-03-10 02:19:50 - INFO - ——————————————————————————————
# 2025-03-10 02:19:59 - INFO - 轮次 19/100, 训练损失: 0.6660, 训练准确率: 0.5653, 类别0/1: 0.2978/0.8172, 训练F1: 0.5263, 训练精确率: 0.5787, 训练召回率: 0.5583, 训练特异性: 0.2978, 训练MCC: 0.1347, 训练归一化MCC: 0.5673, 验证损失: 0.6709, 验证准确率: 0.6222, 类别0/1: 0.7958/0.2814, 验证F1: 0.5774, 验证精确率: 0.5755, 验证召回率: 0.6034, 验证特异性: 0.7958, 验证MCC: 0.0884, 验证归一化MCC: 0.5442, 学习率: 0.001000
# 2025-03-10 02:19:59 - INFO - 本轮用时: 9.31 秒
# 2025-03-10 02:19:59 - INFO - ——————————————————————————————
# 2025-03-10 02:20:08 - INFO - 轮次 20/100, 训练损失: 0.6556, 训练准确率: 0.5767, 类别0/1: 0.3110/0.8207, 训练F1: 0.5440, 训练精确率: 0.5885, 训练召回率: 0.5742, 训练特异性: 0.3110, 训练MCC: 0.1535, 训练归一化MCC: 0.5767, 验证损失: 0.7739, 验证准确率: 0.4111, 类别0/1: 0.1051/0.9698, 验证F1: 0.3264, 验证精确率: 0.6814, 验证召回率: 0.4286, 验证特异性: 0.1051, 验证MCC: 0.1360, 验证归一化MCC: 0.5680, 学习率: 0.001000
# 2025-03-10 02:20:08 - INFO - 本轮用时: 8.96 秒
# 2025-03-10 02:20:08 - INFO - ——————————————————————————————
# 2025-03-10 02:20:19 - INFO - 轮次 21/100, 训练损失: 0.6447, 训练准确率: 0.5997, 类别0/1: 0.3070/0.8902, 训练F1: 0.5618, 训练精确率: 0.6494, 训练召回率: 0.5992, 训练特异性: 0.3070, 训练MCC: 0.2429, 训练归一化MCC: 0.6214, 验证损失: 0.7397, 验证准确率: 0.4785, 类别0/1: 0.2072/0.9497, 验证F1: 0.4265, 验证精确率: 0.7028, 验证召回率: 0.4850, 验证特异性: 0.2072, 验证MCC: 0.2136, 验证归一化MCC: 0.6068, 学习率: 0.001000
# 2025-03-10 02:20:19 - INFO - 本轮用时: 10.35 秒
# 2025-03-10 02:20:19 - INFO - ——————————————————————————————
# 2025-03-10 02:20:28 - INFO - 轮次 22/100, 训练损失: 0.6716, 训练准确率: 0.5712, 类别0/1: 0.3071/0.8341, 训练F1: 0.5407, 训练精确率: 0.5975, 训练召回率: 0.5728, 训练特异性: 0.3071, 训练MCC: 0.1663, 训练归一化MCC: 0.5832, 验证损失: 0.7025, 验证准确率: 0.6590, 类别0/1: 0.9850/0.0603, 验证F1: 0.5258, 验证精确率: 0.6627, 验证召回率: 0.6391, 验证特异性: 0.9850, 验证MCC: 0.1246, 验证归一化MCC: 0.5623, 学习率: 0.001000
# 2025-03-10 02:20:28 - INFO - 本轮用时: 9.10 秒
# 2025-03-10 02:20:28 - INFO - ——————————————————————————————
# 2025-03-10 02:20:37 - INFO - 轮次 23/100, 训练损失: 0.6683, 训练准确率: 0.5510, 类别0/1: 0.2318/0.8655, 训练F1: 0.5004, 训练精确率: 0.5811, 训练召回率: 0.5508, 训练特异性: 0.2318, 训练MCC: 0.1259, 训练归一化MCC: 0.5630, 验证损失: 0.7055, 验证准确率: 0.5309, 类别0/1: 0.2913/0.9497, 验证F1: 0.5026, 验证精确率: 0.7338, 验证召回率: 0.5376, 验证特异性: 0.2913, 验证MCC: 0.2910, 验证归一化MCC: 0.6455, 学习率: 0.001000
# 2025-03-10 02:20:37 - INFO - 本轮用时: 8.77 秒
# 2025-03-10 02:20:37 - INFO - ——————————————————————————————
# 2025-03-10 02:20:45 - INFO - 轮次 24/100, 训练损失: 0.6529, 训练准确率: 0.5846, 类别0/1: 0.3085/0.8557, 训练F1: 0.5525, 训练精确率: 0.6167, 训练召回率: 0.5865, 训练特异性: 0.3085, 训练MCC: 0.1965, 训练归一化MCC: 0.5983, 验证损失: 0.7364, 验证准确率: 0.4378, 类别0/1: 0.1502/0.9497, 验证F1: 0.3700, 验证精确率: 0.6714, 验证召回率: 0.4492, 验证特异性: 0.1502, 验证MCC: 0.1528, 验证归一化MCC: 0.5764, 学习率: 0.001000
# 2025-03-10 02:20:45 - INFO - 本轮用时: 8.76 秒
# 2025-03-10 02:20:45 - INFO - ——————————————————————————————
# 2025-03-10 02:20:55 - INFO - 轮次 25/100, 训练损失: 0.6582, 训练准确率: 0.5827, 类别0/1: 0.3302/0.8301, 训练F1: 0.5537, 训练精确率: 0.6066, 训练召回率: 0.5818, 训练特异性: 0.3302, 训练MCC: 0.1851, 训练归一化MCC: 0.5926, 验证损失: 0.7683, 验证准确率: 0.5924, 类别0/1: 0.6276/0.5427, 验证F1: 0.6008, 验证精确率: 0.6102, 验证召回率: 0.5959, 验证特异性: 0.6276, 验证MCC: 0.1662, 验证归一化MCC: 0.5831, 学习率: 0.001000
# 2025-03-10 02:20:55 - INFO - 本轮用时: 9.93 秒
# 2025-03-10 02:20:55 - INFO - ——————————————————————————————
# 2025-03-10 02:21:05 - INFO - 轮次 26/100, 训练损失: 0.6668, 训练准确率: 0.5528, 类别0/1: 0.2453/0.8703, 训练F1: 0.5076, 训练精确率: 0.5951, 训练召回率: 0.5555, 训练特异性: 0.2453, 训练MCC: 0.1479, 训练归一化MCC: 0.5740, 验证损失: 0.8458, 验证准确率: 0.4851, 类别0/1: 0.2162/0.9648, 验证F1: 0.4391, 验证精确率: 0.7290, 验证召回率: 0.4962, 验证特异性: 0.2162, 验证MCC: 0.2464, 验证归一化MCC: 0.6232, 学习率: 0.001000
# 2025-03-10 02:21:05 - INFO - 本轮用时: 10.23 秒
# 2025-03-10 02:21:05 - INFO - ——————————————————————————————
# 2025-03-10 02:21:16 - INFO - 轮次 27/100, 训练损失: 0.6525, 训练准确率: 0.5841, 类别0/1: 0.3113/0.8569, 训练F1: 0.5484, 训练精确率: 0.6200, 训练召回率: 0.5818, 训练特异性: 0.3113, 训练MCC: 0.2004, 训练归一化MCC: 0.6002, 验证损失: 0.6568, 验证准确率: 0.6115, 类别0/1: 0.8288/0.2613, 验证F1: 0.5833, 验证精确率: 0.5869, 验证召回率: 0.6165, 验证特异性: 0.8288, 验证MCC: 0.1081, 验证归一化MCC: 0.5540, 学习率: 0.001000
# 2025-03-10 02:21:16 - INFO - 本轮用时: 10.11 秒
# 2025-03-10 02:21:16 - INFO - ——————————————————————————————
# 2025-03-10 02:21:25 - INFO - 轮次 28/100, 训练损失: 0.6526, 训练准确率: 0.5938, 类别0/1: 0.3844/0.8059, 训练F1: 0.5692, 训练精确率: 0.6171, 训练召回率: 0.5874, 训练特异性: 0.3844, 训练MCC: 0.2089, 训练归一化MCC: 0.6045, 验证损失: 0.7050, 验证准确率: 0.4684, 类别0/1: 0.1652/0.9799, 验证F1: 0.3927, 验证精确率: 0.7377, 验证召回率: 0.4699, 验证特异性: 0.1652, 验证MCC: 0.2235, 验证归一化MCC: 0.6118, 学习率: 0.001000
# 2025-03-10 02:21:25 - INFO - 本轮用时: 9.59 秒
# 2025-03-10 02:21:25 - INFO - ——————————————————————————————
# 2025-03-10 02:21:35 - INFO - 轮次 29/100, 训练损失: 0.6512, 训练准确率: 0.5878, 类别0/1: 0.3713/0.8041, 训练F1: 0.5681, 训练精确率: 0.6079, 训练召回率: 0.5883, 训练特异性: 0.3713, 训练MCC: 0.1947, 训练归一化MCC: 0.5973, 验证损失: 0.7561, 验证准确率: 0.4139, 类别0/1: 0.0390/1.0000, 验证F1: 0.2544, 验证精确率: 0.7694, 验证召回率: 0.3985, 验证特异性: 0.0390, 验证MCC: 0.1223, 验证归一化MCC: 0.5612, 学习率: 0.001000
# 2025-03-10 02:21:35 - INFO - 本轮用时: 10.02 秒
# 2025-03-10 02:21:35 - INFO - ——————————————————————————————
# 2025-03-10 02:21:43 - INFO - *** 新的最佳模型 (F1分数: 0.6319) ***
# 2025-03-10 02:21:43 - INFO - 轮次 30/100, 训练损失: 0.6460, 训练准确率: 0.5836, 类别0/1: 0.3174/0.8434, 训练F1: 0.5528, 训练精确率: 0.6108, 训练召回率: 0.5841, 训练特异性: 0.3174, 训练MCC: 0.1894, 训练归一化MCC: 0.5947, 验证损失: 0.7819, 验证准确率: 0.6368, 类别0/1: 0.7027/0.5126, 验证F1: 0.6319, 验证精确率: 0.6323, 验证召回率: 0.6316, 验证特异性: 0.7027, 验证MCC: 0.2148, 验证归一化MCC: 0.6074, 学习率: 0.001000
# 2025-03-10 02:21:43 - INFO - 本轮用时: 7.66 秒
# 2025-03-10 02:21:43 - INFO - ——————————————————————————————
# 2025-03-10 02:21:50 - INFO - *** 新的最佳模型 (F1分数: 0.6354) ***
# 2025-03-10 02:21:50 - INFO - 轮次 31/100, 训练损失: 0.6457, 训练准确率: 0.5956, 类别0/1: 0.3429/0.8570, 训练F1: 0.5682, 训练精确率: 0.6364, 训练召回率: 0.5963, 训练特异性: 0.3429, 训练MCC: 0.2326, 训练归一化MCC: 0.6163, 验证损失: 0.7144, 验证准确率: 0.6396, 类别0/1: 0.7628/0.4422, 验证F1: 0.6354, 验证精确率: 0.6327, 验证召回率: 0.6429, 验证特异性: 0.7628, 验证MCC: 0.2137, 验证归一化MCC: 0.6069, 学习率: 0.001000
# 2025-03-10 02:21:50 - INFO - 本轮用时: 7.55 秒
# 2025-03-10 02:21:50 - INFO - ——————————————————————————————
# 2025-03-10 02:21:58 - INFO - 轮次 32/100, 训练损失: 0.6375, 训练准确率: 0.6112, 类别0/1: 0.3854/0.8197, 训练F1: 0.5895, 训练精确率: 0.6259, 训练召回率: 0.6095, 训练特异性: 0.3854, 训练MCC: 0.2284, 训练归一化MCC: 0.6142, 验证损失: 0.7386, 验证准确率: 0.4722, 类别0/1: 0.1682/0.9749, 验证F1: 0.3946, 验证精确率: 0.7287, 验证召回率: 0.4699, 验证特异性: 0.1682, 验证MCC: 0.2172, 验证归一化MCC: 0.6086, 学习率: 0.001000
# 2025-03-10 02:21:58 - INFO - 本轮用时: 7.56 秒
# 2025-03-10 02:21:58 - INFO - ——————————————————————————————
# 2025-03-10 02:22:06 - INFO - 轮次 33/100, 训练损失: 0.6592, 训练准确率: 0.5625, 类别0/1: 0.3188/0.8325, 训练F1: 0.5372, 训练精确率: 0.6043, 训练召回率: 0.5667, 训练特异性: 0.3188, 训练MCC: 0.1756, 训练归一化MCC: 0.5878, 验证损失: 0.7605, 验证准确率: 0.4712, 类别0/1: 0.1592/0.9648, 验证F1: 0.3829, 验证精确率: 0.7051, 验证召回率: 0.4605, 验证特异性: 0.1592, 验证MCC: 0.1897, 验证归一化MCC: 0.5948, 学习率: 0.001000
# 2025-03-10 02:22:06 - INFO - 本轮用时: 7.81 秒
# 2025-03-10 02:22:06 - INFO - ——————————————————————————————
# 2025-03-10 02:22:13 - INFO - 轮次 34/100, 训练损失: 0.6530, 训练准确率: 0.5749, 类别0/1: 0.3191/0.8352, 训练F1: 0.5438, 训练精确率: 0.6057, 训练召回率: 0.5738, 训练特异性: 0.3191, 训练MCC: 0.1799, 训练归一化MCC: 0.5900, 验证损失: 0.7291, 验证准确率: 0.5444, 类别0/1: 0.3123/0.9095, 验证F1: 0.5085, 验证精确率: 0.6987, 验证召回率: 0.5357, 验证特异性: 0.3123, 验证MCC: 0.2554, 验证归一化MCC: 0.6277, 学习率: 0.001000
# 2025-03-10 02:22:13 - INFO - 本轮用时: 7.57 秒
# 2025-03-10 02:22:13 - INFO - ——————————————————————————————
# 2025-03-10 02:22:20 - INFO - 轮次 35/100, 训练损失: 0.6466, 训练准确率: 0.5878, 类别0/1: 0.3795/0.7987, 训练F1: 0.5682, 训练精确率: 0.6084, 训练召回率: 0.5869, 训练特异性: 0.3795, 训练MCC: 0.1961, 训练归一化MCC: 0.5980, 验证损失: 0.7684, 验证准确率: 0.4684, 类别0/1: 0.1712/0.9698, 验证F1: 0.3963, 验证精确率: 0.7203, 验证召回率: 0.4699, 验证特异性: 0.1712, 验证MCC: 0.2112, 验证归一化MCC: 0.6056, 学习率: 0.001000
# 2025-03-10 02:22:20 - INFO - 本轮用时: 7.01 秒
# 2025-03-10 02:22:20 - INFO - ——————————————————————————————
# 2025-03-10 02:22:29 - INFO - *** 新的最佳模型 (F1分数: 0.6372) ***
# 2025-03-10 02:22:29 - INFO - 轮次 36/100, 训练损失: 0.6507, 训练准确率: 0.5827, 类别0/1: 0.3136/0.8504, 训练F1: 0.5493, 训练精确率: 0.6153, 训练召回率: 0.5818, 训练特异性: 0.3136, 训练MCC: 0.1944, 训练归一化MCC: 0.5972, 验证损失: 0.6809, 验证准确率: 0.6444, 类别0/1: 0.5826/0.7136, 验证F1: 0.6372, 验证精确率: 0.6728, 验证召回率: 0.6316, 验证特异性: 0.5826, 验证MCC: 0.2871, 验证归一化MCC: 0.6435, 学习率: 0.001000
# 2025-03-10 02:22:29 - INFO - 本轮用时: 8.47 秒
# 2025-03-10 02:22:29 - INFO - ——————————————————————————————
# 2025-03-10 02:22:38 - INFO - 轮次 37/100, 训练损失: 0.6373, 训练准确率: 0.5910, 类别0/1: 0.3252/0.8361, 训练F1: 0.5607, 训练精确率: 0.6084, 训练召回率: 0.5902, 训练特异性: 0.3252, 训练MCC: 0.1882, 训练归一化MCC: 0.5941, 验证损失: 0.6888, 验证准确率: 0.5927, 类别0/1: 0.5886/0.5980, 验证F1: 0.5986, 验证精确率: 0.6184, 验证召回率: 0.5921, 验证特异性: 0.5886, 验证MCC: 0.1807, 验证归一化MCC: 0.5903, 学习率: 0.001000
# 2025-03-10 02:22:38 - INFO - 本轮用时: 9.48 秒
# 2025-03-10 02:22:38 - INFO - ——————————————————————————————
# 2025-03-10 02:22:48 - INFO - 轮次 38/100, 训练损失: 0.6518, 训练准确率: 0.5703, 类别0/1: 0.2948/0.8532, 训练F1: 0.5359, 训练精确率: 0.6078, 训练召回率: 0.5719, 训练特异性: 0.2948, 训练MCC: 0.1782, 训练归一化MCC: 0.5891, 验证损失: 0.6743, 验证准确率: 0.5767, 类别0/1: 0.4324/0.8241, 验证F1: 0.5744, 验证精确率: 0.6773, 验证召回率: 0.5789, 验证特异性: 0.4324, 验证MCC: 0.2627, 验证归一化MCC: 0.6314, 学习率: 0.000100
# 2025-03-10 02:22:48 - INFO - 本轮用时: 9.32 秒
# 2025-03-10 02:22:48 - INFO - ——————————————————————————————
# 2025-03-10 02:22:56 - INFO - 轮次 39/100, 训练损失: 0.6400, 训练准确率: 0.5965, 类别0/1: 0.3672/0.8341, 训练F1: 0.5758, 训练精确率: 0.6290, 训练召回率: 0.5987, 训练特异性: 0.3672, 训练MCC: 0.2274, 训练归一化MCC: 0.6137, 验证损失: 0.6604, 验证准确率: 0.5611, 类别0/1: 0.3033/0.9397, 验证F1: 0.5099, 验证精确率: 0.7264, 验证召回率: 0.5414, 验证特异性: 0.3033, 验证MCC: 0.2875, 验证归一化MCC: 0.6437, 学习率: 0.000100
# 2025-03-10 02:22:56 - INFO - 本轮用时: 8.61 秒
# 2025-03-10 02:22:56 - INFO - ——————————————————————————————
# 2025-03-10 02:23:04 - INFO - 轮次 40/100, 训练损失: 0.6161, 训练准确率: 0.6140, 类别0/1: 0.3778/0.8365, 训练F1: 0.5929, 训练精确率: 0.6351, 训练召回率: 0.6151, 训练特异性: 0.3778, 训练MCC: 0.2421, 训练归一化MCC: 0.6210, 验证损失: 0.6775, 验证准确率: 0.5323, 类别0/1: 0.3063/0.9397, 验证F1: 0.5124, 验证精确率: 0.7274, 验证召回率: 0.5432, 验证特异性: 0.3063, 验证MCC: 0.2901, 验证归一化MCC: 0.6451, 学习率: 0.000100
# 2025-03-10 02:23:04 - INFO - 本轮用时: 8.08 秒
# 2025-03-10 02:23:04 - INFO - ——————————————————————————————
# 2025-03-10 02:23:12 - INFO - 轮次 41/100, 训练损失: 0.6179, 训练准确率: 0.6167, 类别0/1: 0.3756/0.8625, 训练F1: 0.5914, 训练精确率: 0.6565, 训练召回率: 0.6151, 训练特异性: 0.3756, 训练MCC: 0.2718, 训练归一化MCC: 0.6359, 验证损失: 0.6629, 验证准确率: 0.5524, 类别0/1: 0.3363/0.9146, 验证F1: 0.5297, 验证精确率: 0.7124, 验证召回率: 0.5526, 验证特异性: 0.3363, 验证MCC: 0.2833, 验证归一化MCC: 0.6416, 学习率: 0.000100
# 2025-03-10 02:23:12 - INFO - 本轮用时: 7.22 秒
# 2025-03-10 02:23:12 - INFO - ——————————————————————————————
# 2025-03-10 02:23:19 - INFO - 轮次 42/100, 训练损失: 0.6094, 训练准确率: 0.6250, 类别0/1: 0.3836/0.8594, 训练F1: 0.5994, 训练精确率: 0.6570, 训练召回率: 0.6222, 训练特异性: 0.3836, 训练MCC: 0.2764, 训练归一化MCC: 0.6382, 验证损失: 0.6852, 验证准确率: 0.5604, 类别0/1: 0.3574/0.9246, 验证F1: 0.5496, 验证精确率: 0.7288, 验证召回率: 0.5695, 验证特异性: 0.3574, 验证MCC: 0.3143, 验证归一化MCC: 0.6572, 学习率: 0.000100
# 2025-03-10 02:23:19 - INFO - 本轮用时: 7.63 秒
# 2025-03-10 02:23:19 - INFO - ——————————————————————————————
# 2025-03-10 02:23:27 - INFO - 轮次 43/100, 训练损失: 0.6207, 训练准确率: 0.6195, 类别0/1: 0.4068/0.8472, 训练F1: 0.6023, 训练精确率: 0.6585, 训练召回率: 0.6208, 训练特异性: 0.4068, 训练MCC: 0.2817, 训练归一化MCC: 0.6408, 验证损失: 0.7217, 验证准确率: 0.5750, 类别0/1: 0.3844/0.8995, 验证F1: 0.5628, 验证精确率: 0.7157, 验证召回率: 0.5771, 验证特异性: 0.3844, 验证MCC: 0.3065, 验证归一化MCC: 0.6533, 学习率: 0.000100
# 2025-03-10 02:23:27 - INFO - 本轮用时: 7.90 秒
# 2025-03-10 02:23:27 - INFO - ——————————————————————————————
# 2025-03-10 02:23:35 - INFO - 轮次 44/100, 训练损失: 0.6102, 训练准确率: 0.6356, 类别0/1: 0.4389/0.8383, 训练F1: 0.6236, 训练精确率: 0.6649, 训练召回率: 0.6386, 训练特异性: 0.4389, 训练MCC: 0.3024, 训练归一化MCC: 0.6512, 验证损失: 0.6866, 验证准确率: 0.5677, 类别0/1: 0.3544/0.9397, 验证F1: 0.5518, 验证精确率: 0.7422, 验证召回率: 0.5733, 验证特异性: 0.3544, 验证MCC: 0.3311, 验证归一化MCC: 0.6656, 学习率: 0.000100
# 2025-03-10 02:23:35 - INFO - 本轮用时: 7.62 秒
# 2025-03-10 02:23:35 - INFO - ——————————————————————————————
# 2025-03-10 02:23:42 - INFO - 轮次 45/100, 训练损失: 0.6008, 训练准确率: 0.6356, 类别0/1: 0.4221/0.8419, 训练F1: 0.6160, 训练精确率: 0.6601, 训练召回率: 0.6330, 训练特异性: 0.4221, 训练MCC: 0.2911, 训练归一化MCC: 0.6455, 验证损失: 0.6421, 验证准确率: 0.5993, 类别0/1: 0.4595/0.8442, 验证F1: 0.6002, 验证精确率: 0.7011, 验证召回率: 0.6034, 验证特异性: 0.4595, 验证MCC: 0.3089, 验证归一化MCC: 0.6545, 学习率: 0.000100
# 2025-03-10 02:23:42 - INFO - 本轮用时: 6.96 秒
# 2025-03-10 02:23:42 - INFO - ——————————————————————————————
# 2025-03-10 02:23:48 - INFO - 轮次 46/100, 训练损失: 0.5976, 训练准确率: 0.6429, 类别0/1: 0.4383/0.8303, 训练F1: 0.6242, 训练精确率: 0.6583, 训练召回率: 0.6391, 训练特异性: 0.4383, 训练MCC: 0.2928, 训练归一化MCC: 0.6464, 验证损失: 0.7035, 验证准确率: 0.5802, 类别0/1: 0.3934/0.8995, 验证F1: 0.5697, 验证精确率: 0.7188, 验证召回率: 0.5827, 验证特异性: 0.3934, 验证MCC: 0.3143, 验证归一化MCC: 0.6572, 学习率: 0.000100
# 2025-03-10 02:23:48 - INFO - 本轮用时: 6.07 秒
# 2025-03-10 02:23:48 - INFO - ——————————————————————————————
# 2025-03-10 02:23:54 - INFO - 轮次 47/100, 训练损失: 0.6091, 训练准确率: 0.6227, 类别0/1: 0.4141/0.8429, 训练F1: 0.6104, 训练精确率: 0.6575, 训练召回率: 0.6283, 训练特异性: 0.4141, 训练MCC: 0.2844, 训练归一化MCC: 0.6422, 验证损失: 0.6620, 验证准确率: 0.5997, 类别0/1: 0.4174/0.9045, 验证F1: 0.5894, 验证精确率: 0.7307, 验证召回率: 0.5996, 验证特异性: 0.4174, 验证MCC: 0.3409, 验证归一化MCC: 0.6705, 学习率: 0.000100
# 2025-03-10 02:23:54 - INFO - 本轮用时: 6.28 秒
# 2025-03-10 02:23:54 - INFO - ——————————————————————————————
# 2025-03-10 02:24:00 - INFO - *** 新的最佳模型 (F1分数: 0.6489) ***
# 2025-03-10 02:24:00 - INFO - 轮次 48/100, 训练损失: 0.5932, 训练准确率: 0.6448, 类别0/1: 0.4427/0.8417, 训练F1: 0.6301, 训练精确率: 0.6689, 训练召回率: 0.6452, 训练特异性: 0.4427, 训练MCC: 0.3108, 训练归一化MCC: 0.6554, 验证损失: 0.6144, 验证准确率: 0.6413, 类别0/1: 0.5646/0.7789, 验证F1: 0.6489, 验证精确率: 0.7005, 验证召回率: 0.6447, 验证特异性: 0.5646, 验证MCC: 0.3351, 验证归一化MCC: 0.6676, 学习率: 0.000100
# 2025-03-10 02:24:00 - INFO - 本轮用时: 5.60 秒
# 2025-03-10 02:24:00 - INFO - ——————————————————————————————
# 2025-03-10 02:24:06 - INFO - 轮次 49/100, 训练损失: 0.5917, 训练准确率: 0.6581, 类别0/1: 0.4752/0.8404, 训练F1: 0.6482, 训练精确率: 0.6819, 训练召回率: 0.6602, 训练特异性: 0.4752, 训练MCC: 0.3397, 训练归一化MCC: 0.6698, 验证损失: 0.6847, 验证准确率: 0.6056, 类别0/1: 0.4054/0.9196, 验证F1: 0.5852, 验证精确率: 0.7393, 验证召回率: 0.5977, 验证特异性: 0.4054, 验证MCC: 0.3488, 验证归一化MCC: 0.6744, 学习率: 0.000100
# 2025-03-10 02:24:06 - INFO - 本轮用时: 5.87 秒
# 2025-03-10 02:24:06 - INFO - ——————————————————————————————
# 2025-03-10 02:24:12 - INFO - 轮次 50/100, 训练损失: 0.5972, 训练准确率: 0.6507, 类别0/1: 0.4744/0.8161, 训练F1: 0.6389, 训练精确率: 0.6641, 训练召回率: 0.6499, 训练特异性: 0.4744, 训练MCC: 0.3100, 训练归一化MCC: 0.6550, 验证损失: 0.6259, 验证准确率: 0.6274, 类别0/1: 0.4565/0.8643, 验证F1: 0.6048, 验证精确率: 0.7138, 验证召回率: 0.6090, 验证特异性: 0.4565, 验证MCC: 0.3285, 验证归一化MCC: 0.6643, 学习率: 0.000100
# 2025-03-10 02:24:12 - INFO - 本轮用时: 6.34 秒
# 2025-03-10 02:24:12 - INFO - ——————————————————————————————
# 2025-03-10 02:24:20 - INFO - 轮次 51/100, 训练损失: 0.5859, 训练准确率: 0.6599, 类别0/1: 0.4878/0.8336, 训练F1: 0.6503, 训练精确率: 0.6826, 训练召回率: 0.6607, 训练特异性: 0.4878, 训练MCC: 0.3426, 训练归一化MCC: 0.6713, 验证损失: 0.6557, 验证准确率: 0.6205, 类别0/1: 0.4895/0.8442, 验证F1: 0.6213, 验证精确率: 0.7118, 验证召回率: 0.6222, 验证特异性: 0.4895, 验证MCC: 0.3355, 验证归一化MCC: 0.6677, 学习率: 0.000100
# 2025-03-10 02:24:20 - INFO - 本轮用时: 7.81 秒
# 2025-03-10 02:24:20 - INFO - ——————————————————————————————
# 2025-03-10 02:24:29 - INFO - 轮次 52/100, 训练损失: 0.5902, 训练准确率: 0.6526, 类别0/1: 0.4782/0.8286, 训练F1: 0.6474, 训练精确率: 0.6746, 训练召回率: 0.6588, 训练特异性: 0.4782, 训练MCC: 0.3287, 训练归一化MCC: 0.6643, 验证损失: 0.6678, 验证准确率: 0.6316, 类别0/1: 0.4685/0.8894, 验证F1: 0.6216, 验证精确率: 0.7356, 验证召回率: 0.6259, 验证特异性: 0.4685, 验证MCC: 0.3670, 验证归一化MCC: 0.6835, 学习率: 0.000100
# 2025-03-10 02:24:29 - INFO - 本轮用时: 8.96 秒
# 2025-03-10 02:24:29 - INFO - ——————————————————————————————
# 2025-03-10 02:24:38 - INFO - 轮次 53/100, 训练损失: 0.5923, 训练准确率: 0.6461, 类别0/1: 0.4598/0.8443, 训练F1: 0.6338, 训练精确率: 0.6792, 训练召回率: 0.6466, 训练特异性: 0.4598, 训练MCC: 0.3280, 训练归一化MCC: 0.6640, 验证损失: 0.8201, 验证准确率: 0.6163, 类别0/1: 0.4715/0.8844, 验证F1: 0.6221, 验证精确率: 0.7330, 验证召回率: 0.6259, 验证特异性: 0.4715, 验证MCC: 0.3640, 验证归一化MCC: 0.6820, 学习率: 0.000100
# 2025-03-10 02:24:38 - INFO - 本轮用时: 8.93 秒
# 2025-03-10 02:24:38 - INFO - ——————————————————————————————
# 2025-03-10 02:24:47 - INFO - 轮次 54/100, 训练损失: 0.5957, 训练准确率: 0.6530, 类别0/1: 0.5028/0.8084, 训练F1: 0.6482, 训练精确率: 0.6716, 训练召回率: 0.6565, 训练特异性: 0.5028, 训练MCC: 0.3271, 训练归一化MCC: 0.6635, 验证损失: 0.7007, 验证准确率: 0.6292, 类别0/1: 0.4895/0.8693, 验证F1: 0.6297, 验证精确率: 0.7285, 验证召回率: 0.6316, 验证特异性: 0.4895, 验证MCC: 0.3628, 验证归一化MCC: 0.6814, 学习率: 0.000100
# 2025-03-10 02:24:47 - INFO - 本轮用时: 9.48 秒
# 2025-03-10 02:24:47 - INFO - ——————————————————————————————
# 2025-03-10 02:24:56 - INFO - 轮次 55/100, 训练损失: 0.5746, 训练准确率: 0.6723, 类别0/1: 0.5221/0.8351, 训练F1: 0.6647, 训练精确率: 0.6990, 训练召回率: 0.6720, 训练特异性: 0.5221, 训练MCC: 0.3739, 训练归一化MCC: 0.6869, 验证损失: 0.6544, 验证准确率: 0.6205, 类别0/1: 0.4505/0.9095, 验证F1: 0.6153, 验证精确率: 0.7449, 验证召回率: 0.6222, 验证特异性: 0.4505, 验证MCC: 0.3748, 验证归一化MCC: 0.6874, 学习率: 0.000100
# 2025-03-10 02:24:56 - INFO - 本轮用时: 8.69 秒
# 2025-03-10 02:24:56 - INFO - ——————————————————————————————
# 2025-03-10 02:25:05 - INFO - 轮次 56/100, 训练损失: 0.5712, 训练准确率: 0.6636, 类别0/1: 0.4968/0.8373, 训练F1: 0.6536, 训练精确率: 0.6895, 训练召回率: 0.6631, 训练特异性: 0.4968, 训练MCC: 0.3542, 训练归一化MCC: 0.6771, 验证损失: 0.6371, 验证准确率: 0.6458, 类别0/1: 0.5285/0.8191, 验证F1: 0.6392, 验证精确率: 0.7102, 验证召回率: 0.6372, 验证特异性: 0.5285, 验证MCC: 0.3436, 验证归一化MCC: 0.6718, 学习率: 0.000100
# 2025-03-10 02:25:05 - INFO - 本轮用时: 9.26 秒
# 2025-03-10 02:25:05 - INFO - ——————————————————————————————
# 2025-03-10 02:25:14 - INFO - *** 新的最佳模型 (F1分数: 0.6699) ***
# 2025-03-10 02:25:14 - INFO - 轮次 57/100, 训练损失: 0.5758, 训练准确率: 0.6742, 类别0/1: 0.5295/0.8286, 训练F1: 0.6672, 训练精确率: 0.6974, 训练召回率: 0.6739, 训练特异性: 0.5295, 训练MCC: 0.3736, 训练归一化MCC: 0.6868, 验证损失: 0.6508, 验证准确率: 0.6757, 类别0/1: 0.5916/0.7889, 验证F1: 0.6699, 验证精确率: 0.7164, 验证召回率: 0.6654, 验证特异性: 0.5916, 验证MCC: 0.3702, 验证归一化MCC: 0.6851, 学习率: 0.000100
# 2025-03-10 02:25:14 - INFO - 本轮用时: 9.07 秒
# 2025-03-10 02:25:14 - INFO - ——————————————————————————————
# 2025-03-10 02:25:23 - INFO - 轮次 58/100, 训练损失: 0.5807, 训练准确率: 0.6746, 类别0/1: 0.5333/0.8260, 训练F1: 0.6704, 训练精确率: 0.6968, 训练召回率: 0.6772, 训练特异性: 0.5333, 训练MCC: 0.3750, 训练归一化MCC: 0.6875, 验证损失: 0.6873, 验证准确率: 0.6073, 类别0/1: 0.4775/0.8593, 验证F1: 0.6179, 验证精确率: 0.7176, 验证召回率: 0.6203, 验证特异性: 0.4775, 验证MCC: 0.3413, 验证归一化MCC: 0.6707, 学习率: 0.000100
# 2025-03-10 02:25:23 - INFO - 本轮用时: 9.42 秒
# 2025-03-10 02:25:23 - INFO - ——————————————————————————————
# 2025-03-10 02:25:33 - INFO - 轮次 59/100, 训练损失: 0.5628, 训练准确率: 0.6958, 类别0/1: 0.5564/0.8242, 训练F1: 0.6898, 训练精确率: 0.7050, 训练召回率: 0.6960, 训练特异性: 0.5564, 训练MCC: 0.3966, 训练归一化MCC: 0.6983, 验证损失: 0.7362, 验证准确率: 0.6295, 类别0/1: 0.4715/0.8894, 验证F1: 0.6238, 验证精确率: 0.7366, 验证召回率: 0.6278, 验证特异性: 0.4715, 验证MCC: 0.3696, 验证归一化MCC: 0.6848, 学习率: 0.000010
# 2025-03-10 02:25:33 - INFO - 本轮用时: 9.33 秒
# 2025-03-10 02:25:33 - INFO - ——————————————————————————————
# 2025-03-10 02:25:43 - INFO - 轮次 60/100, 训练损失: 0.5587, 训练准确率: 0.6792, 类别0/1: 0.5371/0.8200, 训练F1: 0.6737, 训练精确率: 0.6940, 训练召回率: 0.6805, 训练特异性: 0.5371, 训练MCC: 0.3729, 训练归一化MCC: 0.6865, 验证损失: 0.7163, 验证准确率: 0.6368, 类别0/1: 0.5045/0.8442, 验证F1: 0.6316, 验证精确率: 0.7171, 验证召回率: 0.6316, 验证特异性: 0.5045, 验证MCC: 0.3487, 验证归一化MCC: 0.6744, 学习率: 0.000010
# 2025-03-10 02:25:43 - INFO - 本轮用时: 9.80 秒
# 2025-03-10 02:25:43 - INFO - ——————————————————————————————
# 2025-03-10 02:25:52 - INFO - 轮次 61/100, 训练损失: 0.5539, 训练准确率: 0.6870, 类别0/1: 0.5385/0.8283, 训练F1: 0.6812, 训练精确率: 0.7001, 训练召回率: 0.6884, 训练特异性: 0.5385, 训练MCC: 0.3846, 训练归一化MCC: 0.6923, 验证损失: 0.6845, 验证准确率: 0.6267, 类别0/1: 0.5165/0.8392, 验证F1: 0.6380, 验证精确率: 0.7182, 验证召回率: 0.6372, 验证特异性: 0.5165, 验证MCC: 0.3540, 验证归一化MCC: 0.6770, 学习率: 0.000010
# 2025-03-10 02:25:52 - INFO - 本轮用时: 9.59 秒
# 2025-03-10 02:25:52 - INFO - ——————————————————————————————
# 2025-03-10 02:26:01 - INFO - 轮次 62/100, 训练损失: 0.5587, 训练准确率: 0.6870, 类别0/1: 0.5446/0.8410, 训练F1: 0.6858, 训练精确率: 0.7114, 训练召回率: 0.6927, 训练特异性: 0.5446, 训练MCC: 0.4037, 训练归一化MCC: 0.7019, 验证损失: 0.6510, 验证准确率: 0.6309, 类别0/1: 0.5105/0.8392, 验证F1: 0.6340, 验证精确率: 0.7161, 验证召回率: 0.6335, 验证特异性: 0.5105, 验证MCC: 0.3487, 验证归一化MCC: 0.6743, 学习率: 0.000010
# 2025-03-10 02:26:01 - INFO - 本轮用时: 8.52 秒
# 2025-03-10 02:26:01 - INFO - ——————————————————————————————
# 2025-03-10 02:26:09 - INFO - 轮次 63/100, 训练损失: 0.5649, 训练准确率: 0.6723, 类别0/1: 0.5480/0.8116, 训练F1: 0.6710, 训练精确率: 0.6937, 训练召回率: 0.6762, 训练特异性: 0.5480, 训练MCC: 0.3717, 训练归一化MCC: 0.6858, 验证损失: 0.6593, 验证准确率: 0.6437, 类别0/1: 0.4925/0.8844, 验证F1: 0.6369, 验证精确率: 0.7398, 验证召回率: 0.6391, 验证特异性: 0.4925, 验证MCC: 0.3820, 验证归一化MCC: 0.6910, 学习率: 0.000010
# 2025-03-10 02:26:09 - INFO - 本轮用时: 8.41 秒
# 2025-03-10 02:26:09 - INFO - ——————————————————————————————
# 2025-03-10 02:26:18 - INFO - 轮次 64/100, 训练损失: 0.5616, 训练准确率: 0.6852, 类别0/1: 0.5457/0.8182, 训练F1: 0.6788, 训练精确率: 0.6964, 训练召回率: 0.6852, 训练特异性: 0.5457, 训练MCC: 0.3791, 训练归一化MCC: 0.6895, 验证损失: 0.6115, 验证准确率: 0.6531, 类别0/1: 0.5736/0.8090, 验证F1: 0.6654, 验证精确率: 0.7208, 验证召回率: 0.6617, 验证特异性: 0.5736, 验证MCC: 0.3739, 验证归一化MCC: 0.6870, 学习率: 0.000010
# 2025-03-10 02:26:18 - INFO - 本轮用时: 8.43 秒
# 2025-03-10 02:26:18 - INFO - ——————————————————————————————
# 2025-03-10 02:26:26 - INFO - 轮次 65/100, 训练损失: 0.5561, 训练准确率: 0.6981, 类别0/1: 0.5534/0.8297, 训练F1: 0.6917, 训练精确率: 0.7075, 训练召回率: 0.6983, 训练特异性: 0.5534, 训练MCC: 0.4005, 训练归一化MCC: 0.7002, 验证损失: 0.6434, 验证准确率: 0.6236, 类别0/1: 0.5405/0.8342, 验证F1: 0.6525, 验证精确率: 0.7236, 验证召回率: 0.6504, 验证特异性: 0.5405, 验证MCC: 0.3701, 验证归一化MCC: 0.6850, 学习率: 0.000010
# 2025-03-10 02:26:26 - INFO - 本轮用时: 8.63 秒
# 2025-03-10 02:26:26 - INFO - ——————————————————————————————
# 2025-03-10 02:26:35 - INFO - 轮次 66/100, 训练损失: 0.5580, 训练准确率: 0.6875, 类别0/1: 0.5446/0.8337, 训练F1: 0.6811, 训练精确率: 0.7065, 训练召回率: 0.6875, 训练特异性: 0.5446, 训练MCC: 0.3946, 训练归一化MCC: 0.6973, 验证损失: 0.6357, 验证准确率: 0.6361, 类别0/1: 0.5165/0.8442, 验证F1: 0.6398, 验证精确率: 0.7214, 验证召回率: 0.6391, 验证特异性: 0.5165, 验证MCC: 0.3593, 验证归一化MCC: 0.6797, 学习率: 0.000010
# 2025-03-10 02:26:35 - INFO - 本轮用时: 8.64 秒
# 2025-03-10 02:26:35 - INFO - ——————————————————————————————
# 2025-03-10 02:26:44 - INFO - *** 新的最佳模型 (F1分数: 0.6714) ***
# 2025-03-10 02:26:44 - INFO - 轮次 67/100, 训练损失: 0.5464, 训练准确率: 0.6953, 类别0/1: 0.5650/0.8340, 训练F1: 0.6942, 训练精确率: 0.7150, 训练召回率: 0.6997, 训练特异性: 0.5650, 训练MCC: 0.4143, 训练归一化MCC: 0.7071, 验证损失: 0.5988, 验证准确率: 0.6698, 类别0/1: 0.5856/0.8040, 验证F1: 0.6714, 验证精确率: 0.7225, 验证召回率: 0.6673, 验证特异性: 0.5856, 验证MCC: 0.3798, 验证归一化MCC: 0.6899, 学习率: 0.000010
# 2025-03-10 02:26:44 - INFO - 本轮用时: 9.03 秒
# 2025-03-10 02:26:44 - INFO - ——————————————————————————————
# 2025-03-10 02:26:54 - INFO - 轮次 68/100, 训练损失: 0.5596, 训练准确率: 0.6935, 类别0/1: 0.5640/0.8255, 训练F1: 0.6897, 训练精确率: 0.7091, 训练召回率: 0.6950, 训练特异性: 0.5640, 训练MCC: 0.4037, 训练归一化MCC: 0.7018, 验证损失: 0.6474, 验证准确率: 0.6490, 类别0/1: 0.5345/0.8291, 验证F1: 0.6467, 验证精确率: 0.7184, 验证召回率: 0.6447, 验证特异性: 0.5345, 验证MCC: 0.3594, 验证归一化MCC: 0.6797, 学习率: 0.000010
# 2025-03-10 02:26:54 - INFO - 本轮用时: 9.78 秒
# 2025-03-10 02:26:54 - INFO - ——————————————————————————————
# 2025-03-10 02:27:03 - INFO - 轮次 69/100, 训练损失: 0.5557, 训练准确率: 0.6898, 类别0/1: 0.5597/0.8149, 训练F1: 0.6857, 训练精确率: 0.7003, 训练召回率: 0.6913, 训练特异性: 0.5597, 训练MCC: 0.3885, 训练归一化MCC: 0.6943, 验证损失: 0.6128, 验证准确率: 0.6813, 类别0/1: 0.5856/0.8040, 验证F1: 0.6714, 验证精确率: 0.7225, 验证召回率: 0.6673, 验证特异性: 0.5856, 验证MCC: 0.3798, 验证归一化MCC: 0.6899, 学习率: 0.000010
# 2025-03-10 02:27:03 - INFO - 本轮用时: 9.34 秒
# 2025-03-10 02:27:03 - INFO - ——————————————————————————————
# 2025-03-10 02:27:12 - INFO - 轮次 70/100, 训练损失: 0.5568, 训练准确率: 0.6916, 类别0/1: 0.5588/0.8194, 训练F1: 0.6848, 训练精确率: 0.7028, 训练召回率: 0.6903, 训练特异性: 0.5588, 训练MCC: 0.3921, 训练归一化MCC: 0.6960, 验证损失: 0.7046, 验证准确率: 0.6507, 类别0/1: 0.5405/0.8241, 验证F1: 0.6490, 验证精确率: 0.7176, 验证召回率: 0.6466, 验证特异性: 0.5405, 验证MCC: 0.3596, 验证归一化MCC: 0.6798, 学习率: 0.000010
# 2025-03-10 02:27:12 - INFO - 本轮用时: 9.22 秒
# 2025-03-10 02:27:12 - INFO - ——————————————————————————————
# 2025-03-10 02:27:21 - INFO - 轮次 71/100, 训练损失: 0.5643, 训练准确率: 0.6866, 类别0/1: 0.5502/0.8260, 训练F1: 0.6807, 训练精确率: 0.7038, 训练召回率: 0.6866, 训练特异性: 0.5502, 训练MCC: 0.3909, 训练归一化MCC: 0.6955, 验证损失: 0.5960, 验证准确率: 0.6632, 类别0/1: 0.5556/0.8241, 验证F1: 0.6589, 验证精确率: 0.7230, 验证召回率: 0.6560, 验证特异性: 0.5556, 验证MCC: 0.3731, 验证归一化MCC: 0.6865, 学习率: 0.000010
# 2025-03-10 02:27:21 - INFO - 本轮用时: 9.25 秒
# 2025-03-10 02:27:21 - INFO - ——————————————————————————————
# 2025-03-10 02:27:30 - INFO - 轮次 72/100, 训练损失: 0.5521, 训练准确率: 0.6926, 类别0/1: 0.5582/0.8305, 训练F1: 0.6883, 训练精确率: 0.7099, 训练召回率: 0.6941, 训练特异性: 0.5582, 训练MCC: 0.4039, 训练归一化MCC: 0.7019, 验证损失: 0.6104, 验证准确率: 0.6542, 类别0/1: 0.5405/0.8342, 验证F1: 0.6525, 验证精确率: 0.7236, 验证召回率: 0.6504, 验证特异性: 0.5405, 验证MCC: 0.3701, 验证归一化MCC: 0.6850, 学习率: 0.000010
# 2025-03-10 02:27:30 - INFO - 本轮用时: 8.90 秒
# 2025-03-10 02:27:30 - INFO - ——————————————————————————————
# 2025-03-10 02:27:39 - INFO - 轮次 73/100, 训练损失: 0.5749, 训练准确率: 0.6769, 类别0/1: 0.5363/0.8333, 训练F1: 0.6731, 训练精确率: 0.7034, 训练召回率: 0.6795, 训练特异性: 0.5363, 训练MCC: 0.3852, 训练归一化MCC: 0.6926, 验证损失: 0.6046, 验证准确率: 0.6618, 类别0/1: 0.5405/0.8342, 验证F1: 0.6525, 验证精确率: 0.7236, 验证召回率: 0.6504, 验证特异性: 0.5405, 验证MCC: 0.3701, 验证归一化MCC: 0.6850, 学习率: 0.000010
# 2025-03-10 02:27:39 - INFO - 本轮用时: 8.61 秒
# 2025-03-10 02:27:39 - INFO - ——————————————————————————————
# 2025-03-10 02:27:49 - INFO - 轮次 74/100, 训练损失: 0.5633, 训练准确率: 0.6834, 类别0/1: 0.5477/0.8141, 训练F1: 0.6735, 训练精确率: 0.6950, 训练召回率: 0.6790, 训练特异性: 0.5477, 训练MCC: 0.3748, 训练归一化MCC: 0.6874, 验证损失: 0.6609, 验证准确率: 0.6503, 类别0/1: 0.5375/0.8392, 验证F1: 0.6522, 验证精确率: 0.7256, 验证召回率: 0.6504, 验证特异性: 0.5375, 验证MCC: 0.3726, 验证归一化MCC: 0.6863, 学习率: 0.000010
# 2025-03-10 02:27:49 - INFO - 本轮用时: 9.93 秒
# 2025-03-10 02:27:49 - INFO - ——————————————————————————————
# 2025-03-10 02:27:58 - INFO - 轮次 75/100, 训练损失: 0.5456, 训练准确率: 0.7027, 类别0/1: 0.5699/0.8300, 训练F1: 0.7001, 训练精确率: 0.7146, 训练召回率: 0.7058, 训练特异性: 0.5699, 训练MCC: 0.4159, 训练归一化MCC: 0.7080, 验证损失: 0.5889, 验证准确率: 0.6736, 类别0/1: 0.5856/0.8040, 验证F1: 0.6714, 验证精确率: 0.7225, 验证召回率: 0.6673, 验证特异性: 0.5856, 验证MCC: 0.3798, 验证归一化MCC: 0.6899, 学习率: 0.000010
# 2025-03-10 02:27:58 - INFO - 本轮用时: 9.18 秒
# 2025-03-10 02:27:58 - INFO - ——————————————————————————————
# 2025-03-10 02:28:07 - INFO - 轮次 76/100, 训练损失: 0.5538, 训练准确率: 0.6935, 类别0/1: 0.5602/0.8193, 训练F1: 0.6893, 训练精确率: 0.7034, 训练召回率: 0.6950, 训练特异性: 0.5602, 训练MCC: 0.3944, 训练归一化MCC: 0.6972, 验证损失: 0.6465, 验证准确率: 0.6458, 类别0/1: 0.4865/0.8894, 验证F1: 0.6344, 验证精确率: 0.7414, 验证召回率: 0.6372, 验证特异性: 0.4865, 验证MCC: 0.3824, 验证归一化MCC: 0.6912, 学习率: 0.000010
# 2025-03-10 02:28:07 - INFO - 本轮用时: 9.19 秒
# 2025-03-10 02:28:07 - INFO - ——————————————————————————————
# 2025-03-10 02:28:16 - INFO - 轮次 77/100, 训练损失: 0.5493, 训练准确率: 0.6967, 类别0/1: 0.5673/0.8252, 训练F1: 0.6930, 训练精确率: 0.7101, 训练召回率: 0.6983, 训练特异性: 0.5673, 训练MCC: 0.4069, 训练归一化MCC: 0.7034, 验证损失: 0.6517, 验证准确率: 0.6681, 类别0/1: 0.5826/0.8040, 验证F1: 0.6694, 验证精确率: 0.7213, 验证召回率: 0.6654, 验证特异性: 0.5826, 验证MCC: 0.3771, 验证归一化MCC: 0.6885, 学习率: 0.000010
# 2025-03-10 02:28:16 - INFO - 本轮用时: 9.17 秒
# 2025-03-10 02:28:16 - INFO - ——————————————————————————————
# 2025-03-10 02:28:26 - INFO - 轮次 78/100, 训练损失: 0.5626, 训练准确率: 0.6788, 类别0/1: 0.5550/0.8061, 训练F1: 0.6737, 训练精确率: 0.6930, 训练召回率: 0.6786, 训练特异性: 0.5550, 训练MCC: 0.3725, 训练归一化MCC: 0.6862, 验证损失: 0.6539, 验证准确率: 0.6618, 类别0/1: 0.5375/0.8392, 验证F1: 0.6522, 验证精确率: 0.7256, 验证召回率: 0.6504, 验证特异性: 0.5375, 验证MCC: 0.3726, 验证归一化MCC: 0.6863, 学习率: 0.000010
# 2025-03-10 02:28:26 - INFO - 本轮用时: 9.22 秒
# 2025-03-10 02:28:26 - INFO - ——————————————————————————————
# 2025-03-10 02:28:35 - INFO - 轮次 79/100, 训练损失: 0.5669, 训练准确率: 0.6765, 类别0/1: 0.5327/0.8290, 训练F1: 0.6708, 训练精确率: 0.6986, 训练召回率: 0.6776, 训练特异性: 0.5327, 训练MCC: 0.3776, 训练归一化MCC: 0.6888, 验证损失: 0.6615, 验证准确率: 0.6590, 类别0/1: 0.5616/0.8241, 验证F1: 0.6628, 验证精确率: 0.7251, 验证召回率: 0.6598, 验证特异性: 0.5616, 验证MCC: 0.3785, 验证归一化MCC: 0.6892, 学习率: 0.000010
# 2025-03-10 02:28:35 - INFO - 本轮用时: 9.55 秒
# 2025-03-10 02:28:35 - INFO - ——————————————————————————————
# 2025-03-10 02:28:45 - INFO - 轮次 80/100, 训练损失: 0.5430, 训练准确率: 0.7013, 类别0/1: 0.5633/0.8260, 训练F1: 0.6970, 训练精确率: 0.7095, 训练召回率: 0.7030, 训练特异性: 0.5633, 训练MCC: 0.4056, 训练归一化MCC: 0.7028, 验证损失: 0.6018, 验证准确率: 0.6736, 类别0/1: 0.5826/0.8090, 验证F1: 0.6712, 验证精确率: 0.7242, 验证召回率: 0.6673, 验证特异性: 0.5826, 验证MCC: 0.3821, 验证归一化MCC: 0.6911, 学习率: 0.000010
# 2025-03-10 02:28:45 - INFO - 本轮用时: 9.33 秒
# 2025-03-10 02:28:45 - INFO - ——————————————————————————————
# 2025-03-10 02:28:54 - INFO - 轮次 81/100, 训练损失: 0.5388, 训练准确率: 0.7109, 类别0/1: 0.5768/0.8435, 训练F1: 0.7073, 训练精确率: 0.7262, 训练召回率: 0.7129, 训练特异性: 0.5768, 训练MCC: 0.4370, 训练归一化MCC: 0.7185, 验证损失: 0.6235, 验证准确率: 0.6552, 类别0/1: 0.5075/0.8593, 验证F1: 0.6388, 验证精确率: 0.7279, 验证召回率: 0.6391, 验证特异性: 0.5075, 验证MCC: 0.3676, 验证归一化MCC: 0.6838, 学习率: 0.000010
# 2025-03-10 02:28:54 - INFO - 本轮用时: 9.41 秒
# 2025-03-10 02:28:54 - INFO - ——————————————————————————————
# 2025-03-10 02:29:03 - INFO - 轮次 82/100, 训练损失: 0.5411, 训练准确率: 0.7031, 类别0/1: 0.5580/0.8545, 训练F1: 0.6948, 训练精确率: 0.7267, 训练召回率: 0.7007, 训练特异性: 0.5580, 训练MCC: 0.4295, 训练归一化MCC: 0.7147, 验证损失: 0.7010, 验证准确率: 0.6493, 类别0/1: 0.5045/0.8693, 验证F1: 0.6401, 验证精确率: 0.7335, 验证召回率: 0.6410, 验证特异性: 0.5045, 验证MCC: 0.3758, 验证归一化MCC: 0.6879, 学习率: 0.000010
# 2025-03-10 02:29:03 - INFO - 本轮用时: 9.08 秒
# 2025-03-10 02:29:03 - INFO - ——————————————————————————————
# 2025-03-10 02:29:13 - INFO - 轮次 83/100, 训练损失: 0.5508, 训练准确率: 0.6967, 类别0/1: 0.5750/0.8261, 训练F1: 0.6975, 训练精确率: 0.7140, 训练召回率: 0.7025, 训练特异性: 0.5750, 训练MCC: 0.4150, 训练归一化MCC: 0.7075, 验证损失: 0.6274, 验证准确率: 0.6528, 类别0/1: 0.5706/0.8241, 验证F1: 0.6687, 验证精确率: 0.7284, 验证召回率: 0.6654, 验证特异性: 0.5706, 验证MCC: 0.3866, 验证归一化MCC: 0.6933, 学习率: 0.000010
# 2025-03-10 02:29:13 - INFO - 本轮用时: 9.49 秒
# 2025-03-10 02:29:13 - INFO - ——————————————————————————————
# 2025-03-10 02:29:21 - INFO - 轮次 84/100, 训练损失: 0.5518, 训练准确率: 0.6949, 类别0/1: 0.5513/0.8304, 训练F1: 0.6872, 训练精确率: 0.7069, 训练召回率: 0.6936, 训练特异性: 0.5513, 训练MCC: 0.3984, 训练归一化MCC: 0.6992, 验证损失: 0.6287, 验证准确率: 0.6552, 类别0/1: 0.5616/0.8241, 验证F1: 0.6628, 验证精确率: 0.7251, 验证召回率: 0.6598, 验证特异性: 0.5616, 验证MCC: 0.3785, 验证归一化MCC: 0.6892, 学习率: 0.000010
# 2025-03-10 02:29:21 - INFO - 本轮用时: 8.79 秒
# 2025-03-10 02:29:21 - INFO - ——————————————————————————————
# 2025-03-10 02:29:30 - INFO - 轮次 85/100, 训练损失: 0.5450, 训练准确率: 0.6962, 类别0/1: 0.5636/0.8285, 训练F1: 0.6910, 训练精确率: 0.7108, 训练召回率: 0.6964, 训练特异性: 0.5636, 训练MCC: 0.4068, 训练归一化MCC: 0.7034, 验证损失: 0.6503, 验证准确率: 0.6424, 类别0/1: 0.5465/0.8342, 验证F1: 0.6564, 验证精确率: 0.7257, 验证召回率: 0.6541, 验证特异性: 0.5465, 验证MCC: 0.3754, 验证归一化MCC: 0.6877, 学习率: 0.000010
# 2025-03-10 02:29:30 - INFO - 本轮用时: 8.55 秒
# 2025-03-10 02:29:30 - INFO - ——————————————————————————————
# 2025-03-10 02:29:38 - INFO - 轮次 86/100, 训练损失: 0.5546, 训练准确率: 0.6889, 类别0/1: 0.5410/0.8241, 训练F1: 0.6780, 训练精确率: 0.6983, 训练召回率: 0.6847, 训练特异性: 0.5410, 训练MCC: 0.3813, 训练归一化MCC: 0.6906, 验证损失: 0.6300, 验证准确率: 0.6705, 类别0/1: 0.5586/0.8291, 验证F1: 0.6626, 验证精确率: 0.7270, 验证召回率: 0.6598, 验证特异性: 0.5586, 验证MCC: 0.3809, 验证归一化MCC: 0.6905, 学习率: 0.000001
# 2025-03-10 02:29:38 - INFO - 本轮用时: 8.31 秒
# 2025-03-10 02:29:38 - INFO - ——————————————————————————————
# 2025-03-10 02:29:47 - INFO - 轮次 87/100, 训练损失: 0.5430, 训练准确率: 0.7036, 类别0/1: 0.5841/0.8255, 训练F1: 0.7048, 训练精确率: 0.7176, 训练召回率: 0.7096, 训练特异性: 0.5841, 训练MCC: 0.4236, 训练归一化MCC: 0.7118, 验证损失: 0.6131, 验证准确率: 0.6628, 类别0/1: 0.5586/0.8291, 验证F1: 0.6626, 验证精确率: 0.7270, 验证召回率: 0.6598, 验证特异性: 0.5586, 验证MCC: 0.3809, 验证归一化MCC: 0.6905, 学习率: 0.000001
# 2025-03-10 02:29:47 - INFO - 本轮用时: 8.41 秒
# 2025-03-10 02:29:47 - INFO - ——————————————————————————————
# 2025-03-10 02:29:55 - INFO - 轮次 88/100, 训练损失: 0.5232, 训练准确率: 0.7155, 类别0/1: 0.5788/0.8464, 训练F1: 0.7093, 训练精确率: 0.7290, 训练召回率: 0.7148, 训练特异性: 0.5788, 训练MCC: 0.4422, 训练归一化MCC: 0.7211, 验证损失: 0.6216, 验证准确率: 0.6486, 类别0/1: 0.5375/0.8342, 验证F1: 0.6505, 验证精确率: 0.7225, 验证召回率: 0.6485, 验证特异性: 0.5375, 验证MCC: 0.3674, 验证归一化MCC: 0.6837, 学习率: 0.000001
# 2025-03-10 02:29:55 - INFO - 本轮用时: 8.23 秒
# 2025-03-10 02:29:55 - INFO - ——————————————————————————————
# 2025-03-10 02:30:03 - INFO - 轮次 89/100, 训练损失: 0.5571, 训练准确率: 0.6797, 类别0/1: 0.5416/0.8159, 训练F1: 0.6720, 训练精确率: 0.6933, 训练召回率: 0.6781, 训练特异性: 0.5416, 训练MCC: 0.3716, 训练归一化MCC: 0.6858, 验证损失: 0.6270, 验证准确率: 0.6663, 类别0/1: 0.5736/0.8141, 验证F1: 0.6672, 验证精确率: 0.7237, 验证召回率: 0.6635, 验证特异性: 0.5736, 验证MCC: 0.3790, 验证归一化MCC: 0.6895, 学习率: 0.000001
# 2025-03-10 02:30:03 - INFO - 本轮用时: 8.47 秒
# 2025-03-10 02:30:03 - INFO - ——————————————————————————————
# 2025-03-10 02:30:11 - INFO - 轮次 90/100, 训练损失: 0.5532, 训练准确率: 0.6935, 类别0/1: 0.5714/0.8095, 训练F1: 0.6889, 训练精确率: 0.7019, 训练召回率: 0.6936, 训练特异性: 0.5714, 训练MCC: 0.3931, 训练归一化MCC: 0.6966, 验证损失: 0.6174, 验证准确率: 0.6462, 类别0/1: 0.5465/0.8342, 验证F1: 0.6564, 验证精确率: 0.7257, 验证召回率: 0.6541, 验证特异性: 0.5465, 验证MCC: 0.3754, 验证归一化MCC: 0.6877, 学习率: 0.000001
# 2025-03-10 02:30:11 - INFO - 本轮用时: 8.21 秒
# 2025-03-10 02:30:11 - INFO - ——————————————————————————————
# 2025-03-10 02:30:20 - INFO - 轮次 91/100, 训练损失: 0.5705, 训练准确率: 0.6756, 类别0/1: 0.5504/0.8185, 训练F1: 0.6756, 训练精确率: 0.6992, 训练召回率: 0.6809, 训练特异性: 0.5504, 训练MCC: 0.3817, 训练归一化MCC: 0.6909, 验证损失: 0.7152, 验证准确率: 0.6726, 类别0/1: 0.5526/0.8342, 验证F1: 0.6604, 验证精确率: 0.7279, 验证召回率: 0.6579, 验证特异性: 0.5526, 验证MCC: 0.3808, 验证归一化MCC: 0.6904, 学习率: 0.000001
# 2025-03-10 02:30:20 - INFO - 本轮用时: 8.31 秒
# 2025-03-10 02:30:20 - INFO - ——————————————————————————————
# 2025-03-10 02:30:28 - INFO - 轮次 92/100, 训练损失: 0.5312, 训练准确率: 0.7119, 类别0/1: 0.5741/0.8324, 训练F1: 0.7040, 训练精确率: 0.7180, 训练召回率: 0.7096, 训练特异性: 0.5741, 训练MCC: 0.4228, 训练归一化MCC: 0.7114, 验证损失: 0.5788, 验证准确率: 0.6757, 类别0/1: 0.5706/0.8241, 验证F1: 0.6687, 验证精确率: 0.7284, 验证召回率: 0.6654, 验证特异性: 0.5706, 验证MCC: 0.3866, 验证归一化MCC: 0.6933, 学习率: 0.000001
# 2025-03-10 02:30:28 - INFO - 本轮用时: 7.94 秒
# 2025-03-10 02:30:28 - INFO - ——————————————————————————————
# 2025-03-10 02:30:35 - INFO - 轮次 93/100, 训练损失: 0.5467, 训练准确率: 0.6847, 类别0/1: 0.5503/0.8103, 训练F1: 0.6749, 训练精确率: 0.6934, 训练召回率: 0.6805, 训练特异性: 0.5503, 训练MCC: 0.3735, 训练归一化MCC: 0.6868, 验证损失: 0.7117, 验证准确率: 0.6510, 类别0/1: 0.5706/0.8191, 验证F1: 0.6670, 验证精确率: 0.7255, 验证召回率: 0.6635, 验证特异性: 0.5706, 验证MCC: 0.3814, 验证归一化MCC: 0.6907, 学习率: 0.000001
# 2025-03-10 02:30:35 - INFO - 本轮用时: 7.01 秒
# 2025-03-10 02:30:35 - INFO - ——————————————————————————————
# 2025-03-10 02:30:42 - INFO - 轮次 94/100, 训练损失: 0.5637, 训练准确率: 0.6861, 类别0/1: 0.5627/0.8116, 训练F1: 0.6825, 训练精确率: 0.6995, 训练召回率: 0.6875, 训练特异性: 0.5627, 训练MCC: 0.3866, 训练归一化MCC: 0.6933, 验证损失: 0.6450, 验证准确率: 0.6688, 类别0/1: 0.5526/0.8342, 验证F1: 0.6604, 验证精确率: 0.7279, 验证召回率: 0.6579, 验证特异性: 0.5526, 验证MCC: 0.3808, 验证归一化MCC: 0.6904, 学习率: 0.000001
# 2025-03-10 02:30:42 - INFO - 本轮用时: 7.32 秒
# 2025-03-10 02:30:42 - INFO - ——————————————————————————————
# 2025-03-10 02:30:50 - INFO - 轮次 95/100, 训练损失: 0.5572, 训练准确率: 0.6999, 类别0/1: 0.5610/0.8414, 训练F1: 0.6968, 训练精确率: 0.7183, 训练召回率: 0.7030, 训练特异性: 0.5610, 训练MCC: 0.4198, 训练归一化MCC: 0.7099, 验证损失: 0.6256, 验证准确率: 0.6389, 类别0/1: 0.5405/0.8342, 验证F1: 0.6525, 验证精确率: 0.7236, 验证召回率: 0.6504, 验证特异性: 0.5405, 验证MCC: 0.3701, 验证归一化MCC: 0.6850, 学习率: 0.000001
# 2025-03-10 02:30:50 - INFO - 本轮用时: 7.45 秒
# 2025-03-10 02:30:50 - INFO - ——————————————————————————————
# 2025-03-10 02:30:57 - INFO - 轮次 96/100, 训练损失: 0.5322, 训练准确率: 0.6990, 类别0/1: 0.5685/0.8201, 训练F1: 0.6939, 训练精确率: 0.7074, 训练召回率: 0.6992, 训练特异性: 0.5685, 训练MCC: 0.4029, 训练归一化MCC: 0.7014, 验证损失: 0.6449, 验证准确率: 0.6448, 类别0/1: 0.5225/0.8593, 验证F1: 0.6490, 验证精确率: 0.7330, 验证召回率: 0.6485, 验证特异性: 0.5225, 验证MCC: 0.3807, 验证归一化MCC: 0.6903, 学习率: 0.000001
# 2025-03-10 02:30:57 - INFO - 本轮用时: 7.76 秒
# 2025-03-10 02:30:57 - INFO - ——————————————————————————————
# 2025-03-10 02:31:06 - INFO - 轮次 97/100, 训练损失: 0.5465, 训练准确率: 0.6870, 类别0/1: 0.5566/0.8249, 训练F1: 0.6855, 训练精确率: 0.7055, 训练召回率: 0.6913, 训练特异性: 0.5566, 训练MCC: 0.3962, 训练归一化MCC: 0.6981, 验证损失: 0.6556, 验证准确率: 0.6340, 类别0/1: 0.4985/0.8794, 验证F1: 0.6393, 验证精确率: 0.7383, 验证召回率: 0.6410, 验证特异性: 0.4985, 验证MCC: 0.3816, 验证归一化MCC: 0.6908, 学习率: 0.000001
# 2025-03-10 02:31:06 - INFO - 本轮用时: 8.45 秒
# 2025-03-10 02:31:06 - INFO - ——————————————————————————————
# 2025-03-10 02:31:13 - INFO - 轮次 98/100, 训练损失: 0.5500, 训练准确率: 0.6935, 类别0/1: 0.5612/0.8337, 训练F1: 0.6884, 训练精确率: 0.7137, 训练召回率: 0.6936, 训练特异性: 0.5612, 训练MCC: 0.4089, 训练归一化MCC: 0.7045, 验证损失: 0.6833, 验证准确率: 0.6323, 类别0/1: 0.5015/0.8693, 验证F1: 0.6380, 验证精确率: 0.7325, 验证召回率: 0.6391, 验证特异性: 0.5015, 验证MCC: 0.3732, 验证归一化MCC: 0.6866, 学习率: 0.000001
# 2025-03-10 02:31:13 - INFO - 本轮用时: 7.69 秒
# 2025-03-10 02:31:13 - INFO - ——————————————————————————————
# 2025-03-10 02:31:21 - INFO - 轮次 99/100, 训练损失: 0.5458, 训练准确率: 0.6944, 类别0/1: 0.5504/0.8494, 训练F1: 0.6896, 训练精确率: 0.7199, 训练召回率: 0.6960, 训练特异性: 0.5504, 训练MCC: 0.4174, 训练归一化MCC: 0.7087, 验证损失: 0.6081, 验证准确率: 0.6615, 类别0/1: 0.5465/0.8342, 验证F1: 0.6564, 验证精确率: 0.7257, 验证召回率: 0.6541, 验证特异性: 0.5465, 验证MCC: 0.3754, 验证归一化MCC: 0.6877, 学习率: 0.000001
# 2025-03-10 02:31:21 - INFO - 本轮用时: 7.21 秒
# 2025-03-10 02:31:21 - INFO - ——————————————————————————————
# 2025-03-10 02:31:28 - INFO - 轮次 100/100, 训练损失: 0.5447, 训练准确率: 0.6962, 类别0/1: 0.5597/0.8477, 训练F1: 0.6935, 训练精确率: 0.7226, 训练召回率: 0.6992, 训练特异性: 0.5597, 训练MCC: 0.4236, 训练归一化MCC: 0.7118, 验证损失: 0.6347, 验证准确率: 0.6479, 类别0/1: 0.5495/0.8342, 验证F1: 0.6584, 验证精确率: 0.7268, 验证召回率: 0.6560, 验证特异性: 0.5495, 验证MCC: 0.3781, 验证归一化MCC: 0.6890, 学习率: 0.000001
# 2025-03-10 02:31:28 - INFO - 本轮用时: 7.84 秒
# 2025-03-10 02:31:28 - INFO - ——————————————————————————————
# 2025-03-10 02:31:29 - INFO - 最终训练类别准确率 - 类别0: 0.5597, 类别1: 0.8477
# 2025-03-10 02:31:29 - INFO - 最终验证类别准确率 - 类别0: 0.5495, 类别1: 0.8342
# 2025-03-10 02:31:29 - INFO - 最终F1分数 - 训练: 0.6935, 验证: 0.6584
# 2025-03-10 02:31:29 - INFO - 最终精确率 - 训练: 0.7226, 验证: 0.7268
# 2025-03-10 02:31:29 - INFO - 最终召回率 - 训练: 0.6992, 验证: 0.6560
# 2025-03-10 02:31:29 - INFO - 最终特异性 - 训练: 0.5597, 验证: 0.5495
# 2025-03-10 02:31:29 - INFO - 最终MCC - 训练: 0.4236, 验证: 0.3781
# 2025-03-10 02:31:29 - INFO - 最终归一化MCC - 训练: 0.7118, 验证: 0.6890
# 2025-03-10 02:31:29 - INFO - 已保存模型权重到: C:\Users\USTC\Desktop\地磁论文（5级以上）\对比模型结果\RNN模型结果\RNNModel_7天_fold_1.pth
# 2025-03-10 02:31:29 - INFO - 已保存训练日志到: C:\Users\USTC\Desktop\地磁论文（5级以上）\对比模型结果\RNN模型结果\RNNModel_7天_fold_1_epoch_logs.txt
# 2025-03-10 02:31:29 - INFO - 已保存训练集预测概率到: C:\Users\USTC\Desktop\地磁论文（5级以上）\对比模型结果\RNN模型结果\RNNModel_7天_fold_1_train_probs.npy
# 2025-03-10 02:31:29 - INFO - 已保存训练集标签到: C:\Users\USTC\Desktop\地磁论文（5级以上）\对比模型结果\RNN模型结果\RNNModel_7天_fold_1_train_labels.npy
# 2025-03-10 02:31:29 - INFO - 已保存测试集预测概率到: C:\Users\USTC\Desktop\地磁论文（5级以上）\对比模型结果\RNN模型结果\RNNModel_7天_fold_1_test_probs.npy
# 2025-03-10 02:31:29 - INFO - 已保存测试集标签到: C:\Users\USTC\Desktop\地磁论文（5级以上）\对比模型结果\RNN模型结果\RNNModel_7天_fold_1_test_labels.npy
# 2025-03-10 02:31:29 - INFO - 类别准确率: 类别0: 1.0991, 类别1: 0.8342
# 2025-03-10 02:31:29 - INFO - F1分数: 训练: 0.6935, 验证: 0.6584
# 2025-03-10 02:31:29 - INFO - 精确率: 训练: 0.7226, 验证: 0.7268
# 2025-03-10 02:31:29 - INFO - 召回率: 训练: 0.6992, 验证: 0.6560
# 2025-03-10 02:31:29 - INFO - 特异性: 训练: 0.5597, 验证: 0.5495
# 2025-03-10 02:31:29 - INFO - MCC: 训练: 0.4236, 验证: 0.3781
# 2025-03-10 02:31:29 - INFO - 归一化MCC: 训练: 0.7118, 验证: 0.6890
# 2025-03-10 02:31:29 - INFO - 第 1 折训练完成
# 2025-03-10 02:31:29 - INFO - 第 1 折训练结束
# 2025-03-10 02:31:29 - INFO - 开始训练第 2/5 折
# ...
# 2025-03-10 06:43:39 - INFO - 本轮用时: 8.45 秒
# 2025-03-10 06:43:39 - INFO - ——————————————————————————————
# 2025-03-10 06:43:48 - INFO - 轮次 88/100, 训练损失: 0.6126, 训练准确率: 0.6436, 类别0/1: 0.5028/0.8002, 训练F1: 0.6390, 训练精确率: 0.6671, 训练召回率: 0.6463, 训练特异性: 0.5028, 训练MCC: 0.3161, 训练归一化MCC: 0.6581, 验证损失: 0.6567, 验证准确率: 0.5904, 类别0/1: 0.4859/0.7792, 验证F1: 0.5934, 验证精确率: 0.6788, 验证召回率: 0.5890, 验证特异性: 0.4859, 验证MCC: 0.2592, 验证归一化MCC: 0.6296, 学习率: 0.000001
# 2025-03-10 06:43:48 - INFO - 本轮用时: 9.13 秒
# 2025-03-10 06:43:48 - INFO - ——————————————————————————————
# 2025-03-10 06:43:56 - INFO - 轮次 89/100, 训练损失: 0.5789, 训练准确率: 0.6743, 类别0/1: 0.5203/0.8146, 训练F1: 0.6621, 训练精确率: 0.6832, 训练召回率: 0.6697, 训练特异性: 0.5203, 训练MCC: 0.3510, 训练归一化MCC: 0.6755, 验证损失: 0.6487, 验证准确率: 0.5942, 类别0/1: 0.5070/0.7597, 验证F1: 0.6018, 验证精确率: 0.6759, 验证召回率: 0.5959, 验证特异性: 0.5070, 验证MCC: 0.2587, 验证归一化MCC: 0.6293, 学习率: 0.000001
# 2025-03-10 06:43:56 - INFO - 本轮用时: 8.32 秒
# 2025-03-10 06:43:56 - INFO - ——————————————————————————————
# 2025-03-10 06:44:05 - INFO - 轮次 90/100, 训练损失: 0.5999, 训练准确率: 0.6708, 类别0/1: 0.5145/0.8202, 训练F1: 0.6615, 训练精确率: 0.6844, 训练召回率: 0.6697, 训练特异性: 0.5145, 训练MCC: 0.3521, 训练归一化MCC: 0.6761, 验证损失: 0.6593, 验证准确率: 0.5808, 类别0/1: 0.4789/0.7727, 验证F1: 0.5864, 验证精确率: 0.6724, 验证召回率: 0.5822, 验证特异性: 0.4789, 验证MCC: 0.2463, 验证归一化MCC: 0.6231, 学习率: 0.000001
# 2025-03-10 06:44:05 - INFO - 本轮用时: 8.64 秒
# 2025-03-10 06:44:05 - INFO - ——————————————————————————————
# 2025-03-10 06:44:13 - INFO - 轮次 91/100, 训练损失: 0.6232, 训练准确率: 0.6359, 类别0/1: 0.4961/0.7844, 训练F1: 0.6279, 训练精确率: 0.6540, 训练召回率: 0.6349, 训练特异性: 0.4961, 训练MCC: 0.2918, 训练归一化MCC: 0.6459, 验证损失: 0.6679, 验证准确率: 0.5725, 类别0/1: 0.4542/0.7857, 验证F1: 0.5730, 验证精确率: 0.6705, 验证召回率: 0.5708, 验证特异性: 0.4542, 验证MCC: 0.2373, 验证归一化MCC: 0.6187, 学习率: 0.000001
# 2025-03-10 06:44:13 - INFO - 本轮用时: 8.59 秒
# 2025-03-10 06:44:13 - INFO - ——————————————————————————————
# 2025-03-10 06:44:22 - INFO - 轮次 92/100, 训练损失: 0.5966, 训练准确率: 0.6630, 类别0/1: 0.5261/0.7870, 训练F1: 0.6554, 训练精确率: 0.6679, 训练召回率: 0.6617, 训练特异性: 0.5261, 训练MCC: 0.3253, 训练归一化MCC: 0.6627, 验证损失: 0.6561, 验证准确率: 0.5899, 类别0/1: 0.4859/0.7792, 验证F1: 0.5934, 验证精确率: 0.6788, 验证召回率: 0.5890, 验证特异性: 0.4859, 验证MCC: 0.2592, 验证归一化MCC: 0.6296, 学习率: 0.000001
# 2025-03-10 06:44:22 - INFO - 本轮用时: 8.41 秒
# 2025-03-10 06:44:22 - INFO - ——————————————————————————————
# 2025-03-10 06:44:30 - INFO - 轮次 93/100, 训练损失: 0.6007, 训练准确率: 0.6546, 类别0/1: 0.5068/0.8062, 训练F1: 0.6472, 训练精确率: 0.6721, 训练召回率: 0.6549, 训练特异性: 0.5068, 训练MCC: 0.3277, 训练归一化MCC: 0.6638, 验证损失: 0.6500, 验证准确率: 0.5950, 类别0/1: 0.5000/0.7727, 验证F1: 0.6011, 验证精确率: 0.6805, 验证召回率: 0.5959, 验证特异性: 0.5000, 验证MCC: 0.2654, 验证归一化MCC: 0.6327, 学习率: 0.000001
# 2025-03-10 06:44:30 - INFO - 本轮用时: 8.44 秒
# 2025-03-10 06:44:30 - INFO - ——————————————————————————————
# 2025-03-10 06:44:38 - INFO - 轮次 94/100, 训练损失: 0.6067, 训练准确率: 0.6518, 类别0/1: 0.5017/0.7998, 训练F1: 0.6424, 训练精确率: 0.6655, 训练召回率: 0.6503, 训练特异性: 0.5017, 训练MCC: 0.3157, 训练归一化MCC: 0.6579, 验证损失: 0.6450, 验证准确率: 0.5919, 类别0/1: 0.5070/0.7532, 验证F1: 0.5997, 验证精确率: 0.6723, 验证召回率: 0.5936, 验证特异性: 0.5070, 验证MCC: 0.2522, 验证归一化MCC: 0.6261, 学习率: 0.000001
# 2025-03-10 06:44:38 - INFO - 本轮用时: 8.04 秒
# 2025-03-10 06:44:38 - INFO - ——————————————————————————————
# 2025-03-10 06:44:47 - INFO - 轮次 95/100, 训练损失: 0.5946, 训练准确率: 0.6601, 类别0/1: 0.5023/0.8165, 训练F1: 0.6519, 训练精确率: 0.6768, 训练召回率: 0.6606, 训练特异性: 0.5023, 训练MCC: 0.3361, 训练归一化MCC: 0.6681, 验证损失: 0.6587, 验证准确率: 0.5780, 类别0/1: 0.4718/0.7727, 验证F1: 0.5814, 验证精确率: 0.6697, 验证召回率: 0.5776, 验证特异性: 0.4718, 验证MCC: 0.2399, 验证归一化MCC: 0.6199, 学习率: 0.000001
# 2025-03-10 06:44:47 - INFO - 本轮用时: 8.41 秒
# 2025-03-10 06:44:47 - INFO - ——————————————————————————————
# 2025-03-10 06:44:54 - INFO - 轮次 96/100, 训练损失: 0.5869, 训练准确率: 0.6714, 类别0/1: 0.5358/0.8062, 训练F1: 0.6642, 训练精确率: 0.6845, 训练召回率: 0.6703, 训练特异性: 0.5358, 训练MCC: 0.3550, 训练归一化MCC: 0.6775, 验证损失: 0.6573, 验证准确率: 0.5851, 类别0/1: 0.4859/0.7662, 验证F1: 0.5892, 验证精确率: 0.6714, 验证召回率: 0.5845, 验证特异性: 0.4859, 验证MCC: 0.2460, 验证归一化MCC: 0.6230, 学习率: 0.000001
# 2025-03-10 06:44:54 - INFO - 本轮用时: 7.60 秒
# 2025-03-10 06:44:54 - INFO - ——————————————————————————————
# 2025-03-10 06:45:02 - INFO - 轮次 97/100, 训练损失: 0.6154, 训练准确率: 0.6490, 类别0/1: 0.4938/0.8097, 训练F1: 0.6405, 训练精确率: 0.6690, 训练召回率: 0.6492, 训练特异性: 0.4938, 训练MCC: 0.3194, 训练归一化MCC: 0.6597, 验证损失: 0.6458, 验证准确率: 0.5968, 类别0/1: 0.5106/0.7597, 验证F1: 0.6042, 验证精确率: 0.6773, 验证召回率: 0.5982, 验证特异性: 0.5106, 验证MCC: 0.2619, 验证归一化MCC: 0.6309, 学习率: 0.000001
# 2025-03-10 06:45:02 - INFO - 本轮用时: 8.07 秒
# 2025-03-10 06:45:02 - INFO - ——————————————————————————————
# 2025-03-10 06:45:11 - INFO - 轮次 98/100, 训练损失: 0.5970, 训练准确率: 0.6575, 类别0/1: 0.4984/0.8230, 训练F1: 0.6459, 训练精确率: 0.6807, 训练召回率: 0.6543, 训练特异性: 0.4984, 训练MCC: 0.3380, 训练归一化MCC: 0.6690, 验证损失: 0.6524, 验证准确率: 0.5891, 类别0/1: 0.4965/0.7597, 验证F1: 0.5945, 验证精确率: 0.6718, 验证召回率: 0.5890, 验证特异性: 0.4965, 验证MCC: 0.2491, 验证归一化MCC: 0.6245, 学习率: 0.000001
# 2025-03-10 06:45:11 - INFO - 本轮用时: 8.39 秒
# 2025-03-10 06:45:11 - INFO - ——————————————————————————————
# 2025-03-10 06:45:19 - INFO - 轮次 99/100, 训练损失: 0.6119, 训练准确率: 0.6498, 类别0/1: 0.5107/0.7917, 训练F1: 0.6424, 训练精确率: 0.6644, 训练召回率: 0.6492, 训练特异性: 0.5107, 训练MCC: 0.3146, 训练归一化MCC: 0.6573, 验证损失: 0.6475, 验证准确率: 0.5950, 类别0/1: 0.5070/0.7597, 验证F1: 0.6018, 验证精确率: 0.6759, 验证召回率: 0.5959, 验证特异性: 0.5070, 验证MCC: 0.2587, 验证归一化MCC: 0.6293, 学习率: 0.000001
# 2025-03-10 06:45:19 - INFO - 本轮用时: 8.14 秒
# 2025-03-10 06:45:19 - INFO - ——————————————————————————————
# 2025-03-10 06:45:27 - INFO - 轮次 100/100, 训练损失: 0.5972, 训练准确率: 0.6689, 类别0/1: 0.5176/0.8184, 训练F1: 0.6593, 训练精确率: 0.6848, 训练召回率: 0.6669, 训练特异性: 0.5176, 训练MCC: 0.3520, 训练归一化MCC: 0.6760, 验证损失: 0.6419, 验证准确率: 0.6003, 类别0/1: 0.5176/0.7532, 验证F1: 0.6069, 验证精确率: 0.6764, 验证召回率: 0.6005, 验证特异性: 0.5176, 验证MCC: 0.2618, 验证归一化MCC: 0.6309, 学习率: 0.000001
# 2025-03-10 06:45:27 - INFO - 本轮用时: 8.29 秒
# 2025-03-10 06:45:27 - INFO - ——————————————————————————————
# 2025-03-10 06:45:27 - INFO - 最终训练类别准确率 - 类别0: 0.5176, 类别1: 0.8184
# 2025-03-10 06:45:27 - INFO - 最终验证类别准确率 - 类别0: 0.5176, 类别1: 0.7532
# 2025-03-10 06:45:27 - INFO - 最终F1分数 - 训练: 0.6593, 验证: 0.6069
# 2025-03-10 06:45:27 - INFO - 最终精确率 - 训练: 0.6848, 验证: 0.6764
# 2025-03-10 06:45:27 - INFO - 最终召回率 - 训练: 0.6669, 验证: 0.6005
# 2025-03-10 06:45:27 - INFO - 最终特异性 - 训练: 0.5176, 验证: 0.5176
# 2025-03-10 06:45:27 - INFO - 最终MCC - 训练: 0.3520, 验证: 0.2618
# 2025-03-10 06:45:27 - INFO - 最终归一化MCC - 训练: 0.6760, 验证: 0.6309
# 2025-03-10 06:45:27 - INFO - 已保存模型权重到: C:\Users\USTC\Desktop\地磁论文（5级以上）\对比模型结果\RNN模型结果\RNNModel_30天_fold_5.pth
# 2025-03-10 06:45:27 - INFO - 已保存训练日志到: C:\Users\USTC\Desktop\地磁论文（5级以上）\对比模型结果\RNN模型结果\RNNModel_30天_fold_5_epoch_logs.txt
# 2025-03-10 06:45:27 - INFO - 已保存训练集预测概率到: C:\Users\USTC\Desktop\地磁论文（5级以上）\对比模型结果\RNN模型结果\RNNModel_30天_fold_5_train_probs.npy
# 2025-03-10 06:45:27 - INFO - 已保存训练集标签到: C:\Users\USTC\Desktop\地磁论文（5级以上）\对比模型结果\RNN模型结果\RNNModel_30天_fold_5_train_labels.npy
# 2025-03-10 06:45:27 - INFO - 已保存测试集预测概率到: C:\Users\USTC\Desktop\地磁论文（5级以上）\对比模型结果\RNN模型结果\RNNModel_30天_fold_5_test_probs.npy
# 2025-03-10 06:45:27 - INFO - 已保存测试集标签到: C:\Users\USTC\Desktop\地磁论文（5级以上）\对比模型结果\RNN模型结果\RNNModel_30天_fold_5_test_labels.npy
# 2025-03-10 06:45:27 - INFO - 类别准确率: 类别0: 1.1338, 类别1: 0.7532
# 2025-03-10 06:45:27 - INFO - F1分数: 训练: 0.6593, 验证: 0.6069
# 2025-03-10 06:45:27 - INFO - 精确率: 训练: 0.6848, 验证: 0.6764
# 2025-03-10 06:45:27 - INFO - 召回率: 训练: 0.6669, 验证: 0.6005
# 2025-03-10 06:45:27 - INFO - 特异性: 训练: 0.5176, 验证: 0.5176
# 2025-03-10 06:45:27 - INFO - MCC: 训练: 0.3520, 验证: 0.2618
# 2025-03-10 06:45:27 - INFO - 归一化MCC: 训练: 0.6760, 验证: 0.6309
# 2025-03-10 06:45:27 - INFO - 第 5 折训练完成
# 2025-03-10 06:45:27 - INFO - 第 5 折训练结束
# 2025-03-10 06:45:27 - INFO -
# 训练总结:
# 2025-03-10 06:45:27 - INFO - - 总训练时间: 1小时 26分钟 23秒
# 2025-03-10 06:45:27 - INFO - - 平均训练准确率: 0.7410 ± 0.0658
# 2025-03-10 06:45:27 - INFO - - 平均验证准确率: 0.6841 ± 0.0829
# 2025-03-10 06:45:27 - INFO - - 平均训练精确率: 0.7510
# 2025-03-10 06:45:27 - INFO - - 平均验证精确率: 0.7481
# 2025-03-10 06:45:27 - INFO - - 平均训练召回率: 0.7413
# 2025-03-10 06:45:27 - INFO - - 平均验证召回率: 0.6837
# 2025-03-10 06:45:27 - INFO - - 平均训练特异性: 0.6471
# 2025-03-10 06:45:27 - INFO - - 平均验证特异性: 0.6100
# 2025-03-10 06:45:27 - INFO - - 平均训练MCC: 0.4921
# 2025-03-10 06:45:27 - INFO - - 平均验证MCC: 0.4158
# 2025-03-10 06:45:27 - INFO - - 平均训练归一化MCC: 0.7461
# 2025-03-10 06:45:27 - INFO - - 平均验证归一化MCC: 0.7079
# 2025-03-10 06:45:27 - INFO - - 类别0平均准确率: 1.0978
# 2025-03-10 06:45:27 - INFO - - 类别1平均准确率: 0.8195
# 2025-03-10 06:45:27 - INFO - - 平均验证损失: 0.5852 ± 0.0671
# 2025-03-10 06:45:27 - INFO - 开始进行模型集成 - RNNModel_30天
# C:\Users\USTC\AppData\Local\Temp\ipykernel_43608\4214241656.py:356: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(model_path)
# 2025-03-10 06:45:27 - INFO - 第 1 折模型评估指标:
# 2025-03-10 06:45:27 - INFO -   F1分数: 0.7928
# 2025-03-10 06:45:27 - INFO -   精确率: 0.8203
# 2025-03-10 06:45:27 - INFO -   召回率: 0.7882
# 2025-03-10 06:45:27 - INFO -   特异性: 0.7439
# 2025-03-10 06:45:27 - INFO -   MCC: 0.5870
# 2025-03-10 06:45:27 - INFO -   归一化MCC: 0.7935
# 2025-03-10 06:45:27 - INFO - 已加载第 1 折模型
# C:\Users\USTC\AppData\Local\Temp\ipykernel_43608\4214241656.py:356: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(model_path)
# 2025-03-10 06:45:27 - INFO - 第 2 折模型评估指标:
# 2025-03-10 06:45:27 - INFO -   F1分数: 0.7672
# 2025-03-10 06:45:27 - INFO -   精确率: 0.7845
# 2025-03-10 06:45:27 - INFO -   召回率: 0.7626
# 2025-03-10 06:45:27 - INFO -   特异性: 0.7465
# 2025-03-10 06:45:27 - INFO -   MCC: 0.5178
# 2025-03-10 06:45:27 - INFO -   归一化MCC: 0.7589
# 2025-03-10 06:45:27 - INFO - 已加载第 2 折模型
# C:\Users\USTC\AppData\Local\Temp\ipykernel_43608\4214241656.py:356: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(model_path)
# 2025-03-10 06:45:27 - INFO - 第 3 折模型评估指标:
# 2025-03-10 06:45:27 - INFO -   F1分数: 0.6939
# 2025-03-10 06:45:27 - INFO -   精确率: 0.7453
# 2025-03-10 06:45:27 - INFO -   召回率: 0.6872
# 2025-03-10 06:45:27 - INFO -   特异性: 0.6197
# 2025-03-10 06:45:27 - INFO -   MCC: 0.4128
# 2025-03-10 06:45:27 - INFO -   归一化MCC: 0.7064
# 2025-03-10 06:45:27 - INFO - 已加载第 3 折模型
# C:\Users\USTC\AppData\Local\Temp\ipykernel_43608\4214241656.py:356: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(model_path)
# 2025-03-10 06:45:27 - INFO - 第 4 折模型评估指标:
# 2025-03-10 06:45:27 - INFO -   F1分数: 0.5755
# 2025-03-10 06:45:28 - INFO -   精确率: 0.7139
# 2025-03-10 06:45:28 - INFO -   召回率: 0.5799
# 2025-03-10 06:45:28 - INFO -   特异性: 0.4225
# 2025-03-10 06:45:28 - INFO -   MCC: 0.2997
# 2025-03-10 06:45:28 - INFO -   归一化MCC: 0.6498
# 2025-03-10 06:45:28 - INFO - 已加载第 4 折模型
# C:\Users\USTC\AppData\Local\Temp\ipykernel_43608\4214241656.py:356: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(model_path)
# 2025-03-10 06:45:28 - INFO - 第 5 折模型评估指标:
# 2025-03-10 06:45:28 - INFO -   F1分数: 0.6069
# 2025-03-10 06:45:28 - INFO -   精确率: 0.6764
# 2025-03-10 06:45:28 - INFO -   召回率: 0.6005
# 2025-03-10 06:45:28 - INFO -   特异性: 0.5176
# 2025-03-10 06:45:28 - INFO -   MCC: 0.2618
# 2025-03-10 06:45:28 - INFO -   归一化MCC: 0.6309
# 2025-03-10 06:45:28 - INFO - 已加载第 5 折模型
# 2025-03-10 06:45:28 - INFO - 基于F1分数的模型权重: [0.230727   0.22326604 0.20192468 0.16747361 0.17660867]
# 2025-03-10 06:45:28 - INFO - 集成模型权重: [0.23072699708006206, 0.22326604177047887, 0.20192467885117882, 0.16747360835878908, 0.17660867393949112]
# 2025-03-10 06:45:28 - INFO - F1加权集成模型已保存: C:\Users\USTC\Desktop\地磁论文（5级以上）\对比模型结果\RNN模型结果\RNNModel_30天.pth
# 2025-03-10 06:45:28 - INFO - 集成模型平均评估指标:
# 2025-03-10 06:45:28 - INFO -   平均f1 scores: 0.6873
# 2025-03-10 06:45:28 - INFO -   平均precisions: 0.7481
# 2025-03-10 06:45:28 - INFO -   平均recalls: 0.6837
# 2025-03-10 06:45:28 - INFO -   平均specificities: 0.6100
# 2025-03-10 06:45:28 - INFO -   平均mccs: 0.4158
# 2025-03-10 06:45:28 - INFO -   平均norm mccs: 0.7079
# 2025-03-10 06:45:28 - INFO - 集成配置已保存: C:\Users\USTC\Desktop\地磁论文（5级以上）\对比模型结果\RNN模型结果\RNNModel_30天_ensemble_config.json
# 2025-03-10 06:45:28 - INFO -
# === 所有处理完成！===
